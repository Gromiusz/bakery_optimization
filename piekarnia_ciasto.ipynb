# %%
# !pip install pulp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pulp
#   Downloading PuLP-2.9.0-py3-none-any.whl (17.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 24.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pulp
# Successfully installed pulp-2.9.0

# %%
import pulp as pl
import numpy as np
# from scipy.stats import multivariate_t

print("==============================================================================")

# Define the problem
model = pl.LpProblem("Maximize_Profit", pl.LpMaximize)

# Products, machines and days
subproducts = ['Ciasto_na_chleb_domowy_0_5kg', 'Ciasto_na_chleb_domowy_0_9kg', 'Ciasto_na_chleb_na_zakwasie', 'Ciasto_na_bulki', 'Ciasto_na_bagietki', 'Ciasto_na_rogaliki_z_czekolada']
products = ['Chleb_domowy_0_5kg', 'Chleb_domowy_0_9kg', 'Chleb_na_zakwasie', 'Bulki', 'Bagietki', 'Rogaliki_z_czekolada']
days = ['Pon', 'Wt', 'Sr', 'Czw', 'Pt', 'Sob']
machines = {'Dzieza', 'Wazenie', 'Dzielarka', 'Tabula', 'Rogalikarka', 'Nadziewarka', 'Garownia', 'Piec', 'Studzenie', 'Pakowanie'}

# Income from product sales and production cost in PLN/piece
product_income = {'Chleb_domowy_0_5kg': 5.2, 'Chleb_domowy_0_9kg': 7.9, 'Chleb_na_zakwasie': 6.2, 'Bulki': 1.4, 'Bagietki': 1.55, 'Rogaliki_z_czekolada': 2.1}
sub_product_cost = {'Ciasto_na_chleb_domowy_0_5kg': 1.6, 'Ciasto_na_chleb_domowy_0_9kg': 2.0, 'Ciasto_na_chleb_na_zakwasie': 2.0, 'Ciasto_na_bulki': 0.5, 'Ciasto_na_bagietki': 0.6, 'Ciasto_na_rogaliki_z_czekolada': 1.0}
product_cost = {'Chleb_domowy_0_5kg': 0.8, 'Chleb_domowy_0_9kg': 0.9, 'Chleb_na_zakwasie': 0.8, 'Bulki': 0.2, 'Bagietki': 0.2, 'Rogaliki_z_czekolada': 0.2}

# Time available
shifts_per_day = 2
hours_per_shift = 8
hours_per_day = shifts_per_day * hours_per_shift

# Initial stock and storage cost
initial_stock = 0
fridge_count = 5
fridge_capacity = 160
end_stock = 0
storage_capacity = fridge_count * fridge_capacity

fridge_cost_per_day = 0.281 * 24 * 1.4 * 0.2 # kW * 24h * price per hour * factor

furnace_cost_per_hour = 82.4 # https://giko.pl/kalkulator-zuzycia-energii-dla-piecow-piekarniczych/

# Production times required per product in hours
production_times = {
    'Ciasto_na_chleb_domowy_0_5kg': {'Dzieza': 4.7, 'Wazenie': 0.29, 'Dzielarka': 0.0, 'Tabula': 0.7, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0, 'Garownia': 0.0, 'Piec': 0.0, 'Studzenie': 0.0, 'Pakowanie': 0.0},
    'Ciasto_na_chleb_domowy_0_9kg': {'Dzieza': 5, 'Wazenie': 0.2, 'Dzielarka': 0.0, 'Tabula': 0.55, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0, 'Garownia': 0.0, 'Piec': 0.0, 'Studzenie': 0.0, 'Pakowanie': 0.0},
    'Ciasto_na_chleb_na_zakwasie': {'Dzieza': 8.6, 'Wazenie': 0.22, 'Dzielarka': 0.0, 'Tabula': 0.6, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0, 'Garownia': 0.0, 'Piec': 0.0, 'Studzenie': 0.0, 'Pakowanie': 0.0},
    'Ciasto_na_bulki': {'Dzieza': 1, 'Wazenie': 0.0, 'Dzielarka': 0.23, 'Tabula': 0.34, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0, 'Garownia': 0.0, 'Piec': 0.0, 'Studzenie': 0.0, 'Pakowanie': 0.0},
    'Ciasto_na_bagietki': {'Dzieza': 0.95, 'Wazenie': 0.0, 'Dzielarka': 0.24, 'Tabula': 0.0, 'Rogalikarka': 0.28, 'Nadziewarka': 0.0, 'Garownia': 0.0, 'Piec': 0.0, 'Studzenie': 0.0, 'Pakowanie': 0.0},
    'Ciasto_na_rogaliki_z_czekolada': {'Dzieza': 0.55, 'Wazenie': 0.0, 'Dzielarka': 0.28, 'Tabula': 0.0, 'Rogalikarka': 0.31, 'Nadziewarka': 0.4, 'Garownia': 0.0, 'Piec': 0.18, 'Studzenie': 0.0, 'Pakowanie': 0.0},
    'Chleb_domowy_0_5kg': {'Dzieza': 0.0, 'Wazenie': 0.0, 'Dzielarka': 0.0, 'Tabula': 0.0, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0, 'Garownia': 1.0, 'Piec': 0.68, 'Studzenie': 1.8, 'Pakowanie': 0.56},
    'Chleb_domowy_0_9kg': {'Dzieza': 0.0, 'Wazenie': 0.0, 'Dzielarka': 0.0, 'Tabula': 0.0, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0, 'Garownia': 1.5, 'Piec': 1.2, 'Studzenie': 2.5, 'Pakowanie': 0.57},
    'Chleb_na_zakwasie': {'Dzieza': 0.0, 'Wazenie': 0.0, 'Dzielarka': 0.0, 'Tabula': 0.0, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0, 'Garownia': 1.4, 'Piec': 1.0, 'Studzenie': 2.3, 'Pakowanie': 0.6},
    'Bulki': {'Dzieza': 0.0, 'Wazenie': 0.0, 'Dzielarka': 0.0, 'Tabula': 0.0, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0, 'Garownia': 0.38, 'Piec': 0.25, 'Studzenie': 0.48, 'Pakowanie': 0.0},
    'Bagietki': {'Dzieza': 0.0, 'Wazenie': 0.0, 'Dzielarka': 0.0, 'Tabula': 0.0, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0, 'Garownia': 0.33, 'Piec': 0.23, 'Studzenie': 0.42, 'Pakowanie': 0.0},
    'Rogaliki_z_czekolada': {'Dzieza': 0.0, 'Wazenie': 0.0, 'Dzielarka': 0.0, 'Tabula': 0.0, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0, 'Garownia': 0.25, 'Piec': 0.18, 'Studzenie': 0.82, 'Pakowanie': 0.42}
}

# Market limits for sales of Products
# market_limits = {
#     "Chleb_domowy_0_5kg": {"Pon": 200, "Wt": 30, "Sr": 0, "Czw": 20, "Pt": 30, "Sob": 18},
#     "Chleb_domowy_0_9kg": {"Pon": 150, "Wt": 25, "Sr": 80, "Czw": 150, "Pt": 250, "Sob": 180},
#     "Chleb_na_zakwasie": {"Pon": 180, "Wt": 280, "Sr": 0, "Czw": 180, "Pt": 280, "Sob": 18},
#     "Bulki": {"Pon": 400, "Wt": 500, "Sr": 0, "Czw": 40, "Pt": 50, "Sob": 180},
#     "Bagietki": {"Pon": 350, "Wt": 450, "Sr": 0, "Czw": 350, "Pt": 45, "Sob": 180},
#     "Rogaliki_z_czekolada": {"Pon": 300, "Wt": 400, "Sr": 0, "Czw": 300, "Pt": 400, "Sob": 180},
# }
market_limits = {
    "Chleb_domowy_0_5kg": {"Pon": 290, "Wt": 530, "Sr": 240, "Czw": 420, "Pt": 530, "Sob": 680},
    "Chleb_domowy_0_9kg": {"Pon": 350, "Wt": 525, "Sr": 380, "Czw": 150, "Pt": 250, "Sob": 580},
    "Chleb_na_zakwasie": {"Pon": 480, "Wt": 280, "Sr": 320, "Czw": 180, "Pt": 280, "Sob": 418},
    "Bulki": {"Pon": 620, "Wt": 670, "Sr": 840, "Czw": 530, "Pt": 650, "Sob": 580},
    "Bagietki": {"Pon": 350, "Wt": 750, "Sr": 430, "Czw": 350, "Pt": 650, "Sob": 680},
    "Rogaliki_z_czekolada": {"Pon": 300, "Wt": 400, "Sr": 240, "Czw": 310, "Pt": 400, "Sob": 280},
}

# Maximum batch size
batch_size = {
    "Ciasto_na_chleb_domowy_0_5kg": 240,
    "Ciasto_na_chleb_domowy_0_9kg": 130,
    "Ciasto_na_chleb_na_zakwasie": 200,
    "Ciasto_na_bulki": 200,
    "Ciasto_na_bagietki": 200,
    "Ciasto_na_rogaliki_z_czekolada": 200,
    "Chleb_domowy_0_5kg": 240,
    "Chleb_domowy_0_9kg": 130,
    "Chleb_na_zakwasie": 200,
    "Bulki": 200,
    "Bagietki": 200,
    "Rogaliki_z_czekolada": 200,
}


# Machines available
machines_available = {"Dzieza": 6, "Wazenie": 2, "Dzielarka": 2, "Tabula": 3, "Rogalikarka": 1, "Nadziewarka": 1, "Garownia": 2, "Piec": 6, "Studzenie": 4, "Pakowanie": 2}

# Variables for production, sales, and storage of products each day
sub_production_vars = pl.LpVariable.dicts("Subproduct production", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
production_vars = pl.LpVariable.dicts("Production", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
sub_batch_vars = pl.LpVariable.dicts("SubBatches", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
batch_vars = pl.LpVariable.dicts("Batches", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
sales_vars = pl.LpVariable.dicts("Sales", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
storage_vars = pl.LpVariable.dicts("Storage", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, upBound=storage_capacity, cat='Integer')
fridge_count_usage_vars = pl.LpVariable.dicts("FridgeCount", ((day) for day in days), lowBound=0, upBound=fridge_count, cat='Integer')

# Inventory and sales constraints
for subproduct, product in zip(subproducts, products):
    model += storage_vars[subproduct, 'Pon'] == initial_stock + sub_production_vars[subproduct, 'Pon'] - production_vars[product, 'Pon']
    for i in range(1, len(days)):
        day = days[i]
        prev_day = days[i-1]
        model += storage_vars[subproduct, day] == storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day]
    # model += storage_vars[product, 'Sob'] == end_stock  # Ending stock

# Machine time constraints for each product and day
for day in days:
    total_production_time = sum((production_vars[product, day] * production_times[product][machine]) / (machines_available[machine] * batch_size[product])
                                for product in products
                                for machine in machines) \
                            + sum((sub_production_vars[subproduct, day] * production_times[subproduct][machine]) / (machines_available[machine] * batch_size[subproduct])
                                for subproduct in subproducts
                                for machine in machines)
    model += total_production_time <= hours_per_day, f"Global_production_time_{day}"
    # total_production_time = sum(batch_vars[product, day] * production_times[product][machine] /machines_available[machine]
    #                             for product in products
    #                             for machine in machines)
    # total_subproduction_time = sum((sub_batch_vars[subproduct, day] * production_times[subproduct][machine]) / machines_available[machine]
    #                             for subproduct in subproducts
    #                             for machine in machines)
    # model += total_subproduction_time <= hours_per_day, f"Global_subproduction_time_{day}"
    # model += total_production_time <= hours_per_day, f"Global_production_time_{day}"
    model += storage_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts for day in days)
    model += fridge_count_usage_vars[day] * fridge_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)
    # model += sales_vars['Bagietki',day] + sales_vars['Bulki',day] <= 8 * sales_vars['Rogaliki_z_czekolada', day]
    # model += sales_vars['Bagietki',day] >= 0.2 * (sales_vars['Chleb_domowy_0_5kg', day] + sales_vars['Chleb_na_zakwasie', day])
    # model += sales_vars['Bulki',day] >= 0.05 * (sales_vars['Chleb_domowy_0_9kg', day])

# Market sales constraints
for product, subproduct in zip(products, subproducts):
    # model += sales_vars[product, 'Pon'] + sales_vars[product, 'Wt'] >= 0.5 * (market_limits[product]['Pon'] + market_limits[product]['Wt'])
    # model += sales_vars[product, 'Sr'] + sales_vars[product, 'Czw'] >= 0.5 * (market_limits[product]['Sr'] + market_limits[product]['Czw'])
    # model += sales_vars[product, 'Pt'] + sales_vars[product, 'Sob'] >= 0.5 * (market_limits[product]['Pt'] + market_limits[product]['Sob'])
    for day in days:
        model += sales_vars[product, day] == production_vars[product, day]
        model += sales_vars[product, day] <= 3* market_limits[product][day], f"Max_sales_{product}_{day}"
        # model += sales_vars[product, day] <= production_vars[product, day] + (storage_vars[product, days[days.index(day) - 1]] if day != 'Pon' else initial_stock)
        model += batch_vars[product, day] * batch_size[product] >= production_vars[product, day]
        model += sub_batch_vars[subproduct, day] * batch_size[subproduct] >= sub_production_vars[subproduct, day]
        model += sales_vars[product, day] >= 0.5 * market_limits[product][day]
    # model += sales_vars[product, 'Sr'] >= 0.8 * market_limits[product]['Sr']
    # model += sales_vars[product, 'Pt'] >= 0.9 * market_limits[product]['Pt']



# Objective function: Maximize profit from sales minus costs
model += pl.lpSum([sales_vars[product, day] * product_income[product] for product in products for day in days]) \
                    - pl.lpSum([production_vars[product, day] * product_cost[product] for product in products for day in days]) \
                    - pl.lpSum([sub_production_vars[subproduct, day] * sub_product_cost[subproduct] for subproduct in subproducts for day in days]) \
                    - pl.lpSum([fridge_count_usage_vars[day] * fridge_cost_per_day for day in days]) \
                    - pl.lpSum([batch_vars[product, day] * production_times[product]['Piec'] * furnace_cost_per_hour for product in products for day in days]), "Total_Profit"

solver = pl.PULP_CBC_CMD(timeLimit=20)

model.solve(solver)

# model.solve()

# Results
print("Status:", pl.LpStatus[model.status])
if pl.LpStatus[model.status] == 'Optimal':
    print("Total Profit:", pl.value(model.objective))

    print(f"{'day':<10} {'Product':<10} {'SubProduction':<12} {'Production':<12} {'Sales':<10} {'Storage':<10}")

    
    for day in days:
        for product, subproduct in zip(products, subproducts):
            subproduction = sub_production_vars[subproduct, day].varValue
            production = production_vars[product, day].varValue
            sales = sales_vars[product, day].varValue
            storage = storage_vars[subproduct, day].varValue
            print(f"{day:<10} {product:<10} {subproduction:<12} {production:<12} {sales:<10} {storage:<10}")

    # print("\nProduction Time Usage per Product and Day:")
    # for day in days:
    #     print(f"\Day: {day}")
    #     for product in products:
    #         total_production_time = sum(
    #             batch_vars[product, day].varValue * production_times[product]s.get(machine, 0) 
    #             for machine in machines #.keys()
    #         )
    #         print(f"  Product: {product}, Total Production Time: {total_production_time:.2f} hours")

else:
    print("No optimal solution was found.")
    # Analiza ograniczeń
    for name, constraint in model.constraints.items():
        if constraint.pi < 0:
            print(f"Ograniczenie {name}: {constraint}")
# Out:
# ==============================================================================
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gromiusz/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ff54b468dac54c96a49e3efebcf13afe-pulp.mps -max -sec 20 -timeMode elapsed -branch -printingOptions all -solution /tmp/ff54b468dac54c96a49e3efebcf13afe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 239 COLUMNS
# At line 1590 RHS
# At line 1825 BOUNDS
# At line 2048 ENDATA
# Problem MODEL has 234 rows, 222 columns and 756 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 20
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 18465 - 0.00 seconds
# Cgl0003I 0 fixed, 36 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 79 rows, 144 columns (144 integer (0 of which binary)) and 342 elements
# Cbc0012I Integer solution of -17596.18 found by DiveCoefficient after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 79 rows 144 columns, reduced to 6 rows 9 columns
# Cbc0012I Integer solution of -17708.244 found by DiveCoefficient after 828 iterations and 0 nodes (0.48 seconds)
# Cbc0031I 9 added rows had average density of 105.44444
# Cbc0013I At root node, 9 cuts changed objective from -17743.441 to -17719.574 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 11 column cuts (11 active)  in 0.060 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 636 row cuts average 105.1 elements, 0 column cuts (0 active)  in 0.086 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.019 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.053 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 85 row cuts average 69.7 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -17708.244 best solution, best possible -17719.574 (0.49 seconds)
# Cbc0012I Integer solution of -17711.044 found by DiveCoefficient after 843 iterations and 3 nodes (0.52 seconds)
# Cbc0012I Integer solution of -17712.444 found by DiveCoefficient after 886 iterations and 4 nodes (0.54 seconds)
# Cbc0038I Full problem 79 rows 144 columns, reduced to 13 rows 19 columns
# Cbc0038I Full problem 88 rows 144 columns, reduced to 48 rows 113 columns
# Cbc0044I Reduced cost fixing - 48 rows, 113 columns - restarting search
# Cbc0012I Integer solution of -17712.444 found by Previous solution after 0 iterations and 0 nodes (0.69 seconds)
# Cbc0038I Full problem 48 rows 113 columns, reduced to 18 rows 24 columns
# Cbc0031I 11 added rows had average density of 87.363636
# Cbc0013I At root node, 11 cuts changed objective from -17743.441 to -17719.572 in 42 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 3 column cuts (3 active)  in 0.014 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 85 row cuts average 72.8 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 41 row cuts average 33.1 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (Stored from first) - 28 row cuts average 93.5 elements, 0 column cuts (0 active)
# Cbc0010I After 0 nodes, 1 on tree, -17712.444 best solution, best possible -17719.572 (0.82 seconds)
# Cbc0012I Integer solution of -17713.844 found by DiveCoefficient after 357 iterations and 4 nodes (0.83 seconds)
# Cbc0038I Full problem 48 rows 113 columns, reduced to 14 rows 23 columns
# Cbc0038I Full problem 48 rows 113 columns, reduced to 15 rows 25 columns
# Cbc0038I Full problem 48 rows 113 columns, reduced to 16 rows 26 columns
# Cbc0038I Full problem 48 rows 113 columns, reduced to 15 rows 22 columns
# Cbc0038I Full problem 48 rows 113 columns, reduced to 15 rows 24 columns
# Cbc0016I Integer solution of -17715.244 found by strong branching after 4249 iterations and 501 nodes (3.11 seconds)
# Cbc0016I Integer solution of -17716.644 found by strong branching after 4301 iterations and 502 nodes (3.52 seconds)
# Cbc0016I Integer solution of -17717.244 found by strong branching after 4629 iterations and 549 nodes (4.58 seconds)
# Cbc0038I Full problem 48 rows 113 columns, reduced to 16 rows 27 columns
# Cbc0016I Integer solution of -17717.394 found by strong branching after 5271 iterations and 652 nodes (5.07 seconds)
# Cbc0038I Full problem 48 rows 113 columns, reduced to 16 rows 20 columns
# Cbc0010I After 1000 nodes, 461 on tree, -17717.394 best solution, best possible -17719.572 (6.48 seconds)
# Cbc0016I Integer solution of -17718.044 found by strong branching after 7744 iterations and 1022 nodes (7.38 seconds)
# Cbc0038I Full problem 48 rows 113 columns, reduced to 15 rows 26 columns
# Cbc0016I Integer solution of -17718.094 found by strong branching after 9054 iterations and 1345 nodes (7.76 seconds)
# Cbc0038I Full problem 48 rows 113 columns, reduced to 15 rows 25 columns
# Cbc0010I After 2000 nodes, 913 on tree, -17718.094 best solution, best possible -17719.572 (8.47 seconds)
# Cbc0038I Full problem 48 rows 113 columns, reduced to 14 rows 22 columns
# Cbc0038I Full problem 48 rows 113 columns, reduced to 14 rows 26 columns
# Cbc0010I After 3000 nodes, 1334 on tree, -17718.094 best solution, best possible -17719.572 (9.48 seconds)
# Cbc0038I Full problem 48 rows 113 columns, reduced to 16 rows 31 columns
# Cbc0010I After 4000 nodes, 1850 on tree, -17718.094 best solution, best possible -17719.572 (10.00 seconds)
# Cbc0038I Full problem 48 rows 113 columns, reduced to 16 rows 26 columns
# Cbc0038I Full problem 48 rows 113 columns, reduced to 14 rows 28 columns
# Cbc0010I After 5000 nodes, 2218 on tree, -17718.094 best solution, best possible -17719.572 (10.37 seconds)
# Cbc0038I Full problem 48 rows 113 columns, reduced to 13 rows 26 columns
# Cbc0010I After 6000 nodes, 2234 on tree, -17718.094 best solution, best possible -17719.572 (12.29 seconds)
# Cbc0038I Full problem 48 rows 113 columns, reduced to 13 rows 21 columns
# Cbc0010I After 7000 nodes, 2227 on tree, -17718.094 best solution, best possible -17719.572 (16.24 seconds)
# Cbc0038I Full problem 48 rows 113 columns, reduced to 15 rows 27 columns
# Cbc0010I After 8000 nodes, 2229 on tree, -17718.094 best solution, best possible -17719.572 (17.12 seconds)
# Cbc0010I After 9000 nodes, 2231 on tree, -17718.094 best solution, best possible -17719.572 (17.77 seconds)
# Cbc0010I After 10000 nodes, 2240 on tree, -17718.094 best solution, best possible -17719.572 (18.22 seconds)
# Cbc0038I Full problem 48 rows 113 columns, reduced to 13 rows 23 columns
# Cbc0010I After 11000 nodes, 2241 on tree, -17718.094 best solution, best possible -17719.572 (18.90 seconds)
# Cbc0010I After 12000 nodes, 2691 on tree, -17718.094 best solution, best possible -17719.032 (19.37 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective -17718.094 (best possible -17719.032), took 1131535 iterations and 469824 nodes (20.11 seconds)
# Cbc0032I Strong branching done 52116 times (124422 iterations), fathomed 264 nodes and fixed 2748 variables
# Cbc0041I Maximum depth 71, 6461 variables fixed on reduced cost (complete fathoming 1366 times, 457418 nodes taking 1059866 iterations)
# Cbc0038I Probing was tried 11315 times and created 12769 cuts of which 0 were active after adding rounds of cuts (0.740 seconds)
# Cbc0038I Gomory was tried 11026 times and created 12817 cuts of which 0 were active after adding rounds of cuts (0.860 seconds)
# Cbc0038I Knapsack was tried 42 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Cbc0038I Clique was tried 42 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Cbc0038I MixedIntegerRounding2 was tried 42 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Cbc0038I FlowCover was tried 42 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# Cbc0038I TwoMirCuts was tried 1863 times and created 74 cuts of which 0 were active after adding rounds of cuts (0.053 seconds)
# Cbc0038I ZeroHalf was tried 42 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# Cbc0038I Stored from first was tried 11031 times and created 34 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Cbc0012I Integer solution of -17718.094 found by Reduced search after 1132614 iterations and 469874 nodes (20.12 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective -17718.094 (best possible -17719.574), took 1132614 iterations and 469874 nodes (20.12 seconds)
# Cbc0032I Strong branching done 948 times (1921 iterations), fathomed 0 nodes and fixed 19 variables
# Cbc0035I Maximum depth 16, 36 variables fixed on reduced cost
# Cuts at root node changed objective from -17743.4 to -17719.6
# Probing was tried 127 times and created 57 cuts of which 0 were active after adding rounds of cuts (0.064 seconds)
# Gomory was tried 127 times and created 664 cuts of which 0 were active after adding rounds of cuts (0.099 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.019 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.053 seconds)
# TwoMirCuts was tried 100 times and created 85 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                17718.09376000
# Upper bound:                    17719.574
# Gap:                            -0.00
# Enumerated nodes:               469874
# Total iterations:               1132614
# Time (CPU seconds):             21.71
# Time (Wallclock seconds):       20.12
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       21.71   (Wallclock seconds):       20.12
#
# Status: Optimal
# Total Profit: 17718.093760000043
# day        Product    SubProduction Production   Sales      Storage
# Pon        Chleb_domowy_0_5kg 242.0        237.0        237.0      5.0
# Pon        Chleb_domowy_0_9kg 305.0        175.0        175.0      130.0
# Pon        Chleb_na_zakwasie 369.0        240.0        240.0      129.0
# Pon        Bulki      310.0        310.0        310.0      0.0
# Pon        Bagietki   175.0        175.0        175.0      0.0
# Pon        Rogaliki_z_czekolada 150.0        150.0        150.0      0.0
# Wt         Chleb_domowy_0_5kg 464.0        469.0        469.0      0.0
# Wt         Chleb_domowy_0_9kg 133.0        263.0        263.0      0.0
# Wt         Chleb_na_zakwasie 67.0         140.0        140.0      56.0
# Wt         Bulki      335.0        335.0        335.0      0.0
# Wt         Bagietki   376.0        375.0        375.0      1.0
# Wt         Rogaliki_z_czekolada 200.0        200.0        200.0      0.0
# Sr         Chleb_domowy_0_5kg 476.0        474.0        474.0      2.0
# Sr         Chleb_domowy_0_9kg 297.0        190.0        190.0      107.0
# Sr         Chleb_na_zakwasie 104.0        160.0        160.0      0.0
# Sr         Bulki      420.0        420.0        420.0      0.0
# Sr         Bagietki   218.0        216.0        216.0      3.0
# Sr         Rogaliki_z_czekolada 128.0        120.0        120.0      8.0
# Czw        Chleb_domowy_0_5kg 968.0        960.0        960.0      10.0
# Czw        Chleb_domowy_0_9kg 2.0          75.0         75.0       34.0
# Czw        Chleb_na_zakwasie 133.0        90.0         90.0       43.0
# Czw        Bulki      265.0        265.0        265.0      0.0
# Czw        Bagietki   173.0        175.0        175.0      1.0
# Czw        Rogaliki_z_czekolada 149.0        155.0        155.0      2.0
# Pt         Chleb_domowy_0_5kg 471.0        480.0        480.0      1.0
# Pt         Chleb_domowy_0_9kg 347.0        125.0        125.0      256.0
# Pt         Chleb_na_zakwasie 98.0         140.0        140.0      1.0
# Pt         Bulki      326.0        325.0        325.0      1.0
# Pt         Bagietki   329.0        325.0        325.0      5.0
# Pt         Rogaliki_z_czekolada 203.0        200.0        200.0      5.0
# Sob        Chleb_domowy_0_5kg 414.0        415.0        415.0      0.0
# Sob        Chleb_domowy_0_9kg 34.0         290.0        290.0      0.0
# Sob        Chleb_na_zakwasie 208.0        209.0        209.0      0.0
# Sob        Bulki      290.0        291.0        291.0      0.0
# Sob        Bagietki   335.0        340.0        340.0      0.0
# Sob        Rogaliki_z_czekolada 135.0        140.0        140.0      0.0

# %%
# Results
print("Status:", pl.LpStatus[model.status])
if pl.LpStatus[model.status] == 'Optimal':
    print("Total Profit:", pl.value(model.objective))

    print(f"{'day':<10} {'Product':<10} {'SubProduction':<12} {'Production':<12} {'Sales':<10} {'Storage':<10}")

    
    # for day in days:
    #     for product, subproduct in zip(products, subproducts):
    #         subproduction = sub_production_vars[subproduct, day].varValue
    #         production = production_vars[product, day].varValue
    #         sales = sales_vars[product, day].varValue
    #         storage = storage_vars[subproduct, day].varValue
    #         print(f"{day:<10} {product:<10} {subproduction:<12} {production:<12} {sales:<10} {storage:<10}")
    from tabulate import tabulate

    # Prepare data for the table
    table_data = []
    headers = ["Day", "Product", "SubProduction", "Production", "Sales", "Storage"]

    for day in days:
        for product, subproduct in zip(products, subproducts):
            subproduction = sub_production_vars[subproduct, day].varValue
            production = production_vars[product, day].varValue
            sales = sales_vars[product, day].varValue
            storage = storage_vars[subproduct, day].varValue
            table_data.append([day, product, subproduction, production, sales, storage])

    # Print the table
    print(tabulate(table_data, headers=headers))

    import matplotlib.pyplot as plt
    import pandas as pd

    # Prepare data for DataFrame
    data = {
        "Day": [],
        "Product": [],
        "SubProduction": [],
        "Production": [],
        "Sales": [],
        "Storage": []
    }

    for day in days:
        for product, subproduct in zip(products, subproducts):
            data["Day"].append(day)
            data["Product"].append(product)
            data["SubProduction"].append(sub_production_vars[subproduct, day].varValue)
            data["Production"].append(production_vars[product, day].varValue)
            data["Sales"].append(sales_vars[product, day].varValue)
            data["Storage"].append(storage_vars[subproduct, day].varValue)

    # Convert to DataFrame
    df = pd.DataFrame(data)

    # Plot production, sales, and storage for each product
    for product in df["Product"].unique():
        product_data = df[df["Product"] == product]
        
        plt.figure(figsize=(10, 6))
        plt.plot(product_data["Day"], product_data["SubProduction"], label="SubProduction", marker="o")
        plt.plot(product_data["Day"], product_data["Production"], label="Production", marker="o")
        plt.plot(product_data["Day"], product_data["Sales"], label="Sales", marker="s")
        plt.plot(product_data["Day"], product_data["Storage"], label="Storage", marker="^")
        
        plt.title(f"Production, Sales, and Storage for {product}", fontsize=14)
        plt.xlabel("Day", fontsize=12)
        plt.ylabel("Units", fontsize=12)
        plt.legend()
        plt.grid(True, linestyle="--", alpha=0.7)
        plt.tight_layout()
        plt.show()

    # print("\nProduction Time Usage per Product and Day:")
    # for day in days:
    #     print(f"\Day: {day}")
    #     for product in products:
    #         total_production_time = sum(
    #             batch_vars[product, day].varValue * production_times[product]s.get(machine, 0) 
    #             for machine in machines #.keys()
    #         )
    #         print(f"  Product: {product}, Total Production Time: {total_production_time:.2f} hours")

else:
    print("No optimal solution was found.")
    # Analiza ograniczeń
    for name, constraint in model.constraints.items():
        if constraint.pi < 0:
            print(f"Ograniczenie {name}: {constraint}")
# Out:
# Status: Optimal
# Total Profit: 17718.093760000043
# day        Product    SubProduction Production   Sales      Storage
# Day    Product                 SubProduction    Production    Sales    Storage
# -----  --------------------  ---------------  ------------  -------  ---------
# Pon    Chleb_domowy_0_5kg                242           237      237          5
# Pon    Chleb_domowy_0_9kg                305           175      175        130
# Pon    Chleb_na_zakwasie                 369           240      240        129
# Pon    Bulki                             310           310      310          0
# Pon    Bagietki                          175           175      175          0
# Pon    Rogaliki_z_czekolada              150           150      150          0
# Wt     Chleb_domowy_0_5kg                464           469      469          0
# Wt     Chleb_domowy_0_9kg                133           263      263          0
# Wt     Chleb_na_zakwasie                  67           140      140         56
# Wt     Bulki                             335           335      335          0
# Wt     Bagietki                          376           375      375          1
# Wt     Rogaliki_z_czekolada              200           200      200          0
# Sr     Chleb_domowy_0_5kg                476           474      474          2
# Sr     Chleb_domowy_0_9kg                297           190      190        107
# Sr     Chleb_na_zakwasie                 104           160      160          0
# Sr     Bulki                             420           420      420          0
# Sr     Bagietki                          218           216      216          3
# Sr     Rogaliki_z_czekolada              128           120      120          8
# Czw    Chleb_domowy_0_5kg                968           960      960         10
# Czw    Chleb_domowy_0_9kg                  2            75       75         34
# Czw    Chleb_na_zakwasie                 133            90       90         43
# Czw    Bulki                             265           265      265          0
# Czw    Bagietki                          173           175      175          1
# Czw    Rogaliki_z_czekolada              149           155      155          2
# Pt     Chleb_domowy_0_5kg                471           480      480          1
# Pt     Chleb_domowy_0_9kg                347           125      125        256
# Pt     Chleb_na_zakwasie                  98           140      140          1
# Pt     Bulki                             326           325      325          1
# Pt     Bagietki                          329           325      325          5
# Pt     Rogaliki_z_czekolada              203           200      200          5
# Sob    Chleb_domowy_0_5kg                414           415      415          0
# Sob    Chleb_domowy_0_9kg                 34           290      290          0
# Sob    Chleb_na_zakwasie                 208           209      209          0
# Sob    Bulki                             290           291      291          0
# Sob    Bagietki                          335           340      340          0
# Sob    Rogaliki_z_czekolada              135           140      140          0

# %%
# Extended Results Display
print("\nDetailed Results:")

# Fridge usage
print(f"\n{'Day':<10} {'Fridges Used':<15}")
for day in days:
    fridges_used = fridge_count_usage_vars[day].varValue
    print(f"{day:<10} {fridges_used:<15}")

# Batches produced
print(f"\n{'Product':<20} {'Day':<10} {'Batches':<10}")
for product in products:
    for day in days:
        batches = batch_vars[product, day].varValue
        print(f"{product:<20} {day:<10} {batches:<10}")

# Machine usage time
print(f"\n{'Machine':<15} {'Day':<10} {'Total Time Used (h)':<20}")
machine_usage = {machine: {day: 0 for day in days} for machine in machines}

for day in days:
    for subproduct in subproducts:
        for machine in machines:
            if machine in production_times[subproduct]:
                machine_usage[machine][day] += sub_batch_vars[subproduct, day].varValue * production_times[subproduct][machine] / machines_available[machine]
    for product in products:
        for machine in machines:
            if machine in production_times[product]:
                machine_usage[machine][day] += batch_vars[product, day].varValue * production_times[product][machine] / machines_available[machine]

for machine, usage in machine_usage.items():
    for day, time_used in usage.items():
        print(f"{machine:<15} {day:<10} {time_used:<20.2f}")


import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np

# Dane do wykresów
fridges_used_per_day = [fridge_count_usage_vars[day].varValue for day in days]

batches_per_product_day = {
    product: [batch_vars[product, day].varValue for day in days]
    for product in products
}

machine_usage_per_day = {
    machine: [machine_usage[machine][day] for day in days]
    for machine in machines
}

# Wykres 1: Liczba używanych lodówek w każdym dniu
plt.figure(figsize=(10, 5))
plt.bar(days, fridges_used_per_day, color='skyblue')
plt.title('Freezers Used Per Day')
plt.xlabel('Day')
plt.ylabel('Number of Freezers Used')
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Wykres 2: Liczba partii produkowanych dla każdego produktu każdego dnia
plt.figure(figsize=(12, 6))
x = np.arange(len(days))  # Pozycje x
width = 0.15  # Szerokość słupków

for i, (product, batches) in enumerate(batches_per_product_day.items()):
    plt.bar(x + i * width, batches, width, label=product)

plt.title('Batches Produced Per Product Per Day')
plt.xlabel('Day')
plt.ylabel('Number of Batches')
plt.xticks(x + width * (len(products) / 2 - 0.5), days)
plt.legend(title='Product')
plt.gca().yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Wykres 3: Całkowity czas użycia maszyn w każdym dniu dla każdej maszyny
plt.figure(figsize=(12, 6))

for machine, usage in machine_usage_per_day.items():
    plt.plot(days, usage, marker='o', label=machine)

plt.title('Machine Usage Time Per Day')
plt.xlabel('Day')
plt.ylabel('Total Time Used (h)')
plt.legend(title='Machine')
plt.grid(axis='both', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Detailed Results:
#
# Day        Fridges Used
# Pon        2.0
# Wt         1.0
# Sr         1.0
# Czw        1.0
# Pt         2.0
# Sob        0.0
#
# Product              Day        Batches
# Chleb_domowy_0_5kg   Pon        1.0
# Chleb_domowy_0_5kg   Wt         2.0
# Chleb_domowy_0_5kg   Sr         2.0
# Chleb_domowy_0_5kg   Czw        4.0
# Chleb_domowy_0_5kg   Pt         2.0
# Chleb_domowy_0_5kg   Sob        2.0
# Chleb_domowy_0_9kg   Pon        2.0
# Chleb_domowy_0_9kg   Wt         3.0
# Chleb_domowy_0_9kg   Sr         2.0
# Chleb_domowy_0_9kg   Czw        1.0
# Chleb_domowy_0_9kg   Pt         1.0
# Chleb_domowy_0_9kg   Sob        3.0
# Chleb_na_zakwasie    Pon        2.0
# Chleb_na_zakwasie    Wt         1.0
# Chleb_na_zakwasie    Sr         1.0
# Chleb_na_zakwasie    Czw        1.0
# Chleb_na_zakwasie    Pt         1.0
# Chleb_na_zakwasie    Sob        2.0
# Bulki                Pon        2.0
# Bulki                Wt         2.0
# Bulki                Sr         3.0
# Bulki                Czw        2.0
# Bulki                Pt         2.0
# Bulki                Sob        2.0
# Bagietki             Pon        1.0
# Bagietki             Wt         2.0
# Bagietki             Sr         2.0
# Bagietki             Czw        1.0
# Bagietki             Pt         2.0
# Bagietki             Sob        2.0
# Rogaliki_z_czekolada Pon        1.0
# Rogaliki_z_czekolada Wt         1.0
# Rogaliki_z_czekolada Sr         1.0
# Rogaliki_z_czekolada Czw        1.0
# Rogaliki_z_czekolada Pt         1.0
# Rogaliki_z_czekolada Sob        1.0
#
# Machine         Day        Total Time Used (h)
# Rogalikarka     Pon        0.59
# Rogalikarka     Wt         0.87
# Rogalikarka     Sr         0.87
# Rogalikarka     Czw        0.59
# Rogalikarka     Pt         1.18
# Rogalikarka     Sob        0.87
# Piec            Pon        1.03
# Piec            Wt         1.21
# Piec            Sr         1.06
# Piec            Czw        1.00
# Piec            Pt         0.84
# Piec            Sob        1.38
# Dzieza          Pon        7.52
# Dzieza          Wt         5.41
# Dzieza          Sr         6.41
# Dzieza          Czw        6.77
# Dzieza          Pt         6.33
# Dzieza          Sob        6.01
# Pakowanie       Pon        1.66
# Pakowanie       Wt         1.93
# Pakowanie       Sr         1.64
# Pakowanie       Czw        1.92
# Pakowanie       Pt         1.35
# Pakowanie       Sob        2.23
# Wazenie         Pon        0.81
# Wazenie         Wt         0.60
# Wazenie         Sr         0.70
# Wazenie         Czw        0.93
# Wazenie         Pt         0.70
# Wazenie         Sob        0.61
# Nadziewarka     Pon        0.40
# Nadziewarka     Wt         0.40
# Nadziewarka     Sr         0.40
# Nadziewarka     Czw        0.40
# Nadziewarka     Pt         0.80
# Nadziewarka     Sob        0.40
# Garownia        Pon        4.07
# Garownia        Wt         4.79
# Garownia        Sr         4.23
# Garownia        Czw        4.12
# Garownia        Pt         3.29
# Garownia        Sob        5.49
# Tabula          Pon        1.64
# Tabula          Wt         1.26
# Tabula          Sr         1.56
# Tabula          Czw        1.78
# Tabula          Pt         1.44
# Tabula          Sob        1.28
# Studzenie       Pon        3.40
# Studzenie       Wt         4.00
# Studzenie       Sr         3.50
# Studzenie       Czw        3.55
# Studzenie       Pt         2.75
# Studzenie       Sob        4.58
# Dzielarka       Pon        0.49
# Dzielarka       Wt         0.61
# Dzielarka       Sr         0.72
# Dzielarka       Czw        0.49
# Dzielarka       Pt         0.75
# Dzielarka       Sob        0.61
