# %%
import pulp as pl
import numpy as np
# from scipy.stats import multivariate_t

print("==============================================================================")

# Define the problem
model = pl.LpProblem("Maximize_Profit", pl.LpMaximize)

# Products, machines and days
subproducts = ['Ciasto_na_chleb_domowy_0_5kg', 'Ciasto_na_chleb_domowy_0_9kg', 'Ciasto_na_chleb_na_zakwasie', 'Ciasto_na_bulki', 'Ciasto_na_bagietki', 'Ciasto_na_rogaliki_z_czekolada']
products = ['Chleb_domowy_0_5kg', 'Chleb_domowy_0_9kg', 'Chleb_na_zakwasie', 'Bulki', 'Bagietki', 'Rogaliki_z_czekolada']
days = ['Pon', 'Wt', 'Sr']
sub_machines = ['Dzieza', 'Wazenie', 'Dzielarka', 'Tabula', 'Rogalikarka', 'Nadziewarka']
machines = ['Garownia', 'Piec', 'Studzenie', 'Pakowanie']
batches = ['#1', '#2', '#3']

# Income from product sales and production cost in PLN/piece
product_income = {'Chleb_domowy_0_5kg': 5.2, 'Chleb_domowy_0_9kg': 7.9, 'Chleb_na_zakwasie': 6.2, 'Bulki': 1.4, 'Bagietki': 1.55, 'Rogaliki_z_czekolada': 2.1}
sub_product_cost = {'Ciasto_na_chleb_domowy_0_5kg': 1.6, 'Ciasto_na_chleb_domowy_0_9kg': 2.0, 'Ciasto_na_chleb_na_zakwasie': 2.0, 'Ciasto_na_bulki': 0.5, 'Ciasto_na_bagietki': 0.6, 'Ciasto_na_rogaliki_z_czekolada': 1.0}
product_cost = {'Chleb_domowy_0_5kg': 0.8, 'Chleb_domowy_0_9kg': 0.9, 'Chleb_na_zakwasie': 0.8, 'Bulki': 0.2, 'Bagietki': 0.2, 'Rogaliki_z_czekolada': 0.2}

# Time available
shifts_per_day = 2
hours_per_shift = 10
hours_per_day = shifts_per_day * hours_per_shift

max_batches = 1
large_number = 10000

sub_production_times = {
    'Ciasto_na_chleb_domowy_0_5kg': {'Dzieza': 4.7, 'Wazenie': 0.29, 'Dzielarka': 0.0, 'Tabula': 0.7, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_domowy_0_9kg': {'Dzieza': 5, 'Wazenie': 0.2, 'Dzielarka': 0.0, 'Tabula': 0.55, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_na_zakwasie': {'Dzieza': 8.6, 'Wazenie': 0.22, 'Dzielarka': 0.0, 'Tabula': 0.6, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bulki': {'Dzieza': 1, 'Wazenie': 0.0, 'Dzielarka': 0.23, 'Tabula': 0.34, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bagietki': {'Dzieza': 0.95, 'Wazenie': 0.0, 'Dzielarka': 0.24, 'Tabula': 0.0, 'Rogalikarka': 0.28, 'Nadziewarka': 0.0},
    'Ciasto_na_rogaliki_z_czekolada': {'Dzieza': 0.55, 'Wazenie': 0.0, 'Dzielarka': 0.28, 'Tabula': 0.0, 'Rogalikarka': 0.31, 'Nadziewarka': 0.4}
}

production_times = {
    'Chleb_domowy_0_5kg': {'Garownia': 1.0, 'Piec': 0.68, 'Studzenie': 1.8, 'Pakowanie': 0.56},
    'Chleb_domowy_0_9kg': {'Garownia': 1.5, 'Piec': 1.2, 'Studzenie': 2.5, 'Pakowanie': 0.57},
    'Chleb_na_zakwasie': {'Garownia': 1.4, 'Piec': 1.0, 'Studzenie': 2.3, 'Pakowanie': 0.6},
    'Bulki': {'Garownia': 0.38, 'Piec': 0.25, 'Studzenie': 0.48, 'Pakowanie': 0.0},
    'Bagietki': {'Garownia': 0.33, 'Piec': 0.23, 'Studzenie': 0.42, 'Pakowanie': 0.0},
    'Rogaliki_z_czekolada': {'Garownia': 0.25, 'Piec': 0.18, 'Studzenie': 0.82, 'Pakowanie': 0.42}
}


batch_size = {
    "Ciasto_na_chleb_domowy_0_5kg": 240,
    "Ciasto_na_chleb_domowy_0_9kg": 130,
    "Ciasto_na_chleb_na_zakwasie": 200,
    "Ciasto_na_bulki": 200,
    "Ciasto_na_bagietki": 200,
    "Ciasto_na_rogaliki_z_czekolada": 200,
    "Chleb_domowy_0_5kg": 240,
    "Chleb_domowy_0_9kg": 130,
    "Chleb_na_zakwasie": 200,
    "Bulki": 200,
    "Bagietki": 200,
    "Rogaliki_z_czekolada": 200,
}

market_limits = {
    "Chleb_domowy_0_5kg": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 420, "Pt": 530, "Sob": 680},
    "Chleb_domowy_0_9kg": {"Pon": 100, "Wt": 100, "Sr": 380, "Czw": 150, "Pt": 250, "Sob": 580},
    "Chleb_na_zakwasie": {"Pon": 100, "Wt": 100, "Sr": 320, "Czw": 180, "Pt": 280, "Sob": 418},
    "Bulki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 530, "Pt": 650, "Sob": 580},
    "Bagietki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 350, "Pt": 650, "Sob": 680},
    "Rogaliki_z_czekolada": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 310, "Pt": 400, "Sob": 280},
}

# Machines cost
fridge_cost_per_day = 0.281 * 24 * 1.4 * 0.2 # kW * 24h * price per hour * factor
furnace_cost_per_hour = 82.4 # https://giko.pl/kalkulator-zuzycia-energii-dla-piecow-piekarniczych/


fridge_count = 10
fridge_capacity = 160
end_stock = 0
storage_capacity = fridge_count * fridge_capacity

# Variables for production, sales, and storage of products each day
sub_production_vars = pl.LpVariable.dicts("Subproduct production", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
production_vars = pl.LpVariable.dicts("Production", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# batch_count_vars = pl.LpVariable.dicts("Batches Count", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# subbatch_count_vars = pl.LpVariable.dicts("Subproduct Batches Count", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
product_batch_start_time = pl.LpVariable.dicts("ProductStartTime",  [(product, batch, machine, day) for product in products for batch in batches for machine in machines for day in days], lowBound=0, cat="Continuous")
subproduct_batch_start_time = pl.LpVariable.dicts("Subproduction start time for batch",  [(subproduct, batch, machine, day) for subproduct in subproducts for batch in batches for machine in sub_machines for day in days], lowBound=0, cat="Continuous")
sales_vars = pl.LpVariable.dicts("Sales", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, idx) for (machine, idx) in specific_machines], cat="Binary")
# subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, day, batch) for subproduct in subproducts for day in days for batch in range(1, max_batches + 1)], cat="Binary")
subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, day) for subproduct in subproducts for day in days], cat="Binary")
batch_produced = pl.LpVariable.dicts("BatchProduced", [(product, day) for product in products for day in days], cat="Binary")
specific_sub_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, subproduct, batch, day) for machine in sub_machines for subproduct in subproducts for batch in batches for day in days], cat="Binary")
specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, product, batch, day) for machine in machines for product in products for batch in batches for day in days], cat="Binary")
storage_vars = pl.LpVariable.dicts("Storage", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, upBound=storage_capacity, cat='Integer')
fridge_count_usage_vars = pl.LpVariable.dicts("FridgeCount", ((day) for day in days), lowBound=0, upBound=fridge_count, cat='Integer')


# xij = pl.LpVariable.dicts("xij", [(machine, idx, i, j) for (machine, idx) in specific_machines for i in subproducts for j in subproducts if i != j], 0, 1, pl.LpBinary)
is_produced_sub = pl.LpVariable.dicts("is_produced", ((subproduct, batch, machine, day) for subproduct in subproducts for batch in batches for machine in sub_machines for day in days), cat="Binary")
is_produced = pl.LpVariable.dicts("is_produced",
                                     ((product, batch, machine, day) for product in products for batch in batches
                                                                      for machine in machines
                                                                      for day in days),
                                     cat="Binary")

for subproduct in subproducts:
    for i, machine in enumerate(sub_machines[1:], start=1):  # Od ważenia do nadziewarki
        prev = 1
        prev_machine = sub_machines[i - prev]
        while sub_production_times[subproduct][prev_machine] == 0.0 or prev_machine == machine:
            prev += 1
            prev_machine = sub_machines[i - prev]

    for batch in batches:
        for day in days:
            model += subproduct_batch_start_time[subproduct, batch, machine, day] >= (
                subproduct_batch_start_time[subproduct, batch, prev_machine, day] + sub_production_times[subproduct][prev_machine]
            )

            # model += subproduct_batch_start_time[subproduct, batch, machine, day] <= specific_sub_machine_used[machine, subproduct, day] * hours_per_day

            last_machine = sub_machines[-1]
            model += hours_per_day >= (
                subproduct_batch_start_time[subproduct, batch, last_machine, day] + sub_production_times[subproduct][last_machine]
            )

for product in products:
    for i, machine in enumerate(machines[1:], start=1):  # Od ważenia do nadziewarki
        prev = 1
        prev_machine = machines[i - prev]
        while production_times[product][prev_machine] == 0.0 or prev_machine == machine:
            prev += 1
            prev_machine = machines[i - prev]

    for day in days:
        for batch in batches:
            model += product_batch_start_time[product, batch, machine, day] >= (
                product_batch_start_time[product, batch, prev_machine, day] + production_times[product][prev_machine]
            )
            # model += product_batch_start_time[product, machine, day] <= specific_machine_used[machine, product, day] * hours_per_day
            last_machine = machines[-1]
            model += hours_per_day >= (
                product_batch_start_time[product, batch, last_machine, day] + production_times[product][last_machine]
            )
'''
        model += subbatch_produced[subproduct, day] * large_number >= subproduct_batch_start_time[subproduct, last_machine, last_idx, day]

        # Brak nakładania się produkcji na maszynie
        for machine, idx in specific_machines[:6]:  # Zakres maszyn
            for subproduct1 in subproducts:
                for subproduct2 in subproducts:
                    if subproduct1 != subproduct2:
                        model += (subproduct_batch_start_time[subproduct1, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct2, machine, idx, day] + production_times[subproduct2][machine]) | \
                                 (subproduct_batch_start_time[subproduct2, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct1, machine, idx, day] + production_times[subproduct1][machine])

                        # model += specific_machine_used[machine, idx, subproduct1, day] + specific_machine_used[machine, idx, subproduct2, day] <= 1
'''
# Ograniczenie: produkcja subproduktu tylko na maszynach, gdzie czas produkcji > 0
for subproduct in subproducts:
    for machine in sub_machines:
        if sub_production_times[subproduct][machine] == 0:
            for day in days:
                for batch in batches:
                    model += is_produced_sub[subproduct, batch, machine, day] == 0

# Ograniczenie: produkcja produktu tylko na maszynach, gdzie czas produkcji > 0
for product in products:
    for machine in machines:
        if production_times[product][machine] == 0:
            for day in days:
                for batch in batches:
                    model += is_produced[product, batch, machine, day] == 0
                

# Warunek: jeśli subprodukt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for subproduct in subproducts:
    machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for machine in machines_with_production:
                for batch in batches:
                    model += pl.lpSum(is_produced_sub[subproduct, batch, m, day] for m in machines_with_production) == \
                            len(machines_with_production) * is_produced_sub[subproduct, batch, machine, day]
        
        # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
        model += subbatch_produced[subproduct, day] * len(machines_with_production) <= pl.lpSum(is_produced_sub[subproduct, batch, machine, day] for machine in machines_with_production for batch in batches)

# Warunek: jeśli produkt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for product in products:
    machines_with_production = [machine for machine in machines if production_times[product][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for machine in machines_with_production:
                for batch in batches:
                    model += pl.lpSum(is_produced[product, batch, m, day] for m in machines_with_production) == \
                            len(machines_with_production) * is_produced[product, batch, machine, day]
        
        # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
        model += batch_produced[product, day] * len(machines_with_production) <= pl.lpSum(is_produced[product, batch, machine, day] for machine in machines_with_production for batch in batches)

# Aktualizacja ograniczenia: brak nakładania się produkcji
big_M = 1000000
for subproduct1 in subproducts:
    for subproduct2 in subproducts:
        if subproduct1 != subproduct2:
            machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct1][machine] > 0 and sub_production_times[subproduct2][machine] > 0]
            for machine in machines_with_production: 
                for day in days:
                    for batch1 in batches:
                        for batch2 in batches:
                            if batch1 != batch2:
                        # Dodanie binarnych zmiennych pomocniczych
                                y1 = pl.LpVariable(f"y1_{subproduct1}_{subproduct2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")
                                y2 = pl.LpVariable(f"y2_{subproduct1}_{subproduct2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")
                                y3 = pl.LpVariable(f"y3_{subproduct1}_{subproduct2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")
                                y4 = pl.LpVariable(f"y4_{subproduct1}_{subproduct2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")

                                # Powiązanie warunków logicznych z binarnymi zmiennymi
                                model += subproduct_batch_start_time[subproduct1, batch, machine, day] >= \
                                            subproduct_batch_start_time[subproduct2, batch, machine, day] + sub_production_times[subproduct2][machine] - \
                                            big_M * (1 - y1)
                                
                                model += subproduct_batch_start_time[subproduct2, batch, machine, day] >= \
                                            subproduct_batch_start_time[subproduct1, batch, machine, day] + sub_production_times[subproduct1][machine] - \
                                            big_M * (1 - y2)

                                model += is_produced_sub[subproduct1, batch, machine, day] + y3 == 1
                                model += is_produced_sub[subproduct2, batch, machine, day] + y4 == 1

                                # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                                model += y1 + y2 + y3 + y4 == 1

for product1 in products:
    for product2 in products:
        if product1 != product2:
            machines_with_production = [machine for machine in machines if production_times[product1][machine] > 0 and production_times[product2][machine] > 0]
            for machine in machines_with_production: 
                for day in days:
                    for batch1 in batches:
                        for batch2 in batches:
                            if batch1 != batch2:
                                # Dodanie binarnych zmiennych pomocniczych
                                y1 = pl.LpVariable(f"y1_{product1}_{product2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")
                                y2 = pl.LpVariable(f"y2_{product1}_{product2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")
                                y3 = pl.LpVariable(f"y3_{product1}_{product2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")
                                y4 = pl.LpVariable(f"y4_{product1}_{product2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")

                                # Powiązanie warunków logicznych z binarnymi zmiennymi
                                model += product_batch_start_time[product1, batch, machine, day] >= \
                                            product_batch_start_time[product2, batch, machine, day] + production_times[product2][machine] - \
                                            big_M * (1 - y1)
                                
                                model += product_batch_start_time[product2, batch, machine, day] >= \
                                            product_batch_start_time[product1, batch, machine, day] + production_times[product1][machine] - \
                                            big_M * (1 - y2)

                                model += is_produced[product1, batch, machine, day] + y3 == 1
                                model += is_produced[product2, batch, machine, day] + y4 == 1

                                # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                                model += y1 + y2 + y3 + y4 == 1


for subproduct, product in zip(subproducts, products):
    model += storage_vars[subproduct, 'Pon'] == sub_production_vars[subproduct, 'Pon'] - production_vars[product, 'Pon']
    for i in range(1, len(days)):
        day = days[i]
        prev_day = days[i-1]
        model += storage_vars[subproduct, day] == storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day]

for day in days:
    model += storage_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)
    model += fridge_count_usage_vars[day] * fridge_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)

for product, subproduct in zip(products, subproducts):
    for day in days:
        model += batch_produced[product, day] * batch_size[product] >= production_vars[product, day]
        model += subbatch_produced[subproduct, day] * batch_size[subproduct] >= sub_production_vars[subproduct, day]
        # model += sub_production_vars[subproduct, day] >= production_vars[product, day]
        model += sales_vars[product, day] == production_vars[product, day]
    model += sales_vars[product, 'Sr'] >= 0.01*market_limits[product]['Wt'], f"Max_sales_{product}_{'Sr'}"


# Objective function: Maximize profit from sales minus costs
model += pl.lpSum([sales_vars[product, day] * product_income[product] for product in products for day in days]) \
                    - pl.lpSum([production_vars[product, day] * product_cost[product] for product in products for day in days]) \
                    - pl.lpSum([sub_production_vars[subproduct, day] * sub_product_cost[subproduct] for subproduct in subproducts for day in days])


solver = pl.PULP_CBC_CMD(timeLimit=60)

model.solve(solver)

# model.solve()

# Results
print("Status:", pl.LpStatus[model.status])
if pl.LpStatus[model.status] == 'Optimal':
    print("Total Profit:", pl.value(model.objective))

    print(f"{'Product':<10} {'day':<10} {'SubProduction':<10} {'Production':<12} {'Sales':<10} {'Storage':<10}")

    for product, subproduct in zip(products, subproducts):
        for day in days:
            subproduction = sub_production_vars[subproduct, day].varValue
            production = production_vars[product, day].varValue
            sales = sales_vars[product, day].varValue
            storage = storage_vars[subproduct, day].varValue

            print(f"{product:<10} {day:<10} {subproduction:<12} {production:<12} {sales:<10} {storage:<10}")

    # print("\nProduction Time Usage per Product and Day:")
    # for day in days:
    #     print(f"\Day: {day}")
    #     for product in products:
    #         total_production_time = sum(
    #             batch_count_vars[product, day].varValue * production_times[product]s.get(machine, 0) 
    #             for machine in machines #.keys()
    #         )
    #         print(f"  Product: {product}, Total Production Time: {total_production_time:.2f} hours")

else:
    print("No optimal solution was found.")
    # Analiza ograniczeń
    for name, constraint in model.constraints.items():
        if constraint.pi < 0:
            print(f"Ograniczenie {name}: {constraint}")
# Out:
# ==============================================================================
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gromiusz/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/8635900f5cea42198c8c9c092baec7e0-pulp.mps -max -sec 60 -timeMode elapsed -branch -printingOptions all -solution /tmp/8635900f5cea42198c8c9c092baec7e0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 15101 COLUMNS
# At line 81432 RHS
# At line 96529 BOUNDS
# At line 108557 ENDATA
# Problem MODEL has 15096 rows, 12315 columns and 42222 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 60
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7416 - 0.21 seconds
# Cgl0002I 171 variables fixed
# Cgl0003I 0 fixed, 0 tightened bounds, 2016 strengthened rows, 921 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1920 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 707 strengthened rows, 0 substitutions
# Cgl0004I processed model has 8566 rows, 5892 columns (5772 integer (5724 of which binary)) and 33191 elements
# Cbc0038I Initial state - 36 integers unsatisfied sum - 18
# Cbc0038I Pass   1: (3.98 seconds) suminf.   18.00000 (36) obj. -7416 iterations 10
# Cbc0038I Pass   2: (4.03 seconds) suminf.   18.00000 (36) obj. -7416 iterations 6
# Cbc0038I Pass   3: (4.07 seconds) suminf.   18.00000 (36) obj. -7416 iterations 4
# Cbc0038I Pass   4: (4.10 seconds) suminf.   18.00000 (36) obj. -7416 iterations 1
# Cbc0038I Pass   5: (4.14 seconds) suminf.   18.00000 (36) obj. -7416 iterations 1
# Cbc0038I Pass   6: (4.21 seconds) suminf.   18.00000 (36) obj. -7416 iterations 478
# Cbc0038I Pass   7: (4.26 seconds) suminf.   18.00000 (36) obj. -7416 iterations 159
# Cbc0038I Pass   8: (4.27 seconds) suminf.   18.00000 (36) obj. -7416 iterations 0
# Cbc0038I Pass   9: (4.31 seconds) suminf.   18.00000 (36) obj. -7416 iterations 2
# Cbc0038I Pass  10: (4.36 seconds) suminf.   18.00000 (36) obj. -7416 iterations 205
# Cbc0038I Pass  11: (4.41 seconds) suminf.   18.00000 (36) obj. -7416 iterations 282
# Cbc0038I Pass  12: (4.45 seconds) suminf.   18.00000 (36) obj. -7416 iterations 105
# Cbc0038I Pass  13: (4.49 seconds) suminf.   18.00000 (36) obj. -7416 iterations 4
# Cbc0038I Pass  14: (4.54 seconds) suminf.   18.00000 (36) obj. -7416 iterations 183
# Cbc0038I Pass  15: (4.59 seconds) suminf.   18.00000 (36) obj. -7416 iterations 116
# Cbc0038I Pass  16: (4.64 seconds) suminf.   18.00000 (36) obj. -7416 iterations 1
# Cbc0038I Pass  17: (4.65 seconds) suminf.   18.00000 (36) obj. -7416 iterations 0
# Cbc0038I Pass  18: (4.67 seconds) suminf.   18.00000 (36) obj. -7416 iterations 0
# Cbc0038I Pass  19: (4.72 seconds) suminf.   18.00000 (36) obj. -7416 iterations 165
# Cbc0038I Pass  20: (4.76 seconds) suminf.   18.00000 (36) obj. -7416 iterations 96
# Cbc0038I Pass  21: (4.81 seconds) suminf.   18.00000 (36) obj. -7416 iterations 172
# Cbc0038I Pass  22: (4.86 seconds) suminf.   18.00000 (36) obj. -7416 iterations 121
# Cbc0038I Pass  23: (4.88 seconds) suminf.   18.00000 (36) obj. -7416 iterations 0
# Cbc0038I Pass  24: (4.92 seconds) suminf.   18.00000 (36) obj. -7416 iterations 142
# Cbc0038I Pass  25: (4.97 seconds) suminf.   18.00000 (36) obj. -7416 iterations 97
# Cbc0038I Pass  26: (5.02 seconds) suminf.   18.00000 (36) obj. -7416 iterations 155
# Cbc0038I Pass  27: (5.07 seconds) suminf.   18.00000 (36) obj. -7416 iterations 98
# Cbc0038I Pass  28: (5.12 seconds) suminf.   18.00000 (36) obj. -7416 iterations 4
# Cbc0038I Pass  29: (5.16 seconds) suminf.   18.00000 (36) obj. -7416 iterations 173
# Cbc0038I Pass  30: (5.22 seconds) suminf.   18.00000 (36) obj. -7416 iterations 283
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 5736 integers at bound fixed and 108 continuous
# Cbc0038I Mini branch and bound did not improve solution (5.25 seconds)
# Cbc0038I After 5.25 seconds - Feasibility pump exiting - took 1.48 seconds
# Cbc0031I 127 added rows had average density of 3.7322835
# Cbc0013I At root node, 127 cuts changed objective from -7416 to -7416 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 1338 row cuts average 2.2 elements, 0 column cuts (0 active)  in 6.185 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 478 row cuts average 12.8 elements, 0 column cuts (0 active)  in 4.748 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 11 row cuts average 3.8 elements, 0 column cuts (0 active)  in 0.197 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.429 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 4417 row cuts average 2.8 elements, 0 column cuts (0 active)  in 0.224 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 36 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.192 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 4991 row cuts average 12.9 elements, 0 column cuts (0 active)  in 6.040 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible -7416 (28.05 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective 1e+50 (best possible -7416), took 5906 iterations and 5 nodes (78.80 seconds)
# Cbc0032I Strong branching done 110 times (5027 iterations), fathomed 0 nodes and fixed 1 variables
# Cbc0035I Maximum depth 4, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -7416 to -7416
# Probing was tried 19 times and created 1452 cuts of which 0 were active after adding rounds of cuts (6.640 seconds)
# Gomory was tried 19 times and created 599 cuts of which 0 were active after adding rounds of cuts (9.465 seconds)
# Knapsack was tried 10 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.197 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.429 seconds)
# MixedIntegerRounding2 was tried 19 times and created 5871 cuts of which 0 were active after adding rounds of cuts (0.420 seconds)
# FlowCover was tried 10 times and created 36 cuts of which 0 were active after adding rounds of cuts (0.192 seconds)
# TwoMirCuts was tried 10 times and created 4991 cuts of which 0 were active after adding rounds of cuts (6.040 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.034 seconds)
# ImplicationCuts was tried 9 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
#
# Result - Stopped on time limit
#
# No feasible solution found
# Upper bound:                    7416.000
# Enumerated nodes:               5
# Total iterations:               5906
# Time (CPU seconds):             75.21
# Time (Wallclock seconds):       78.86
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       75.62   (Wallclock seconds):       79.26
#
# Status: Not Solved
# No optimal solution was found.
# Ograniczenie _C15037: 240*BatchProduced_('Chleb_domowy_0_5kg',_'Pon') - Production_('Chleb_domowy_0_5kg',_'Pon') >= 0
# Ograniczenie _C15040: 240*BatchProduced_('Chleb_domowy_0_5kg',_'Wt') - Production_('Chleb_domowy_0_5kg',_'Wt') >= 0
# Ograniczenie _C15043: 240*BatchProduced_('Chleb_domowy_0_5kg',_'Sr') - Production_('Chleb_domowy_0_5kg',_'Sr') >= 0
# Ograniczenie _C15046: 130*BatchProduced_('Chleb_domowy_0_9kg',_'Pon') - Production_('Chleb_domowy_0_9kg',_'Pon') >= 0
# Ograniczenie _C15049: 130*BatchProduced_('Chleb_domowy_0_9kg',_'Wt') - Production_('Chleb_domowy_0_9kg',_'Wt') >= 0
# Ograniczenie _C15052: 130*BatchProduced_('Chleb_domowy_0_9kg',_'Sr') - Production_('Chleb_domowy_0_9kg',_'Sr') >= 0
# Ograniczenie _C15055: 200*BatchProduced_('Chleb_na_zakwasie',_'Pon') - Production_('Chleb_na_zakwasie',_'Pon') >= 0
# Ograniczenie _C15058: 200*BatchProduced_('Chleb_na_zakwasie',_'Wt') - Production_('Chleb_na_zakwasie',_'Wt') >= 0
# Ograniczenie _C15061: 200*BatchProduced_('Chleb_na_zakwasie',_'Sr') - Production_('Chleb_na_zakwasie',_'Sr') >= 0
# Ograniczenie _C15064: 200*BatchProduced_('Bulki',_'Pon') - Production_('Bulki',_'Pon') >= 0
# Ograniczenie _C15067: 200*BatchProduced_('Bulki',_'Wt') - Production_('Bulki',_'Wt') >= 0
# Ograniczenie _C15070: 200*BatchProduced_('Bulki',_'Sr') - Production_('Bulki',_'Sr') >= 0
# Ograniczenie _C15073: 200*BatchProduced_('Bagietki',_'Pon') - Production_('Bagietki',_'Pon') >= 0
# Ograniczenie _C15076: 200*BatchProduced_('Bagietki',_'Wt') - Production_('Bagietki',_'Wt') >= 0
# Ograniczenie _C15079: 200*BatchProduced_('Bagietki',_'Sr') - Production_('Bagietki',_'Sr') >= 0
# Ograniczenie _C15082: 200*BatchProduced_('Rogaliki_z_czekolada',_'Pon') - Production_('Rogaliki_z_czekolada',_'Pon') >= 0
# Ograniczenie _C15085: 200*BatchProduced_('Rogaliki_z_czekolada',_'Wt') - Production_('Rogaliki_z_czekolada',_'Wt') >= 0
# Ograniczenie _C15088: 200*BatchProduced_('Rogaliki_z_czekolada',_'Sr') - Production_('Rogaliki_z_czekolada',_'Sr') >= 0
#  - 1338 row cuts average 2.2 elements, 0 column cuts (0 active)  in 6.624 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 478 row cuts average 12.8 elements, 0 column cuts (0 active)  in 4.721 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 11 row cuts average 3.8 elements, 0 column cuts (0 active)  in 0.243 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.393 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 4417 row cuts average 2.8 elements, 0 column cuts (0 active)  in 0.247 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 36 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.214 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 4991 row cuts average 12.9 elements, 0 column cuts (0 active)  in 6.044 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible -7416 (30.81 seconds)
# Cbc0010I After 100 nodes, 52 on tree, 1e+50 best solution, best possible -7416 (180.97 seconds)
# Cbc0010I After 200 nodes, 87 on tree, 1e+50 best solution, best possible -7416 (206.37 seconds)
# Cbc0010I After 300 nodes, 100 on tree, 1e+50 best solution, best possible -7416 (228.42 seconds)
# Cbc0010I After 400 nodes, 101 on tree, 1e+50 best solution, best possible -7416 (240.65 seconds)
# Cbc0010I After 500 nodes, 101 on tree, 1e+50 best solution, best possible -7416 (248.40 seconds)
# Cbc0010I After 600 nodes, 103 on tree, 1e+50 best solution, best possible -7416 (254.63 seconds)
# Cbc0010I After 700 nodes, 104 on tree, 1e+50 best solution, best possible -7416 (259.59 seconds)
# Cbc0010I After 800 nodes, 104 on tree, 1e+50 best solution, best possible -7416 (270.74 seconds)
# Cbc0010I After 900 nodes, 104 on tree, 1e+50 best solution, best possible -7416 (278.53 seconds)
# Cbc0010I After 1000 nodes, 105 on tree, 1e+50 best solution, best possible -7416 (284.03 seconds)
# Cbc0010I After 1100 nodes, 107 on tree, 1e+50 best solution, best possible -7416 (289.05 seconds)
# Cbc0010I After 1200 nodes, 107 on tree, 1e+50 best solution, best possible -7416 (294.26 seconds)
# Cbc0004I Integer solution of -7416 found after 17176 iterations and 1249 nodes (300.11 seconds)
# Cbc0001I Search completed - best objective -7416, took 17176 iterations and 1249 nodes (300.12 seconds)
# Cbc0032I Strong branching done 5858 times (37439 iterations), fathomed 0 nodes and fixed 113 variables
# Cbc0035I Maximum depth 653, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -7416 to -7416
# Probing was tried 163 times and created 3092 cuts of which 0 were active after adding rounds of cuts (8.995 seconds)
# Gomory was tried 163 times and created 1502 cuts of which 0 were active after adding rounds of cuts (18.852 seconds)
# Knapsack was tried 10 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.243 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.393 seconds)
# MixedIntegerRounding2 was tried 163 times and created 8623 cuts of which 0 were active after adding rounds of cuts (2.552 seconds)
# FlowCover was tried 10 times and created 36 cuts of which 0 were active after adding rounds of cuts (0.214 seconds)
# TwoMirCuts was tried 10 times and created 4991 cuts of which 0 were active after adding rounds of cuts (6.044 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.034 seconds)
# ImplicationCuts was tried 16 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.036 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7416.00000000
# Enumerated nodes:               1249
# Total iterations:               17176
# Time (CPU seconds):             287.34
# Time (Wallclock seconds):       300.41
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       287.56   (Wallclock seconds):       300.67
#
#  - 1338 row cuts average 2.2 elements, 0 column cuts (0 active)  in 5.859 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 478 row cuts average 12.8 elements, 0 column cuts (0 active)  in 4.693 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 11 row cuts average 3.8 elements, 0 column cuts (0 active)  in 0.199 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.382 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 4417 row cuts average 2.8 elements, 0 column cuts (0 active)  in 0.218 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 36 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.195 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 4991 row cuts average 12.9 elements, 0 column cuts (0 active)  in 5.786 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible -7416 (30.20 seconds)
# Cbc0010I After 100 nodes, 52 on tree, 1e+50 best solution, best possible -7416 (184.95 seconds)
# Cbc0010I After 200 nodes, 87 on tree, 1e+50 best solution, best possible -7416 (207.71 seconds)
# Cbc0010I After 300 nodes, 100 on tree, 1e+50 best solution, best possible -7416 (229.03 seconds)
# Cbc0010I After 400 nodes, 101 on tree, 1e+50 best solution, best possible -7416 (241.38 seconds)
# Cbc0010I After 500 nodes, 101 on tree, 1e+50 best solution, best possible -7416 (252.45 seconds)
# Cbc0010I After 600 nodes, 103 on tree, 1e+50 best solution, best possible -7416 (257.83 seconds)
# Cbc0010I After 700 nodes, 104 on tree, 1e+50 best solution, best possible -7416 (262.47 seconds)
# Cbc0010I After 800 nodes, 104 on tree, 1e+50 best solution, best possible -7416 (270.45 seconds)
# Cbc0010I After 900 nodes, 104 on tree, 1e+50 best solution, best possible -7416 (278.52 seconds)
# Cbc0010I After 1000 nodes, 105 on tree, 1e+50 best solution, best possible -7416 (287.72 seconds)
# Cbc0010I After 1100 nodes, 107 on tree, 1e+50 best solution, best possible -7416 (292.51 seconds)
# Cbc0010I After 1200 nodes, 107 on tree, 1e+50 best solution, best possible -7416 (296.89 seconds)
# Cbc0004I Integer solution of -7416 found after 17176 iterations and 1249 nodes (299.66 seconds)
# Cbc0001I Search completed - best objective -7416, took 17176 iterations and 1249 nodes (299.68 seconds)
# Cbc0032I Strong branching done 5858 times (37439 iterations), fathomed 0 nodes and fixed 113 variables
# Cbc0035I Maximum depth 653, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -7416 to -7416
# Probing was tried 163 times and created 3092 cuts of which 0 were active after adding rounds of cuts (8.134 seconds)
# Gomory was tried 163 times and created 1502 cuts of which 0 were active after adding rounds of cuts (17.985 seconds)
# Knapsack was tried 10 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.199 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.382 seconds)
# MixedIntegerRounding2 was tried 163 times and created 8623 cuts of which 0 were active after adding rounds of cuts (2.400 seconds)
# FlowCover was tried 10 times and created 36 cuts of which 0 were active after adding rounds of cuts (0.195 seconds)
# TwoMirCuts was tried 10 times and created 4991 cuts of which 0 were active after adding rounds of cuts (5.786 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.042 seconds)
# ImplicationCuts was tried 16 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.033 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7416.00000000
# Enumerated nodes:               1249
# Total iterations:               17176
# Time (CPU seconds):             287.04
# Time (Wallclock seconds):       299.99
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       287.31   (Wallclock seconds):       300.28

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_colwidth', None)  # Ustaw brak limitu szerokości kolumny


# Po rozwiązaniu problemu upewnijmy się, że rozwiązanie jest optymalne
if pl.LpStatus[model.status] != 'Optimal':
    print("Model did not solve to optimality.")
    exit()

# Pobierz wartości czasu rozpoczęcia
start_times = {
    (subproduct, machine, day): subproduct_batch_start_time[subproduct, machine, day].varValue
    for subproduct in subproducts for machine in sub_machines for day in days
    if subproduct_batch_start_time[subproduct, machine, day].varValue is not None
}

# Oblicz czas zakończenia
end_times = {
    (subproduct, machine, day): start_times[subproduct, machine, day] + sub_production_times[subproduct][machine]
    for subproduct, machine, day in start_times
}

# Wersja 1: Widok z perspektywy subproduktu
subproduct_schedule = []
for subproduct in subproducts:
    for day in days:
        for machine in sub_machines:
            if (subproduct, machine, day) in start_times:
                start = start_times[(subproduct, machine, day)]
                end = end_times[(subproduct, machine, day)]
                subproduct_schedule.append({
                    'Subproduct': subproduct,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

subproduct_df = pd.DataFrame(subproduct_schedule)
print("\nSubproduct Schedule:\n")
print(subproduct_df.sort_values(['Day', 'Subproduct', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania subproduktów na litery
subproduct_mapping = {subproduct: chr(65 + i) for i, subproduct in enumerate(subproducts)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for subproduct in subproducts:
        if (subproduct, machine, day) in start_times:
            start = start_times[(subproduct, machine, day)]
            end = end_times[(subproduct, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = subproduct_mapping[subproduct]  # Wstaw literę dla subproduktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_subproduct = timeline[i]
                    prev_duration = (
                        end_times[(subproducts[ord(prev_subproduct) - 65], machine, day)] -
                        start_times[(subproducts[ord(prev_subproduct) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = subproduct_mapping[subproduct]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in sub_machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
subproduct_df.to_csv("subproduct_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Subproduktów:")
for subproduct, letter in subproduct_mapping.items():
    print(f"{letter}: {subproduct}")
# Out:
# Subproduct Schedule:
#
#                          Subproduct  Day      Machine  Start Time  End Time
# 72               Ciasto_na_bagietki  Pon       Dzieza        0.00      0.95
# 74               Ciasto_na_bagietki  Pon    Dzielarka       19.48     19.72
# 76               Ciasto_na_bagietki  Pon  Rogalikarka       19.72     20.00
# 73               Ciasto_na_bagietki  Pon      Wazenie       20.00     20.00
# 75               Ciasto_na_bagietki  Pon       Tabula       20.00     20.00
# ..                              ...  ...          ...         ...       ...
# 98   Ciasto_na_rogaliki_z_czekolada   Wt    Dzielarka       19.01     19.29
# 100  Ciasto_na_rogaliki_z_czekolada   Wt  Rogalikarka       19.29     19.60
# 101  Ciasto_na_rogaliki_z_czekolada   Wt  Nadziewarka       19.60     20.00
# 97   Ciasto_na_rogaliki_z_czekolada   Wt      Wazenie       20.00     20.00
# 99   Ciasto_na_rogaliki_z_czekolada   Wt       Tabula       20.00     20.00
#
# [108 rows x 5 columns]
#
# Machine Usage Timeline:
#
#         Machine  Day  \
# 0        Dzieza  Pon
# 1       Wazenie  Pon
# 2     Dzielarka  Pon
# 3        Tabula  Pon
# 4   Rogalikarka  Pon
# 5   Nadziewarka  Pon
# 6        Dzieza   Wt
# 7       Wazenie   Wt
# 8     Dzielarka   Wt
# 9        Tabula   Wt
# 10  Rogalikarka   Wt
# 11  Nadziewarka   Wt
# 12       Dzieza   Sr
# 13      Wazenie   Sr
# 14    Dzielarka   Sr
# 15       Tabula   Sr
# 16  Rogalikarka   Sr
# 17  Nadziewarka   Sr
#
#                                                                                                 Timeline
# 0   EEEEDDDDD________________CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCAAAAAAAAAAAAAAAAAAAAAAAAFFFB____
# 1   ____________________________________________________________________________________________A__CB___
# 2   __________________________________________________________________________________________D____F_E__
# 3   ___________________________________________________________________________________________DDAAACBBB
# 4   ________________________________________________________________________________________________F_EE
# 5   __________________________________________________________________________________________________FF
# 6   FFDDDDD________________EEEEECCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCAAAAAAAAAAAAAAAAAAAAAAAAB____
# 7   _____________________________________________________________________________________________C_AB___
# 8   ___________________________________________________________________________________________D___F_E__
# 9   ____________________________________________________________________________________________DDCCCBBB
# 10  ________________________________________________________________________________________________F_EE
# 11  __________________________________________________________________________________________________FF
# 12  EEEEFFF_______________CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCAAAAAAAAAAAAAAAAAAAAAAAADDDDDBB____
# 13  __________________________________________________________________________________________A____CB___
# 14  ___________________________________________________________________________________________FEED_____
# 15  ___________________________________________________________________________________________AAAADCBBB
# 16  _______________________________________________________________________________________________EF___
# 17  __________________________________________________________________________________________________FF
#
# Legenda Subproduktów:
# A: Ciasto_na_chleb_domowy_0_5kg
# B: Ciasto_na_chleb_domowy_0_9kg
# C: Ciasto_na_chleb_na_zakwasie
# D: Ciasto_na_bulki
# E: Ciasto_na_bagietki
# F: Ciasto_na_rogaliki_z_czekolada

# %%
# Pobierz wartości czasu rozpoczęcia
start_times = {
    (product, machine, day): product_batch_start_time[product, machine, day].varValue
    for product in products for machine in machines for day in days
    if product_batch_start_time[product, machine, day].varValue is not None
}

# Oblicz czas zakończenia
end_times = {
    (product, machine, day): start_times[product, machine, day] + production_times[product][machine]
    for product, machine, day in start_times
}

# Wersja 1: Widok z perspektywy produktu
product_schedule = []
for product in products:
    for day in days:
        for machine in machines:
            if (product, machine, day) in start_times:
                start = start_times[(product, machine, day)]
                end = end_times[(product, machine, day)]
                product_schedule.append({
                    'Product': product,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

product_df = pd.DataFrame(product_schedule)
print("\nProduct Schedule:\n")
print(product_df.sort_values(['Day', 'Product', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania produktów na litery
product_mapping = {product: chr(65 + i) for i, product in enumerate(products)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for product in products:
        if (product, machine, day) in start_times:
            start = start_times[(product, machine, day)]
            end = end_times[(product, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = product_mapping[product]  # Wstaw literę dla produktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_product = timeline[i]
                    prev_duration = (
                        end_times[(products[ord(prev_product) - 65], machine, day)] -
                        start_times[(products[ord(prev_product) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = product_mapping[product]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
product_df.to_csv("product_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Produktów:")
for product, letter in product_mapping.items():
    print(f"{letter}: {product}")
# Out:
# Product Schedule:
#
#                  Product  Day    Machine  Start Time  End Time
# 48              Bagietki  Pon   Garownia        1.78      2.11
# 49              Bagietki  Pon       Piec       11.00     11.23
# 50              Bagietki  Pon  Studzenie       11.81     12.23
# 51              Bagietki  Pon  Pakowanie       20.00     20.00
# 36                 Bulki  Pon   Garownia        0.00      0.38
# ..                   ...  ...        ...         ...       ...
# 31     Chleb_na_zakwasie   Wt  Pakowanie       19.40     20.00
# 64  Rogaliki_z_czekolada   Wt   Garownia        0.00      0.25
# 65  Rogaliki_z_czekolada   Wt       Piec        9.07      9.25
# 66  Rogaliki_z_czekolada   Wt  Studzenie       15.51     16.33
# 67  Rogaliki_z_czekolada   Wt  Pakowanie       17.85     18.27
#
# [72 rows x 5 columns]
#
# Machine Usage Timeline:
#
#       Machine  Day  \
# 0    Garownia  Pon
# 1        Piec  Pon
# 2   Studzenie  Pon
# 3   Pakowanie  Pon
# 4    Garownia   Wt
# 5        Piec   Wt
# 6   Studzenie   Wt
# 7   Pakowanie   Wt
# 8    Garownia   Sr
# 9        Piec   Sr
# 10  Studzenie   Sr
# 11  Pakowanie   Sr
#
#                                                                                                 Timeline
# 0   DCCCCCCCEE______________________________FAAAAA_____________BBBBBBB__________________________________
# 1   _____________________________________________FAAAA___DDECCCCC_____BBBBBB____________________________
# 2   __________________________________________________AAAAAAAAAEECCCCCCCCCCCBBBBBBBBBBBBBFFFF________DDD
# 3   _________________________________________________________________________________________FFBBBCCCAAA
# 4   FBBBBBBBEE_____________CCCCCCCDAAAAA________________________________________________________________
# 5   ____________________________________AAAACCCCCFBBBBBBED______________________________________________
# 6   ______________________________________________________DDDAAAAAAAAACCCCCCCCCCCFFFFBBBBBBBBBBBBB___EEE
# 7   _________________________________________________________________________________________FFAAABBCCCC
# 8   EAAAAADD_____________________________BBBBBBBBCCCCCCC___________________________F____________________
# 9   _E________________________________________________DDCCCCC_____BBBBBB________AAAAF___________________
# 10  _________________________________________________________CCCCCCCCCCCBBBBBBBBBBBBBFFFFAAAAAAAAA_EEDDD
# 11  _________________________________________________________________________________________CCCFFAAABBB
#
# Legenda Produktów:
# A: Chleb_domowy_0_5kg
# B: Chleb_domowy_0_9kg
# C: Chleb_na_zakwasie
# D: Bulki
# E: Bagietki
# F: Rogaliki_z_czekolada
