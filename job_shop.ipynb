# %%
import pulp as pl
import numpy as np
# from scipy.stats import multivariate_t

print("==============================================================================")

# Define the problem
model = pl.LpProblem("Maximize_Profit", pl.LpMaximize)

# Products, machines and days
subproducts = ['Ciasto_na_chleb_domowy_0_5kg', 'Ciasto_na_chleb_domowy_0_9kg', 'Ciasto_na_chleb_na_zakwasie', 'Ciasto_na_bulki', 'Ciasto_na_bagietki', 'Ciasto_na_rogaliki_z_czekolada']
products = ['Chleb_domowy_0_5kg', 'Chleb_domowy_0_9kg', 'Chleb_na_zakwasie', 'Bulki', 'Bagietki', 'Rogaliki_z_czekolada']
days = ['Pon', 'Wt', 'Sr']
sub_machines = ['Dzieza', 'Wazenie', 'Dzielarka', 'Tabula', 'Rogalikarka', 'Nadziewarka']
machines = ['Garownia', 'Piec', 'Studzenie', 'Pakowanie']

# Income from product sales and production cost in PLN/piece
product_income = {'Chleb_domowy_0_5kg': 5.2, 'Chleb_domowy_0_9kg': 7.9, 'Chleb_na_zakwasie': 6.2, 'Bulki': 1.4, 'Bagietki': 1.55, 'Rogaliki_z_czekolada': 2.1}
sub_product_cost = {'Ciasto_na_chleb_domowy_0_5kg': 1.6, 'Ciasto_na_chleb_domowy_0_9kg': 2.0, 'Ciasto_na_chleb_na_zakwasie': 2.0, 'Ciasto_na_bulki': 0.5, 'Ciasto_na_bagietki': 0.6, 'Ciasto_na_rogaliki_z_czekolada': 1.0}
product_cost = {'Chleb_domowy_0_5kg': 0.8, 'Chleb_domowy_0_9kg': 0.9, 'Chleb_na_zakwasie': 0.8, 'Bulki': 0.2, 'Bagietki': 0.2, 'Rogaliki_z_czekolada': 0.2}

# Time available
shifts_per_day = 2
hours_per_shift = 10
hours_per_day = shifts_per_day * hours_per_shift

max_batches = 1
large_number = 10000

sub_production_times = {
    'Ciasto_na_chleb_domowy_0_5kg': {'Dzieza': 4.7, 'Wazenie': 0.29, 'Dzielarka': 0.0, 'Tabula': 0.7, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_domowy_0_9kg': {'Dzieza': 5, 'Wazenie': 0.2, 'Dzielarka': 0.0, 'Tabula': 0.55, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_na_zakwasie': {'Dzieza': 8.6, 'Wazenie': 0.22, 'Dzielarka': 0.0, 'Tabula': 0.6, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bulki': {'Dzieza': 1, 'Wazenie': 0.0, 'Dzielarka': 0.23, 'Tabula': 0.34, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bagietki': {'Dzieza': 0.95, 'Wazenie': 0.0, 'Dzielarka': 0.24, 'Tabula': 0.0, 'Rogalikarka': 0.28, 'Nadziewarka': 0.0},
    'Ciasto_na_rogaliki_z_czekolada': {'Dzieza': 0.55, 'Wazenie': 0.0, 'Dzielarka': 0.28, 'Tabula': 0.0, 'Rogalikarka': 0.31, 'Nadziewarka': 0.4}
}

production_times = {
    'Chleb_domowy_0_5kg': {'Garownia': 1.0, 'Piec': 0.68, 'Studzenie': 1.8, 'Pakowanie': 0.56},
    'Chleb_domowy_0_9kg': {'Garownia': 1.5, 'Piec': 1.2, 'Studzenie': 2.5, 'Pakowanie': 0.57},
    'Chleb_na_zakwasie': {'Garownia': 1.4, 'Piec': 1.0, 'Studzenie': 2.3, 'Pakowanie': 0.6},
    'Bulki': {'Garownia': 0.38, 'Piec': 0.25, 'Studzenie': 0.48, 'Pakowanie': 0.0},
    'Bagietki': {'Garownia': 0.33, 'Piec': 0.23, 'Studzenie': 0.42, 'Pakowanie': 0.0},
    'Rogaliki_z_czekolada': {'Garownia': 0.25, 'Piec': 0.18, 'Studzenie': 0.82, 'Pakowanie': 0.42}
}


batch_size = {
    "Ciasto_na_chleb_domowy_0_5kg": 240,
    "Ciasto_na_chleb_domowy_0_9kg": 130,
    "Ciasto_na_chleb_na_zakwasie": 200,
    "Ciasto_na_bulki": 200,
    "Ciasto_na_bagietki": 200,
    "Ciasto_na_rogaliki_z_czekolada": 200,
    "Chleb_domowy_0_5kg": 240,
    "Chleb_domowy_0_9kg": 130,
    "Chleb_na_zakwasie": 200,
    "Bulki": 200,
    "Bagietki": 200,
    "Rogaliki_z_czekolada": 200,
}

market_limits = {
    "Chleb_domowy_0_5kg": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 420, "Pt": 530, "Sob": 680},
    "Chleb_domowy_0_9kg": {"Pon": 100, "Wt": 100, "Sr": 380, "Czw": 150, "Pt": 250, "Sob": 580},
    "Chleb_na_zakwasie": {"Pon": 100, "Wt": 100, "Sr": 320, "Czw": 180, "Pt": 280, "Sob": 418},
    "Bulki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 530, "Pt": 650, "Sob": 580},
    "Bagietki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 350, "Pt": 650, "Sob": 680},
    "Rogaliki_z_czekolada": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 310, "Pt": 400, "Sob": 280},
}

# Machines cost
fridge_cost_per_day = 0.281 * 24 * 1.4 * 0.2 # kW * 24h * price per hour * factor
furnace_cost_per_hour = 82.4 # https://giko.pl/kalkulator-zuzycia-energii-dla-piecow-piekarniczych/


fridge_count = 10
fridge_capacity = 160
end_stock = 0
storage_capacity = fridge_count * fridge_capacity

# Variables for production, sales, and storage of products each day
sub_production_vars = pl.LpVariable.dicts("Subproduct production", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
production_vars = pl.LpVariable.dicts("Production", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# batch_count_vars = pl.LpVariable.dicts("Batches Count", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# subbatch_count_vars = pl.LpVariable.dicts("Subproduct Batches Count", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
product_batch_start_time = pl.LpVariable.dicts("ProductStartTime",  [(product, machine, day) for product in products for machine in machines for day in days], lowBound=0, cat="Continuous")
subproduct_batch_start_time = pl.LpVariable.dicts("Subproduction start time for batch",  [(subproduct, machine, day) for subproduct in subproducts for machine in sub_machines for day in days], lowBound=0, cat="Continuous")
sales_vars = pl.LpVariable.dicts("Sales", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, idx) for (machine, idx) in specific_machines], cat="Binary")
# subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, day, batch) for subproduct in subproducts for day in days for batch in range(1, max_batches + 1)], cat="Binary")
subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, day) for subproduct in subproducts for day in days], cat="Binary")
batch_produced = pl.LpVariable.dicts("BatchProduced", [(product, day) for product in products for day in days], cat="Binary")
specific_sub_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, subproduct, day) for machine in sub_machines for subproduct in subproducts for day in days], cat="Binary")
specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, product, day) for machine in machines for product in products for day in days], cat="Binary")
storage_vars = pl.LpVariable.dicts("Storage", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, upBound=storage_capacity, cat='Integer')
fridge_count_usage_vars = pl.LpVariable.dicts("FridgeCount", ((day) for day in days), lowBound=0, upBound=fridge_count, cat='Integer')


# xij = pl.LpVariable.dicts("xij", [(machine, idx, i, j) for (machine, idx) in specific_machines for i in subproducts for j in subproducts if i != j], 0, 1, pl.LpBinary)
is_produced_sub = pl.LpVariable.dicts("is_produced",
                                     ((subproduct, machine, day) for subproduct in subproducts
                                                                      for machine in sub_machines
                                                                      for day in days),
                                     cat="Binary")
is_produced = pl.LpVariable.dicts("is_produced",
                                     ((product, machine, day) for product in products
                                                                      for machine in machines
                                                                      for day in days),
                                     cat="Binary")

for subproduct in subproducts:
    for day in days:
        for i, machine in enumerate(sub_machines[1:], start=1):  # Od ważenia do nadziewarki
            prev = 1
            prev_machine = sub_machines[i - prev]

            while sub_production_times[subproduct][prev_machine] == 0.0 or prev_machine == machine:
                prev += 1
                prev_machine = sub_machines[i - prev]

            model += subproduct_batch_start_time[subproduct, machine, day] >= (
                subproduct_batch_start_time[subproduct, prev_machine, day] + sub_production_times[subproduct][prev_machine]
            )

            model += subproduct_batch_start_time[subproduct, machine, day] <= specific_sub_machine_used[machine, subproduct, day] * hours_per_day

        last_machine = sub_machines[-1]
        model += hours_per_day >= (
            subproduct_batch_start_time[subproduct, last_machine, day] + sub_production_times[subproduct][last_machine]
        )

for product in products:
    for day in days:
        for i, machine in enumerate(machines[1:], start=1):  # Od ważenia do nadziewarki
            prev = 1
            prev_machine = machines[i - prev]

            while production_times[product][prev_machine] == 0.0 or prev_machine == machine:
                prev += 1
                prev_machine = machines[i - prev]

            model += product_batch_start_time[product, machine, day] >= (
                product_batch_start_time[product, prev_machine, day] + production_times[product][prev_machine]
            )

            model += product_batch_start_time[product, machine, day] <= specific_machine_used[machine, product, day] * hours_per_day

        last_machine = machines[-1]
        model += hours_per_day >= (
            product_batch_start_time[product, last_machine, day] + production_times[product][last_machine]
        )
'''
        model += subbatch_produced[subproduct, day] * large_number >= subproduct_batch_start_time[subproduct, last_machine, last_idx, day]

        # Brak nakładania się produkcji na maszynie
        for machine, idx in specific_machines[:6]:  # Zakres maszyn
            for subproduct1 in subproducts:
                for subproduct2 in subproducts:
                    if subproduct1 != subproduct2:
                        model += (subproduct_batch_start_time[subproduct1, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct2, machine, idx, day] + production_times[subproduct2][machine]) | \
                                 (subproduct_batch_start_time[subproduct2, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct1, machine, idx, day] + production_times[subproduct1][machine])

                        # model += specific_machine_used[machine, idx, subproduct1, day] + specific_machine_used[machine, idx, subproduct2, day] <= 1
'''
# Ograniczenie: produkcja subproduktu tylko na maszynach, gdzie czas produkcji > 0
for subproduct in subproducts:
    for machine in sub_machines:
        for day in days:
            if sub_production_times[subproduct][machine] == 0:
                model += is_produced_sub[subproduct, machine, day] == 0

# Ograniczenie: produkcja produktu tylko na maszynach, gdzie czas produkcji > 0
for product in products:
    for machine in machines:
        for day in days:
            if production_times[product][machine] == 0:
                model += is_produced[product, machine, day] == 0
                

# Warunek: jeśli subprodukt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for subproduct in subproducts:
    machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for machine in machines_with_production:
                    model += pl.lpSum(is_produced_sub[subproduct, m, day] for m in machines_with_production) == \
                            len(machines_with_production) * is_produced_sub[subproduct, machine, day]
        
        # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
        model += subbatch_produced[subproduct, day] <= pl.lpSum(is_produced_sub[subproduct, machine, day] for machine in machines_with_production)

# Warunek: jeśli produkt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for product in products:
    machines_with_production = [machine for machine in machines if production_times[product][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for machine in machines_with_production:
                    model += pl.lpSum(is_produced[product, m, day] for m in machines_with_production) == \
                            len(machines_with_production) * is_produced[product, machine, day]
        
        # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
        model += batch_produced[product, day] <= pl.lpSum(is_produced[product, machine, day] for machine in machines_with_production)

# Aktualizacja ograniczenia: brak nakładania się produkcji
big_M = 1000000
for subproduct1 in subproducts:
    for subproduct2 in subproducts:
        if subproduct1 != subproduct2:
            machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct1][machine] > 0 and sub_production_times[subproduct2][machine] > 0]
            for machine in machines_with_production: 
                for day in days:
                    # Dodanie binarnych zmiennych pomocniczych
                    y1 = pl.LpVariable(f"y1_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y2 = pl.LpVariable(f"y2_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y3 = pl.LpVariable(f"y3_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y4 = pl.LpVariable(f"y4_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")

                    # Powiązanie warunków logicznych z binarnymi zmiennymi
                    model += subproduct_batch_start_time[subproduct1, machine, day] >= \
                                subproduct_batch_start_time[subproduct2, machine, day] + sub_production_times[subproduct2][machine] - \
                                big_M * (1 - y1)
                    
                    model += subproduct_batch_start_time[subproduct2, machine, day] >= \
                                subproduct_batch_start_time[subproduct1, machine, day] + sub_production_times[subproduct1][machine] - \
                                big_M * (1 - y2)

                    model += is_produced_sub[subproduct1, machine, day] + y3 == 1
                    model += is_produced_sub[subproduct2, machine, day] + y4 == 1

                    # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                    model += y1 + y2 + y3 + y4 == 1

for product1 in products:
    for product2 in products:
        if product1 != product2:
            machines_with_production = [machine for machine in machines if production_times[product1][machine] > 0 and production_times[product2][machine] > 0]
            for machine in machines_with_production: 
                for day in days:
                    # Dodanie binarnych zmiennych pomocniczych
                    y1 = pl.LpVariable(f"y1_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y2 = pl.LpVariable(f"y2_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y3 = pl.LpVariable(f"y3_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y4 = pl.LpVariable(f"y4_{product1}_{product2}_{machine}_{day}", cat="Binary")

                    # Powiązanie warunków logicznych z binarnymi zmiennymi
                    model += product_batch_start_time[product1, machine, day] >= \
                                product_batch_start_time[product2, machine, day] + production_times[product2][machine] - \
                                big_M * (1 - y1)
                    
                    model += product_batch_start_time[product2, machine, day] >= \
                                product_batch_start_time[product1, machine, day] + production_times[product1][machine] - \
                                big_M * (1 - y2)

                    model += is_produced[product1, machine, day] + y3 == 1
                    model += is_produced[product2, machine, day] + y4 == 1

                    # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                    model += y1 + y2 + y3 + y4 == 1


for subproduct, product in zip(subproducts, products):
    model += storage_vars[subproduct, 'Pon'] == sub_production_vars[subproduct, 'Pon'] - production_vars[product, 'Pon']
    for i in range(1, len(days)):
        day = days[i]
        prev_day = days[i-1]
        model += storage_vars[subproduct, day] == storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day]

for day in days:
    model += storage_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)
    model += fridge_count_usage_vars[day] * fridge_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)

for product, subproduct in zip(products, subproducts):
    for day in days:
        model += batch_produced[product, day] * batch_size[product] >= production_vars[product, day]
        model += subbatch_produced[subproduct, day] * batch_size[subproduct] >= sub_production_vars[subproduct, day]
        # model += sub_production_vars[subproduct, day] >= production_vars[product, day]
        model += sales_vars[product, day] == production_vars[product, day]
    model += sales_vars[product, 'Sr'] >= 0.01*market_limits[product]['Wt'], f"Max_sales_{product}_{'Sr'}"


# Objective function: Maximize profit from sales minus costs
model += pl.lpSum([sales_vars[product, day] * product_income[product] for product in products for day in days]) \
                    - pl.lpSum([production_vars[product, day] * product_cost[product] for product in products for day in days]) \
                    - pl.lpSum([sub_production_vars[subproduct, day] * sub_product_cost[subproduct] for subproduct in subproducts for day in days])


solver = pl.PULP_CBC_CMD(timeLimit=600)

model.solve(solver)

# model.solve()

# Results
print("Status:", pl.LpStatus[model.status])
if pl.LpStatus[model.status] == 'Optimal':
    print("Total Profit:", pl.value(model.objective))

    print(f"{'Product':<10} {'day':<10} {'SubProduction':<10} {'Production':<12} {'Sales':<10} {'Storage':<10}")

    for product, subproduct in zip(products, subproducts):
        for day in days:
            subproduction = sub_production_vars[subproduct, day].varValue
            production = production_vars[product, day].varValue
            sales = sales_vars[product, day].varValue
            storage = storage_vars[subproduct, day].varValue

            print(f"{product:<10} {day:<10} {subproduction:<12} {production:<12} {sales:<10} {storage:<10}")

    # print("\nProduction Time Usage per Product and Day:")
    # for day in days:
    #     print(f"\Day: {day}")
    #     for product in products:
    #         total_production_time = sum(
    #             batch_count_vars[product, day].varValue * production_times[product]s.get(machine, 0) 
    #             for machine in machines #.keys()
    #         )
    #         print(f"  Product: {product}, Total Production Time: {total_production_time:.2f} hours")

else:
    print("No optimal solution was found.")
    # Analiza ograniczeń
    for name, constraint in model.constraints.items():
        if constraint.pi < 0:
            print(f"Ograniczenie {name}: {constraint}")
# Out:
# ==============================================================================
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gromiusz/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1c95c53dc7cf45e98a93188e4839f9ce-pulp.mps -max -sec 600 -timeMode elapsed -branch -printingOptions all -solution /tmp/1c95c53dc7cf45e98a93188e4839f9ce-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2999 COLUMNS
# At line 15828 RHS
# At line 18823 BOUNDS
# At line 21155 ENDATA
# Problem MODEL has 2994 rows, 2511 columns and 8112 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 600
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7416 - 0.01 seconds
# Cgl0002I 57 variables fixed
# Cgl0003I 22 fixed, 0 tightened bounds, 984 strengthened rows, 276 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 759 strengthened rows, 108 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 803 strengthened rows, 6 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 36 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 11 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1453 rows, 1056 columns (936 integer (888 of which binary)) and 6893 elements
# Cbc0038I Initial state - 410 integers unsatisfied sum - 71.5628
# Cbc0038I Pass   1: suminf.   38.70702 (576) obj. -7310.29 iterations 385
# Cbc0038I Pass   2: suminf.   34.99605 (579) obj. -7310.29 iterations 30
# Cbc0038I Pass   3: suminf.   33.43019 (572) obj. -7310.29 iterations 24
# Cbc0038I Pass   4: suminf.   32.77473 (570) obj. -7310.29 iterations 5
# Cbc0038I Pass   5: suminf.   24.27413 (517) obj. -7310.29 iterations 90
# Cbc0038I Pass   6: suminf.   24.21350 (511) obj. -7310.29 iterations 17
# Cbc0038I Pass   7: suminf.   21.73764 (489) obj. -7323.95 iterations 81
# Cbc0038I Pass   8: suminf.   22.25561 (508) obj. -7313.91 iterations 50
# Cbc0038I Pass   9: suminf.   18.21094 (445) obj. -7373.28 iterations 84
# Cbc0038I Pass  10: suminf.   17.23093 (425) obj. -7376.98 iterations 14
# Cbc0038I Pass  11: suminf.   14.06699 (362) obj. -7402.26 iterations 98
# Cbc0038I Pass  12: suminf.   14.05777 (364) obj. -7402.26 iterations 11
# Cbc0038I Pass  13: suminf.   10.21851 (258) obj. -7416 iterations 93
# Cbc0038I Pass  14: suminf.    7.75473 (216) obj. -7416 iterations 96
# Cbc0038I Pass  15: suminf.    6.32795 (186) obj. -7416 iterations 44
# Cbc0038I Pass  16: suminf.    6.32795 (186) obj. -7416 iterations 0
# Cbc0038I Pass  17: suminf.    5.30631 (171) obj. -7416 iterations 57
# Cbc0038I Pass  18: suminf.    5.30631 (171) obj. -7416 iterations 0
# Cbc0038I Pass  19: suminf.    4.36723 (153) obj. -7416 iterations 43
# Cbc0038I Pass  20: suminf.    4.36366 (152) obj. -7416 iterations 8
# Cbc0038I Pass  21: suminf.    3.62742 (116) obj. -7416 iterations 42
# Cbc0038I Pass  22: suminf.    3.60976 (118) obj. -7416 iterations 7
# Cbc0038I Pass  23: suminf.    3.17210 (97) obj. -7416 iterations 38
# Cbc0038I Pass  24: suminf.    3.17210 (97) obj. -7416 iterations 0
# Cbc0038I Pass  25: suminf.    2.53087 (68) obj. -7416 iterations 66
# Cbc0038I Pass  26: suminf.    2.43450 (64) obj. -7416 iterations 1
# Cbc0038I Pass  27: suminf.    2.28819 (58) obj. -7416 iterations 34
# Cbc0038I Pass  28: suminf.    1.80983 (45) obj. -7416 iterations 62
# Cbc0038I Pass  29: suminf.    1.27829 (21) obj. -7416 iterations 92
# Cbc0038I Pass  30: suminf.    1.03365 (15) obj. -7416 iterations 54
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 257 integers at bound fixed and 2 continuous
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 1097 rows 599 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.27 seconds)
# Cbc0038I After 0.27 seconds - Feasibility pump exiting - took 0.14 seconds
# Cbc0031I 152 added rows had average density of 12.894737
# Cbc0013I At root node, 152 cuts changed objective from -7416 to -7416 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 260 row cuts average 2.2 elements, 0 column cuts (64 active)  in 0.057 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 402 row cuts average 26.8 elements, 0 column cuts (0 active)  in 0.019 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 5 row cuts average 6.6 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 188 row cuts average 2.8 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 954 row cuts average 27.2 elements, 0 column cuts (0 active)  in 0.041 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 13 row cuts average 6.3 elements, 0 column cuts (0 active)  in 0.027 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible -7416 (0.80 seconds)
# Cbc0010I After 1000 nodes, 132 on tree, 1e+50 best solution, best possible -7416 (5.95 seconds)
# Cbc0010I After 2000 nodes, 169 on tree, 1e+50 best solution, best possible -7416 (8.90 seconds)
# Cbc0010I After 3000 nodes, 171 on tree, 1e+50 best solution, best possible -7416 (11.61 seconds)
# Cbc0010I After 4000 nodes, 169 on tree, 1e+50 best solution, best possible -7416 (13.97 seconds)
# Cbc0010I After 5000 nodes, 163 on tree, 1e+50 best solution, best possible -7416 (19.38 seconds)
# Cbc0010I After 6000 nodes, 202 on tree, 1e+50 best solution, best possible -7416 (22.23 seconds)
# Cbc0010I After 7000 nodes, 203 on tree, 1e+50 best solution, best possible -7416 (25.00 seconds)
# Cbc0010I After 8000 nodes, 199 on tree, 1e+50 best solution, best possible -7416 (28.00 seconds)
# Cbc0010I After 9000 nodes, 202 on tree, 1e+50 best solution, best possible -7416 (30.99 seconds)
# Cbc0010I After 10000 nodes, 222 on tree, 1e+50 best solution, best possible -7416 (33.78 seconds)
# Cbc0010I After 11000 nodes, 225 on tree, 1e+50 best solution, best possible -7416 (36.49 seconds)
# Cbc0010I After 12000 nodes, 563 on tree, 1e+50 best solution, best possible -7416 (40.04 seconds)
# Cbc0010I After 13000 nodes, 982 on tree, 1e+50 best solution, best possible -7416 (43.44 seconds)
# Cbc0010I After 14000 nodes, 985 on tree, 1e+50 best solution, best possible -7416 (48.49 seconds)
# Cbc0010I After 15000 nodes, 968 on tree, 1e+50 best solution, best possible -7416 (54.63 seconds)
# Cbc0010I After 16000 nodes, 967 on tree, 1e+50 best solution, best possible -7416 (58.73 seconds)
# Cbc0010I After 17000 nodes, 962 on tree, 1e+50 best solution, best possible -7416 (62.20 seconds)
# Cbc0010I After 18000 nodes, 957 on tree, 1e+50 best solution, best possible -7416 (65.16 seconds)
# Cbc0010I After 19000 nodes, 953 on tree, 1e+50 best solution, best possible -7416 (68.17 seconds)
# Cbc0010I After 20000 nodes, 954 on tree, 1e+50 best solution, best possible -7416 (70.77 seconds)
# Cbc0010I After 21000 nodes, 955 on tree, 1e+50 best solution, best possible -7416 (73.33 seconds)
# Cbc0010I After 22000 nodes, 950 on tree, 1e+50 best solution, best possible -7416 (76.37 seconds)
# Cbc0010I After 23000 nodes, 940 on tree, 1e+50 best solution, best possible -7416 (79.28 seconds)
# Cbc0010I After 24000 nodes, 913 on tree, 1e+50 best solution, best possible -7416 (83.37 seconds)
# Cbc0010I After 25000 nodes, 885 on tree, 1e+50 best solution, best possible -7416 (90.29 seconds)
# Cbc0010I After 26000 nodes, 851 on tree, 1e+50 best solution, best possible -7416 (94.47 seconds)
# Cbc0010I After 27000 nodes, 829 on tree, 1e+50 best solution, best possible -7416 (98.32 seconds)
# Cbc0010I After 28000 nodes, 797 on tree, 1e+50 best solution, best possible -7416 (102.44 seconds)
# Cbc0010I After 29000 nodes, 796 on tree, 1e+50 best solution, best possible -7416 (107.01 seconds)
# Cbc0010I After 30000 nodes, 802 on tree, 1e+50 best solution, best possible -7416 (111.57 seconds)
# Cbc0010I After 31000 nodes, 805 on tree, 1e+50 best solution, best possible -7416 (115.83 seconds)
# Cbc0010I After 32000 nodes, 814 on tree, 1e+50 best solution, best possible -7416 (119.75 seconds)
# Cbc0010I After 33000 nodes, 808 on tree, 1e+50 best solution, best possible -7416 (126.58 seconds)
# Cbc0010I After 34000 nodes, 817 on tree, 1e+50 best solution, best possible -7416 (130.58 seconds)
# Cbc0010I After 35000 nodes, 816 on tree, 1e+50 best solution, best possible -7416 (134.58 seconds)
# Cbc0010I After 36000 nodes, 819 on tree, 1e+50 best solution, best possible -7416 (138.81 seconds)
# Cbc0010I After 37000 nodes, 813 on tree, 1e+50 best solution, best possible -7416 (142.92 seconds)
# Cbc0010I After 38000 nodes, 806 on tree, 1e+50 best solution, best possible -7416 (146.88 seconds)
# Cbc0010I After 39000 nodes, 812 on tree, 1e+50 best solution, best possible -7416 (150.69 seconds)
# Cbc0010I After 40000 nodes, 810 on tree, 1e+50 best solution, best possible -7416 (155.35 seconds)
# Cbc0010I After 41000 nodes, 805 on tree, 1e+50 best solution, best possible -7416 (162.54 seconds)
# Cbc0010I After 42000 nodes, 802 on tree, 1e+50 best solution, best possible -7416 (167.00 seconds)
# Cbc0010I After 43000 nodes, 799 on tree, 1e+50 best solution, best possible -7416 (171.44 seconds)
# Cbc0010I After 44000 nodes, 797 on tree, 1e+50 best solution, best possible -7416 (176.09 seconds)
# Cbc0010I After 45000 nodes, 797 on tree, 1e+50 best solution, best possible -7416 (180.27 seconds)
# Cbc0010I After 46000 nodes, 813 on tree, 1e+50 best solution, best possible -7416 (184.34 seconds)
# Cbc0010I After 47000 nodes, 803 on tree, 1e+50 best solution, best possible -7416 (188.36 seconds)
# Cbc0010I After 48000 nodes, 819 on tree, 1e+50 best solution, best possible -7416 (195.15 seconds)
# Cbc0010I After 49000 nodes, 820 on tree, 1e+50 best solution, best possible -7416 (199.27 seconds)
# Cbc0010I After 50000 nodes, 809 on tree, 1e+50 best solution, best possible -7416 (203.73 seconds)
# Cbc0010I After 51000 nodes, 808 on tree, 1e+50 best solution, best possible -7416 (208.06 seconds)
# Cbc0010I After 52000 nodes, 807 on tree, 1e+50 best solution, best possible -7416 (212.50 seconds)
# Cbc0010I After 53000 nodes, 807 on tree, 1e+50 best solution, best possible -7416 (216.70 seconds)
# Cbc0010I After 54000 nodes, 809 on tree, 1e+50 best solution, best possible -7416 (220.76 seconds)
# Cbc0010I After 55000 nodes, 816 on tree, 1e+50 best solution, best possible -7416 (224.77 seconds)
# Cbc0010I After 56000 nodes, 821 on tree, 1e+50 best solution, best possible -7416 (230.88 seconds)
# Cbc0010I After 57000 nodes, 816 on tree, 1e+50 best solution, best possible -7416 (234.14 seconds)
# Cbc0010I After 58000 nodes, 821 on tree, 1e+50 best solution, best possible -7416 (238.42 seconds)
# Cbc0010I After 59000 nodes, 820 on tree, 1e+50 best solution, best possible -7416 (241.57 seconds)
# Cbc0010I After 60000 nodes, 819 on tree, 1e+50 best solution, best possible -7416 (244.88 seconds)
# Cbc0010I After 61000 nodes, 820 on tree, 1e+50 best solution, best possible -7416 (248.50 seconds)
# Cbc0010I After 62000 nodes, 822 on tree, 1e+50 best solution, best possible -7416 (251.30 seconds)
# Cbc0010I After 63000 nodes, 816 on tree, 1e+50 best solution, best possible -7416 (254.46 seconds)
# Cbc0010I After 64000 nodes, 821 on tree, 1e+50 best solution, best possible -7416 (257.42 seconds)
# Cbc0010I After 65000 nodes, 819 on tree, 1e+50 best solution, best possible -7416 (260.58 seconds)
# Cbc0010I After 66000 nodes, 818 on tree, 1e+50 best solution, best possible -7416 (266.77 seconds)
# Cbc0010I After 67000 nodes, 817 on tree, 1e+50 best solution, best possible -7416 (269.73 seconds)
# Cbc0010I After 68000 nodes, 813 on tree, 1e+50 best solution, best possible -7416 (272.71 seconds)
# Cbc0010I After 69000 nodes, 820 on tree, 1e+50 best solution, best possible -7416 (275.44 seconds)
# Cbc0010I After 70000 nodes, 816 on tree, 1e+50 best solution, best possible -7416 (278.41 seconds)
# Cbc0010I After 71000 nodes, 822 on tree, 1e+50 best solution, best possible -7416 (281.21 seconds)
# Cbc0010I After 72000 nodes, 817 on tree, 1e+50 best solution, best possible -7416 (283.85 seconds)
# Cbc0010I After 73000 nodes, 824 on tree, 1e+50 best solution, best possible -7416 (286.70 seconds)
# Cbc0010I After 74000 nodes, 819 on tree, 1e+50 best solution, best possible -7416 (289.52 seconds)
# Cbc0010I After 75000 nodes, 816 on tree, 1e+50 best solution, best possible -7416 (292.18 seconds)
# Cbc0010I After 76000 nodes, 810 on tree, 1e+50 best solution, best possible -7416 (294.69 seconds)
# Cbc0010I After 77000 nodes, 817 on tree, 1e+50 best solution, best possible -7416 (300.20 seconds)
# Cbc0010I After 78000 nodes, 838 on tree, 1e+50 best solution, best possible -7416 (304.21 seconds)
# Cbc0010I After 79000 nodes, 832 on tree, 1e+50 best solution, best possible -7416 (308.41 seconds)
# Cbc0010I After 80000 nodes, 830 on tree, 1e+50 best solution, best possible -7416 (312.77 seconds)
# Cbc0010I After 81000 nodes, 834 on tree, 1e+50 best solution, best possible -7416 (317.13 seconds)
# Cbc0010I After 82000 nodes, 864 on tree, 1e+50 best solution, best possible -7416 (320.77 seconds)
# Cbc0010I After 83000 nodes, 868 on tree, 1e+50 best solution, best possible -7416 (324.39 seconds)
# Cbc0010I After 84000 nodes, 856 on tree, 1e+50 best solution, best possible -7416 (327.88 seconds)
# Cbc0010I After 85000 nodes, 864 on tree, 1e+50 best solution, best possible -7416 (331.30 seconds)
# Cbc0010I After 86000 nodes, 849 on tree, 1e+50 best solution, best possible -7416 (337.57 seconds)
# Cbc0010I After 87000 nodes, 846 on tree, 1e+50 best solution, best possible -7416 (340.93 seconds)
# Cbc0010I After 88000 nodes, 843 on tree, 1e+50 best solution, best possible -7416 (343.67 seconds)
# Cbc0010I After 89000 nodes, 844 on tree, 1e+50 best solution, best possible -7416 (346.92 seconds)
# Cbc0012I Integer solution of -5414 found by rounding after 1463211 iterations and 89317 nodes (347.99 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 282 rows 136 columns
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 332 rows 156 columns
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 393 rows 184 columns
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 282 rows 129 columns
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 297 rows 138 columns
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 376 rows 177 columns
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 332 rows 149 columns
# Cbc0010I After 90000 nodes, 1072 on tree, -5414 best solution, best possible -7416 (349.64 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 356 rows 161 columns
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 371 rows 170 columns
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 329 rows 164 columns
# Cbc0010I After 91000 nodes, 1382 on tree, -5414 best solution, best possible -7416 (353.03 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 304 rows 146 columns
# Cbc0010I After 92000 nodes, 1700 on tree, -5414 best solution, best possible -7416 (356.08 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 331 rows 159 columns
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 391 rows 181 columns
# Cbc0010I After 93000 nodes, 1930 on tree, -5414 best solution, best possible -7416 (359.19 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 270 rows 121 columns
# Cbc0010I After 94000 nodes, 1963 on tree, -5414 best solution, best possible -7416 (362.10 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 369 rows 172 columns
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 327 rows 156 columns
# Cbc0010I After 95000 nodes, 2200 on tree, -5414 best solution, best possible -7416 (364.99 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 316 rows 151 columns
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 357 rows 166 columns
# Cbc0010I After 96000 nodes, 2420 on tree, -5414 best solution, best possible -7416 (370.86 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 395 rows 184 columns
# Cbc0010I After 97000 nodes, 2644 on tree, -5414 best solution, best possible -7416 (373.96 seconds)
# Cbc0010I After 98000 nodes, 2639 on tree, -5414 best solution, best possible -7416 (376.78 seconds)
# Cbc0010I After 99000 nodes, 2893 on tree, -5414 best solution, best possible -7416 (379.55 seconds)
# Cbc0010I After 100000 nodes, 3100 on tree, -5414 best solution, best possible -7416 (382.62 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 301 rows 141 columns
# Cbc0010I After 101000 nodes, 3378 on tree, -5414 best solution, best possible -7416 (385.25 seconds)
# Cbc0010I After 102000 nodes, 3621 on tree, -5414 best solution, best possible -7416 (387.58 seconds)
# Cbc0010I After 103000 nodes, 3908 on tree, -5414 best solution, best possible -7416 (390.31 seconds)
# Cbc0010I After 104000 nodes, 4129 on tree, -5414 best solution, best possible -7416 (392.94 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 318 rows 144 columns
# Cbc0010I After 105000 nodes, 4350 on tree, -5414 best solution, best possible -7416 (396.08 seconds)
# Cbc0010I After 106000 nodes, 4620 on tree, -5414 best solution, best possible -7416 (398.71 seconds)
# Cbc0010I After 107000 nodes, 4876 on tree, -5414 best solution, best possible -7416 (402.08 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 295 rows 144 columns
# Cbc0010I After 108000 nodes, 5171 on tree, -5414 best solution, best possible -7416 (408.25 seconds)
# Cbc0010I After 109000 nodes, 5389 on tree, -5414 best solution, best possible -7416 (411.36 seconds)
# Cbc0010I After 110000 nodes, 5533 on tree, -5414 best solution, best possible -7416 (413.90 seconds)
# Cbc0010I After 111000 nodes, 5699 on tree, -5414 best solution, best possible -7416 (417.32 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 385 rows 183 columns
# Cbc0010I After 112000 nodes, 6027 on tree, -5414 best solution, best possible -7416 (420.83 seconds)
# Cbc0010I After 113000 nodes, 6264 on tree, -5414 best solution, best possible -7416 (423.59 seconds)
# Cbc0010I After 114000 nodes, 6520 on tree, -5414 best solution, best possible -7416 (426.16 seconds)
# Cbc0010I After 115000 nodes, 6785 on tree, -5414 best solution, best possible -7416 (429.23 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 314 rows 150 columns
# Cbc0010I After 116000 nodes, 7049 on tree, -5414 best solution, best possible -7416 (432.33 seconds)
# Cbc0010I After 117000 nodes, 7222 on tree, -5414 best solution, best possible -7416 (435.44 seconds)
# Cbc0010I After 118000 nodes, 7455 on tree, -5414 best solution, best possible -7416 (438.10 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 367 rows 175 columns
# Cbc0010I After 119000 nodes, 7718 on tree, -5414 best solution, best possible -7416 (443.36 seconds)
# Cbc0010I After 120000 nodes, 8032 on tree, -5414 best solution, best possible -7416 (446.12 seconds)
# Cbc0010I After 121000 nodes, 8254 on tree, -5414 best solution, best possible -7416 (449.25 seconds)
# Cbc0010I After 122000 nodes, 8458 on tree, -5414 best solution, best possible -7416 (451.65 seconds)
# Cbc0010I After 123000 nodes, 8659 on tree, -5414 best solution, best possible -7416 (454.43 seconds)
# Cbc0010I After 124000 nodes, 8904 on tree, -5414 best solution, best possible -7416 (457.36 seconds)
# Cbc0010I After 125000 nodes, 9268 on tree, -5414 best solution, best possible -7416 (460.47 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 323 rows 145 columns
# Cbc0010I After 126000 nodes, 9509 on tree, -5414 best solution, best possible -7416 (462.64 seconds)
# Cbc0010I After 127000 nodes, 9703 on tree, -5414 best solution, best possible -7416 (465.26 seconds)
# Cbc0010I After 128000 nodes, 9861 on tree, -5414 best solution, best possible -7416 (468.05 seconds)
# Cbc0010I After 129000 nodes, 10121 on tree, -5414 best solution, best possible -7416 (470.93 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 313 rows 155 columns
# Cbc0010I After 130000 nodes, 10357 on tree, -5414 best solution, best possible -7416 (477.26 seconds)
# Cbc0010I After 131000 nodes, 10606 on tree, -5414 best solution, best possible -7416 (480.08 seconds)
# Cbc0010I After 132000 nodes, 10841 on tree, -5414 best solution, best possible -7416 (482.73 seconds)
# Cbc0010I After 133000 nodes, 11066 on tree, -5414 best solution, best possible -7416 (486.03 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 362 rows 163 columns
# Cbc0010I After 134000 nodes, 11375 on tree, -5414 best solution, best possible -7416 (489.11 seconds)
# Cbc0010I After 135000 nodes, 11659 on tree, -5414 best solution, best possible -7416 (491.56 seconds)
# Cbc0010I After 136000 nodes, 11877 on tree, -5414 best solution, best possible -7416 (494.01 seconds)
# Cbc0010I After 137000 nodes, 12038 on tree, -5414 best solution, best possible -7416 (497.38 seconds)
# Cbc0010I After 138000 nodes, 12265 on tree, -5414 best solution, best possible -7416 (500.05 seconds)
# Cbc0010I After 139000 nodes, 12516 on tree, -5414 best solution, best possible -7416 (502.41 seconds)
# Cbc0010I After 140000 nodes, 12747 on tree, -5414 best solution, best possible -7416 (504.89 seconds)
# Cbc0004I Integer solution of -5444 found after 2521266 iterations and 140159 nodes (505.55 seconds)
# Cbc0038I Full problem 1453 rows 1056 columns, reduced to 363 rows 174 columns
# Cbc0010I After 141000 nodes, 12967 on tree, -5444 best solution, best possible -7416 (507.91 seconds)
# Cbc0010I After 142000 nodes, 13048 on tree, -5444 best solution, best possible -7416 (512.48 seconds)
# Cbc0010I After 143000 nodes, 13251 on tree, -5444 best solution, best possible -7416 (514.80 seconds)
# Cbc0010I After 144000 nodes, 13490 on tree, -5444 best solution, best possible -7416 (517.26 seconds)
# Cbc0010I After 145000 nodes, 13551 on tree, -5444 best solution, best possible -7416 (521.24 seconds)
# Cbc0010I After 146000 nodes, 13741 on tree, -5444 best solution, best possible -7416 (523.85 seconds)
# Cbc0010I After 147000 nodes, 13927 on tree, -5444 best solution, best possible -7416 (526.20 seconds)
# Cbc0010I After 148000 nodes, 14263 on tree, -5444 best solution, best possible -7416 (528.96 seconds)
# Cbc0010I After 149000 nodes, 14436 on tree, -5444 best solution, best possible -7416 (532.45 seconds)
# Cbc0010I After 150000 nodes, 14623 on tree, -5444 best solution, best possible -7416 (535.10 seconds)
# Cbc0010I After 151000 nodes, 14764 on tree, -5444 best solution, best possible -7416 (538.06 seconds)
# Cbc0010I After 152000 nodes, 14867 on tree, -5444 best solution, best possible -7416 (540.64 seconds)
# Cbc0010I After 153000 nodes, 15008 on tree, -5444 best solution, best possible -7416 (547.18 seconds)
# Cbc0010I After 154000 nodes, 15284 on tree, -5444 best solution, best possible -7416 (550.36 seconds)
# Cbc0010I After 155000 nodes, 15510 on tree, -5444 best solution, best possible -7416 (553.67 seconds)
# Cbc0010I After 156000 nodes, 15719 on tree, -5444 best solution, best possible -7416 (556.69 seconds)
# Cbc0010I After 157000 nodes, 15872 on tree, -5444 best solution, best possible -7416 (559.82 seconds)
# Cbc0010I After 158000 nodes, 16119 on tree, -5444 best solution, best possible -7416 (563.00 seconds)
# Cbc0010I After 159000 nodes, 16352 on tree, -5444 best solution, best possible -7416 (565.74 seconds)
# Cbc0010I After 160000 nodes, 16540 on tree, -5444 best solution, best possible -7416 (568.70 seconds)
# Cbc0010I After 161000 nodes, 16731 on tree, -5444 best solution, best possible -7416 (572.19 seconds)
# Cbc0010I After 162000 nodes, 16848 on tree, -5444 best solution, best possible -7416 (575.14 seconds)
# Cbc0010I After 163000 nodes, 17024 on tree, -5444 best solution, best possible -7416 (577.86 seconds)
# Cbc0010I After 164000 nodes, 17211 on tree, -5444 best solution, best possible -7416 (582.42 seconds)
# Cbc0010I After 165000 nodes, 17341 on tree, -5444 best solution, best possible -7416 (586.02 seconds)
# Cbc0010I After 166000 nodes, 17549 on tree, -5444 best solution, best possible -7416 (589.20 seconds)
# Cbc0010I After 167000 nodes, 17754 on tree, -5444 best solution, best possible -7416 (592.03 seconds)
# Cbc0010I After 168000 nodes, 17934 on tree, -5444 best solution, best possible -7416 (594.95 seconds)
# Cbc0010I After 169000 nodes, 17944 on tree, -5444 best solution, best possible -7416 (597.81 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective -5444 (best possible -7416), took 3093506 iterations and 169639 nodes (600.09 seconds)
# Cbc0032I Strong branching done 386962 times (2475937 iterations), fathomed 22765 nodes and fixed 62179 variables
# Cbc0035I Maximum depth 70, 4011 variables fixed on reduced cost
# Cuts at root node changed objective from -7416 to -7416
# Probing was tried 10 times and created 260 cuts of which 64 were active after adding rounds of cuts (0.057 seconds)
# Gomory was tried 10 times and created 402 cuts of which 0 were active after adding rounds of cuts (0.019 seconds)
# Knapsack was tried 10 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 10 times and created 188 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# FlowCover was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# TwoMirCuts was tried 10 times and created 954 cuts of which 0 were active after adding rounds of cuts (0.041 seconds)
# ZeroHalf was tried 10 times and created 13 cuts of which 0 were active after adding rounds of cuts (0.027 seconds)
# ImplicationCuts was tried 165 times and created 66 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                5444.00000000
# Upper bound:                    7416.000
# Gap:                            -0.27
# Enumerated nodes:               169639
# Total iterations:               3093506
# Time (CPU seconds):             577.29
# Time (Wallclock seconds):       600.12
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       577.30   (Wallclock seconds):       600.13
#
# Status: Optimal
# Total Profit: 5444.0
# Product    day        SubProduction Production   Sales      Storage
# Chleb_domowy_0_5kg Pon        240.0        240.0        240.0      0.0
# Chleb_domowy_0_5kg Wt         0.0          0.0          0.0        0.0
# Chleb_domowy_0_5kg Sr         240.0        240.0        240.0      0.0
# Chleb_domowy_0_9kg Pon        0.0          0.0          0.0        0.0
# Chleb_domowy_0_9kg Wt         130.0        0.0          0.0        130.0
# Chleb_domowy_0_9kg Sr         0.0          130.0        130.0      0.0
# Chleb_na_zakwasie Pon        200.0        200.0        200.0      0.0
# Chleb_na_zakwasie Wt         200.0        200.0        200.0      0.0
# Chleb_na_zakwasie Sr         200.0        200.0        200.0      0.0
# Bulki      Pon        200.0        200.0        200.0      0.0
# Bulki      Wt         200.0        200.0        200.0      0.0
# Bulki      Sr         200.0        200.0        200.0      0.0
# Bagietki   Pon        200.0        200.0        200.0      0.0
# Bagietki   Wt         200.0        200.0        200.0      0.0
# Bagietki   Sr         200.0        200.0        200.0      0.0
# Rogaliki_z_czekolada Pon        200.0        200.0        200.0      0.0
# Rogaliki_z_czekolada Wt         200.0        200.0        200.0      0.0
# Rogaliki_z_czekolada Sr         200.0        200.0        200.0      0.0

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_colwidth', None)  # Ustaw brak limitu szerokości kolumny


# Po rozwiązaniu problemu upewnijmy się, że rozwiązanie jest optymalne
if pl.LpStatus[model.status] != 'Optimal':
    print("Model did not solve to optimality.")
    exit()

# Pobierz wartości czasu rozpoczęcia
start_times = {
    (subproduct, machine, day): subproduct_batch_start_time[subproduct, machine, day].varValue
    for subproduct in subproducts for machine in sub_machines for day in days
    if subproduct_batch_start_time[subproduct, machine, day].varValue is not None
}

# Oblicz czas zakończenia
end_times = {
    (subproduct, machine, day): start_times[subproduct, machine, day] + sub_production_times[subproduct][machine]
    for subproduct, machine, day in start_times
}

# Wersja 1: Widok z perspektywy subproduktu
subproduct_schedule = []
for subproduct in subproducts:
    for day in days:
        for machine in sub_machines:
            if (subproduct, machine, day) in start_times:
                start = start_times[(subproduct, machine, day)]
                end = end_times[(subproduct, machine, day)]
                subproduct_schedule.append({
                    'Subproduct': subproduct,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

subproduct_df = pd.DataFrame(subproduct_schedule)
print("\nSubproduct Schedule:\n")
print(subproduct_df.sort_values(['Day', 'Subproduct', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania subproduktów na litery
subproduct_mapping = {subproduct: chr(65 + i) for i, subproduct in enumerate(subproducts)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for subproduct in subproducts:
        if (subproduct, machine, day) in start_times:
            start = start_times[(subproduct, machine, day)]
            end = end_times[(subproduct, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = subproduct_mapping[subproduct]  # Wstaw literę dla subproduktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_subproduct = timeline[i]
                    prev_duration = (
                        end_times[(subproducts[ord(prev_subproduct) - 65], machine, day)] -
                        start_times[(subproducts[ord(prev_subproduct) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = subproduct_mapping[subproduct]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in sub_machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
subproduct_df.to_csv("subproduct_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Subproduktów:")
for subproduct, letter in subproduct_mapping.items():
    print(f"{letter}: {subproduct}")
# Out:
# Subproduct Schedule:
#
#                          Subproduct  Day      Machine  Start Time  End Time
# 72               Ciasto_na_bagietki  Pon       Dzieza        0.00      0.95
# 74               Ciasto_na_bagietki  Pon    Dzielarka       19.48     19.72
# 76               Ciasto_na_bagietki  Pon  Rogalikarka       19.72     20.00
# 73               Ciasto_na_bagietki  Pon      Wazenie       20.00     20.00
# 75               Ciasto_na_bagietki  Pon       Tabula       20.00     20.00
# ..                              ...  ...          ...         ...       ...
# 98   Ciasto_na_rogaliki_z_czekolada   Wt    Dzielarka       19.01     19.29
# 100  Ciasto_na_rogaliki_z_czekolada   Wt  Rogalikarka       19.29     19.60
# 101  Ciasto_na_rogaliki_z_czekolada   Wt  Nadziewarka       19.60     20.00
# 97   Ciasto_na_rogaliki_z_czekolada   Wt      Wazenie       20.00     20.00
# 99   Ciasto_na_rogaliki_z_czekolada   Wt       Tabula       20.00     20.00
#
# [108 rows x 5 columns]
#
# Machine Usage Timeline:
#
#         Machine  Day  \
# 0        Dzieza  Pon
# 1       Wazenie  Pon
# 2     Dzielarka  Pon
# 3        Tabula  Pon
# 4   Rogalikarka  Pon
# 5   Nadziewarka  Pon
# 6        Dzieza   Wt
# 7       Wazenie   Wt
# 8     Dzielarka   Wt
# 9        Tabula   Wt
# 10  Rogalikarka   Wt
# 11  Nadziewarka   Wt
# 12       Dzieza   Sr
# 13      Wazenie   Sr
# 14    Dzielarka   Sr
# 15       Tabula   Sr
# 16  Rogalikarka   Sr
# 17  Nadziewarka   Sr
#
#                                                                                                 Timeline
# 0   EEEEDDDDD________________CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCAAAAAAAAAAAAAAAAAAAAAAAAFFFB____
# 1   ____________________________________________________________________________________________A__CB___
# 2   __________________________________________________________________________________________D____F_E__
# 3   ___________________________________________________________________________________________DDAAACBBB
# 4   ________________________________________________________________________________________________F_EE
# 5   __________________________________________________________________________________________________FF
# 6   FFDDDDD________________EEEEECCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCAAAAAAAAAAAAAAAAAAAAAAAAB____
# 7   _____________________________________________________________________________________________C_AB___
# 8   ___________________________________________________________________________________________D___F_E__
# 9   ____________________________________________________________________________________________DDCCCBBB
# 10  ________________________________________________________________________________________________F_EE
# 11  __________________________________________________________________________________________________FF
# 12  EEEEFFF_______________CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCAAAAAAAAAAAAAAAAAAAAAAAADDDDDBB____
# 13  __________________________________________________________________________________________A____CB___
# 14  ___________________________________________________________________________________________FEED_____
# 15  ___________________________________________________________________________________________AAAADCBBB
# 16  _______________________________________________________________________________________________EF___
# 17  __________________________________________________________________________________________________FF
#
# Legenda Subproduktów:
# A: Ciasto_na_chleb_domowy_0_5kg
# B: Ciasto_na_chleb_domowy_0_9kg
# C: Ciasto_na_chleb_na_zakwasie
# D: Ciasto_na_bulki
# E: Ciasto_na_bagietki
# F: Ciasto_na_rogaliki_z_czekolada

# %%
# Pobierz wartości czasu rozpoczęcia
start_times = {
    (product, machine, day): product_batch_start_time[product, machine, day].varValue
    for product in products for machine in machines for day in days
    if product_batch_start_time[product, machine, day].varValue is not None
}

# Oblicz czas zakończenia
end_times = {
    (product, machine, day): start_times[product, machine, day] + production_times[product][machine]
    for product, machine, day in start_times
}

# Wersja 1: Widok z perspektywy produktu
product_schedule = []
for product in products:
    for day in days:
        for machine in machines:
            if (product, machine, day) in start_times:
                start = start_times[(product, machine, day)]
                end = end_times[(product, machine, day)]
                product_schedule.append({
                    'Product': product,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

product_df = pd.DataFrame(product_schedule)
print("\nProduct Schedule:\n")
print(product_df.sort_values(['Day', 'Product', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania produktów na litery
product_mapping = {product: chr(65 + i) for i, product in enumerate(products)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for product in products:
        if (product, machine, day) in start_times:
            start = start_times[(product, machine, day)]
            end = end_times[(product, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = product_mapping[product]  # Wstaw literę dla produktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_product = timeline[i]
                    prev_duration = (
                        end_times[(products[ord(prev_product) - 65], machine, day)] -
                        start_times[(products[ord(prev_product) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = product_mapping[product]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
product_df.to_csv("product_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Produktów:")
for product, letter in product_mapping.items():
    print(f"{letter}: {product}")
# Out:
# Product Schedule:
#
#                  Product  Day    Machine  Start Time  End Time
# 48              Bagietki  Pon   Garownia        1.78      2.11
# 49              Bagietki  Pon       Piec       11.00     11.23
# 50              Bagietki  Pon  Studzenie       11.81     12.23
# 51              Bagietki  Pon  Pakowanie       20.00     20.00
# 36                 Bulki  Pon   Garownia        0.00      0.38
# ..                   ...  ...        ...         ...       ...
# 31     Chleb_na_zakwasie   Wt  Pakowanie       19.40     20.00
# 64  Rogaliki_z_czekolada   Wt   Garownia        0.00      0.25
# 65  Rogaliki_z_czekolada   Wt       Piec        9.07      9.25
# 66  Rogaliki_z_czekolada   Wt  Studzenie       15.51     16.33
# 67  Rogaliki_z_czekolada   Wt  Pakowanie       17.85     18.27
#
# [72 rows x 5 columns]
#
# Machine Usage Timeline:
#
#       Machine  Day  \
# 0    Garownia  Pon
# 1        Piec  Pon
# 2   Studzenie  Pon
# 3   Pakowanie  Pon
# 4    Garownia   Wt
# 5        Piec   Wt
# 6   Studzenie   Wt
# 7   Pakowanie   Wt
# 8    Garownia   Sr
# 9        Piec   Sr
# 10  Studzenie   Sr
# 11  Pakowanie   Sr
#
#                                                                                                 Timeline
# 0   DCCCCCCCEE______________________________FAAAAA_____________BBBBBBB__________________________________
# 1   _____________________________________________FAAAA___DDECCCCC_____BBBBBB____________________________
# 2   __________________________________________________AAAAAAAAAEECCCCCCCCCCCBBBBBBBBBBBBBFFFF________DDD
# 3   _________________________________________________________________________________________FFBBBCCCAAA
# 4   FBBBBBBBEE_____________CCCCCCCDAAAAA________________________________________________________________
# 5   ____________________________________AAAACCCCCFBBBBBBED______________________________________________
# 6   ______________________________________________________DDDAAAAAAAAACCCCCCCCCCCFFFFBBBBBBBBBBBBB___EEE
# 7   _________________________________________________________________________________________FFAAABBCCCC
# 8   EAAAAADD_____________________________BBBBBBBBCCCCCCC___________________________F____________________
# 9   _E________________________________________________DDCCCCC_____BBBBBB________AAAAF___________________
# 10  _________________________________________________________CCCCCCCCCCCBBBBBBBBBBBBBFFFFAAAAAAAAA_EEDDD
# 11  _________________________________________________________________________________________CCCFFAAABBB
#
# Legenda Produktów:
# A: Chleb_domowy_0_5kg
# B: Chleb_domowy_0_9kg
# C: Chleb_na_zakwasie
# D: Bulki
# E: Bagietki
# F: Rogaliki_z_czekolada
