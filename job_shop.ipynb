# %%
import pulp as pl
import numpy as np
# from scipy.stats import multivariate_t

print("==============================================================================")

# Define the problem
model = pl.LpProblem("Maximize_Profit", pl.LpMaximize)

# Products, machines and days
subproducts = ['Ciasto_na_chleb_domowy_0_5kg', 'Ciasto_na_chleb_domowy_0_9kg', 'Ciasto_na_chleb_na_zakwasie', 'Ciasto_na_bulki', 'Ciasto_na_bagietki', 'Ciasto_na_rogaliki_z_czekolada']
products = ['Chleb_domowy_0_5kg', 'Chleb_domowy_0_9kg', 'Chleb_na_zakwasie', 'Bulki', 'Bagietki', 'Rogaliki_z_czekolada']
days = ['Pon', 'Wt', 'Sr', 'Czw', 'Pt', 'Sob']
sub_machines = ['Dzieza', 'Wazenie', 'Dzielarka', 'Tabula', 'Rogalikarka', 'Nadziewarka']
machines = ['Garownia', 'Piec', 'Studzenie', 'Pakowanie']

# Income from product sales and production cost in PLN/piece
product_income = {'Chleb_domowy_0_5kg': 5.2, 'Chleb_domowy_0_9kg': 7.9, 'Chleb_na_zakwasie': 6.2, 'Bulki': 1.4, 'Bagietki': 1.55, 'Rogaliki_z_czekolada': 2.1}
sub_product_cost = {'Ciasto_na_chleb_domowy_0_5kg': 1.6, 'Ciasto_na_chleb_domowy_0_9kg': 2.0, 'Ciasto_na_chleb_na_zakwasie': 2.0, 'Ciasto_na_bulki': 0.5, 'Ciasto_na_bagietki': 0.6, 'Ciasto_na_rogaliki_z_czekolada': 1.0}
product_cost = {'Chleb_domowy_0_5kg': 0.8, 'Chleb_domowy_0_9kg': 0.9, 'Chleb_na_zakwasie': 0.8, 'Bulki': 0.2, 'Bagietki': 0.2, 'Rogaliki_z_czekolada': 0.2}

# Time available
shifts_per_day = 2
hours_per_shift = 10
hours_per_day = shifts_per_day * hours_per_shift

max_batches = 1
large_number = 10000

sub_production_times = {
    'Ciasto_na_chleb_domowy_0_5kg': {'Dzieza': 4.7, 'Wazenie': 0.29, 'Dzielarka': 0.0, 'Tabula': 0.7, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_domowy_0_9kg': {'Dzieza': 5, 'Wazenie': 0.2, 'Dzielarka': 0.0, 'Tabula': 0.55, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_na_zakwasie': {'Dzieza': 8.6, 'Wazenie': 0.22, 'Dzielarka': 0.0, 'Tabula': 0.6, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bulki': {'Dzieza': 1, 'Wazenie': 0.0, 'Dzielarka': 0.23, 'Tabula': 0.34, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bagietki': {'Dzieza': 0.95, 'Wazenie': 0.0, 'Dzielarka': 0.24, 'Tabula': 0.0, 'Rogalikarka': 0.28, 'Nadziewarka': 0.0},
    'Ciasto_na_rogaliki_z_czekolada': {'Dzieza': 0.55, 'Wazenie': 0.0, 'Dzielarka': 0.28, 'Tabula': 0.0, 'Rogalikarka': 0.31, 'Nadziewarka': 0.4}
}

production_times = {
    'Chleb_domowy_0_5kg': {'Garownia': 1.0, 'Piec': 0.68, 'Studzenie': 1.8, 'Pakowanie': 0.56},
    'Chleb_domowy_0_9kg': {'Garownia': 1.5, 'Piec': 1.2, 'Studzenie': 2.5, 'Pakowanie': 0.57},
    'Chleb_na_zakwasie': {'Garownia': 1.4, 'Piec': 1.0, 'Studzenie': 2.3, 'Pakowanie': 0.6},
    'Bulki': {'Garownia': 0.38, 'Piec': 0.25, 'Studzenie': 0.48, 'Pakowanie': 0.0},
    'Bagietki': {'Garownia': 0.33, 'Piec': 0.23, 'Studzenie': 0.42, 'Pakowanie': 0.0},
    'Rogaliki_z_czekolada': {'Garownia': 0.25, 'Piec': 0.18, 'Studzenie': 0.82, 'Pakowanie': 0.42}
}


batch_size = {
    "Ciasto_na_chleb_domowy_0_5kg": 240,
    "Ciasto_na_chleb_domowy_0_9kg": 130,
    "Ciasto_na_chleb_na_zakwasie": 200,
    "Ciasto_na_bulki": 200,
    "Ciasto_na_bagietki": 200,
    "Ciasto_na_rogaliki_z_czekolada": 200,
    "Chleb_domowy_0_5kg": 240,
    "Chleb_domowy_0_9kg": 130,
    "Chleb_na_zakwasie": 200,
    "Bulki": 200,
    "Bagietki": 200,
    "Rogaliki_z_czekolada": 200,
}

# market_limits = {
#     "Chleb_domowy_0_5kg": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 420, "Pt": 530, "Sob": 680},
#     "Chleb_domowy_0_9kg": {"Pon": 100, "Wt": 100, "Sr": 380, "Czw": 150, "Pt": 250, "Sob": 580},
#     "Chleb_na_zakwasie": {"Pon": 100, "Wt": 100, "Sr": 320, "Czw": 180, "Pt": 280, "Sob": 418},
#     "Bulki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 530, "Pt": 650, "Sob": 580},
#     "Bagietki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 350, "Pt": 650, "Sob": 680},
#     "Rogaliki_z_czekolada": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 310, "Pt": 400, "Sob": 280},
# }

market_limits = {
    "Chleb_domowy_0_5kg": {"Pon": 132, "Wt": 87, "Sr": 163, "Czw": 134, "Pt": 173, "Sob": 68},
    "Chleb_domowy_0_9kg": {"Pon": 145, "Wt": 134, "Sr": 67, "Czw": 98, "Pt": 64, "Sob": 58},
    "Chleb_na_zakwasie": {"Pon": 89, "Wt": 100, "Sr": 320, "Czw": 180, "Pt": 280, "Sob": 79},
    "Bulki": {"Pon": 93, "Wt": 187, "Sr": 135, "Czw": 79, "Pt": 145, "Sob": 100},
    "Bagietki": {"Pon": 76, "Wt": 72, "Sr": 231, "Czw": 88, "Pt": 65, "Sob": 154},
    "Rogaliki_z_czekolada": {"Pon": 176, "Wt": 100, "Sr": 126, "Czw": 310, "Pt": 200, "Sob": 280},
}

# Machines cost
fridge_cost_per_day = 0.281 * 24 * 1.4 * 0.2 # kW * 24h * price per hour * factor
furnace_cost_per_hour = 82.4 # https://giko.pl/kalkulator-zuzycia-energii-dla-piecow-piekarniczych/


fridge_count = 10
fridge_capacity = 160
end_stock = 0
storage_capacity = fridge_count * fridge_capacity

# Variables for production, sales, and storage of products each day
sub_production_vars = pl.LpVariable.dicts("Subproduct production", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
production_vars = pl.LpVariable.dicts("Production", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# batch_count_vars = pl.LpVariable.dicts("Batches Count", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# subbatch_count_vars = pl.LpVariable.dicts("Subproduct Batches Count", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
product_batch_start_time = pl.LpVariable.dicts("ProductStartTime",  [(product, machine, day) for product in products for machine in machines for day in days], lowBound=0, cat="Continuous")
subproduct_batch_start_time = pl.LpVariable.dicts("Subproduction start time for batch",  [(subproduct, machine, day) for subproduct in subproducts for machine in sub_machines for day in days], lowBound=0, cat="Continuous")
sales_vars = pl.LpVariable.dicts("Sales", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, idx) for (machine, idx) in specific_machines], cat="Binary")
# subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, day, batch) for subproduct in subproducts for day in days for batch in range(1, max_batches + 1)], cat="Binary")
subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, day) for subproduct in subproducts for day in days], cat="Binary")
batch_produced = pl.LpVariable.dicts("BatchProduced", [(product, day) for product in products for day in days], cat="Binary")
specific_sub_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, subproduct, day) for machine in sub_machines for subproduct in subproducts for day in days], cat="Binary")
specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, product, day) for machine in machines for product in products for day in days], cat="Binary")
storage_vars = pl.LpVariable.dicts("Storage", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, upBound=storage_capacity, cat='Integer')
fridge_count_usage_vars = pl.LpVariable.dicts("FridgeCount", ((day) for day in days), lowBound=0, upBound=fridge_count, cat='Integer')
all_from_storage = pl.LpVariable.dicts("AllFromStorage", [(subproduct, day) for subproduct in subproducts for day in days], cat="Binary")


# xij = pl.LpVariable.dicts("xij", [(machine, idx, i, j) for (machine, idx) in specific_machines for i in subproducts for j in subproducts if i != j], 0, 1, pl.LpBinary)
is_produced_sub = pl.LpVariable.dicts("is_produced",
                                     ((subproduct, machine, day) for subproduct in subproducts
                                                                      for machine in sub_machines
                                                                      for day in days),
                                     cat="Binary")
is_produced = pl.LpVariable.dicts("is_produced",
                                     ((product, machine, day) for product in products
                                                                      for machine in machines
                                                                      for day in days),
                                     cat="Binary")

for subproduct in subproducts:
    for day in days:
        for i, machine in enumerate(sub_machines[1:], start=1):  # Od ważenia do nadziewarki
            prev = 1
            prev_machine = sub_machines[i - prev]

            while sub_production_times[subproduct][prev_machine] == 0.0 or prev_machine == machine:
                prev += 1
                prev_machine = sub_machines[i - prev]

            model += subproduct_batch_start_time[subproduct, machine, day] >= (
                subproduct_batch_start_time[subproduct, prev_machine, day] + sub_production_times[subproduct][prev_machine]
            )

            model += subproduct_batch_start_time[subproduct, machine, day] <= specific_sub_machine_used[machine, subproduct, day] * hours_per_day

        last_machine = sub_machines[-1]
        model += hours_per_day >= (
            subproduct_batch_start_time[subproduct, last_machine, day] + sub_production_times[subproduct][last_machine]
        )

for product in products:
    for day in days:
        for i, machine in enumerate(machines[1:], start=1):  # Od ważenia do nadziewarki
            prev = 1
            prev_machine = machines[i - prev]

            while production_times[product][prev_machine] == 0.0 or prev_machine == machine:
                prev += 1
                prev_machine = machines[i - prev]

            model += product_batch_start_time[product, machine, day] >= (
                product_batch_start_time[product, prev_machine, day] + production_times[product][prev_machine]
            )

            model += product_batch_start_time[product, machine, day] <= specific_machine_used[machine, product, day] * hours_per_day

        last_machine = machines[-1]
        model += hours_per_day >= (
            product_batch_start_time[product, last_machine, day] + production_times[product][last_machine]
        )
'''
        model += subbatch_produced[subproduct, day] * large_number >= subproduct_batch_start_time[subproduct, last_machine, last_idx, day]

        # Brak nakładania się produkcji na maszynie
        for machine, idx in specific_machines[:6]:  # Zakres maszyn
            for subproduct1 in subproducts:
                for subproduct2 in subproducts:
                    if subproduct1 != subproduct2:
                        model += (subproduct_batch_start_time[subproduct1, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct2, machine, idx, day] + production_times[subproduct2][machine]) | \
                                 (subproduct_batch_start_time[subproduct2, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct1, machine, idx, day] + production_times[subproduct1][machine])

                        # model += specific_machine_used[machine, idx, subproduct1, day] + specific_machine_used[machine, idx, subproduct2, day] <= 1
'''
# Ograniczenie: produkcja subproduktu tylko na maszynach, gdzie czas produkcji > 0
for subproduct in subproducts:
    for machine in sub_machines:
        for day in days:
            if sub_production_times[subproduct][machine] == 0:
                model += is_produced_sub[subproduct, machine, day] == 0

# Ograniczenie: produkcja produktu tylko na maszynach, gdzie czas produkcji > 0
for product in products:
    for machine in machines:
        for day in days:
            if production_times[product][machine] == 0:
                model += is_produced[product, machine, day] == 0
                

# Warunek: jeśli subprodukt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for subproduct in subproducts:
    machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for machine in machines_with_production:
                    model += pl.lpSum(is_produced_sub[subproduct, m, day] for m in machines_with_production) == \
                            len(machines_with_production) * is_produced_sub[subproduct, machine, day]
        
            # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
            model += subbatch_produced[subproduct, day] <= pl.lpSum(is_produced_sub[subproduct, machine, day] for machine in machines_with_production)
            model += subbatch_produced[subproduct, day] >= is_produced_sub[subproduct, machines_with_production[0], day]

# Warunek: jeśli produkt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for product in products:
    machines_with_production = [machine for machine in machines if production_times[product][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for machine in machines_with_production:
                    model += pl.lpSum(is_produced[product, m, day] for m in machines_with_production) == \
                            len(machines_with_production) * is_produced[product, machine, day]
        
            # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
            model += batch_produced[product, day] <= pl.lpSum(is_produced[product, machine, day] for machine in machines_with_production)
            model += batch_produced[product, day] >= is_produced[product, machines_with_production[0], day]

# Aktualizacja ograniczenia: brak nakładania się produkcji
big_M = 1000000
for subproduct1 in subproducts:
    for subproduct2 in subproducts:
        if subproduct1 != subproduct2:
            machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct1][machine] > 0 and sub_production_times[subproduct2][machine] > 0]
            for machine in machines_with_production: 
                for day in days:
                    # Dodanie binarnych zmiennych pomocniczych
                    y0 = pl.LpVariable(f"y0_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y1 = pl.LpVariable(f"y1_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y2 = pl.LpVariable(f"y2_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y3 = pl.LpVariable(f"y3_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y4 = pl.LpVariable(f"y4_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")

                    # Powiązanie warunków logicznych z binarnymi zmiennymi
                    model += subproduct_batch_start_time[subproduct1, machine, day] >= \
                                subproduct_batch_start_time[subproduct2, machine, day] + sub_production_times[subproduct2][machine] - \
                                big_M * (1 - y1)
                    
                    model += subproduct_batch_start_time[subproduct2, machine, day] >= \
                                subproduct_batch_start_time[subproduct1, machine, day] + sub_production_times[subproduct1][machine] - \
                                big_M * (1 - y2)

                    model += is_produced_sub[subproduct1, machine, day] + y3 == 1
                    model += is_produced_sub[subproduct2, machine, day] + y4 == 1

                    model += y0 <= 1 - is_produced_sub[subproduct1, machine, day]
                    model += y0 <= 1 - is_produced_sub[subproduct2, machine, day]

                    # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                    model += y0 + y1 + y2 + y3 + y4 == 1

for product1 in products:
    for product2 in products:
        if product1 != product2:
            machines_with_production = [machine for machine in machines if production_times[product1][machine] > 0 and production_times[product2][machine] > 0]
            for machine in machines_with_production: 
                for day in days:
                    # Dodanie binarnych zmiennych pomocniczych
                    y0 = pl.LpVariable(f"y0_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y1 = pl.LpVariable(f"y1_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y2 = pl.LpVariable(f"y2_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y3 = pl.LpVariable(f"y3_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y4 = pl.LpVariable(f"y4_{product1}_{product2}_{machine}_{day}", cat="Binary")

                    # Powiązanie warunków logicznych z binarnymi zmiennymi
                    model += product_batch_start_time[product1, machine, day] >= \
                                product_batch_start_time[product2, machine, day] + production_times[product2][machine] - \
                                big_M * (1 - y1)
                    
                    model += product_batch_start_time[product2, machine, day] >= \
                                product_batch_start_time[product1, machine, day] + production_times[product1][machine] - \
                                big_M * (1 - y2)

                    model += is_produced[product1, machine, day] + y3 == 1
                    model += is_produced[product2, machine, day] + y4 == 1

                    model += y0 <= 1 - is_produced[product1, machine, day]
                    model += y0 <= 1 - is_produced[product2, machine, day]

                    # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                    model += y0 + y1 + y2 + y3 + y4 == 1

M = 1000
for subproduct, product in zip(subproducts, products):
    model += storage_vars[subproduct, 'Pon'] == sub_production_vars[subproduct, 'Pon'] - production_vars[product, 'Pon']
    model += product_batch_start_time[product, machines[0], 'Pon'] >= (subproduct_batch_start_time[subproduct, sub_machines[-1], 'Pon']) + sub_production_times[subproduct][sub_machines[-1]]
    for i in range(1, len(days)):
        day = days[i]
        # prev_day = days[i-1]
        # model += storage_vars[subproduct, day] == storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day]
        # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
        # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
        # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
        model += product_batch_start_time[product, machines[0], day] >= (subproduct_batch_start_time[subproduct, sub_machines[-1], day]) + sub_production_times[subproduct][sub_machines[-1]] - M * all_from_storage[subproduct, day]

expr1 = pl.LpVariable.dicts("expr1", [(s, d) for s in subproducts for d in days], lowBound=0)
expr2 = pl.LpVariable.dicts("expr2", [(s, d) for s in subproducts for d in days], lowBound=0)

# Dodaj ograniczenia dla zmiennych pomocniczych
for s, p in zip(subproducts, products):
    all_from_storage[s, 'Pon'] = 0
    for i in range(1, len(days)):
        d = days[i]
        prev_day = days[i-1]
        model += expr1[s, d] >= storage_vars[s, prev_day] - production_vars[p, d] - M * (1 - all_from_storage[s, d])
        model += expr1[s, d] <= storage_vars[s, prev_day] - production_vars[p, d]
        model += expr1[s, d] <= M * all_from_storage[s, d]
        model += expr1[s, d] >= 0
        
        model += expr2[s, d] >= storage_vars[s, prev_day] + sub_production_vars[s, d] - production_vars[p, d] - M * all_from_storage[s, d]
        model += expr2[s, d] <= storage_vars[s, prev_day] + sub_production_vars[s, d] - production_vars[p, d]
        model += expr2[s, d] <= M * (1 - all_from_storage[s, d])
        model += expr2[s, d] >= 0

        # Ograniczenie
        model += storage_vars[s, d] == expr1[s, d] + expr2[s, d]


for day in days:
    model += storage_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)
    model += fridge_count_usage_vars[day] * fridge_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)

for product, subproduct in zip(products, subproducts):
    for day in days:
        model += batch_produced[product, day] * batch_size[product] >= production_vars[product, day]
        model += production_vars[product, day] >= batch_produced[product, day]
        model += subbatch_produced[subproduct, day] * batch_size[subproduct] >= sub_production_vars[subproduct, day]
        model += sub_production_vars[subproduct, day] >= subbatch_produced[subproduct, day]

        # model += sub_production_vars[subproduct, day] >= production_vars[product, day]
        model += sales_vars[product, day] == production_vars[product, day]
        model += sales_vars[product, day] <= market_limits[product][day]
        model += sales_vars['Bagietki',day] + sales_vars['Bulki',day] >= sales_vars['Rogaliki_z_czekolada', day]
    model += sales_vars[product, 'Sr'] >= 0.5*market_limits[product]['Sr'], f"Max_sales_{product}_{'Sr'}"
    model += sales_vars[product, 'Pt'] >= 0.5*market_limits[product]['Pt'], f"Max_sales_{product}_{'Pt'}"


# Objective function: Maximize profit from sales minus costs
model += pl.lpSum([sales_vars[product, day] * product_income[product] for product in products for day in days]) \
                    - pl.lpSum([production_vars[product, day] * product_cost[product] for product in products for day in days]) \
                    - pl.lpSum([sub_production_vars[subproduct, day] * sub_product_cost[subproduct] for subproduct in subproducts for day in days]) \
                    - pl.lpSum([fridge_count_usage_vars[day] * fridge_cost_per_day for day in days]) \
                    - pl.lpSum([batch_produced[product, day] * production_times[product]['Piec'] * furnace_cost_per_hour for product in products for day in days]), "Total_Profit"


solver = pl.PULP_CBC_CMD(timeLimit=3600)

model.solve(solver)

# model.solve()

# Results
print("Status:", pl.LpStatus[model.status])
if pl.LpStatus[model.status] == 'Optimal':
    print("Total Profit:", pl.value(model.objective))

    print(f"{'Product':<10} {'day':<10} {'SubProduction':<10} {'Production':<12} {'Sales':<10} {'Storage':<10}")

    for product, subproduct in zip(products, subproducts):
        for day in days:
            subproduction = sub_production_vars[subproduct, day].varValue
            production = production_vars[product, day].varValue
            sales = sales_vars[product, day].varValue
            storage = storage_vars[subproduct, day].varValue

            print(f"{product:<10} {day:<10} {subproduction:<12} {production:<12} {sales:<10} {storage:<10}")

    # print("\nProduction Time Usage per Product and Day:")
    # for day in days:
    #     print(f"\Day: {day}")
    #     for product in products:
    #         total_production_time = sum(
    #             batch_count_vars[product, day].varValue * production_times[product]s.get(machine, 0) 
    #             for machine in machines #.keys()
    #         )
    #         print(f"  Product: {product}, Total Production Time: {total_production_time:.2f} hours")

else:
    print("No optimal solution was found.")
    # Analiza ograniczeń
    for name, constraint in model.constraints.items():
        if constraint.pi < 0:
            print(f"Ograniczenie {name}: {constraint}")
# Out:
# ==============================================================================
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gromiusz/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/db6df7211c254052bb3f1bb802b95915-pulp.mps -max -sec 3600 -timeMode elapsed -branch -printingOptions all -solution /tmp/db6df7211c254052bb3f1bb802b95915-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8381 COLUMNS
# At line 41946 RHS
# At line 50323 BOUNDS
# At line 55964 ENDATA
# Problem MODEL has 8376 rows, 6060 columns and 22134 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 3600
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 9662.05 - 0.04 seconds
# Cgl0002I 114 variables fixed
# Cgl0003I 998 fixed, 39 tightened bounds, 2561 strengthened rows, 990 substitutions
# Cgl0003I 0 fixed, 9 tightened bounds, 1300 strengthened rows, 261 substitutions
# Cgl0003I 7 fixed, 7 tightened bounds, 1603 strengthened rows, 42 substitutions
# Cgl0003I 0 fixed, 6 tightened bounds, 70 strengthened rows, 0 substitutions
# Cgl0003I 2 fixed, 2 tightened bounds, 226 strengthened rows, 23 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 0 tightened bounds, 44 strengthened rows, 5 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 27 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3180 rows, 2136 columns (1800 integer (1692 of which binary)) and 14264 elements
# Cbc0038I Initial state - 455 integers unsatisfied sum - 100.852
# Cbc0038I Pass   1: (0.60 seconds) suminf.   71.98763 (403) obj. -3309.57 iterations 503
# Cbc0038I Pass   2: (0.60 seconds) suminf.   71.98763 (403) obj. -3309.57 iterations 9
# Cbc0038I Pass   3: (0.61 seconds) suminf.   71.98763 (403) obj. -3309.57 iterations 2
# Cbc0038I Pass   4: (0.62 seconds) suminf.   71.98763 (403) obj. -3309.57 iterations 1
# Cbc0038I Pass   5: (0.62 seconds) suminf.   71.98763 (403) obj. -3309.57 iterations 0
# Cbc0038I Pass   6: (0.62 seconds) suminf.   71.98763 (403) obj. -3309.57 iterations 4
# Cbc0038I Pass   7: (0.63 seconds) suminf.   71.98763 (403) obj. -3309.57 iterations 2
# Cbc0038I Pass   8: (0.63 seconds) suminf.   71.98763 (403) obj. -3309.57 iterations 1
# Cbc0038I Pass   9: (0.65 seconds) suminf.   83.17433 (448) obj. -1946.91 iterations 480
# Cbc0038I Pass  10: (0.67 seconds) suminf.   65.93490 (571) obj. -2119 iterations 283
# Cbc0038I Pass  11: (0.67 seconds) suminf.   65.93490 (571) obj. -2119 iterations 5
# Cbc0038I Pass  12: (0.67 seconds) suminf.   65.93490 (571) obj. -2119 iterations 1
# Cbc0038I Pass  13: (0.69 seconds) suminf.   78.31657 (565) obj. -1720.38 iterations 422
# Cbc0038I Pass  14: (0.70 seconds) suminf.   62.47181 (611) obj. -1719.49 iterations 197
# Cbc0038I Pass  15: (0.71 seconds) suminf.   62.47181 (611) obj. -1719.49 iterations 3
# Cbc0038I Pass  16: (0.71 seconds) suminf.   62.47181 (611) obj. -1719.49 iterations 1
# Cbc0038I Pass  17: (0.73 seconds) suminf.   71.62719 (582) obj. -653.964 iterations 422
# Cbc0038I Pass  18: (0.74 seconds) suminf.   61.05656 (582) obj. -652.203 iterations 210
# Cbc0038I Pass  19: (0.75 seconds) suminf.   61.05656 (582) obj. -652.203 iterations 2
# Cbc0038I Pass  20: (0.75 seconds) suminf.   61.05656 (582) obj. -652.203 iterations 1
# Cbc0038I Pass  21: (0.76 seconds) suminf.   61.61797 (651) obj. -716.746 iterations 411
# Cbc0038I Pass  22: (0.78 seconds) suminf.   59.04125 (592) obj. -719.301 iterations 194
# Cbc0038I Pass  23: (0.78 seconds) suminf.   59.04125 (592) obj. -719.301 iterations 3
# Cbc0038I Pass  24: (0.79 seconds) suminf.   59.04125 (592) obj. -719.301 iterations 1
# Cbc0038I Pass  25: (0.79 seconds) suminf.   59.04125 (592) obj. -719.301 iterations 1
# Cbc0038I Pass  26: (0.79 seconds) suminf.   59.04125 (592) obj. -719.301 iterations 0
# Cbc0038I Pass  27: (0.79 seconds) suminf.   59.04125 (592) obj. -719.301 iterations 0
# Cbc0038I Pass  28: (0.80 seconds) suminf.   59.04125 (592) obj. -719.301 iterations 6
# Cbc0038I Pass  29: (0.81 seconds) suminf.   62.57034 (578) obj. -782.654 iterations 339
# Cbc0038I Pass  30: (0.82 seconds) suminf.   61.98531 (616) obj. -787.804 iterations 217
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 636 integers at bound fixed and 32 continuous of which 2 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (0.83 seconds)
# Cbc0038I After 0.83 seconds - Feasibility pump exiting - took 0.28 seconds
# Cbc0031I 299 added rows had average density of 18.946488
# Cbc0013I At root node, 299 cuts changed objective from -8389.8376 to -7134.3557 in 11 passes
# Cbc0014I Cut generator 0 (Probing) - 748 row cuts average 2.3 elements, 0 column cuts (64 active)  in 0.078 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 739 row cuts average 31.4 elements, 0 column cuts (0 active)  in 0.165 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 20 row cuts average 5.3 elements, 0 column cuts (0 active)  in 0.023 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 367 row cuts average 2.6 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 90 row cuts average 2.3 elements, 0 column cuts (0 active)  in 0.021 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 1725 row cuts average 34.9 elements, 0 column cuts (0 active)  in 0.196 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible -7134.3557 (2.21 seconds)
# Cbc0010I After 100 nodes, 58 on tree, 1e+50 best solution, best possible -7134.3557 (13.18 seconds)
# Cbc0010I After 200 nodes, 121 on tree, 1e+50 best solution, best possible -7134.3557 (15.93 seconds)
# Cbc0010I After 300 nodes, 175 on tree, 1e+50 best solution, best possible -7134.3557 (16.75 seconds)
# Cbc0010I After 400 nodes, 228 on tree, 1e+50 best solution, best possible -7134.3557 (17.52 seconds)
# Cbc0010I After 500 nodes, 222 on tree, 1e+50 best solution, best possible -7134.3557 (18.18 seconds)
# Cbc0010I After 600 nodes, 229 on tree, 1e+50 best solution, best possible -7134.3557 (18.91 seconds)
# Cbc0010I After 700 nodes, 224 on tree, 1e+50 best solution, best possible -7134.3557 (19.54 seconds)
# Cbc0010I After 800 nodes, 223 on tree, 1e+50 best solution, best possible -7134.3557 (20.30 seconds)
# Cbc0010I After 900 nodes, 220 on tree, 1e+50 best solution, best possible -7134.3557 (21.04 seconds)
# Cbc0010I After 1000 nodes, 219 on tree, 1e+50 best solution, best possible -7134.3557 (21.71 seconds)
# Cbc0010I After 1100 nodes, 276 on tree, 1e+50 best solution, best possible -7134.106 (27.92 seconds)
# Cbc0010I After 1200 nodes, 275 on tree, 1e+50 best solution, best possible -7134.106 (29.39 seconds)
# Cbc0010I After 1300 nodes, 272 on tree, 1e+50 best solution, best possible -7134.106 (30.83 seconds)
# Cbc0010I After 1400 nodes, 283 on tree, 1e+50 best solution, best possible -7134.106 (32.21 seconds)
# Cbc0010I After 1500 nodes, 275 on tree, 1e+50 best solution, best possible -7134.106 (33.67 seconds)
# Cbc0010I After 1600 nodes, 281 on tree, 1e+50 best solution, best possible -7134.106 (34.76 seconds)
# Cbc0010I After 1700 nodes, 279 on tree, 1e+50 best solution, best possible -7134.106 (35.73 seconds)
# Cbc0010I After 1800 nodes, 275 on tree, 1e+50 best solution, best possible -7134.106 (36.88 seconds)
# Cbc0010I After 1900 nodes, 277 on tree, 1e+50 best solution, best possible -7134.106 (37.97 seconds)
# Cbc0010I After 2000 nodes, 282 on tree, 1e+50 best solution, best possible -7134.106 (43.98 seconds)
# Cbc0010I After 2100 nodes, 282 on tree, 1e+50 best solution, best possible -7134.106 (45.40 seconds)
# Cbc0010I After 2200 nodes, 284 on tree, 1e+50 best solution, best possible -7134.106 (46.66 seconds)
# Cbc0010I After 2300 nodes, 280 on tree, 1e+50 best solution, best possible -7134.106 (48.21 seconds)
# Cbc0010I After 2400 nodes, 290 on tree, 1e+50 best solution, best possible -7134.106 (50.80 seconds)
# Cbc0010I After 2500 nodes, 291 on tree, 1e+50 best solution, best possible -7134.106 (52.80 seconds)
# Cbc0010I After 2600 nodes, 290 on tree, 1e+50 best solution, best possible -7134.106 (54.58 seconds)
# Cbc0010I After 2700 nodes, 300 on tree, 1e+50 best solution, best possible -7134.106 (55.79 seconds)
# Cbc0010I After 2800 nodes, 301 on tree, 1e+50 best solution, best possible -7134.106 (56.91 seconds)
# Cbc0010I After 2900 nodes, 291 on tree, 1e+50 best solution, best possible -7134.106 (58.25 seconds)
# Cbc0010I After 3000 nodes, 296 on tree, 1e+50 best solution, best possible -7134.106 (59.55 seconds)
# Cbc0010I After 3100 nodes, 290 on tree, 1e+50 best solution, best possible -7134.106 (60.71 seconds)
# Cbc0010I After 3200 nodes, 287 on tree, 1e+50 best solution, best possible -7134.106 (61.77 seconds)
# Cbc0010I After 3300 nodes, 290 on tree, 1e+50 best solution, best possible -7134.106 (62.91 seconds)
# Cbc0010I After 3400 nodes, 298 on tree, 1e+50 best solution, best possible -7134.106 (63.96 seconds)
# Cbc0010I After 3500 nodes, 301 on tree, 1e+50 best solution, best possible -7134.106 (64.84 seconds)
# Cbc0010I After 3600 nodes, 301 on tree, 1e+50 best solution, best possible -7134.106 (66.05 seconds)
# Cbc0010I After 3700 nodes, 300 on tree, 1e+50 best solution, best possible -7134.106 (67.25 seconds)
# Cbc0010I After 3800 nodes, 298 on tree, 1e+50 best solution, best possible -7134.106 (68.24 seconds)
# Cbc0010I After 3900 nodes, 302 on tree, 1e+50 best solution, best possible -7134.106 (69.21 seconds)
# Cbc0010I After 4000 nodes, 299 on tree, 1e+50 best solution, best possible -7134.106 (70.23 seconds)
# Cbc0010I After 4100 nodes, 303 on tree, 1e+50 best solution, best possible -7134.106 (71.23 seconds)
# Cbc0010I After 4200 nodes, 296 on tree, 1e+50 best solution, best possible -7134.106 (72.25 seconds)
# Cbc0010I After 4300 nodes, 299 on tree, 1e+50 best solution, best possible -7134.106 (73.08 seconds)
# Cbc0010I After 4400 nodes, 298 on tree, 1e+50 best solution, best possible -7134.106 (73.81 seconds)
# Cbc0010I After 4500 nodes, 294 on tree, 1e+50 best solution, best possible -7134.106 (74.61 seconds)
# Cbc0010I After 4600 nodes, 306 on tree, 1e+50 best solution, best possible -7134.106 (75.47 seconds)
# Cbc0010I After 4700 nodes, 301 on tree, 1e+50 best solution, best possible -7134.106 (79.02 seconds)
# Cbc0010I After 4800 nodes, 298 on tree, 1e+50 best solution, best possible -7134.106 (79.59 seconds)
# Cbc0010I After 4900 nodes, 294 on tree, 1e+50 best solution, best possible -7134.106 (80.32 seconds)
# Cbc0010I After 5000 nodes, 291 on tree, 1e+50 best solution, best possible -7134.106 (81.04 seconds)
# Cbc0010I After 5100 nodes, 328 on tree, 1e+50 best solution, best possible -7133.8659 (88.24 seconds)
# Cbc0010I After 5200 nodes, 332 on tree, 1e+50 best solution, best possible -7133.8659 (89.62 seconds)
# Cbc0010I After 5300 nodes, 367 on tree, 1e+50 best solution, best possible -7133.8659 (91.25 seconds)
# Cbc0010I After 5400 nodes, 367 on tree, 1e+50 best solution, best possible -7133.8659 (92.59 seconds)
# Cbc0010I After 5500 nodes, 371 on tree, 1e+50 best solution, best possible -7133.8659 (93.98 seconds)
# Cbc0010I After 5600 nodes, 366 on tree, 1e+50 best solution, best possible -7133.8659 (95.05 seconds)
# Cbc0010I After 5700 nodes, 365 on tree, 1e+50 best solution, best possible -7133.8659 (96.05 seconds)
# Cbc0010I After 5800 nodes, 364 on tree, 1e+50 best solution, best possible -7133.8659 (97.07 seconds)
# Cbc0010I After 5900 nodes, 368 on tree, 1e+50 best solution, best possible -7133.8659 (98.21 seconds)
# Cbc0010I After 6000 nodes, 368 on tree, 1e+50 best solution, best possible -7133.8659 (99.47 seconds)
# Cbc0010I After 6100 nodes, 362 on tree, 1e+50 best solution, best possible -7133.8659 (100.62 seconds)
# Cbc0010I After 6200 nodes, 364 on tree, 1e+50 best solution, best possible -7133.8659 (101.90 seconds)
# Cbc0010I After 6300 nodes, 365 on tree, 1e+50 best solution, best possible -7133.8659 (103.17 seconds)
# Cbc0010I After 6400 nodes, 362 on tree, 1e+50 best solution, best possible -7133.8659 (103.98 seconds)
# Cbc0010I After 6500 nodes, 361 on tree, 1e+50 best solution, best possible -7133.8659 (104.96 seconds)
# Cbc0010I After 6600 nodes, 360 on tree, 1e+50 best solution, best possible -7133.8659 (105.84 seconds)
# Cbc0010I After 6700 nodes, 363 on tree, 1e+50 best solution, best possible -7133.8659 (106.76 seconds)
# Cbc0010I After 6800 nodes, 361 on tree, 1e+50 best solution, best possible -7133.8659 (107.63 seconds)
# Cbc0010I After 6900 nodes, 359 on tree, 1e+50 best solution, best possible -7133.8659 (108.57 seconds)
# Cbc0010I After 7000 nodes, 364 on tree, 1e+50 best solution, best possible -7133.8659 (109.79 seconds)
# Cbc0010I After 7100 nodes, 364 on tree, 1e+50 best solution, best possible -7133.8659 (113.97 seconds)
# Cbc0010I After 7200 nodes, 360 on tree, 1e+50 best solution, best possible -7133.8659 (115.13 seconds)
# Cbc0010I After 7300 nodes, 365 on tree, 1e+50 best solution, best possible -7133.8659 (116.32 seconds)
# Cbc0010I After 7400 nodes, 366 on tree, 1e+50 best solution, best possible -7133.8659 (117.42 seconds)
# Cbc0010I After 7500 nodes, 365 on tree, 1e+50 best solution, best possible -7133.8659 (118.52 seconds)
# Cbc0010I After 7600 nodes, 364 on tree, 1e+50 best solution, best possible -7133.8659 (119.68 seconds)
# Cbc0010I After 7700 nodes, 364 on tree, 1e+50 best solution, best possible -7133.8659 (120.81 seconds)
# Cbc0010I After 7800 nodes, 364 on tree, 1e+50 best solution, best possible -7133.8659 (121.94 seconds)
# Cbc0010I After 7900 nodes, 382 on tree, 1e+50 best solution, best possible -7133.8659 (123.07 seconds)
# Cbc0010I After 8000 nodes, 378 on tree, 1e+50 best solution, best possible -7133.8659 (124.16 seconds)
# Cbc0010I After 8100 nodes, 368 on tree, 1e+50 best solution, best possible -7133.8659 (125.20 seconds)
# Cbc0010I After 8200 nodes, 369 on tree, 1e+50 best solution, best possible -7133.8659 (126.31 seconds)
# Cbc0010I After 8300 nodes, 372 on tree, 1e+50 best solution, best possible -7133.8659 (127.42 seconds)
# Cbc0010I After 8400 nodes, 373 on tree, 1e+50 best solution, best possible -7133.8659 (128.39 seconds)
# Cbc0010I After 8500 nodes, 369 on tree, 1e+50 best solution, best possible -7133.8659 (129.40 seconds)
# Cbc0010I After 8600 nodes, 371 on tree, 1e+50 best solution, best possible -7133.8659 (130.56 seconds)
# Cbc0010I After 8700 nodes, 365 on tree, 1e+50 best solution, best possible -7133.8659 (131.67 seconds)
# Cbc0010I After 8800 nodes, 362 on tree, 1e+50 best solution, best possible -7133.8659 (132.97 seconds)
# Cbc0010I After 8900 nodes, 369 on tree, 1e+50 best solution, best possible -7133.8659 (134.14 seconds)
# Cbc0010I After 9000 nodes, 366 on tree, 1e+50 best solution, best possible -7133.8659 (135.33 seconds)
# Cbc0010I After 9100 nodes, 416 on tree, 1e+50 best solution, best possible -7133.8653 (143.38 seconds)
# Cbc0010I After 9200 nodes, 415 on tree, 1e+50 best solution, best possible -7133.8653 (145.00 seconds)
# Cbc0010I After 9300 nodes, 458 on tree, 1e+50 best solution, best possible -7133.8653 (149.73 seconds)
# Cbc0010I After 9400 nodes, 462 on tree, 1e+50 best solution, best possible -7133.8653 (151.38 seconds)
# Cbc0010I After 9500 nodes, 458 on tree, 1e+50 best solution, best possible -7133.8653 (152.76 seconds)
# Cbc0010I After 9600 nodes, 460 on tree, 1e+50 best solution, best possible -7133.8653 (154.18 seconds)
# Cbc0010I After 9700 nodes, 461 on tree, 1e+50 best solution, best possible -7133.8653 (155.43 seconds)
# Cbc0010I After 9800 nodes, 460 on tree, 1e+50 best solution, best possible -7133.8653 (156.84 seconds)
# Cbc0010I After 9900 nodes, 463 on tree, 1e+50 best solution, best possible -7133.8653 (158.18 seconds)
# Cbc0010I After 10000 nodes, 457 on tree, 1e+50 best solution, best possible -7133.8653 (159.66 seconds)
# Cbc0010I After 10100 nodes, 462 on tree, 1e+50 best solution, best possible -7133.8653 (161.23 seconds)
# Cbc0010I After 10200 nodes, 461 on tree, 1e+50 best solution, best possible -7133.8653 (162.63 seconds)
# Cbc0010I After 10300 nodes, 463 on tree, 1e+50 best solution, best possible -7133.8653 (164.09 seconds)
# Cbc0010I After 10400 nodes, 462 on tree, 1e+50 best solution, best possible -7133.8653 (165.38 seconds)
# Cbc0010I After 10500 nodes, 464 on tree, 1e+50 best solution, best possible -7133.8653 (166.76 seconds)
# Cbc0010I After 10600 nodes, 464 on tree, 1e+50 best solution, best possible -7133.8653 (167.96 seconds)
# Cbc0010I After 10700 nodes, 463 on tree, 1e+50 best solution, best possible -7133.8653 (169.11 seconds)
# Cbc0010I After 10800 nodes, 462 on tree, 1e+50 best solution, best possible -7133.8653 (170.24 seconds)
# Cbc0010I After 10900 nodes, 460 on tree, 1e+50 best solution, best possible -7133.8653 (171.33 seconds)
# Cbc0010I After 11000 nodes, 460 on tree, 1e+50 best solution, best possible -7133.8653 (172.59 seconds)
# Cbc0010I After 11100 nodes, 501 on tree, 1e+50 best solution, best possible -7102.8861 (194.84 seconds)
# Cbc0010I After 11200 nodes, 544 on tree, 1e+50 best solution, best possible -7102.6202 (200.06 seconds)
# Cbc0010I After 11300 nodes, 575 on tree, 1e+50 best solution, best possible -7102.3942 (204.91 seconds)
# Cbc0010I After 11400 nodes, 619 on tree, 1e+50 best solution, best possible -7102.0707 (210.21 seconds)
# Cbc0010I After 11500 nodes, 660 on tree, 1e+50 best solution, best possible -7100.9104 (215.56 seconds)
# Cbc0010I After 11600 nodes, 705 on tree, 1e+50 best solution, best possible -7100.4603 (223.76 seconds)
# Cbc0010I After 11700 nodes, 734 on tree, 1e+50 best solution, best possible -7100.1861 (227.35 seconds)
# Cbc0010I After 11800 nodes, 772 on tree, 1e+50 best solution, best possible -7100.0169 (231.23 seconds)
# Cbc0010I After 11900 nodes, 813 on tree, 1e+50 best solution, best possible -7098.7916 (236.27 seconds)
# Cbc0010I After 12000 nodes, 845 on tree, 1e+50 best solution, best possible -7098.4067 (241.79 seconds)
# Cbc0010I After 12100 nodes, 875 on tree, 1e+50 best solution, best possible -7097.6676 (245.70 seconds)
# Cbc0010I After 12200 nodes, 905 on tree, 1e+50 best solution, best possible -7095.1365 (250.51 seconds)
# Cbc0010I After 12300 nodes, 933 on tree, 1e+50 best solution, best possible -7093.9275 (257.50 seconds)
# Cbc0010I After 12400 nodes, 976 on tree, 1e+50 best solution, best possible -7093.4122 (263.46 seconds)
# Cbc0010I After 12500 nodes, 1015 on tree, 1e+50 best solution, best possible -7092.8959 (268.58 seconds)
# Cbc0010I After 12600 nodes, 1047 on tree, 1e+50 best solution, best possible -7091.2681 (274.46 seconds)
# Cbc0010I After 12700 nodes, 1082 on tree, 1e+50 best solution, best possible -7090.0132 (279.21 seconds)
# Cbc0010I After 12800 nodes, 1119 on tree, 1e+50 best solution, best possible -7087.6054 (284.19 seconds)
# Cbc0010I After 12900 nodes, 1150 on tree, 1e+50 best solution, best possible -7085.377 (292.69 seconds)
# Cbc0010I After 13000 nodes, 1190 on tree, 1e+50 best solution, best possible -7084.6495 (297.40 seconds)
# Cbc0010I After 13100 nodes, 1262 on tree, 1e+50 best solution, best possible -7084.3355 (299.24 seconds)
# Cbc0010I After 13200 nodes, 1279 on tree, 1e+50 best solution, best possible -7084.3355 (299.97 seconds)
# Cbc0010I After 13300 nodes, 1274 on tree, 1e+50 best solution, best possible -7084.3355 (300.61 seconds)
# Cbc0010I After 13400 nodes, 1276 on tree, 1e+50 best solution, best possible -7084.3355 (301.25 seconds)
# Cbc0010I After 13500 nodes, 1268 on tree, 1e+50 best solution, best possible -7084.3355 (301.97 seconds)
# Cbc0010I After 13600 nodes, 1270 on tree, 1e+50 best solution, best possible -7084.3355 (302.63 seconds)
# Cbc0010I After 13700 nodes, 1271 on tree, 1e+50 best solution, best possible -7084.3355 (303.31 seconds)
# Cbc0010I After 13800 nodes, 1273 on tree, 1e+50 best solution, best possible -7084.3355 (303.90 seconds)
# Cbc0010I After 13900 nodes, 1275 on tree, 1e+50 best solution, best possible -7084.3355 (304.48 seconds)
# Cbc0010I After 14000 nodes, 1271 on tree, 1e+50 best solution, best possible -7084.3355 (305.08 seconds)
# Cbc0010I After 14100 nodes, 1275 on tree, 1e+50 best solution, best possible -7084.3355 (305.73 seconds)
# Cbc0010I After 14200 nodes, 1272 on tree, 1e+50 best solution, best possible -7084.3355 (306.27 seconds)
# Cbc0010I After 14300 nodes, 1272 on tree, 1e+50 best solution, best possible -7084.3355 (306.83 seconds)
# Cbc0010I After 14400 nodes, 1273 on tree, 1e+50 best solution, best possible -7084.3355 (307.48 seconds)
# Cbc0010I After 14500 nodes, 1271 on tree, 1e+50 best solution, best possible -7084.3355 (308.11 seconds)
# Cbc0010I After 14600 nodes, 1270 on tree, 1e+50 best solution, best possible -7084.3355 (308.77 seconds)
# Cbc0010I After 14700 nodes, 1275 on tree, 1e+50 best solution, best possible -7084.3355 (309.44 seconds)
# Cbc0010I After 14800 nodes, 1275 on tree, 1e+50 best solution, best possible -7084.3355 (310.08 seconds)
# Cbc0010I After 14900 nodes, 1272 on tree, 1e+50 best solution, best possible -7084.3355 (310.70 seconds)
# Cbc0010I After 15000 nodes, 1267 on tree, 1e+50 best solution, best possible -7084.3355 (311.57 seconds)
# Cbc0010I After 15100 nodes, 1269 on tree, 1e+50 best solution, best possible -7084.3355 (312.25 seconds)
# Cbc0010I After 15200 nodes, 1269 on tree, 1e+50 best solution, best possible -7084.3355 (312.92 seconds)
# Cbc0010I After 15300 nodes, 1268 on tree, 1e+50 best solution, best possible -7084.3355 (313.57 seconds)
# Cbc0010I After 15400 nodes, 1270 on tree, 1e+50 best solution, best possible -7084.3355 (314.25 seconds)
# Cbc0010I After 15500 nodes, 1270 on tree, 1e+50 best solution, best possible -7084.3355 (314.92 seconds)
# Cbc0010I After 15600 nodes, 1270 on tree, 1e+50 best solution, best possible -7084.3355 (315.76 seconds)
# Cbc0010I After 15700 nodes, 1271 on tree, 1e+50 best solution, best possible -7084.3355 (316.50 seconds)
# Cbc0010I After 15800 nodes, 1269 on tree, 1e+50 best solution, best possible -7084.3355 (317.25 seconds)
# Cbc0010I After 15900 nodes, 1268 on tree, 1e+50 best solution, best possible -7084.3355 (317.93 seconds)
# Cbc0010I After 16000 nodes, 1267 on tree, 1e+50 best solution, best possible -7084.3355 (318.80 seconds)
# Cbc0010I After 16100 nodes, 1267 on tree, 1e+50 best solution, best possible -7084.3355 (319.67 seconds)
# Cbc0010I After 16200 nodes, 1270 on tree, 1e+50 best solution, best possible -7084.3355 (320.54 seconds)
# Cbc0010I After 16300 nodes, 1269 on tree, 1e+50 best solution, best possible -7084.3355 (321.42 seconds)
# Cbc0010I After 16400 nodes, 1268 on tree, 1e+50 best solution, best possible -7084.3355 (325.25 seconds)
# Cbc0010I After 16500 nodes, 1277 on tree, 1e+50 best solution, best possible -7084.3355 (326.11 seconds)
# Cbc0010I After 16600 nodes, 1273 on tree, 1e+50 best solution, best possible -7084.3355 (326.86 seconds)
# Cbc0010I After 16700 nodes, 1271 on tree, 1e+50 best solution, best possible -7084.3355 (327.49 seconds)
# Cbc0010I After 16800 nodes, 1270 on tree, 1e+50 best solution, best possible -7084.3355 (328.22 seconds)
# Cbc0010I After 16900 nodes, 1266 on tree, 1e+50 best solution, best possible -7084.3355 (329.00 seconds)
# Cbc0010I After 17000 nodes, 1271 on tree, 1e+50 best solution, best possible -7084.3355 (329.63 seconds)
# Cbc0010I After 17100 nodes, 1312 on tree, 1e+50 best solution, best possible -7084.3279 (331.37 seconds)
# Cbc0012I Integer solution of -3957.0977 found by rounding after 967989 iterations and 17188 nodes (332.35 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1467 rows 739 columns
# Cbc0010I After 17200 nodes, 1364 on tree, -3957.0977 best solution, best possible -7084.3279 (332.95 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1504 rows 735 columns
# Cbc0010I After 17300 nodes, 1394 on tree, -3957.0977 best solution, best possible -7084.3279 (336.66 seconds)
# Cbc0010I After 17400 nodes, 1430 on tree, -3957.0977 best solution, best possible -7084.3279 (340.01 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1389 rows 698 columns
# Cbc0010I After 17500 nodes, 1460 on tree, -3957.0977 best solution, best possible -7084.3279 (343.42 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1457 rows 701 columns
# Cbc0010I After 17600 nodes, 1501 on tree, -3957.0977 best solution, best possible -7084.3279 (346.81 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1362 rows 700 columns
# Cbc0010I After 17700 nodes, 1535 on tree, -3957.0977 best solution, best possible -7084.3279 (350.77 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1412 rows 701 columns
# Cbc0010I After 17800 nodes, 1571 on tree, -3957.0977 best solution, best possible -7084.3279 (355.32 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1362 rows 672 columns
# Cbc0010I After 17900 nodes, 1602 on tree, -3957.0977 best solution, best possible -7084.3279 (361.88 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1492 rows 767 columns
# Cbc0010I After 18000 nodes, 1631 on tree, -3957.0977 best solution, best possible -7084.3279 (366.07 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1434 rows 732 columns
# Cbc0010I After 18100 nodes, 1665 on tree, -3957.0977 best solution, best possible -7082.3006 (370.59 seconds)
# Cbc0010I After 18200 nodes, 1708 on tree, -3957.0977 best solution, best possible -7081.7125 (374.47 seconds)
# Cbc0010I After 18300 nodes, 1751 on tree, -3957.0977 best solution, best possible -7081.4915 (379.33 seconds)
# Cbc0010I After 18400 nodes, 1788 on tree, -3957.0977 best solution, best possible -7081.0835 (383.73 seconds)
# Cbc0010I After 18500 nodes, 1824 on tree, -3957.0977 best solution, best possible -7080.9578 (387.91 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1508 rows 745 columns
# Cbc0010I After 18600 nodes, 1860 on tree, -3957.0977 best solution, best possible -7078.1646 (396.22 seconds)
# Cbc0010I After 18700 nodes, 1899 on tree, -3957.0977 best solution, best possible -7077.8005 (400.86 seconds)
# Cbc0010I After 18800 nodes, 1928 on tree, -3957.0977 best solution, best possible -7076.801 (405.05 seconds)
# Cbc0010I After 18900 nodes, 1969 on tree, -3957.0977 best solution, best possible -7076.4612 (408.19 seconds)
# Cbc0010I After 19000 nodes, 2016 on tree, -3957.0977 best solution, best possible -7076.3212 (411.47 seconds)
# Cbc0010I After 19100 nodes, 2049 on tree, -3957.0977 best solution, best possible -7074.1626 (416.32 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1543 rows 782 columns
# Cbc0010I After 19200 nodes, 2092 on tree, -3957.0977 best solution, best possible -7073.6984 (421.77 seconds)
# Cbc0010I After 19300 nodes, 2135 on tree, -3957.0977 best solution, best possible -7073.6708 (425.98 seconds)
# Cbc0010I After 19400 nodes, 2169 on tree, -3957.0977 best solution, best possible -7072.746 (434.04 seconds)
# Cbc0010I After 19500 nodes, 2210 on tree, -3957.0977 best solution, best possible -7072.1007 (438.87 seconds)
# Cbc0010I After 19600 nodes, 2257 on tree, -3957.0977 best solution, best possible -7072.0675 (443.19 seconds)
# Cbc0010I After 19700 nodes, 2294 on tree, -3957.0977 best solution, best possible -7071.8762 (447.43 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1481 rows 764 columns
# Cbc0010I After 19800 nodes, 2330 on tree, -3957.0977 best solution, best possible -7070.7546 (452.91 seconds)
# Cbc0010I After 19900 nodes, 2365 on tree, -3957.0977 best solution, best possible -7068.3533 (458.28 seconds)
# Cbc0010I After 20000 nodes, 2385 on tree, -3957.0977 best solution, best possible -7067.8497 (462.11 seconds)
# Cbc0010I After 20100 nodes, 2414 on tree, -3957.0977 best solution, best possible -7067.5438 (468.80 seconds)
# Cbc0010I After 20200 nodes, 2449 on tree, -3957.0977 best solution, best possible -7067.0187 (473.57 seconds)
# Cbc0010I After 20300 nodes, 2485 on tree, -3957.0977 best solution, best possible -7063.259 (479.67 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1519 rows 771 columns
# Cbc0010I After 20400 nodes, 2494 on tree, -3957.0977 best solution, best possible -7062.2287 (482.62 seconds)
# Cbc0010I After 20500 nodes, 2531 on tree, -3957.0977 best solution, best possible -7060.8039 (487.22 seconds)
# Cbc0010I After 20600 nodes, 2545 on tree, -3957.0977 best solution, best possible -7058.4905 (491.30 seconds)
# Cbc0010I After 20700 nodes, 2563 on tree, -3957.0977 best solution, best possible -7051.8277 (501.56 seconds)
# Cbc0010I After 20800 nodes, 2587 on tree, -3957.0977 best solution, best possible -7049.3153 (505.48 seconds)
# Cbc0010I After 20900 nodes, 2605 on tree, -3957.0977 best solution, best possible -7047.0012 (509.58 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1438 rows 695 columns
# Cbc0010I After 21000 nodes, 2647 on tree, -3957.0977 best solution, best possible -7045.7321 (514.50 seconds)
# Cbc0010I After 21100 nodes, 2707 on tree, -3957.0977 best solution, best possible -7045.7321 (516.58 seconds)
# Cbc0010I After 21200 nodes, 2711 on tree, -3957.0977 best solution, best possible -7045.7321 (517.40 seconds)
# Cbc0010I After 21300 nodes, 2710 on tree, -3957.0977 best solution, best possible -7045.7321 (518.15 seconds)
# Cbc0010I After 21400 nodes, 2708 on tree, -3957.0977 best solution, best possible -7045.7321 (518.94 seconds)
# Cbc0010I After 21500 nodes, 2714 on tree, -3957.0977 best solution, best possible -7045.7321 (519.78 seconds)
# Cbc0010I After 21600 nodes, 2708 on tree, -3957.0977 best solution, best possible -7045.7321 (520.74 seconds)
# Cbc0010I After 21700 nodes, 2712 on tree, -3957.0977 best solution, best possible -7045.7321 (521.66 seconds)
# Cbc0010I After 21800 nodes, 2729 on tree, -3957.0977 best solution, best possible -7045.7321 (522.62 seconds)
# Cbc0010I After 21900 nodes, 2726 on tree, -3957.0977 best solution, best possible -7045.7321 (523.36 seconds)
# Cbc0010I After 22000 nodes, 2726 on tree, -3957.0977 best solution, best possible -7045.7321 (524.13 seconds)
# Cbc0010I After 22100 nodes, 2770 on tree, -3957.0977 best solution, best possible -7043.9775 (528.65 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1479 rows 745 columns
# Cbc0010I After 22200 nodes, 2806 on tree, -3957.0977 best solution, best possible -7043.7813 (536.15 seconds)
# Cbc0010I After 22300 nodes, 2835 on tree, -3957.0977 best solution, best possible -7043.2394 (540.62 seconds)
# Cbc0010I After 22400 nodes, 2865 on tree, -3957.0977 best solution, best possible -7041.466 (547.45 seconds)
# Cbc0010I After 22500 nodes, 2904 on tree, -3957.0977 best solution, best possible -7041.0562 (555.01 seconds)
# Cbc0010I After 22600 nodes, 2944 on tree, -3957.0977 best solution, best possible -7040.3249 (559.59 seconds)
# Cbc0010I After 22700 nodes, 2971 on tree, -3957.0977 best solution, best possible -7039.9139 (563.38 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1412 rows 711 columns
# Cbc0010I After 22800 nodes, 3014 on tree, -3957.0977 best solution, best possible -7039.8725 (566.01 seconds)
# Cbc0010I After 22900 nodes, 3053 on tree, -3957.0977 best solution, best possible -7039.8274 (572.72 seconds)
# Cbc0010I After 23000 nodes, 3092 on tree, -3957.0977 best solution, best possible -7039.7516 (576.59 seconds)
# Cbc0010I After 23100 nodes, 3124 on tree, -3957.0977 best solution, best possible -7039.693 (580.42 seconds)
# Cbc0010I After 23200 nodes, 3150 on tree, -3957.0977 best solution, best possible -7039.4686 (584.90 seconds)
# Cbc0010I After 23300 nodes, 3174 on tree, -3957.0977 best solution, best possible -7039.4671 (588.82 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1419 rows 729 columns
# Cbc0010I After 23400 nodes, 3186 on tree, -3957.0977 best solution, best possible -7039.421 (593.32 seconds)
# Cbc0010I After 23500 nodes, 3220 on tree, -3957.0977 best solution, best possible -7039.3406 (597.11 seconds)
# Cbc0010I After 23600 nodes, 3250 on tree, -3957.0977 best solution, best possible -7039.196 (601.43 seconds)
# Cbc0010I After 23700 nodes, 3278 on tree, -3957.0977 best solution, best possible -7038.3618 (609.63 seconds)
# Cbc0010I After 23800 nodes, 3310 on tree, -3957.0977 best solution, best possible -7036.9091 (615.07 seconds)
# Cbc0010I After 23900 nodes, 3336 on tree, -3957.0977 best solution, best possible -7035.0503 (620.59 seconds)
# Cbc0010I After 24000 nodes, 3378 on tree, -3957.0977 best solution, best possible -7033.9343 (627.14 seconds)
# Cbc0010I After 24100 nodes, 3412 on tree, -3957.0977 best solution, best possible -7032.6918 (632.83 seconds)
# Cbc0010I After 24200 nodes, 3447 on tree, -3957.0977 best solution, best possible -7031.4804 (638.16 seconds)
# Cbc0010I After 24300 nodes, 3482 on tree, -3957.0977 best solution, best possible -7031.1074 (647.05 seconds)
# Cbc0010I After 24400 nodes, 3521 on tree, -3957.0977 best solution, best possible -7030.4707 (652.96 seconds)
# Cbc0010I After 24500 nodes, 3566 on tree, -3957.0977 best solution, best possible -7030.13 (658.45 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1355 rows 683 columns
# Cbc0010I After 24600 nodes, 3610 on tree, -3957.0977 best solution, best possible -7029.9001 (664.33 seconds)
# Cbc0010I After 24700 nodes, 3653 on tree, -3957.0977 best solution, best possible -7029.3956 (668.76 seconds)
# Cbc0010I After 24800 nodes, 3695 on tree, -3957.0977 best solution, best possible -7028.7849 (673.00 seconds)
# Cbc0010I After 24900 nodes, 3729 on tree, -3957.0977 best solution, best possible -7028.1911 (680.83 seconds)
# Cbc0010I After 25000 nodes, 3753 on tree, -3957.0977 best solution, best possible -7026.8209 (685.24 seconds)
# Cbc0010I After 25100 nodes, 3777 on tree, -3957.0977 best solution, best possible -7026.8209 (686.80 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1101 rows 541 columns
# Cbc0010I After 25200 nodes, 3820 on tree, -3957.0977 best solution, best possible -7026.8209 (688.00 seconds)
# Cbc0010I After 25300 nodes, 3813 on tree, -3957.0977 best solution, best possible -7026.8209 (688.89 seconds)
# Cbc0010I After 25400 nodes, 3795 on tree, -3957.0977 best solution, best possible -7026.8209 (689.98 seconds)
# Cbc0010I After 25500 nodes, 3792 on tree, -3957.0977 best solution, best possible -7026.8209 (691.27 seconds)
# Cbc0010I After 25600 nodes, 3794 on tree, -3957.0977 best solution, best possible -7026.8209 (692.42 seconds)
# Cbc0010I After 25700 nodes, 3792 on tree, -3957.0977 best solution, best possible -7026.8209 (693.45 seconds)
# Cbc0010I After 25800 nodes, 3793 on tree, -3957.0977 best solution, best possible -7026.8209 (694.56 seconds)
# Cbc0010I After 25900 nodes, 3792 on tree, -3957.0977 best solution, best possible -7026.8209 (695.53 seconds)
# Cbc0010I After 26000 nodes, 3799 on tree, -3957.0977 best solution, best possible -7026.8209 (696.68 seconds)
# Cbc0010I After 26100 nodes, 3837 on tree, -3957.0977 best solution, best possible -7025.3733 (702.50 seconds)
# Cbc0010I After 26200 nodes, 3873 on tree, -3957.0977 best solution, best possible -7024.9662 (706.45 seconds)
# Cbc0010I After 26300 nodes, 3907 on tree, -3957.0977 best solution, best possible -7023.5372 (713.81 seconds)
# Cbc0010I After 26400 nodes, 3939 on tree, -3957.0977 best solution, best possible -7023.2995 (717.50 seconds)
# Cbc0010I After 26500 nodes, 3970 on tree, -3957.0977 best solution, best possible -7022.2815 (721.20 seconds)
# Cbc0010I After 26600 nodes, 3989 on tree, -3957.0977 best solution, best possible -7020.1852 (725.38 seconds)
# Cbc0010I After 26700 nodes, 4031 on tree, -3957.0977 best solution, best possible -7019.9792 (730.52 seconds)
# Cbc0010I After 26800 nodes, 4073 on tree, -3957.0977 best solution, best possible -7019.8656 (735.72 seconds)
# Cbc0010I After 26900 nodes, 4119 on tree, -3957.0977 best solution, best possible -7019.7814 (739.99 seconds)
# Cbc0010I After 27000 nodes, 4161 on tree, -3957.0977 best solution, best possible -7019.7736 (743.16 seconds)
# Cbc0010I After 27100 nodes, 4200 on tree, -3957.0977 best solution, best possible -7019.7623 (749.35 seconds)
# Cbc0010I After 27200 nodes, 4243 on tree, -3957.0977 best solution, best possible -7019.641 (753.82 seconds)
# Cbc0010I After 27300 nodes, 4285 on tree, -3957.0977 best solution, best possible -7019.5958 (757.61 seconds)
# Cbc0010I After 27400 nodes, 4326 on tree, -3957.0977 best solution, best possible -7019.5825 (761.73 seconds)
# Cbc0010I After 27500 nodes, 4371 on tree, -3957.0977 best solution, best possible -7019.5759 (765.01 seconds)
# Cbc0010I After 27600 nodes, 4413 on tree, -3957.0977 best solution, best possible -7019.5683 (768.91 seconds)
# Cbc0010I After 27700 nodes, 4451 on tree, -3957.0977 best solution, best possible -7019.5634 (772.61 seconds)
# Cbc0010I After 27800 nodes, 4488 on tree, -3957.0977 best solution, best possible -7019.5568 (776.76 seconds)
# Cbc0010I After 27900 nodes, 4529 on tree, -3957.0977 best solution, best possible -7019.5555 (783.40 seconds)
# Cbc0010I After 28000 nodes, 4567 on tree, -3957.0977 best solution, best possible -7019.5113 (786.84 seconds)
# Cbc0010I After 28100 nodes, 4611 on tree, -3957.0977 best solution, best possible -7019.4718 (791.40 seconds)
# Cbc0010I After 28200 nodes, 4659 on tree, -3957.0977 best solution, best possible -7019.4332 (794.90 seconds)
# Cbc0010I After 28300 nodes, 4701 on tree, -3957.0977 best solution, best possible -7018.5919 (799.53 seconds)
# Cbc0010I After 28400 nodes, 4743 on tree, -3957.0977 best solution, best possible -7018.209 (803.90 seconds)
# Cbc0010I After 28500 nodes, 4788 on tree, -3957.0977 best solution, best possible -7018.0105 (808.82 seconds)
# Cbc0010I After 28600 nodes, 4825 on tree, -3957.0977 best solution, best possible -7017.058 (813.57 seconds)
# Cbc0010I After 28700 nodes, 4873 on tree, -3957.0977 best solution, best possible -7016.7822 (820.93 seconds)
# Cbc0010I After 28800 nodes, 4880 on tree, -3957.0977 best solution, best possible -7016.769 (823.94 seconds)
# Cbc0010I After 28900 nodes, 4910 on tree, -3957.0977 best solution, best possible -7016.7621 (827.48 seconds)
# Cbc0010I After 29000 nodes, 4944 on tree, -3957.0977 best solution, best possible -7016.757 (832.07 seconds)
# Cbc0010I After 29100 nodes, 4937 on tree, -3957.0977 best solution, best possible -7016.757 (833.13 seconds)
# Cbc0010I After 29200 nodes, 4938 on tree, -3957.0977 best solution, best possible -7016.757 (834.21 seconds)
# Cbc0010I After 29300 nodes, 4931 on tree, -3957.0977 best solution, best possible -7016.757 (834.99 seconds)
# Cbc0010I After 29400 nodes, 4926 on tree, -3957.0977 best solution, best possible -7016.757 (835.78 seconds)
# Cbc0010I After 29500 nodes, 4924 on tree, -3957.0977 best solution, best possible -7016.757 (836.64 seconds)
# Cbc0010I After 29600 nodes, 4923 on tree, -3957.0977 best solution, best possible -7016.757 (837.66 seconds)
# Cbc0010I After 29700 nodes, 4919 on tree, -3957.0977 best solution, best possible -7016.757 (838.58 seconds)
# Cbc0010I After 29800 nodes, 4919 on tree, -3957.0977 best solution, best possible -7016.757 (839.49 seconds)
# Cbc0010I After 29900 nodes, 4949 on tree, -3957.0977 best solution, best possible -7016.757 (840.53 seconds)
# Cbc0010I After 30000 nodes, 4954 on tree, -3957.0977 best solution, best possible -7016.757 (841.64 seconds)
# Cbc0010I After 30100 nodes, 4997 on tree, -3957.0977 best solution, best possible -7016.7523 (846.69 seconds)
# Cbc0010I After 30200 nodes, 5041 on tree, -3957.0977 best solution, best possible -7016.7496 (852.83 seconds)
# Cbc0010I After 30300 nodes, 5078 on tree, -3957.0977 best solution, best possible -7016.7184 (856.19 seconds)
# Cbc0010I After 30400 nodes, 5116 on tree, -3957.0977 best solution, best possible -7016.7108 (858.94 seconds)
# Cbc0010I After 30500 nodes, 5159 on tree, -3957.0977 best solution, best possible -7016.7073 (862.05 seconds)
# Cbc0010I After 30600 nodes, 5202 on tree, -3957.0977 best solution, best possible -7016.7041 (865.31 seconds)
# Cbc0010I After 30700 nodes, 5243 on tree, -3957.0977 best solution, best possible -7016.7031 (867.86 seconds)
# Cbc0010I After 30800 nodes, 5283 on tree, -3957.0977 best solution, best possible -7016.6983 (871.08 seconds)
# Cbc0010I After 30900 nodes, 5325 on tree, -3957.0977 best solution, best possible -7016.6968 (873.99 seconds)
# Cbc0010I After 31000 nodes, 5368 on tree, -3957.0977 best solution, best possible -7016.6926 (877.24 seconds)
# Cbc0010I After 31100 nodes, 5407 on tree, -3957.0977 best solution, best possible -7016.6717 (880.39 seconds)
# Cbc0010I After 31200 nodes, 5437 on tree, -3957.0977 best solution, best possible -7016.6258 (883.06 seconds)
# Cbc0010I After 31300 nodes, 5476 on tree, -3957.0977 best solution, best possible -7016.5927 (888.91 seconds)
# Cbc0010I After 31400 nodes, 5520 on tree, -3957.0977 best solution, best possible -7016.5927 (892.08 seconds)
# Cbc0010I After 31500 nodes, 5563 on tree, -3957.0977 best solution, best possible -7016.5836 (895.72 seconds)
# Cbc0010I After 31600 nodes, 5600 on tree, -3957.0977 best solution, best possible -7016.5831 (898.89 seconds)
# Cbc0010I After 31700 nodes, 5638 on tree, -3957.0977 best solution, best possible -7016.5799 (902.17 seconds)
# Cbc0010I After 31800 nodes, 5685 on tree, -3957.0977 best solution, best possible -7016.5731 (905.27 seconds)
# Cbc0010I After 31900 nodes, 5726 on tree, -3957.0977 best solution, best possible -7016.5724 (908.60 seconds)
# Cbc0010I After 32000 nodes, 5771 on tree, -3957.0977 best solution, best possible -7016.5684 (912.36 seconds)
# Cbc0010I After 32100 nodes, 5816 on tree, -3957.0977 best solution, best possible -7016.5677 (916.70 seconds)
# Cbc0010I After 32200 nodes, 5860 on tree, -3957.0977 best solution, best possible -7016.5354 (920.76 seconds)
# Cbc0010I After 32300 nodes, 5888 on tree, -3957.0977 best solution, best possible -7016.4955 (923.95 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1549 rows 747 columns
# Cbc0010I After 32400 nodes, 5930 on tree, -3957.0977 best solution, best possible -7016.4597 (928.01 seconds)
# Cbc0010I After 32500 nodes, 5970 on tree, -3957.0977 best solution, best possible -7016.3653 (932.00 seconds)
# Cbc0010I After 32600 nodes, 6000 on tree, -3957.0977 best solution, best possible -7016.1756 (941.93 seconds)
# Cbc0010I After 32700 nodes, 6041 on tree, -3957.0977 best solution, best possible -7016.0869 (947.43 seconds)
# Cbc0010I After 32800 nodes, 6072 on tree, -3957.0977 best solution, best possible -7015.2364 (953.77 seconds)
# Cbc0010I After 32900 nodes, 6105 on tree, -3957.0977 best solution, best possible -7015.2096 (956.84 seconds)
# Cbc0010I After 33000 nodes, 6138 on tree, -3957.0977 best solution, best possible -7015.2052 (960.03 seconds)
# Cbc0004I Integer solution of -4836.581 found after 3867211 iterations and 33051 nodes (960.86 seconds)
# Cbc0010I After 33100 nodes, 5834 on tree, -4836.581 best solution, best possible -7015.2052 (962.62 seconds)
# Cbc0010I After 33200 nodes, 5876 on tree, -4836.581 best solution, best possible -7015.2052 (965.75 seconds)
# Cbc0010I After 33300 nodes, 5919 on tree, -4836.581 best solution, best possible -7015.2052 (969.64 seconds)
# Cbc0010I After 33400 nodes, 5960 on tree, -4836.581 best solution, best possible -7015.2052 (976.08 seconds)
# Cbc0010I After 33500 nodes, 6005 on tree, -4836.581 best solution, best possible -7015.2052 (980.50 seconds)
# Cbc0010I After 33600 nodes, 6052 on tree, -4836.581 best solution, best possible -7015.2052 (984.20 seconds)
# Cbc0010I After 33700 nodes, 6099 on tree, -4836.581 best solution, best possible -7015.2052 (988.62 seconds)
# Cbc0010I After 33800 nodes, 6132 on tree, -4836.581 best solution, best possible -7015.2052 (992.44 seconds)
# Cbc0010I After 33900 nodes, 6172 on tree, -4836.581 best solution, best possible -7015.2052 (996.71 seconds)
# Cbc0010I After 34000 nodes, 6217 on tree, -4836.581 best solution, best possible -7015.2052 (1000.56 seconds)
# Cbc0010I After 34100 nodes, 6257 on tree, -4836.581 best solution, best possible -7015.1316 (1004.64 seconds)
# Cbc0010I After 34200 nodes, 6299 on tree, -4836.581 best solution, best possible -7015.0839 (1011.89 seconds)
# Cbc0010I After 34300 nodes, 6335 on tree, -4836.581 best solution, best possible -7015.014 (1016.11 seconds)
# Cbc0010I After 34400 nodes, 6367 on tree, -4836.581 best solution, best possible -7014.9984 (1020.30 seconds)
# Cbc0010I After 34500 nodes, 6411 on tree, -4836.581 best solution, best possible -7014.9197 (1024.42 seconds)
# Cbc0010I After 34600 nodes, 6445 on tree, -4836.581 best solution, best possible -7014.7371 (1028.57 seconds)
# Cbc0010I After 34700 nodes, 6487 on tree, -4836.581 best solution, best possible -7014.609 (1033.21 seconds)
# Cbc0010I After 34800 nodes, 6518 on tree, -4836.581 best solution, best possible -7014.4533 (1038.47 seconds)
# Cbc0010I After 34900 nodes, 6563 on tree, -4836.581 best solution, best possible -7013.9767 (1046.21 seconds)
# Cbc0010I After 35000 nodes, 6604 on tree, -4836.581 best solution, best possible -7013.7391 (1050.43 seconds)
# Cbc0010I After 35100 nodes, 6638 on tree, -4836.581 best solution, best possible -7013.7391 (1053.70 seconds)
# Cbc0010I After 35200 nodes, 6672 on tree, -4836.581 best solution, best possible -7013.7391 (1057.17 seconds)
# Cbc0010I After 35300 nodes, 6699 on tree, -4836.581 best solution, best possible -7013.7391 (1060.18 seconds)
# Cbc0010I After 35400 nodes, 6730 on tree, -4836.581 best solution, best possible -7013.719 (1064.20 seconds)
# Cbc0010I After 35500 nodes, 6763 on tree, -4836.581 best solution, best possible -7013.6503 (1068.13 seconds)
# Cbc0010I After 35600 nodes, 6794 on tree, -4836.581 best solution, best possible -7013.5849 (1071.86 seconds)
# Cbc0010I After 35700 nodes, 6830 on tree, -4836.581 best solution, best possible -7013.4707 (1075.14 seconds)
# Cbc0010I After 35800 nodes, 6866 on tree, -4836.581 best solution, best possible -7013.4618 (1082.31 seconds)
# Cbc0010I After 35900 nodes, 6909 on tree, -4836.581 best solution, best possible -7013.4392 (1086.29 seconds)
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1824 rows 802 columns - 79 fixed gives 1648, 648 - ok now
# Cbc0038I Full problem 3180 rows 2136 columns, reduced to 1026 rows 554 columns
# Cbc0010I After 36000 nodes, 6951 on tree, -4836.581 best solution, best possible -7013.369 (1090.28 seconds)
# Cbc0010I After 36100 nodes, 6993 on tree, -4836.581 best solution, best possible -7013.3523 (1094.76 seconds)
# Cbc0010I After 36200 nodes, 7023 on tree, -4836.581 best solution, best possible -7013.3397 (1097.93 seconds)
# Cbc0010I After 36300 nodes, 7056 on tree, -4836.581 best solution, best possible -7013.3289 (1101.32 seconds)
# Cbc0010I After 36400 nodes, 7090 on tree, -4836.581 best solution, best possible -7013.3082 (1105.26 seconds)
# Cbc0010I After 36500 nodes, 7102 on tree, -4836.581 best solution, best possible -7013.2549 (1109.48 seconds)
# Cbc0010I After 36600 nodes, 7138 on tree, -4836.581 best solution, best possible -7013.1979 (1117.63 seconds)
# Cbc0010I After 36700 nodes, 7165 on tree, -4836.581 best solution, best possible -7013.1979 (1121.44 seconds)
# Cbc0010I After 36800 nodes, 7203 on tree, -4836.581 best solution, best possible -7013.1827 (1125.79 seconds)
# Cbc0010I After 36900 nodes, 7240 on tree, -4836.581 best solution, best possible -7013.1499 (1130.15 seconds)
# Cbc0010I After 37000 nodes, 7274 on tree, -4836.581 best solution, best possible -7013.0046 (1134.25 seconds)
# Cbc0010I After 37100 nodes, 7272 on tree, -4836.581 best solution, best possible -7013.0046 (1135.40 seconds)
# Cbc0010I After 37200 nodes, 7278 on tree, -4836.581 best solution, best possible -7013.0046 (1136.28 seconds)
# Cbc0010I After 37300 nodes, 7277 on tree, -4836.581 best solution, best possible -7013.0046 (1137.25 seconds)
# Cbc0010I After 37400 nodes, 7283 on tree, -4836.581 best solution, best possible -7013.0046 (1138.33 seconds)
# Cbc0010I After 37500 nodes, 7277 on tree, -4836.581 best solution, best possible -7013.0046 (1139.23 seconds)
# ...
# Cbc0010I After 161100 nodes, 14160 on tree, -4964.981 best solution, best possible -7001.6196 (3444.09 seconds)
# Cbc0010I After 161200 nodes, 14153 on tree, -4964.981 best solution, best possible -7001.6196 (3445.48 seconds)
# Cbc0010I After 161300 nodes, 14160 on tree, -4964.981 best solution, best possible -7001.6196 (3446.72 seconds)
# Cbc0010I After 161400 nodes, 14158 on tree, -4964.981 best solution, best possible -7001.6196 (3448.19 seconds)
# Cbc0010I After 161500 nodes, 14156 on tree, -4964.981 best solution, best possible -7001.6196 (3449.97 seconds)
# Cbc0010I After 161600 nodes, 14154 on tree, -4964.981 best solution, best possible -7001.6196 (3451.63 seconds)
# Cbc0010I After 161700 nodes, 14150 on tree, -4964.981 best solution, best possible -7001.6196 (3453.28 seconds)
# Cbc0010I After 161800 nodes, 14156 on tree, -4964.981 best solution, best possible -7001.6196 (3455.03 seconds)
# Cbc0010I After 161900 nodes, 14151 on tree, -4964.981 best solution, best possible -7001.6196 (3456.70 seconds)
# Cbc0010I After 162000 nodes, 14159 on tree, -4964.981 best solution, best possible -7001.6196 (3458.38 seconds)
# Cbc0010I After 162100 nodes, 14157 on tree, -4964.981 best solution, best possible -7001.6196 (3460.07 seconds)
# Cbc0010I After 162200 nodes, 14158 on tree, -4964.981 best solution, best possible -7001.6196 (3461.60 seconds)
# Cbc0010I After 162300 nodes, 14159 on tree, -4964.981 best solution, best possible -7001.6196 (3463.08 seconds)
# Cbc0010I After 162400 nodes, 14157 on tree, -4964.981 best solution, best possible -7001.6196 (3464.50 seconds)
# Cbc0010I After 162500 nodes, 14159 on tree, -4964.981 best solution, best possible -7001.6196 (3466.26 seconds)
# Cbc0010I After 162600 nodes, 14156 on tree, -4964.981 best solution, best possible -7001.6196 (3467.83 seconds)
# Cbc0010I After 162700 nodes, 14152 on tree, -4964.981 best solution, best possible -7001.6196 (3469.62 seconds)
# Cbc0010I After 162800 nodes, 14151 on tree, -4964.981 best solution, best possible -7001.6196 (3471.15 seconds)
# Cbc0010I After 162900 nodes, 14159 on tree, -4964.981 best solution, best possible -7001.6196 (3472.93 seconds)
# Cbc0010I After 163000 nodes, 14157 on tree, -4964.981 best solution, best possible -7001.6196 (3474.87 seconds)
# Cbc0010I After 163100 nodes, 14158 on tree, -4964.981 best solution, best possible -7001.6196 (3476.44 seconds)
# Cbc0010I After 163200 nodes, 14158 on tree, -4964.981 best solution, best possible -7001.6196 (3478.21 seconds)
# Cbc0010I After 163300 nodes, 14159 on tree, -4964.981 best solution, best possible -7001.6196 (3480.04 seconds)
# Cbc0010I After 163400 nodes, 14157 on tree, -4964.981 best solution, best possible -7001.6196 (3481.68 seconds)
# Cbc0010I After 163500 nodes, 14157 on tree, -4964.981 best solution, best possible -7001.6196 (3483.31 seconds)
# Cbc0010I After 163600 nodes, 14160 on tree, -4964.981 best solution, best possible -7001.6196 (3484.91 seconds)
# Cbc0010I After 163700 nodes, 14156 on tree, -4964.981 best solution, best possible -7001.6196 (3486.37 seconds)
# Cbc0010I After 163800 nodes, 14156 on tree, -4964.981 best solution, best possible -7001.6196 (3487.73 seconds)
# Cbc0010I After 163900 nodes, 14156 on tree, -4964.981 best solution, best possible -7001.6196 (3489.33 seconds)
# Cbc0010I After 164000 nodes, 14151 on tree, -4964.981 best solution, best possible -7001.6196 (3490.81 seconds)
# Cbc0010I After 164100 nodes, 14154 on tree, -4964.981 best solution, best possible -7001.6196 (3492.64 seconds)
# Cbc0010I After 164200 nodes, 14153 on tree, -4964.981 best solution, best possible -7001.6196 (3501.64 seconds)
# Cbc0010I After 164300 nodes, 14148 on tree, -4964.981 best solution, best possible -7001.6196 (3504.03 seconds)
# Cbc0010I After 164400 nodes, 14152 on tree, -4964.981 best solution, best possible -7001.6196 (3506.15 seconds)
# Cbc0010I After 164500 nodes, 14150 on tree, -4964.981 best solution, best possible -7001.6196 (3508.36 seconds)
# Cbc0010I After 164600 nodes, 14152 on tree, -4964.981 best solution, best possible -7001.6196 (3509.91 seconds)
# Cbc0010I After 164700 nodes, 14147 on tree, -4964.981 best solution, best possible -7001.6196 (3512.10 seconds)
# Cbc0010I After 164800 nodes, 14147 on tree, -4964.981 best solution, best possible -7001.6196 (3514.74 seconds)
# Cbc0010I After 164900 nodes, 14149 on tree, -4964.981 best solution, best possible -7001.6196 (3517.13 seconds)
# Cbc0010I After 165000 nodes, 14159 on tree, -4964.981 best solution, best possible -7001.6196 (3518.68 seconds)
# Cbc0010I After 165100 nodes, 14163 on tree, -4964.981 best solution, best possible -7001.6196 (3519.74 seconds)
# Cbc0010I After 165200 nodes, 14165 on tree, -4964.981 best solution, best possible -7001.6196 (3520.85 seconds)
# Cbc0010I After 165300 nodes, 14164 on tree, -4964.981 best solution, best possible -7001.6196 (3522.07 seconds)
# Cbc0010I After 165400 nodes, 14162 on tree, -4964.981 best solution, best possible -7001.6196 (3523.56 seconds)
# Cbc0010I After 165500 nodes, 14163 on tree, -4964.981 best solution, best possible -7001.6196 (3524.84 seconds)
# Cbc0010I After 165600 nodes, 14156 on tree, -4964.981 best solution, best possible -7001.6196 (3525.86 seconds)
# Cbc0010I After 165700 nodes, 14160 on tree, -4964.981 best solution, best possible -7001.6196 (3526.69 seconds)
# Cbc0010I After 165800 nodes, 14162 on tree, -4964.981 best solution, best possible -7001.6196 (3527.99 seconds)
# Cbc0010I After 165900 nodes, 14161 on tree, -4964.981 best solution, best possible -7001.6196 (3529.05 seconds)
# Cbc0010I After 166000 nodes, 14167 on tree, -4964.981 best solution, best possible -7001.6196 (3530.27 seconds)
# Cbc0010I After 166100 nodes, 14162 on tree, -4964.981 best solution, best possible -7001.6196 (3531.41 seconds)
# Cbc0010I After 166200 nodes, 14162 on tree, -4964.981 best solution, best possible -7001.6196 (3532.62 seconds)
# Cbc0010I After 166300 nodes, 14168 on tree, -4964.981 best solution, best possible -7001.6196 (3536.79 seconds)
# Cbc0010I After 166400 nodes, 14157 on tree, -4964.981 best solution, best possible -7001.6196 (3538.06 seconds)
# Cbc0010I After 166500 nodes, 14157 on tree, -4964.981 best solution, best possible -7001.6196 (3539.24 seconds)
# Cbc0010I After 166600 nodes, 14156 on tree, -4964.981 best solution, best possible -7001.6196 (3540.28 seconds)
# Cbc0010I After 166700 nodes, 14157 on tree, -4964.981 best solution, best possible -7001.6196 (3541.41 seconds)
# Cbc0010I After 166800 nodes, 14159 on tree, -4964.981 best solution, best possible -7001.6196 (3542.40 seconds)
# Cbc0010I After 166900 nodes, 14160 on tree, -4964.981 best solution, best possible -7001.6196 (3543.43 seconds)
# Cbc0010I After 167000 nodes, 14158 on tree, -4964.981 best solution, best possible -7001.6196 (3544.85 seconds)
# Cbc0010I After 167100 nodes, 14160 on tree, -4964.981 best solution, best possible -7001.6196 (3546.26 seconds)
# Cbc0010I After 167200 nodes, 14156 on tree, -4964.981 best solution, best possible -7001.6196 (3547.59 seconds)
# Cbc0010I After 167300 nodes, 14156 on tree, -4964.981 best solution, best possible -7001.6196 (3548.67 seconds)
# Cbc0010I After 167400 nodes, 14156 on tree, -4964.981 best solution, best possible -7001.6196 (3549.80 seconds)
# Cbc0010I After 167500 nodes, 14162 on tree, -4964.981 best solution, best possible -7001.6196 (3550.85 seconds)
# Cbc0010I After 167600 nodes, 14162 on tree, -4964.981 best solution, best possible -7001.6196 (3551.67 seconds)
# Cbc0010I After 167700 nodes, 14162 on tree, -4964.981 best solution, best possible -7001.6196 (3552.89 seconds)
# Cbc0010I After 167800 nodes, 14167 on tree, -4964.981 best solution, best possible -7001.6196 (3553.86 seconds)
# Cbc0010I After 167900 nodes, 14180 on tree, -4964.981 best solution, best possible -7001.6196 (3554.99 seconds)
# Cbc0010I After 168000 nodes, 14178 on tree, -4964.981 best solution, best possible -7001.6196 (3556.07 seconds)
# Cbc0010I After 168100 nodes, 14176 on tree, -4964.981 best solution, best possible -7001.6196 (3557.01 seconds)
# Cbc0010I After 168200 nodes, 14179 on tree, -4964.981 best solution, best possible -7001.6196 (3557.92 seconds)
# Cbc0010I After 168300 nodes, 14173 on tree, -4964.981 best solution, best possible -7001.6196 (3559.25 seconds)
# Cbc0010I After 168400 nodes, 14180 on tree, -4964.981 best solution, best possible -7001.6196 (3560.41 seconds)
# Cbc0010I After 168500 nodes, 14179 on tree, -4964.981 best solution, best possible -7001.6196 (3561.57 seconds)
# Cbc0010I After 168600 nodes, 14178 on tree, -4964.981 best solution, best possible -7001.6196 (3562.51 seconds)
# Cbc0010I After 168700 nodes, 14178 on tree, -4964.981 best solution, best possible -7001.6196 (3563.18 seconds)
# Cbc0010I After 168800 nodes, 14176 on tree, -4964.981 best solution, best possible -7001.6196 (3563.90 seconds)
# Cbc0010I After 168900 nodes, 14177 on tree, -4964.981 best solution, best possible -7001.6196 (3564.69 seconds)
# Cbc0010I After 169000 nodes, 14178 on tree, -4964.981 best solution, best possible -7001.6196 (3565.79 seconds)
# Cbc0010I After 169100 nodes, 14175 on tree, -4964.981 best solution, best possible -7001.6196 (3566.93 seconds)
# Cbc0010I After 169200 nodes, 14178 on tree, -4964.981 best solution, best possible -7001.6196 (3567.72 seconds)
# Cbc0010I After 169300 nodes, 14175 on tree, -4964.981 best solution, best possible -7001.6196 (3571.71 seconds)
# Cbc0010I After 169400 nodes, 14158 on tree, -4964.981 best solution, best possible -7001.6196 (3572.63 seconds)
# Cbc0010I After 169500 nodes, 14157 on tree, -4964.981 best solution, best possible -7001.6196 (3573.70 seconds)
# Cbc0010I After 169600 nodes, 14154 on tree, -4964.981 best solution, best possible -7001.6196 (3574.71 seconds)
# Cbc0010I After 169700 nodes, 14158 on tree, -4964.981 best solution, best possible -7001.6196 (3576.22 seconds)
# Cbc0010I After 169800 nodes, 14157 on tree, -4964.981 best solution, best possible -7001.6196 (3577.49 seconds)
# Cbc0010I After 169900 nodes, 14158 on tree, -4964.981 best solution, best possible -7001.6196 (3578.70 seconds)
# Cbc0010I After 170000 nodes, 14155 on tree, -4964.981 best solution, best possible -7001.6196 (3580.04 seconds)
# Cbc0010I After 170100 nodes, 14149 on tree, -4964.981 best solution, best possible -7001.6196 (3581.31 seconds)
# Cbc0010I After 170200 nodes, 14162 on tree, -4964.981 best solution, best possible -7001.6196 (3584.00 seconds)
# Cbc0010I After 170300 nodes, 14157 on tree, -4964.981 best solution, best possible -7001.6196 (3585.69 seconds)
# Cbc0010I After 170400 nodes, 14157 on tree, -4964.981 best solution, best possible -7001.6196 (3587.38 seconds)
# Cbc0010I After 170500 nodes, 14156 on tree, -4964.981 best solution, best possible -7001.6196 (3589.11 seconds)
# Cbc0010I After 170600 nodes, 14152 on tree, -4964.981 best solution, best possible -7001.6196 (3590.98 seconds)
# Cbc0010I After 170700 nodes, 14146 on tree, -4964.981 best solution, best possible -7001.6196 (3592.82 seconds)
# Cbc0010I After 170800 nodes, 14150 on tree, -4964.981 best solution, best possible -7001.6196 (3594.45 seconds)
# Cbc0010I After 170900 nodes, 14147 on tree, -4964.981 best solution, best possible -7001.6196 (3596.35 seconds)
# Cbc0010I After 171000 nodes, 14150 on tree, -4964.981 best solution, best possible -7001.6196 (3598.75 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective -4964.981 (best possible -7001.6196), took 15362394 iterations and 171050 nodes (3600.30 seconds)
# Cbc0032I Strong branching done 125542 times (2002212 iterations), fathomed 11698 nodes and fixed 14728 variables
# Cbc0035I Maximum depth 233, 20161 variables fixed on reduced cost
# Cuts at root node changed objective from -8389.84 to -7134.36
# Probing was tried 173781 times and created 8065590 cuts of which 64 were active after adding rounds of cuts (310.836 seconds)
# Gomory was tried 149758 times and created 1077362 cuts of which 0 were active after adding rounds of cuts (514.510 seconds)
# Knapsack was tried 11 times and created 20 cuts of which 0 were active after adding rounds of cuts (0.023 seconds)
# Clique was tried 11 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# MixedIntegerRounding2 was tried 149758 times and created 897093 cuts of which 0 were active after adding rounds of cuts (182.443 seconds)
# FlowCover was tried 11 times and created 90 cuts of which 0 were active after adding rounds of cuts (0.021 seconds)
# TwoMirCuts was tried 149757 times and created 271283 cuts of which 0 were active after adding rounds of cuts (112.641 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# ImplicationCuts was tried 569 times and created 4794 cuts of which 0 were active after adding rounds of cuts (0.052 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                4964.98104000
# Upper bound:                    7001.620
# Gap:                            -0.29
# Enumerated nodes:               171050
# Total iterations:               15362394
# Time (CPU seconds):             3571.44
# Time (Wallclock seconds):       3600.40
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       3571.48   (Wallclock seconds):       3600.47
#
# Status: Optimal
# Total Profit: 4964.981039999992
# Product    day        SubProduction Production   Sales      Storage
# Chleb_domowy_0_5kg Pon        219.0        132.0        132.0      87.0
# Chleb_domowy_0_5kg Wt         210.0        87.0         87.0       210.0
# Chleb_domowy_0_5kg Sr         240.0        163.0        163.0      287.0
# Chleb_domowy_0_5kg Czw        0.0          134.0        134.0      153.0
# Chleb_domowy_0_5kg Pt         0.0          110.0        110.0      43.0
# Chleb_domowy_0_5kg Sob        1.0          43.0         43.0       0.0
# Chleb_domowy_0_9kg Pon        130.0        95.0         95.0       35.0
# Chleb_domowy_0_9kg Wt         0.0          1.0          1.0        34.0
# Chleb_domowy_0_9kg Sr         0.0          34.0         34.0       0.0
# Chleb_domowy_0_9kg Czw        122.0        0.0          0.0        122.0
# Chleb_domowy_0_9kg Pt         1.0          64.0         64.0       58.0
# Chleb_domowy_0_9kg Sob        0.0          58.0         58.0       0.0
# Chleb_na_zakwasie Pon        0.0          0.0          0.0        0.0
# Chleb_na_zakwasie Wt         200.0        0.0          0.0        200.0
# Chleb_na_zakwasie Sr         200.0        160.0        160.0      240.0
# Chleb_na_zakwasie Czw        1.0          39.0         39.0       201.0
# Chleb_na_zakwasie Pt         78.0         200.0        200.0      79.0
# Chleb_na_zakwasie Sob        1.0          79.0         79.0       0.0
# Bulki      Pon        200.0        93.0         93.0       107.0
# Bulki      Wt         135.0        107.0        107.0      135.0
# Bulki      Sr         200.0        135.0        135.0      200.0
# Bulki      Czw        80.0         79.0         79.0       201.0
# Bulki      Pt         44.0         145.0        145.0      100.0
# Bulki      Sob        1.0          100.0        100.0      0.0
# Bagietki   Pon        172.0        76.0         76.0       96.0
# Bagietki   Wt         176.0        72.0         72.0       200.0
# Bagietki   Sr         153.0        200.0        200.0      153.0
# Bagietki   Czw        1.0          88.0         88.0       65.0
# Bagietki   Pt         154.0        65.0         65.0       154.0
# Bagietki   Sob        1.0          154.0        154.0      0.0
# Rogaliki_z_czekolada Pon        200.0        169.0        169.0      31.0
# Rogaliki_z_czekolada Wt         126.0        31.0         31.0       126.0
# Rogaliki_z_czekolada Sr         167.0        126.0        126.0      167.0
# Rogaliki_z_czekolada Czw        200.0        167.0        167.0      200.0
# Rogaliki_z_czekolada Pt         200.0        200.0        200.0      200.0
# Rogaliki_z_czekolada Sob        1.0          200.0        200.0      0.0

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_colwidth', None)  # Ustaw brak limitu szerokości kolumny


# Po rozwiązaniu problemu upewnijmy się, że rozwiązanie jest optymalne
if pl.LpStatus[model.status] != 'Optimal':
    print("Model did not solve to optimality.")
    exit()

# Pobierz wartości czasu rozpoczęcia
start_times = {
    (subproduct, machine, day): subproduct_batch_start_time[subproduct, machine, day].varValue
    for subproduct in subproducts for machine in sub_machines for day in days
    if subproduct_batch_start_time[subproduct, machine, day].varValue is not None and is_produced_sub[subproduct, machine, day].varValue != 0 
}

# Oblicz czas zakończenia
end_times = {
    (subproduct, machine, day): start_times[subproduct, machine, day] + sub_production_times[subproduct][machine]
    for subproduct, machine, day in start_times
}

# Wersja 1: Widok z perspektywy subproduktu
subproduct_schedule = []
for subproduct in subproducts:
    for day in days:
        for machine in sub_machines:
            if (subproduct, machine, day) in start_times:
                start = start_times[(subproduct, machine, day)]
                end = end_times[(subproduct, machine, day)]
                subproduct_schedule.append({
                    'Subproduct': subproduct,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

subproduct_df = pd.DataFrame(subproduct_schedule)
print("\nSubproduct Schedule:\n")
print(subproduct_df.sort_values(['Day', 'Subproduct', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania subproduktów na litery
subproduct_mapping = {subproduct: chr(65 + i) for i, subproduct in enumerate(subproducts)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for subproduct in subproducts:
        if (subproduct, machine, day) in start_times:
            start = start_times[(subproduct, machine, day)]
            end = end_times[(subproduct, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = subproduct_mapping[subproduct]  # Wstaw literę dla subproduktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_subproduct = timeline[i]
                    prev_duration = (
                        end_times[(subproducts[ord(prev_subproduct) - 65], machine, day)] -
                        start_times[(subproducts[ord(prev_subproduct) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = subproduct_mapping[subproduct]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in sub_machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
subproduct_df.to_csv("subproduct_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Subproduktów:")
for subproduct, letter in subproduct_mapping.items():
    print(f"{letter}: {subproduct}")

print(subproduct_batch_start_time['Ciasto_na_chleb_domowy_0_5kg', 'Dzieza', 'Pon'].varValue)
print(subproduct_batch_start_time['Ciasto_na_chleb_domowy_0_5kg', 'Dzieza', 'Pon'].varValue + sub_production_times['Ciasto_na_chleb_domowy_0_5kg']['Dzieza'])
print(subproduct_batch_start_time['Ciasto_na_bulki', 'Dzieza', 'Pon'].varValue)

print(is_produced_sub['Ciasto_na_chleb_domowy_0_5kg', 'Dzieza', 'Pon'].varValue)
print(is_produced_sub['Ciasto_na_bulki', 'Dzieza', 'Pon'].varValue)
print(subproduct_batch_start_time['Ciasto_na_chleb_domowy_0_5kg', sub_machines[-1], 'Pon'].varValue)
# Out:
# Subproduct Schedule:
#
#                         Subproduct  Day      Machine  Start Time  End Time
# 63              Ciasto_na_bagietki  Czw       Dzieza        5.55      6.50
# 64              Ciasto_na_bagietki  Czw    Dzielarka        6.50      6.74
# 65              Ciasto_na_bagietki  Czw  Rogalikarka       19.72     20.00
# 45                 Ciasto_na_bulki  Czw       Dzieza        6.50      7.50
# 46                 Ciasto_na_bulki  Czw    Dzielarka        7.50      7.73
# ..                             ...  ...          ...         ...       ...
# 23     Ciasto_na_chleb_na_zakwasie   Wt       Tabula       14.10     14.70
# 76  Ciasto_na_rogaliki_z_czekolada   Wt       Dzieza        4.70      5.25
# 77  Ciasto_na_rogaliki_z_czekolada   Wt    Dzielarka        5.25      5.53
# 78  Ciasto_na_rogaliki_z_czekolada   Wt  Rogalikarka        8.75      9.06
# 79  Ciasto_na_rogaliki_z_czekolada   Wt  Nadziewarka        9.06      9.46
#
# [96 rows x 5 columns]
#
# Machine Usage Timeline:
#
#         Machine  Day  \
# 0        Dzieza  Pon
# 1       Wazenie  Pon
# 2     Dzielarka  Pon
# 3        Tabula  Pon
# 4   Rogalikarka  Pon
# 5   Nadziewarka  Pon
# 6        Dzieza   Wt
# 7       Wazenie   Wt
# 8     Dzielarka   Wt
# 9        Tabula   Wt
# 10  Rogalikarka   Wt
# 11  Nadziewarka   Wt
# 12       Dzieza   Sr
# 13      Wazenie   Sr
# 14    Dzielarka   Sr
# 15       Tabula   Sr
# 16  Rogalikarka   Sr
# 17  Nadziewarka   Sr
# 18       Dzieza  Czw
# 19      Wazenie  Czw
# 20    Dzielarka  Czw
# 21       Tabula  Czw
# 22  Rogalikarka  Czw
# 23  Nadziewarka  Czw
# 24       Dzieza   Pt
# 25      Wazenie   Pt
# 26    Dzielarka   Pt
# 27       Tabula   Pt
# 28  Rogalikarka   Pt
# 29  Nadziewarka   Pt
# 30       Dzieza  Sob
# 31      Wazenie  Sob
# 32    Dzielarka  Sob
# 33       Tabula  Sob
# 34  Rogalikarka  Sob
# 35  Nadziewarka  Sob
#
#                                                                                                 Timeline
# 0   BBBBBBBBBBBBBBBBBBBBBBBBBAAAAAAAAAAAAAAAAAAAAAAA_FFFDDDDD_________EEEEE_____________________________
# 1   _________________________B_______________________A__________________________________________________
# 2   ______________________________________________________F__D_____________E____________________________
# 3   _______________________________________________BBBAAA_____DD________________________________________
# 4   _______________________________________________________FF_______________E___________________________
# 5   _________________________________________________________FF_________________________________________
# 6   AAAAAAAAAAAAAAAAAAAAAAAFFFCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC__DDDDD___________EEEEE________
# 7   ____________________________________________________A________________C______________________________
# 8   __________________________F_________________________________________________DD______________E_______
# 9   _____________________________________________________AAAA_____________CCC_____D_____________________
# 10  ___________________________________________FF________________________________________________EE_____
# 11  _____________________________________________FF_____________________________________________________
# 12  CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCFFFDDDDD_AAAAAAAAAAAAAAAAAAAAAAA_____________EEEEE________
# 13  __________________________________________CC______________________________AA________________________
# 14  _____________________________________________FF_____D_______________________________________E_______
# 15  __________________________________________________CCCDD_____________________AAA_____________________
# 16  ________________________________________________________________FF___________________________EE_____
# 17  __________________________________________________________________FF________________________________
# 18  BBBBBBBBBBBBBBBBBBBBBBBBBFFEEEEEDDDDD_______________CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC_____
# 19  _________________________B_____________________________________________________________________C____
# 20  ___________________________FF___E____D______________________________________________________________
# 21  ______________________________________DD____________________________BBB_________________________CCCC
# 22  _____________________________F____________________________________________________________________EE
# 23  __________________________________________________________________________FF________________________
# 24  CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCFFF__________BBBBBBBBBBBBBBBBBBBBBBBBBDDDDDEEEEE__________
# 25  ____________________________________________________C____________________________________B__________
# 26  __________________________________________________FF______________________________________ED________
# 27  _____________________________________________________CCC__________________________________BBDD______
# 28  ____________________________________________________F______________________________________E________
# 29  _____________________________________________________FF_____________________________________________
# 30  AAAAAAAAAAAAAAAAAAAAAAACCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC____________EEEEFFFDDDDD__________
# 31  __________________________________________________________________________________________CCA_______
# 32  _________________________________________________________________________________________FD______E__
# 33  ___________________________________________________________________________________________DDAAACCCC
# 34  ________________________________________________________________________________________________F_EE
# 35  __________________________________________________________________________________________________FF
#
# Legenda Subproduktów:
# A: Ciasto_na_chleb_domowy_0_5kg
# B: Ciasto_na_chleb_domowy_0_9kg
# C: Ciasto_na_chleb_na_zakwasie
# D: Ciasto_na_bulki
# E: Ciasto_na_bagietki
# F: Ciasto_na_rogaliki_z_czekolada
# 5.0
# 9.7
# 10.48
# 1.0
# 1.0
# 10.8

# %%
# Pobierz wartości czasu rozpoczęcia
start_times = {
    (product, machine, day): product_batch_start_time[product, machine, day].varValue
    for product in products for machine in machines for day in days
    if product_batch_start_time[product, machine, day].varValue is not None and is_produced[product, machine, day].varValue != 0 
}

# Oblicz czas zakończenia
end_times = {
    (product, machine, day): start_times[product, machine, day] + production_times[product][machine]
    for product, machine, day in start_times
}

# Wersja 1: Widok z perspektywy produktu
product_schedule = []
for product in products:
    for day in days:
        for machine in machines:
            if (product, machine, day) in start_times:
                start = start_times[(product, machine, day)]
                end = end_times[(product, machine, day)]
                product_schedule.append({
                    'Product': product,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

product_df = pd.DataFrame(product_schedule)
print("\nProduct Schedule:\n")
print(product_df.sort_values(['Day', 'Product', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania produktów na litery
product_mapping = {product: chr(65 + i) for i, product in enumerate(products)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for product in products:
        if (product, machine, day) in start_times:
            start = start_times[(product, machine, day)]
            end = end_times[(product, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = product_mapping[product]  # Wstaw literę dla produktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_product = timeline[i]
                    prev_duration = (
                        end_times[(products[ord(prev_product) - 65], machine, day)] -
                        start_times[(products[ord(prev_product) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = product_mapping[product]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
product_df.to_csv("product_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Produktów:")
for product, letter in product_mapping.items():
    print(f"{letter}: {product}")

print(is_produced['Chleb_domowy_0_5kg', 'Garownia', 'Pon'].varValue)
print(all_from_storage['Ciasto_na_chleb_domowy_0_5kg', 'Pon'])
# Out:
# Product Schedule:
#
#                   Product  Day    Machine  Start Time  End Time
# 87               Bagietki  Czw   Garownia        1.00      1.33
# 88               Bagietki  Czw       Piec       12.84     13.07
# 89               Bagietki  Czw  Studzenie       13.58     14.00
# 69                  Bulki  Czw   Garownia       12.69     13.07
# 70                  Bulki  Czw       Piec       13.07     13.32
# ..                    ...  ...        ...         ...       ...
# 31     Chleb_domowy_0_9kg   Wt  Pakowanie       19.43     20.00
# 100  Rogaliki_z_czekolada   Wt   Garownia        9.46      9.71
# 101  Rogaliki_z_czekolada   Wt       Piec       13.09     13.27
# 102  Rogaliki_z_czekolada   Wt  Studzenie       13.27     14.09
# 103  Rogaliki_z_czekolada   Wt  Pakowanie       18.45     18.87
#
# [120 rows x 5 columns]
#
# Machine Usage Timeline:
#
#       Machine  Day  \
# 0    Garownia  Pon
# 1        Piec  Pon
# 2   Studzenie  Pon
# 3   Pakowanie  Pon
# 4    Garownia   Wt
# 5        Piec   Wt
# 6   Studzenie   Wt
# 7   Pakowanie   Wt
# 8    Garownia   Sr
# 9        Piec   Sr
# 10  Studzenie   Sr
# 11  Pakowanie   Sr
# 12   Garownia  Czw
# 13       Piec  Czw
# 14  Studzenie  Czw
# 15  Pakowanie  Czw
# 16   Garownia   Pt
# 17       Piec   Pt
# 18  Studzenie   Pt
# 19  Pakowanie   Pt
# 20   Garownia  Sob
# 21       Piec  Sob
# 22  Studzenie  Sob
# 23  Pakowanie  Sob
#
#                                                                                                 Timeline
# 0   ______________________________________________________AAAAAFDDBBBBBBB_____E_________________________
# 1   ________________________________________________________________AAA_DBBBBBBE________________F_______
# 2   ___________________________________________________________________AAAAAAAAAEEBBBBBBBBBBBBBDDFFFF___
# 3   ____________________________________________________________________________________________BBBAAFFF
# 4   _______________________________________________FBBBBBBBB_AAAAA_________________DD______________E____
# 5   ________________________________________________________BBBBBBAAAF_______________D______________E___
# 6   __________________________________________________________________FFFFBBBBBBBBBBBBDDDAAAAAAAAA___EEE
# 7   ____________________________________________________________________________________________FFAAABBB
# 8   ____________________________________________BBBBBBB____DDCCCCCCC____F__________AAAAA___________E____
# 9   ___________________________________________________BBBBBB______DCCCCCF______________AAAA________E___
# 10  _________________________________________________________BBBBBBBBBBBBBFFFFCCCCCCCCCCCDDDAAAAAAAAAEEE
# 11  _________________________________________________________________________________________BBBCCCFFAAA
# 12  AAAAAE_________________________________________________________DD_CCCCCCC___FF______________________
# 13  ________________________________________________________________EDAAAA___CCCCC______________________
# 14  ___________________________________________________________________EEEAAAAAAAAAFFFFDDCCCCCCCCCCCC___
# 15  ____________________________________________________________________________________________FFAACCCC
# 16  BBBBBBB________________________________________________FCCCCCCC_____________AAAAA___________EEDD____
# 17  _______BBBBBB__________________________________________________CCCCCF____________AAAA_________E_D___
# 18  _________________________________________________________BBBBBBBBBBBBFFFFCCCCCCCCCCCCAAAAAAAAA_EEDDD
# 19  _________________________________________________________________________________________FFCCCAAABBB
# 20  BBBBBBBCCCCCCCFEE_____________________________DD_______AAAAA________________________________________
# 21  _______BBBBBB__________________________________EDCCCCCF_____AAAA____________________________________
# 22  _______________________________________________________FFFFEEDDDAAAAAAAAACCCCCCCCCCCBBBBBBBBBBBBB___
# 23  _________________________________________________________________________________________FFAAACCCBBB
#
# Legenda Produktów:
# A: Chleb_domowy_0_5kg
# B: Chleb_domowy_0_9kg
# C: Chleb_na_zakwasie
# D: Bulki
# E: Bagietki
# F: Rogaliki_z_czekolada
# 1.0
# 0
