# %%
import pulp as pl
import numpy as np
# from scipy.stats import multivariate_t

print("==============================================================================")

# Define the problem
model = pl.LpProblem("Maximize_Profit", pl.LpMaximize)

# Products, machines and days
subproducts = ['Ciasto_na_chleb_domowy_0_5kg', 'Ciasto_na_chleb_domowy_0_9kg', 'Ciasto_na_chleb_na_zakwasie', 'Ciasto_na_bulki', 'Ciasto_na_bagietki', 'Ciasto_na_rogaliki_z_czekolada']
products = ['Chleb_domowy_0_5kg', 'Chleb_domowy_0_9kg', 'Chleb_na_zakwasie', 'Bulki', 'Bagietki', 'Rogaliki_z_czekolada']
days = ['Pon', 'Wt', 'Sr']
sub_machines = ['Dzieza', 'Wazenie', 'Dzielarka', 'Tabula', 'Rogalikarka', 'Nadziewarka']
machines = ['Garownia', 'Piec', 'Studzenie', 'Pakowanie']
batches = ['#1', '#2', '#3']

# Income from product sales and production cost in PLN/piece
product_income = {'Chleb_domowy_0_5kg': 5.2, 'Chleb_domowy_0_9kg': 7.9, 'Chleb_na_zakwasie': 6.2, 'Bulki': 1.4, 'Bagietki': 1.55, 'Rogaliki_z_czekolada': 2.1}
sub_product_cost = {'Ciasto_na_chleb_domowy_0_5kg': 1.6, 'Ciasto_na_chleb_domowy_0_9kg': 2.0, 'Ciasto_na_chleb_na_zakwasie': 2.0, 'Ciasto_na_bulki': 0.5, 'Ciasto_na_bagietki': 0.6, 'Ciasto_na_rogaliki_z_czekolada': 1.0}
product_cost = {'Chleb_domowy_0_5kg': 0.8, 'Chleb_domowy_0_9kg': 0.9, 'Chleb_na_zakwasie': 0.8, 'Bulki': 0.2, 'Bagietki': 0.2, 'Rogaliki_z_czekolada': 0.2}

# Time available
shifts_per_day = 2
hours_per_shift = 10
hours_per_day = shifts_per_day * hours_per_shift

max_batches = 1
large_number = 10000

sub_production_times = {
    'Ciasto_na_chleb_domowy_0_5kg': {'Dzieza': 4.7, 'Wazenie': 0.29, 'Dzielarka': 0.0, 'Tabula': 0.7, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_domowy_0_9kg': {'Dzieza': 5, 'Wazenie': 0.2, 'Dzielarka': 0.0, 'Tabula': 0.55, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_na_zakwasie': {'Dzieza': 8.6, 'Wazenie': 0.22, 'Dzielarka': 0.0, 'Tabula': 0.6, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bulki': {'Dzieza': 1, 'Wazenie': 0.0, 'Dzielarka': 0.23, 'Tabula': 0.34, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bagietki': {'Dzieza': 0.95, 'Wazenie': 0.0, 'Dzielarka': 0.24, 'Tabula': 0.0, 'Rogalikarka': 0.28, 'Nadziewarka': 0.0},
    'Ciasto_na_rogaliki_z_czekolada': {'Dzieza': 0.55, 'Wazenie': 0.0, 'Dzielarka': 0.28, 'Tabula': 0.0, 'Rogalikarka': 0.31, 'Nadziewarka': 0.4}
}

production_times = {
    'Chleb_domowy_0_5kg': {'Garownia': 1.0, 'Piec': 0.68, 'Studzenie': 1.8, 'Pakowanie': 0.56},
    'Chleb_domowy_0_9kg': {'Garownia': 1.5, 'Piec': 1.2, 'Studzenie': 2.5, 'Pakowanie': 0.57},
    'Chleb_na_zakwasie': {'Garownia': 1.4, 'Piec': 1.0, 'Studzenie': 2.3, 'Pakowanie': 0.6},
    'Bulki': {'Garownia': 0.38, 'Piec': 0.25, 'Studzenie': 0.48, 'Pakowanie': 0.0},
    'Bagietki': {'Garownia': 0.33, 'Piec': 0.23, 'Studzenie': 0.42, 'Pakowanie': 0.0},
    'Rogaliki_z_czekolada': {'Garownia': 0.25, 'Piec': 0.18, 'Studzenie': 0.82, 'Pakowanie': 0.42}
}


batch_size = {
    "Ciasto_na_chleb_domowy_0_5kg": 240,
    "Ciasto_na_chleb_domowy_0_9kg": 130,
    "Ciasto_na_chleb_na_zakwasie": 200,
    "Ciasto_na_bulki": 200,
    "Ciasto_na_bagietki": 200,
    "Ciasto_na_rogaliki_z_czekolada": 200,
    "Chleb_domowy_0_5kg": 240,
    "Chleb_domowy_0_9kg": 130,
    "Chleb_na_zakwasie": 200,
    "Bulki": 200,
    "Bagietki": 200,
    "Rogaliki_z_czekolada": 200,
}

market_limits = {
    "Chleb_domowy_0_5kg": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 420, "Pt": 530, "Sob": 680},
    "Chleb_domowy_0_9kg": {"Pon": 100, "Wt": 100, "Sr": 380, "Czw": 150, "Pt": 250, "Sob": 580},
    "Chleb_na_zakwasie": {"Pon": 100, "Wt": 100, "Sr": 320, "Czw": 180, "Pt": 280, "Sob": 418},
    "Bulki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 530, "Pt": 650, "Sob": 580},
    "Bagietki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 350, "Pt": 650, "Sob": 680},
    "Rogaliki_z_czekolada": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 310, "Pt": 400, "Sob": 280},
}

# Machines cost
fridge_cost_per_day = 0.281 * 24 * 1.4 * 0.2 # kW * 24h * price per hour * factor
furnace_cost_per_hour = 82.4 # https://giko.pl/kalkulator-zuzycia-energii-dla-piecow-piekarniczych/


fridge_count = 10
fridge_capacity = 160
end_stock = 0
storage_capacity = fridge_count * fridge_capacity

# Variables for production, sales, and storage of products each day
sub_production_vars = pl.LpVariable.dicts("Subproduct production", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
sub_production_vars_batch = pl.LpVariable.dicts("Subproduct production Batch", ((subproduct, batch, day) for subproduct in subproducts for batch in batches for day in days), lowBound=0, cat='Integer')
production_vars = pl.LpVariable.dicts("Production", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
production_vars_batch = pl.LpVariable.dicts("ProductionBatch", ((product, batch, day) for product in products for batch in batches for day in days), lowBound=0, cat='Integer')
# batch_count_vars = pl.LpVariable.dicts("Batches Count", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# subbatch_count_vars = pl.LpVariable.dicts("Subproduct Batches Count", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
product_batch_start_time = pl.LpVariable.dicts("ProductStartTime",  [(product, batch, machine, day) for product in products for batch in batches for machine in machines for day in days], lowBound=0, cat="Continuous")
subproduct_batch_start_time = pl.LpVariable.dicts("Subproduction start time for batch",  [(subproduct, batch, machine, day) for subproduct in subproducts for batch in batches for machine in sub_machines for day in days], lowBound=0, cat="Continuous")
sales_vars = pl.LpVariable.dicts("Sales", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, idx) for (machine, idx) in specific_machines], cat="Binary")
# subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, day, batch) for subproduct in subproducts for day in days for batch in range(1, max_batches + 1)], cat="Binary")
subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, batch, day) for subproduct in subproducts for batch in batches for day in days], cat="Binary")
batch_produced = pl.LpVariable.dicts("BatchProduced", [(product, batch, day) for product in products for batch in batches for day in days], cat="Binary")
specific_sub_machine_used = pl.LpVariable.dicts("SpecificSubMachineUsed", [(machine, subproduct, batch, day) for machine in sub_machines for subproduct in subproducts for batch in batches for day in days], cat="Binary")
specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, product, batch, day) for machine in machines for product in products for batch in batches for day in days], cat="Binary")
storage_vars = pl.LpVariable.dicts("Storage", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, upBound=storage_capacity, cat='Integer')
fridge_count_usage_vars = pl.LpVariable.dicts("FridgeCount", ((day) for day in days), lowBound=0, upBound=fridge_count, cat='Integer')
all_from_storage = pl.LpVariable.dicts("AllFromStorage", [(subproduct, batch, day) for subproduct in subproducts for batch in batches for day in days], cat="Binary")
storage_batch = pl.LpVariable.dicts("StorageBatch", ((subproduct, batch, day) for subproduct in subproducts for batch in batches for day in days), lowBound=0, cat='Integer')


# xij = pl.LpVariable.dicts("xij", [(machine, idx, i, j) for (machine, idx) in specific_machines for i in subproducts for j in subproducts if i != j], 0, 1, pl.LpBinary)
is_produced_sub = pl.LpVariable.dicts("isProducedSub", ((subproduct, batch, machine, day) for subproduct in subproducts for batch in batches for machine in sub_machines for day in days), cat="Binary")
is_produced = pl.LpVariable.dicts("isProduced",
                                     ((product, batch, machine, day) for product in products for batch in batches
                                                                      for machine in machines
                                                                      for day in days),
                                     cat="Binary")

for subproduct in subproducts:
    for i, machine in enumerate(sub_machines[1:], start=1):  # Od ważenia do nadziewarki
        prev = 1
        prev_machine = sub_machines[i - prev]
        while sub_production_times[subproduct][prev_machine] == 0.0 or prev_machine == machine:
            prev += 1
            prev_machine = sub_machines[i - prev]

    for batch in batches:
        for day in days:
            model += subproduct_batch_start_time[subproduct, batch, machine, day] >= (
                subproduct_batch_start_time[subproduct, batch, prev_machine, day] + sub_production_times[subproduct][prev_machine]
            )

            # model += subproduct_batch_start_time[subproduct, batch, machine, day] <= specific_sub_machine_used[machine, subproduct, day] * hours_per_day

            last_machine = sub_machines[-1]
            model += hours_per_day >= (
                subproduct_batch_start_time[subproduct, batch, last_machine, day] + sub_production_times[subproduct][last_machine]
            )

for product in products:
    for i, machine in enumerate(machines[1:], start=1):  # Od ważenia do nadziewarki
        prev = 1
        prev_machine = machines[i - prev]
        while production_times[product][prev_machine] == 0.0 or prev_machine == machine:
            prev += 1
            prev_machine = machines[i - prev]

    for day in days:
        for batch in batches:
            model += product_batch_start_time[product, batch, machine, day] >= (
                product_batch_start_time[product, batch, prev_machine, day] + production_times[product][prev_machine]
            )
            # model += product_batch_start_time[product, machine, day] <= specific_machine_used[machine, product, day] * hours_per_day
            last_machine = machines[-1]
            model += hours_per_day >= (
                product_batch_start_time[product, batch, last_machine, day] + production_times[product][last_machine]
            )
'''
        model += subbatch_produced[subproduct, day] * large_number >= subproduct_batch_start_time[subproduct, last_machine, last_idx, day]

        # Brak nakładania się produkcji na maszynie
        for machine, idx in specific_machines[:6]:  # Zakres maszyn
            for subproduct1 in subproducts:
                for subproduct2 in subproducts:
                    if subproduct1 != subproduct2:
                        model += (subproduct_batch_start_time[subproduct1, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct2, machine, idx, day] + production_times[subproduct2][machine]) | \
                                 (subproduct_batch_start_time[subproduct2, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct1, machine, idx, day] + production_times[subproduct1][machine])

                        # model += specific_machine_used[machine, idx, subproduct1, day] + specific_machine_used[machine, idx, subproduct2, day] <= 1
'''
# Ograniczenie: produkcja subproduktu tylko na maszynach, gdzie czas produkcji > 0
for subproduct in subproducts:
    for machine in sub_machines:
        if sub_production_times[subproduct][machine] == 0:
            for day in days:
                for batch in batches:
                    model += is_produced_sub[subproduct, batch, machine, day] == 0

# Ograniczenie: produkcja produktu tylko na maszynach, gdzie czas produkcji > 0
for product in products:
    for machine in machines:
        if production_times[product][machine] == 0:
            for day in days:
                for batch in batches:
                    model += is_produced[product, batch, machine, day] == 0
                

# Warunek: jeśli subprodukt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for subproduct in subproducts:
    machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for batch in batches:
                for machine in machines_with_production:
                    model += pl.lpSum(is_produced_sub[subproduct, batch, m, day] for m in machines_with_production) == \
                        len(machines_with_production) * is_produced_sub[subproduct, batch, machine, day]
                model += subbatch_produced[subproduct, batch, day] * len(machines_with_production) <= pl.lpSum(is_produced_sub[subproduct, batch, machine, day] for machine in machines_with_production)
        # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
        

# Warunek: jeśli produkt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for product in products:
    machines_with_production = [machine for machine in machines if production_times[product][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for batch in batches:
                for machine in machines_with_production:
                    model += pl.lpSum(is_produced[product, batch, m, day] for m in machines_with_production) == \
                        len(machines_with_production) * is_produced[product, batch, machine, day]
                # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
                model += batch_produced[product, batch, day] * len(machines_with_production) <= pl.lpSum(is_produced[product, batch, machine, day] for machine in machines_with_production)
        

# Aktualizacja ograniczenia: brak nakładania się produkcji
big_M = 1000000
for subproduct1 in subproducts:
    for subproduct2 in subproducts:
        for batch1 in batches:
            for batch2 in batches:
                if not (subproduct1 == subproduct2 and batch1 == batch2):
                    machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct1][machine] > 0 and sub_production_times[subproduct2][machine] > 0]
                    for machine in machines_with_production: 
                        for day in days:
                            # Dodanie binarnych zmiennych pomocniczych
                                    y1 = pl.LpVariable(f"y1_{subproduct1}_{subproduct2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")
                                    y2 = pl.LpVariable(f"y2_{subproduct1}_{subproduct2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")
                                    y3 = pl.LpVariable(f"y3_{subproduct1}_{subproduct2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")
                                    y4 = pl.LpVariable(f"y4_{subproduct1}_{subproduct2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")

                                    # Powiązanie warunków logicznych z binarnymi zmiennymi
                                    model += subproduct_batch_start_time[subproduct1, batch1, machine, day] >= \
                                                subproduct_batch_start_time[subproduct2, batch2, machine, day] + sub_production_times[subproduct2][machine] - \
                                                big_M * (1 - y1)
                                    
                                    model += subproduct_batch_start_time[subproduct2, batch1, machine, day] >= \
                                                subproduct_batch_start_time[subproduct1, batch2, machine, day] + sub_production_times[subproduct1][machine] - \
                                                big_M * (1 - y2)

                                    model += is_produced_sub[subproduct1, batch1, machine, day] + y3 == 1
                                    model += is_produced_sub[subproduct2, batch2, machine, day] + y4 == 1

                                    # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                                    model += y1 + y2 + y3 + y4 == 1

for product1 in products:
    for product2 in products:
        for batch1 in batches:
            for batch2 in batches:
                if not (product1 == product2 and batch1 == batch2):
                    machines_with_production = [machine for machine in machines if production_times[product1][machine] > 0 and production_times[product2][machine] > 0]
                    for machine in machines_with_production: 
                        for day in days:
                            # Dodanie binarnych zmiennych pomocniczych
                            y1 = pl.LpVariable(f"y1_{product1}_{product2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")
                            y2 = pl.LpVariable(f"y2_{product1}_{product2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")
                            y3 = pl.LpVariable(f"y3_{product1}_{product2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")
                            y4 = pl.LpVariable(f"y4_{product1}_{product2}_{batch1}_{batch2}_{machine}_{day}", cat="Binary")

                            # Powiązanie warunków logicznych z binarnymi zmiennymi
                            model += product_batch_start_time[product1, batch1, machine, day] >= \
                                        product_batch_start_time[product2, batch2, machine, day] + production_times[product2][machine] - \
                                        big_M * (1 - y1)
                            
                            model += product_batch_start_time[product2, batch1, machine, day] >= \
                                        product_batch_start_time[product1, batch2, machine, day] + production_times[product1][machine] - \
                                        big_M * (1 - y2)

                            model += is_produced[product1, batch1, machine, day] + y3 == 1
                            model += is_produced[product2, batch2, machine, day] + y4 == 1

                            # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                            model += y1 + y2 + y3 + y4 == 1

M = 1000
for subproduct, product in zip(subproducts, products):
    for batch in batches:
        model += storage_batch[subproduct, batch, 'Pon'] == sub_production_vars_batch[subproduct, batch, 'Pon'] - production_vars_batch[product, batch, 'Pon']
    for i in range(1, len(days)):
        day = days[i]
        prev_day = days[i-1]
        for batch in batches:
            # model += storage_vars[subproduct, day] == storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day]
            # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
            # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
            # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
            model += product_batch_start_time[product, batch, machines[0], day] >= (subproduct_batch_start_time[subproduct, batch, sub_machines[-1], day]) + sub_production_times[subproduct][sub_machines[-1]] - M * all_from_storage[subproduct, batch, day]

expr1 = pl.LpVariable.dicts("expr1", [(s, b, d) for s in subproducts for b in batches for d in days], lowBound=0)
expr2 = pl.LpVariable.dicts("expr2", [(s, b, d) for s in subproducts for b in batches for d in days], lowBound=0)

# Dodaj ograniczenia dla zmiennych pomocniczych
for s, p in zip(subproducts, products):
    for b in batches:
        all_from_storage[s, b, 'Pon'] = 0
        for i in range(1, len(days)):
            d = days[i]
            prev_day = days[i-1]
            model += expr1[s, b, d] >= storage_batch[s, b, prev_day] - production_vars_batch[p, b, d] - M * (1 - all_from_storage[s, b, d])
            model += expr1[s, b, d] <= storage_batch[s, b, prev_day] - production_vars_batch[p, b, d]
            model += expr1[s, b, d] <= M * all_from_storage[s, b, d]
            model += expr1[s, b, d] >= 0
            
            model += expr2[s, b, d] >= storage_batch[s, b, prev_day] + sub_production_vars_batch[s, b, d] - production_vars_batch[p, b, d] - M * all_from_storage[s, b, d]
            model += expr2[s, b, d] <= storage_batch[s, b, prev_day] + sub_production_vars_batch[s, b, d] - production_vars_batch[p, b, d]
            model += expr2[s, b, d] <= M * (1 - all_from_storage[s, b, d])
            model += expr2[s, b, d] >= 0

            # Ograniczenie
            model += storage_batch[s, b, d] == expr1[s, b, d] + expr2[s, b, d]


for day in days:
    model += storage_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)
    model += fridge_count_usage_vars[day] * fridge_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)
    

for product, subproduct in zip(products, subproducts):
    for day in days:
        for batch in batches:
            model += batch_produced[product, batch, day] * batch_size[product] >= production_vars_batch[product, batch, day]
            model += production_vars_batch[product, batch, day] >= batch_produced[product, batch, day]
            model += subbatch_produced[subproduct, batch, day] * batch_size[subproduct] >= sub_production_vars_batch[subproduct, batch, day]
            model += sub_production_vars_batch[subproduct, batch, day] >= subbatch_produced[subproduct, batch, day]

        model += storage_vars[subproduct, day] == pl.lpSum([storage_batch[subproduct, batch, day] for batch in batches])
        model += production_vars[product, day] == pl.lpSum([production_vars_batch[product, batch, day] for batch in batches])
        model += sub_production_vars[subproduct, day] == pl.lpSum([sub_production_vars_batch[subproduct, batch, day] for batch in batches])
        
        # model += sub_production_vars[subproduct, day] >= production_vars[product, day]
        model += sales_vars[product, day] == production_vars[product, day]
    model += sales_vars[product, 'Sr'] >= 0.01*market_limits[product]['Wt'], f"Max_sales_{product}_{'Sr'}"


# Objective function: Maximize profit from sales minus costs
model += pl.lpSum([sales_vars[product, day] * product_income[product] for product in products for day in days]) \
                    - pl.lpSum([production_vars[product, day] * product_cost[product] for product in products for day in days]) \
                    - pl.lpSum([sub_production_vars[subproduct, day] * sub_product_cost[subproduct] for subproduct in subproducts for day in days]) \
                    - pl.lpSum([fridge_count_usage_vars[day] * fridge_cost_per_day for day in days]) \
                    - pl.lpSum([sum(batch_produced[product, batch, day] for batch in batches) * production_times[product]['Piec'] * furnace_cost_per_hour for product in products for day in days]), "Total_Profit"


solver = pl.PULP_CBC_CMD(timeLimit=600)

model.solve(solver)

# model.solve()

# Results
print("Status:", pl.LpStatus[model.status])
if pl.LpStatus[model.status] == 'Optimal':
    print("Total Profit:", pl.value(model.objective))

    print(f"{'Product':<10} {'day':<10} {'SubProduction':<10} {'Production':<12} {'Sales':<10} {'Storage':<10}")

    for product, subproduct in zip(products, subproducts):
        for day in days:
            subproduction = sub_production_vars[subproduct, day].varValue
            production = production_vars[product, day].varValue
            sales = sales_vars[product, day].varValue
            storage = storage_vars[subproduct, day].varValue

            print(f"{product:<10} {day:<10} {subproduction:<12} {production:<12} {sales:<10} {storage:<10}")

    # print("\nProduction Time Usage per Product and Day:")
    # for day in days:
    #     print(f"\Day: {day}")
    #     for product in products:
    #         total_production_time = sum(
    #             batch_count_vars[product, day].varValue * production_times[product]s.get(machine, 0) 
    #             for machine in machines #.keys()
    #         )
    #         print(f"  Product: {product}, Total Production Time: {total_production_time:.2f} hours")

else:
    print("No optimal solution was found.")
    # Analiza ograniczeń
    for name, constraint in model.constraints.items():
        if constraint.pi < 0:
            print(f"Ograniczenie {name}: {constraint}")
# Out:
# ==============================================================================
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gromek/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/37a368cfeac24e038136f4e77a90bc8f-pulp.mps -max -sec 600 -timeMode elapsed -branch -printingOptions all -solution /tmp/37a368cfeac24e038136f4e77a90bc8f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 26567 COLUMNS
# At line 142659 RHS
# At line 169222 BOUNDS
# At line 190160 ENDATA
# Problem MODEL has 26562 rows, 21441 columns and 74106 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 600
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 11528.2 - 0.64 seconds
# Cgl0002I 171 variables fixed
# Cgl0003I 0 fixed, 30 tightened bounds, 3690 strengthened rows, 924 substitutions
# Cgl0003I 0 fixed, 13 tightened bounds, 3045 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 2 tightened bounds, 1055 strengthened rows, 0 substitutions
# Cgl0004I processed model has 15711 rows, 10884 columns (10413 integer (10260 of which binary)) and 59222 elements
# Cbc0038I Initial state - 3288 integers unsatisfied sum - 507.713
# Cbc0038I Pass   1: (2.81 seconds) suminf.  456.73193 (3314) obj. -11486.7 iterations 3530
# Cbc0038I Pass   2: (2.88 seconds) suminf.  456.18313 (3284) obj. -11440.8 iterations 381
# Cbc0038I Pass   3: (2.91 seconds) suminf.  456.18073 (3281) obj. -11440.8 iterations 69
# Cbc0038I Pass   4: (2.98 seconds) suminf.  454.00143 (3288) obj. -11423.3 iterations 291
# Cbc0038I Pass   5: (3.00 seconds) suminf.  454.00213 (3288) obj. -11423.3 iterations 21
# Cbc0038I Pass   6: (3.02 seconds) suminf.  454.00213 (3288) obj. -11423.3 iterations 5
# Cbc0038I Pass   7: (3.04 seconds) suminf.  454.00213 (3288) obj. -11423.3 iterations 1
# Cbc0038I Pass   8: (3.12 seconds) suminf.  454.68422 (3330) obj. -11430.9 iterations 417
# Cbc0038I Pass   9: (3.18 seconds) suminf.  454.00227 (3296) obj. -11423.3 iterations 272
# Cbc0038I Pass  10: (3.22 seconds) suminf.  454.00222 (3289) obj. -11423.3 iterations 152
# Cbc0038I Pass  11: (3.23 seconds) suminf.  454.00222 (3289) obj. -11423.3 iterations 0
# Cbc0038I Pass  12: (3.24 seconds) suminf.  454.00222 (3289) obj. -11423.3 iterations 0
# Cbc0038I Pass  13: (3.25 seconds) suminf.  454.00222 (3289) obj. -11423.3 iterations 0
# Cbc0038I Pass  14: (3.32 seconds) suminf.  455.61280 (3324) obj. -11403.1 iterations 425
# Cbc0038I Pass  15: (3.38 seconds) suminf.  455.01284 (3285) obj. -11402.3 iterations 362
# Cbc0038I Pass  16: (3.41 seconds) suminf.  455.01416 (3293) obj. -11402.3 iterations 22
# Cbc0038I Pass  17: (3.45 seconds) suminf.  454.54992 (3293) obj. -11421.5 iterations 60
# Cbc0038I Pass  18: (3.46 seconds) suminf.  454.54992 (3293) obj. -11421.5 iterations 0
# Cbc0038I Pass  19: (3.52 seconds) suminf.  453.83067 (3288) obj. -11424.1 iterations 46
# Cbc0038I Pass  20: (3.55 seconds) suminf.  453.82946 (3281) obj. -11424.1 iterations 8
# Cbc0038I Pass  21: (3.57 seconds) suminf.  453.82946 (3281) obj. -11424.1 iterations 0
# Cbc0038I Pass  22: (3.64 seconds) suminf.  456.31076 (3332) obj. -11382.3 iterations 427
# Cbc0038I Pass  23: (3.70 seconds) suminf.  453.82946 (3281) obj. -11424.1 iterations 283
# Cbc0038I Pass  24: (3.73 seconds) suminf.  453.82946 (3281) obj. -11424.1 iterations 9
# Cbc0038I Pass  25: (3.75 seconds) suminf.  453.82946 (3281) obj. -11424.1 iterations 2
# Cbc0038I Pass  26: (3.77 seconds) suminf.  453.82946 (3281) obj. -11424.1 iterations 1
# Cbc0038I Pass  27: (3.78 seconds) suminf.  453.82946 (3281) obj. -11424.1 iterations 0
# Cbc0038I Pass  28: (3.85 seconds) suminf.  455.57780 (3331) obj. -11405.2 iterations 490
# Cbc0038I Pass  29: (3.91 seconds) suminf.  454.58038 (3309) obj. -11409.3 iterations 247
# Cbc0038I Pass  30: (3.97 seconds) suminf.  454.58320 (3291) obj. -11409.3 iterations 302
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 5366 integers at bound fixed and 176 continuous of which 4 were internal integer and 0 internal continuous
# Cbc0038I Mini branch and bound did not improve solution (3.99 seconds)
# Cbc0038I After 3.99 seconds - Feasibility pump exiting - took 1.86 seconds
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 329 added rows had average density of 5.7355623
# Cbc0013I At root node, 329 cuts changed objective from -11528.234 to -10766.939 in 9 passes
# Cbc0014I Cut generator 0 (Probing) - 2543 row cuts average 2.9 elements, 59 column cuts (59 active)  in 1.153 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1512 row cuts average 17.8 elements, 0 column cuts (0 active)  in 2.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 13 row cuts average 3.8 elements, 0 column cuts (0 active)  in 0.053 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.207 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 4285 row cuts average 2.7 elements, 0 column cuts (0 active)  in 0.059 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 44 row cuts average 2.1 elements, 0 column cuts (0 active)  in 0.056 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 7569 row cuts average 21.9 elements, 0 column cuts (0 active)  in 3.136 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 32 row cuts average 8.3 elements, 0 column cuts (0 active)  in 9.133 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1e+50, took 36162 iterations and 0 nodes (35.12 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -11528.2 to -10766.9
# Probing was tried 9 times and created 2602 cuts of which 0 were active after adding rounds of cuts (1.153 seconds)
# Gomory was tried 8 times and created 1512 cuts of which 0 were active after adding rounds of cuts (2.000 seconds)
# Knapsack was tried 8 times and created 13 cuts of which 0 were active after adding rounds of cuts (0.053 seconds)
# Clique was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.207 seconds)
# MixedIntegerRounding2 was tried 8 times and created 4285 cuts of which 0 were active after adding rounds of cuts (0.059 seconds)
# FlowCover was tried 8 times and created 44 cuts of which 0 were active after adding rounds of cuts (0.056 seconds)
# TwoMirCuts was tried 8 times and created 7569 cuts of which 0 were active after adding rounds of cuts (3.136 seconds)
# ZeroHalf was tried 8 times and created 32 cuts of which 0 were active after adding rounds of cuts (9.133 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               36162
# Time (CPU seconds):             34.85
# Time (Wallclock seconds):       35.14
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       34.94   (Wallclock seconds):       35.25
#
# Status: Infeasible
# No optimal solution was found.
# Ograniczenie _C26264: 160*FridgeCount_Pon - Storage_('Ciasto_na_bagietki',_'Pon') - Storage_('Ciasto_na_bulki',_'Pon') - Storage_('Ciasto_na_chleb_domowy_0_5kg',_'Pon') - Storage_('Ciasto_na_chleb_domowy_0_9kg',_'Pon') - Storage_('Ciasto_na_chleb_na_zakwasie',_'Pon') - Storage_('Ciasto_na_rogaliki_z_czekolada',_'Pon') >= 0
# Ograniczenie _C26266: 160*FridgeCount_Wt - Storage_('Ciasto_na_bagietki',_'Wt') - Storage_('Ciasto_na_bulki',_'Wt') - Storage_('Ciasto_na_chleb_domowy_0_5kg',_'Wt') - Storage_('Ciasto_na_chleb_domowy_0_9kg',_'Wt') - Storage_('Ciasto_na_chleb_na_zakwasie',_'Wt') - Storage_('Ciasto_na_rogaliki_z_czekolada',_'Wt') >= 0
# Ograniczenie _C26269: 240*BatchProduced_('Chleb_domowy_0_5kg',_'#1',_'Pon') - ProductionBatch_('Chleb_domowy_0_5kg',_'#1',_'Pon') >= 0
# Ograniczenie _C26271: 240*BatchProducedSubproduct_('Ciasto_na_chleb_domowy_0_5kg',_'#1',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_5kg',_'#1',_'Pon') >= 0
# Ograniczenie _C26273: 240*BatchProduced_('Chleb_domowy_0_5kg',_'#2',_'Pon') - ProductionBatch_('Chleb_domowy_0_5kg',_'#2',_'Pon') >= 0
# Ograniczenie _C26275: 240*BatchProducedSubproduct_('Ciasto_na_chleb_domowy_0_5kg',_'#2',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_5kg',_'#2',_'Pon') >= 0
# Ograniczenie _C26277: 240*BatchProduced_('Chleb_domowy_0_5kg',_'#3',_'Pon') - ProductionBatch_('Chleb_domowy_0_5kg',_'#3',_'Pon') >= 0
# Ograniczenie _C26279: 240*BatchProducedSubproduct_('Ciasto_na_chleb_domowy_0_5kg',_'#3',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_5kg',_'#3',_'Pon') >= 0
# Ograniczenie _C26281: -StorageBatch_('Ciasto_na_chleb_domowy_0_5kg',_'#1',_'Pon') - StorageBatch_('Ciasto_na_chleb_domowy_0_5kg',_'#2',_'Pon') - StorageBatch_('Ciasto_na_chleb_domowy_0_5kg',_'#3',_'Pon') + Storage_('Ciasto_na_chleb_domowy_0_5kg',_'Pon') = 0
# Ograniczenie _C26283: Subproduct_production_('Ciasto_na_chleb_domowy_0_5kg',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_5kg',_'#1',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_5kg',_'#2',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_5kg',_'#3',_'Pon') = 0
# Ograniczenie _C26285: 240*BatchProduced_('Chleb_domowy_0_5kg',_'#1',_'Wt') - ProductionBatch_('Chleb_domowy_0_5kg',_'#1',_'Wt') >= 0
# Ograniczenie _C26289: 240*BatchProduced_('Chleb_domowy_0_5kg',_'#2',_'Wt') - ProductionBatch_('Chleb_domowy_0_5kg',_'#2',_'Wt') >= 0
# Ograniczenie _C26293: 240*BatchProduced_('Chleb_domowy_0_5kg',_'#3',_'Wt') - ProductionBatch_('Chleb_domowy_0_5kg',_'#3',_'Wt') >= 0
# Ograniczenie _C26297: -StorageBatch_('Ciasto_na_chleb_domowy_0_5kg',_'#1',_'Wt') - StorageBatch_('Ciasto_na_chleb_domowy_0_5kg',_'#2',_'Wt') - StorageBatch_('Ciasto_na_chleb_domowy_0_5kg',_'#3',_'Wt') + Storage_('Ciasto_na_chleb_domowy_0_5kg',_'Wt') = 0
# Ograniczenie _C26299: Subproduct_production_('Ciasto_na_chleb_domowy_0_5kg',_'Wt') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_5kg',_'#1',_'Wt') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_5kg',_'#2',_'Wt') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_5kg',_'#3',_'Wt') = 0
# Ograniczenie _C26301: 240*BatchProduced_('Chleb_domowy_0_5kg',_'#1',_'Sr') - ProductionBatch_('Chleb_domowy_0_5kg',_'#1',_'Sr') >= 0
# Ograniczenie _C26305: 240*BatchProduced_('Chleb_domowy_0_5kg',_'#2',_'Sr') - ProductionBatch_('Chleb_domowy_0_5kg',_'#2',_'Sr') >= 0
# Ograniczenie _C26309: 240*BatchProduced_('Chleb_domowy_0_5kg',_'#3',_'Sr') - ProductionBatch_('Chleb_domowy_0_5kg',_'#3',_'Sr') >= 0
# Ograniczenie _C26315: Subproduct_production_('Ciasto_na_chleb_domowy_0_5kg',_'Sr') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_5kg',_'#1',_'Sr') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_5kg',_'#2',_'Sr') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_5kg',_'#3',_'Sr') = 0
# Ograniczenie _C26317: 130*BatchProduced_('Chleb_domowy_0_9kg',_'#1',_'Pon') - ProductionBatch_('Chleb_domowy_0_9kg',_'#1',_'Pon') >= 0
# Ograniczenie _C26319: 130*BatchProducedSubproduct_('Ciasto_na_chleb_domowy_0_9kg',_'#1',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_9kg',_'#1',_'Pon') >= 0
# Ograniczenie _C26321: 130*BatchProduced_('Chleb_domowy_0_9kg',_'#2',_'Pon') - ProductionBatch_('Chleb_domowy_0_9kg',_'#2',_'Pon') >= 0
# Ograniczenie _C26323: 130*BatchProducedSubproduct_('Ciasto_na_chleb_domowy_0_9kg',_'#2',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_9kg',_'#2',_'Pon') >= 0
# Ograniczenie _C26325: 130*BatchProduced_('Chleb_domowy_0_9kg',_'#3',_'Pon') - ProductionBatch_('Chleb_domowy_0_9kg',_'#3',_'Pon') >= 0
# Ograniczenie _C26327: 130*BatchProducedSubproduct_('Ciasto_na_chleb_domowy_0_9kg',_'#3',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_9kg',_'#3',_'Pon') >= 0
# Ograniczenie _C26329: -StorageBatch_('Ciasto_na_chleb_domowy_0_9kg',_'#1',_'Pon') - StorageBatch_('Ciasto_na_chleb_domowy_0_9kg',_'#2',_'Pon') - StorageBatch_('Ciasto_na_chleb_domowy_0_9kg',_'#3',_'Pon') + Storage_('Ciasto_na_chleb_domowy_0_9kg',_'Pon') = 0
# Ograniczenie _C26331: Subproduct_production_('Ciasto_na_chleb_domowy_0_9kg',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_9kg',_'#1',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_9kg',_'#2',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_9kg',_'#3',_'Pon') = 0
# Ograniczenie _C26333: 130*BatchProduced_('Chleb_domowy_0_9kg',_'#1',_'Wt') - ProductionBatch_('Chleb_domowy_0_9kg',_'#1',_'Wt') >= 0
# Ograniczenie _C26337: 130*BatchProduced_('Chleb_domowy_0_9kg',_'#2',_'Wt') - ProductionBatch_('Chleb_domowy_0_9kg',_'#2',_'Wt') >= 0
# Ograniczenie _C26339: 130*BatchProducedSubproduct_('Ciasto_na_chleb_domowy_0_9kg',_'#2',_'Wt') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_9kg',_'#2',_'Wt') >= 0
# Ograniczenie _C26341: 130*BatchProduced_('Chleb_domowy_0_9kg',_'#3',_'Wt') - ProductionBatch_('Chleb_domowy_0_9kg',_'#3',_'Wt') >= 0
# Ograniczenie _C26345: -StorageBatch_('Ciasto_na_chleb_domowy_0_9kg',_'#1',_'Wt') - StorageBatch_('Ciasto_na_chleb_domowy_0_9kg',_'#2',_'Wt') - StorageBatch_('Ciasto_na_chleb_domowy_0_9kg',_'#3',_'Wt') + Storage_('Ciasto_na_chleb_domowy_0_9kg',_'Wt') = 0
# Ograniczenie _C26347: Subproduct_production_('Ciasto_na_chleb_domowy_0_9kg',_'Wt') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_9kg',_'#1',_'Wt') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_9kg',_'#2',_'Wt') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_9kg',_'#3',_'Wt') = 0
# Ograniczenie _C26349: 130*BatchProduced_('Chleb_domowy_0_9kg',_'#1',_'Sr') - ProductionBatch_('Chleb_domowy_0_9kg',_'#1',_'Sr') >= 0
# Ograniczenie _C26353: 130*BatchProduced_('Chleb_domowy_0_9kg',_'#2',_'Sr') - ProductionBatch_('Chleb_domowy_0_9kg',_'#2',_'Sr') >= 0
# Ograniczenie _C26357: 130*BatchProduced_('Chleb_domowy_0_9kg',_'#3',_'Sr') - ProductionBatch_('Chleb_domowy_0_9kg',_'#3',_'Sr') >= 0
# Ograniczenie _C26363: Subproduct_production_('Ciasto_na_chleb_domowy_0_9kg',_'Sr') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_9kg',_'#1',_'Sr') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_9kg',_'#2',_'Sr') - Subproduct_production_Batch_('Ciasto_na_chleb_domowy_0_9kg',_'#3',_'Sr') = 0
# Ograniczenie _C26365: 200*BatchProduced_('Chleb_na_zakwasie',_'#1',_'Pon') - ProductionBatch_('Chleb_na_zakwasie',_'#1',_'Pon') >= 0
# Ograniczenie _C26367: 200*BatchProducedSubproduct_('Ciasto_na_chleb_na_zakwasie',_'#1',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_na_zakwasie',_'#1',_'Pon') >= 0
# Ograniczenie _C26369: 200*BatchProduced_('Chleb_na_zakwasie',_'#2',_'Pon') - ProductionBatch_('Chleb_na_zakwasie',_'#2',_'Pon') >= 0
# Ograniczenie _C26371: 200*BatchProducedSubproduct_('Ciasto_na_chleb_na_zakwasie',_'#2',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_na_zakwasie',_'#2',_'Pon') >= 0
# Ograniczenie _C26373: 200*BatchProduced_('Chleb_na_zakwasie',_'#3',_'Pon') - ProductionBatch_('Chleb_na_zakwasie',_'#3',_'Pon') >= 0
# Ograniczenie _C26375: 200*BatchProducedSubproduct_('Ciasto_na_chleb_na_zakwasie',_'#3',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_na_zakwasie',_'#3',_'Pon') >= 0
# Ograniczenie _C26377: -StorageBatch_('Ciasto_na_chleb_na_zakwasie',_'#1',_'Pon') - StorageBatch_('Ciasto_na_chleb_na_zakwasie',_'#2',_'Pon') - StorageBatch_('Ciasto_na_chleb_na_zakwasie',_'#3',_'Pon') + Storage_('Ciasto_na_chleb_na_zakwasie',_'Pon') = 0
# Ograniczenie _C26379: Subproduct_production_('Ciasto_na_chleb_na_zakwasie',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_na_zakwasie',_'#1',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_na_zakwasie',_'#2',_'Pon') - Subproduct_production_Batch_('Ciasto_na_chleb_na_zakwasie',_'#3',_'Pon') = 0
# Ograniczenie _C26381: 200*BatchProduced_('Chleb_na_zakwasie',_'#1',_'Wt') - ProductionBatch_('Chleb_na_zakwasie',_'#1',_'Wt') >= 0
# Ograniczenie _C26385: 200*BatchProduced_('Chleb_na_zakwasie',_'#2',_'Wt') - ProductionBatch_('Chleb_na_zakwasie',_'#2',_'Wt') >= 0
# Ograniczenie _C26387: 200*BatchProducedSubproduct_('Ciasto_na_chleb_na_zakwasie',_'#2',_'Wt') - Subproduct_production_Batch_('Ciasto_na_chleb_na_zakwasie',_'#2',_'Wt') >= 0
# Ograniczenie _C26389: 200*BatchProduced_('Chleb_na_zakwasie',_'#3',_'Wt') - ProductionBatch_('Chleb_na_zakwasie',_'#3',_'Wt') >= 0
# Ograniczenie _C26393: -StorageBatch_('Ciasto_na_chleb_na_zakwasie',_'#1',_'Wt') - StorageBatch_('Ciasto_na_chleb_na_zakwasie',_'#2',_'Wt') - StorageBatch_('Ciasto_na_chleb_na_zakwasie',_'#3',_'Wt') + Storage_('Ciasto_na_chleb_na_zakwasie',_'Wt') = 0
# Ograniczenie _C26395: Subproduct_production_('Ciasto_na_chleb_na_zakwasie',_'Wt') - Subproduct_production_Batch_('Ciasto_na_chleb_na_zakwasie',_'#1',_'Wt') - Subproduct_production_Batch_('Ciasto_na_chleb_na_zakwasie',_'#2',_'Wt') - Subproduct_production_Batch_('Ciasto_na_chleb_na_zakwasie',_'#3',_'Wt') = 0
# Ograniczenie _C26397: 200*BatchProduced_('Chleb_na_zakwasie',_'#1',_'Sr') - ProductionBatch_('Chleb_na_zakwasie',_'#1',_'Sr') >= 0
# Ograniczenie _C26401: 200*BatchProduced_('Chleb_na_zakwasie',_'#2',_'Sr') - ProductionBatch_('Chleb_na_zakwasie',_'#2',_'Sr') >= 0
# Ograniczenie _C26405: 200*BatchProduced_('Chleb_na_zakwasie',_'#3',_'Sr') - ProductionBatch_('Chleb_na_zakwasie',_'#3',_'Sr') >= 0
# Ograniczenie _C26411: Subproduct_production_('Ciasto_na_chleb_na_zakwasie',_'Sr') - Subproduct_production_Batch_('Ciasto_na_chleb_na_zakwasie',_'#1',_'Sr') - Subproduct_production_Batch_('Ciasto_na_chleb_na_zakwasie',_'#2',_'Sr') - Subproduct_production_Batch_('Ciasto_na_chleb_na_zakwasie',_'#3',_'Sr') = 0
# Ograniczenie _C26413: 200*BatchProduced_('Bulki',_'#1',_'Pon') - ProductionBatch_('Bulki',_'#1',_'Pon') >= 0
# Ograniczenie _C26415: 200*BatchProducedSubproduct_('Ciasto_na_bulki',_'#1',_'Pon') - Subproduct_production_Batch_('Ciasto_na_bulki',_'#1',_'Pon') >= 0
# Ograniczenie _C26417: 200*BatchProduced_('Bulki',_'#2',_'Pon') - ProductionBatch_('Bulki',_'#2',_'Pon') >= 0
# Ograniczenie _C26419: 200*BatchProducedSubproduct_('Ciasto_na_bulki',_'#2',_'Pon') - Subproduct_production_Batch_('Ciasto_na_bulki',_'#2',_'Pon') >= 0
# Ograniczenie _C26421: 200*BatchProduced_('Bulki',_'#3',_'Pon') - ProductionBatch_('Bulki',_'#3',_'Pon') >= 0
# Ograniczenie _C26423: 200*BatchProducedSubproduct_('Ciasto_na_bulki',_'#3',_'Pon') - Subproduct_production_Batch_('Ciasto_na_bulki',_'#3',_'Pon') >= 0
# Ograniczenie _C26425: -StorageBatch_('Ciasto_na_bulki',_'#1',_'Pon') - StorageBatch_('Ciasto_na_bulki',_'#2',_'Pon') - StorageBatch_('Ciasto_na_bulki',_'#3',_'Pon') + Storage_('Ciasto_na_bulki',_'Pon') = 0
# Ograniczenie _C26427: Subproduct_production_('Ciasto_na_bulki',_'Pon') - Subproduct_production_Batch_('Ciasto_na_bulki',_'#1',_'Pon') - Subproduct_production_Batch_('Ciasto_na_bulki',_'#2',_'Pon') - Subproduct_production_Batch_('Ciasto_na_bulki',_'#3',_'Pon') = 0
# Ograniczenie _C26429: 200*BatchProduced_('Bulki',_'#1',_'Wt') - ProductionBatch_('Bulki',_'#1',_'Wt') >= 0
# Ograniczenie _C26433: 200*BatchProduced_('Bulki',_'#2',_'Wt') - ProductionBatch_('Bulki',_'#2',_'Wt') >= 0
# Ograniczenie _C26437: 200*BatchProduced_('Bulki',_'#3',_'Wt') - ProductionBatch_('Bulki',_'#3',_'Wt') >= 0
# Ograniczenie _C26441: -StorageBatch_('Ciasto_na_bulki',_'#1',_'Wt') - StorageBatch_('Ciasto_na_bulki',_'#2',_'Wt') - StorageBatch_('Ciasto_na_bulki',_'#3',_'Wt') + Storage_('Ciasto_na_bulki',_'Wt') = 0
# Ograniczenie _C26443: Subproduct_production_('Ciasto_na_bulki',_'Wt') - Subproduct_production_Batch_('Ciasto_na_bulki',_'#1',_'Wt') - Subproduct_production_Batch_('Ciasto_na_bulki',_'#2',_'Wt') - Subproduct_production_Batch_('Ciasto_na_bulki',_'#3',_'Wt') = 0
# Ograniczenie _C26445: 200*BatchProduced_('Bulki',_'#1',_'Sr') - ProductionBatch_('Bulki',_'#1',_'Sr') >= 0
# Ograniczenie _C26449: 200*BatchProduced_('Bulki',_'#2',_'Sr') - ProductionBatch_('Bulki',_'#2',_'Sr') >= 0
# Ograniczenie _C26453: 200*BatchProduced_('Bulki',_'#3',_'Sr') - ProductionBatch_('Bulki',_'#3',_'Sr') >= 0
# Ograniczenie _C26459: Subproduct_production_('Ciasto_na_bulki',_'Sr') - Subproduct_production_Batch_('Ciasto_na_bulki',_'#1',_'Sr') - Subproduct_production_Batch_('Ciasto_na_bulki',_'#2',_'Sr') - Subproduct_production_Batch_('Ciasto_na_bulki',_'#3',_'Sr') = 0
# Ograniczenie Max_sales_Bulki_Sr: Sales_('Bulki',_'Sr') >= 1.0
# Ograniczenie _C26461: 200*BatchProduced_('Bagietki',_'#1',_'Pon') - ProductionBatch_('Bagietki',_'#1',_'Pon') >= 0
# Ograniczenie _C26463: 200*BatchProducedSubproduct_('Ciasto_na_bagietki',_'#1',_'Pon') - Subproduct_production_Batch_('Ciasto_na_bagietki',_'#1',_'Pon') >= 0
# Ograniczenie _C26465: 200*BatchProduced_('Bagietki',_'#2',_'Pon') - ProductionBatch_('Bagietki',_'#2',_'Pon') >= 0
# Ograniczenie _C26467: 200*BatchProducedSubproduct_('Ciasto_na_bagietki',_'#2',_'Pon') - Subproduct_production_Batch_('Ciasto_na_bagietki',_'#2',_'Pon') >= 0
# Ograniczenie _C26469: 200*BatchProduced_('Bagietki',_'#3',_'Pon') - ProductionBatch_('Bagietki',_'#3',_'Pon') >= 0
# Ograniczenie _C26471: 200*BatchProducedSubproduct_('Ciasto_na_bagietki',_'#3',_'Pon') - Subproduct_production_Batch_('Ciasto_na_bagietki',_'#3',_'Pon') >= 0
# Ograniczenie _C26473: -StorageBatch_('Ciasto_na_bagietki',_'#1',_'Pon') - StorageBatch_('Ciasto_na_bagietki',_'#2',_'Pon') - StorageBatch_('Ciasto_na_bagietki',_'#3',_'Pon') + Storage_('Ciasto_na_bagietki',_'Pon') = 0
# Ograniczenie _C26475: Subproduct_production_('Ciasto_na_bagietki',_'Pon') - Subproduct_production_Batch_('Ciasto_na_bagietki',_'#1',_'Pon') - Subproduct_production_Batch_('Ciasto_na_bagietki',_'#2',_'Pon') - Subproduct_production_Batch_('Ciasto_na_bagietki',_'#3',_'Pon') = 0
# Ograniczenie _C26477: 200*BatchProduced_('Bagietki',_'#1',_'Wt') - ProductionBatch_('Bagietki',_'#1',_'Wt') >= 0
# Ograniczenie _C26481: 200*BatchProduced_('Bagietki',_'#2',_'Wt') - ProductionBatch_('Bagietki',_'#2',_'Wt') >= 0
# Ograniczenie _C26485: 200*BatchProduced_('Bagietki',_'#3',_'Wt') - ProductionBatch_('Bagietki',_'#3',_'Wt') >= 0
# Ograniczenie _C26489: -StorageBatch_('Ciasto_na_bagietki',_'#1',_'Wt') - StorageBatch_('Ciasto_na_bagietki',_'#2',_'Wt') - StorageBatch_('Ciasto_na_bagietki',_'#3',_'Wt') + Storage_('Ciasto_na_bagietki',_'Wt') = 0
# Ograniczenie _C26491: Subproduct_production_('Ciasto_na_bagietki',_'Wt') - Subproduct_production_Batch_('Ciasto_na_bagietki',_'#1',_'Wt') - Subproduct_production_Batch_('Ciasto_na_bagietki',_'#2',_'Wt') - Subproduct_production_Batch_('Ciasto_na_bagietki',_'#3',_'Wt') = 0
# Ograniczenie _C26493: 200*BatchProduced_('Bagietki',_'#1',_'Sr') - ProductionBatch_('Bagietki',_'#1',_'Sr') >= 0
# Ograniczenie _C26497: 200*BatchProduced_('Bagietki',_'#2',_'Sr') - ProductionBatch_('Bagietki',_'#2',_'Sr') >= 0
# Ograniczenie _C26501: 200*BatchProduced_('Bagietki',_'#3',_'Sr') - ProductionBatch_('Bagietki',_'#3',_'Sr') >= 0
# Ograniczenie _C26507: Subproduct_production_('Ciasto_na_bagietki',_'Sr') - Subproduct_production_Batch_('Ciasto_na_bagietki',_'#1',_'Sr') - Subproduct_production_Batch_('Ciasto_na_bagietki',_'#2',_'Sr') - Subproduct_production_Batch_('Ciasto_na_bagietki',_'#3',_'Sr') = 0
# Ograniczenie Max_sales_Bagietki_Sr: Sales_('Bagietki',_'Sr') >= 1.0
# Ograniczenie _C26509: 200*BatchProduced_('Rogaliki_z_czekolada',_'#1',_'Pon') - ProductionBatch_('Rogaliki_z_czekolada',_'#1',_'Pon') >= 0
# Ograniczenie _C26511: 200*BatchProducedSubproduct_('Ciasto_na_rogaliki_z_czekolada',_'#1',_'Pon') - Subproduct_production_Batch_('Ciasto_na_rogaliki_z_czekolada',_'#1',_'Pon') >= 0
# Ograniczenie _C26513: 200*BatchProduced_('Rogaliki_z_czekolada',_'#2',_'Pon') - ProductionBatch_('Rogaliki_z_czekolada',_'#2',_'Pon') >= 0
# Ograniczenie _C26515: 200*BatchProducedSubproduct_('Ciasto_na_rogaliki_z_czekolada',_'#2',_'Pon') - Subproduct_production_Batch_('Ciasto_na_rogaliki_z_czekolada',_'#2',_'Pon') >= 0
# Ograniczenie _C26517: 200*BatchProduced_('Rogaliki_z_czekolada',_'#3',_'Pon') - ProductionBatch_('Rogaliki_z_czekolada',_'#3',_'Pon') >= 0
# Ograniczenie _C26519: 200*BatchProducedSubproduct_('Ciasto_na_rogaliki_z_czekolada',_'#3',_'Pon') - Subproduct_production_Batch_('Ciasto_na_rogaliki_z_czekolada',_'#3',_'Pon') >= 0
# Ograniczenie _C26521: -StorageBatch_('Ciasto_na_rogaliki_z_czekolada',_'#1',_'Pon') - StorageBatch_('Ciasto_na_rogaliki_z_czekolada',_'#2',_'Pon') - StorageBatch_('Ciasto_na_rogaliki_z_czekolada',_'#3',_'Pon') + Storage_('Ciasto_na_rogaliki_z_czekolada',_'Pon') = 0
# Ograniczenie _C26523: Subproduct_production_('Ciasto_na_rogaliki_z_czekolada',_'Pon') - Subproduct_production_Batch_('Ciasto_na_rogaliki_z_czekolada',_'#1',_'Pon') - Subproduct_production_Batch_('Ciasto_na_rogaliki_z_czekolada',_'#2',_'Pon') - Subproduct_production_Batch_('Ciasto_na_rogaliki_z_czekolada',_'#3',_'Pon') = 0
# Ograniczenie _C26525: 200*BatchProduced_('Rogaliki_z_czekolada',_'#1',_'Wt') - ProductionBatch_('Rogaliki_z_czekolada',_'#1',_'Wt') >= 0
# Ograniczenie _C26529: 200*BatchProduced_('Rogaliki_z_czekolada',_'#2',_'Wt') - ProductionBatch_('Rogaliki_z_czekolada',_'#2',_'Wt') >= 0
# Ograniczenie _C26533: 200*BatchProduced_('Rogaliki_z_czekolada',_'#3',_'Wt') - ProductionBatch_('Rogaliki_z_czekolada',_'#3',_'Wt') >= 0
# Ograniczenie _C26537: -StorageBatch_('Ciasto_na_rogaliki_z_czekolada',_'#1',_'Wt') - StorageBatch_('Ciasto_na_rogaliki_z_czekolada',_'#2',_'Wt') - StorageBatch_('Ciasto_na_rogaliki_z_czekolada',_'#3',_'Wt') + Storage_('Ciasto_na_rogaliki_z_czekolada',_'Wt') = 0
# Ograniczenie _C26539: Subproduct_production_('Ciasto_na_rogaliki_z_czekolada',_'Wt') - Subproduct_production_Batch_('Ciasto_na_rogaliki_z_czekolada',_'#1',_'Wt') - Subproduct_production_Batch_('Ciasto_na_rogaliki_z_czekolada',_'#2',_'Wt') - Subproduct_production_Batch_('Ciasto_na_rogaliki_z_czekolada',_'#3',_'Wt') = 0
# Ograniczenie _C26541: 200*BatchProduced_('Rogaliki_z_czekolada',_'#1',_'Sr') - ProductionBatch_('Rogaliki_z_czekolada',_'#1',_'Sr') >= 0
# Ograniczenie _C26545: 200*BatchProduced_('Rogaliki_z_czekolada',_'#2',_'Sr') - ProductionBatch_('Rogaliki_z_czekolada',_'#2',_'Sr') >= 0
# Ograniczenie _C26549: 200*BatchProduced_('Rogaliki_z_czekolada',_'#3',_'Sr') - ProductionBatch_('Rogaliki_z_czekolada',_'#3',_'Sr') >= 0
# Ograniczenie _C26555: Subproduct_production_('Ciasto_na_rogaliki_z_czekolada',_'Sr') - Subproduct_production_Batch_('Ciasto_na_rogaliki_z_czekolada',_'#1',_'Sr') - Subproduct_production_Batch_('Ciasto_na_rogaliki_z_czekolada',_'#2',_'Sr') - Subproduct_production_Batch_('Ciasto_na_rogaliki_z_czekolada',_'#3',_'Sr') = 0
# Ograniczenie Max_sales_Rogaliki_z_czekolada_Sr: Sales_('Rogaliki_z_czekolada',_'Sr') >= 1.0

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_colwidth', None)  # Ustaw brak limitu szerokości kolumny


# Po rozwiązaniu problemu upewnijmy się, że rozwiązanie jest optymalne
if pl.LpStatus[model.status] != 'Optimal':
    print("Model did not solve to optimality.")
    exit()

# Pobierz wartości czasu rozpoczęcia
start_times = {
    (subproduct, machine, day): subproduct_batch_start_time[subproduct, machine, day].varValue
    for subproduct in subproducts for machine in sub_machines for day in days
    if subproduct_batch_start_time[subproduct, machine, day].varValue is not None and is_produced_sub[subproduct, machine, day].varValue != 0 
}

# Oblicz czas zakończenia
end_times = {
    (subproduct, machine, day): start_times[subproduct, machine, day] + sub_production_times[subproduct][machine]
    for subproduct, machine, day in start_times
}

# Wersja 1: Widok z perspektywy subproduktu
subproduct_schedule = []
for subproduct in subproducts:
    for day in days:
        for machine in sub_machines:
            if (subproduct, machine, day) in start_times:
                start = start_times[(subproduct, machine, day)]
                end = end_times[(subproduct, machine, day)]
                subproduct_schedule.append({
                    'Subproduct': subproduct,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

subproduct_df = pd.DataFrame(subproduct_schedule)
print("\nSubproduct Schedule:\n")
print(subproduct_df.sort_values(['Day', 'Subproduct', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania subproduktów na litery
subproduct_mapping = {subproduct: chr(65 + i) for i, subproduct in enumerate(subproducts)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for subproduct in subproducts:
        if (subproduct, machine, day) in start_times:
            start = start_times[(subproduct, machine, day)]
            end = end_times[(subproduct, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = subproduct_mapping[subproduct]  # Wstaw literę dla subproduktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_subproduct = timeline[i]
                    prev_duration = (
                        end_times[(subproducts[ord(prev_subproduct) - 65], machine, day)] -
                        start_times[(subproducts[ord(prev_subproduct) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = subproduct_mapping[subproduct]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in sub_machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
subproduct_df.to_csv("subproduct_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Subproduktów:")
for subproduct, letter in subproduct_mapping.items():
    print(f"{letter}: {subproduct}")

print(subproduct_batch_start_time['Ciasto_na_chleb_domowy_0_5kg', 'Dzieza', 'Pon'].varValue)
print(subproduct_batch_start_time['Ciasto_na_chleb_domowy_0_5kg', 'Dzieza', 'Pon'].varValue + sub_production_times['Ciasto_na_chleb_domowy_0_5kg']['Dzieza'])
print(subproduct_batch_start_time['Ciasto_na_bulki', 'Dzieza', 'Pon'].varValue)

print(is_produced_sub['Ciasto_na_chleb_domowy_0_5kg', 'Dzieza', 'Pon'].varValue)
print(is_produced_sub['Ciasto_na_bulki', 'Dzieza', 'Pon'].varValue)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 13
#      10     exit()
#      12 # Pobierz wartości czasu rozpoczęcia
# ---> 13 start_times = {
#      14     (subproduct, machine, day): subproduct_batch_start_time[subproduct, machine, day].varValue
#      15     for subproduct in subproducts for machine in sub_machines for day in days
#      16     if subproduct_batch_start_time[subproduct, machine, day].varValue is not None and is_produced_sub[subproduct, machine, day].varValue != 0
#      17 }
#      19 # Oblicz czas zakończenia
#      20 end_times = {
#      21     (subproduct, machine, day): start_times[subproduct, machine, day] + sub_production_times[subproduct][machine]
#      22     for subproduct, machine, day in start_times
#      23 }
#
# Cell In[12], line 16, in <dictcomp>(.0)
#      10     exit()
#      12 # Pobierz wartości czasu rozpoczęcia
#      13 start_times = {
#      14     (subproduct, machine, day): subproduct_batch_start_time[subproduct, machine, day].varValue
#      15     for subproduct in subproducts for machine in sub_machines for day in days
# ---> 16     if subproduct_batch_start_time[subproduct, machine, day].varValue is not None and is_produced_sub[subproduct, machine, day].varValue != 0
#      17 }
#      19 # Oblicz czas zakończenia
#      20 end_times = {
#      21     (subproduct, machine, day): start_times[subproduct, machine, day] + sub_production_times[subproduct][machine]
#      22     for subproduct, machine, day in start_times
#      23 }
#
# KeyError: ('Ciasto_na_chleb_domowy_0_5kg', 'Dzieza', 'Pon')

# %%
# Pobierz wartości czasu rozpoczęcia
start_times = {
    (product, machine, day): product_batch_start_time[product, machine, day].varValue
    for product in products for machine in machines for day in days
    if product_batch_start_time[product, machine, day].varValue is not None and is_produced[product, machine, day].varValue != 0 
}

# Oblicz czas zakończenia
end_times = {
    (product, machine, day): start_times[product, machine, day] + production_times[product][machine]
    for product, machine, day in start_times
}

# Wersja 1: Widok z perspektywy produktu
product_schedule = []
for product in products:
    for day in days:
        for machine in machines:
            if (product, machine, day) in start_times:
                start = start_times[(product, machine, day)]
                end = end_times[(product, machine, day)]
                product_schedule.append({
                    'Product': product,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

product_df = pd.DataFrame(product_schedule)
print("\nProduct Schedule:\n")
print(product_df.sort_values(['Day', 'Product', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania produktów na litery
product_mapping = {product: chr(65 + i) for i, product in enumerate(products)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for product in products:
        if (product, machine, day) in start_times:
            start = start_times[(product, machine, day)]
            end = end_times[(product, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = product_mapping[product]  # Wstaw literę dla produktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_product = timeline[i]
                    prev_duration = (
                        end_times[(products[ord(prev_product) - 65], machine, day)] -
                        start_times[(products[ord(prev_product) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = product_mapping[product]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
product_df.to_csv("product_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Produktów:")
for product, letter in product_mapping.items():
    print(f"{letter}: {product}")

print(is_produced['Chleb_domowy_0_5kg', 'Garownia', 'Pon'].varValue)
print(all_from_storage['Ciasto_na_chleb_domowy_0_5kg', 'Pon'])
# Out:
# Product Schedule:
#
#                  Product  Day    Machine  Start Time  End Time
# 42              Bagietki  Pon   Garownia        6.39      6.72
# 43              Bagietki  Pon       Piec        7.89      8.12
# 44              Bagietki  Pon  Studzenie       12.00     12.42
# 0     Chleb_domowy_0_5kg  Pon   Garownia        1.50      2.50
# 1     Chleb_domowy_0_5kg  Pon       Piec       10.32     11.00
# 2     Chleb_domowy_0_5kg  Pon  Studzenie       17.22     19.02
# 3     Chleb_domowy_0_5kg  Pon  Pakowanie       19.02     19.58
# 12    Chleb_domowy_0_9kg  Pon   Garownia        0.00      1.50
# 13    Chleb_domowy_0_9kg  Pon       Piec        9.12     10.32
# 14    Chleb_domowy_0_9kg  Pon  Studzenie       12.42     14.92
# 15    Chleb_domowy_0_9kg  Pon  Pakowanie       18.45     19.02
# 24     Chleb_na_zakwasie  Pon   Garownia        6.72      8.12
# 25     Chleb_na_zakwasie  Pon       Piec        8.12      9.12
# 26     Chleb_na_zakwasie  Pon  Studzenie       14.92     17.22
# 27     Chleb_na_zakwasie  Pon  Pakowanie       17.85     18.45
# 51  Rogaliki_z_czekolada  Pon   Garownia        6.14      6.39
# 52  Rogaliki_z_czekolada  Pon       Piec       11.00     11.18
# 53  Rogaliki_z_czekolada  Pon  Studzenie       11.18     12.00
# 54  Rogaliki_z_czekolada  Pon  Pakowanie       19.58     20.00
# 48              Bagietki   Sr   Garownia        2.13      2.46
# 49              Bagietki   Sr       Piec       11.54     11.77
# 50              Bagietki   Sr  Studzenie       19.58     20.00
# 39                 Bulki   Sr   Garownia        0.00      0.38
# 40                 Bulki   Sr       Piec       11.77     12.02
# 41                 Bulki   Sr  Studzenie       19.10     19.58
# 8     Chleb_domowy_0_5kg   Sr   Garownia        9.74     10.74
# 9     Chleb_domowy_0_5kg   Sr       Piec       10.74     11.42
# 10    Chleb_domowy_0_5kg   Sr  Studzenie       11.42     13.22
# 11    Chleb_domowy_0_5kg   Sr  Pakowanie       19.44     20.00
# 20    Chleb_domowy_0_9kg   Sr   Garownia        0.38      1.88
# 21    Chleb_domowy_0_9kg   Sr       Piec       12.02     13.22
# 22    Chleb_domowy_0_9kg   Sr  Studzenie       13.22     15.72
# 23    Chleb_domowy_0_9kg   Sr  Pakowanie       17.85     18.42
# 32     Chleb_na_zakwasie   Sr   Garownia       14.14     15.54
# 33     Chleb_na_zakwasie   Sr       Piec       15.54     16.54
# 34     Chleb_na_zakwasie   Sr  Studzenie       16.54     18.84
# 35     Chleb_na_zakwasie   Sr  Pakowanie       18.84     19.44
# 55  Rogaliki_z_czekolada   Sr   Garownia        1.88      2.13
# 56  Rogaliki_z_czekolada   Sr       Piec       10.56     10.74
# 57  Rogaliki_z_czekolada   Sr  Studzenie       15.72     16.54
# 58  Rogaliki_z_czekolada   Sr  Pakowanie       18.42     18.84
# 45              Bagietki   Wt   Garownia        1.50      1.83
# 46              Bagietki   Wt       Piec       13.95     14.18
# 47              Bagietki   Wt  Studzenie       14.18     14.60
# 36                 Bulki   Wt   Garownia       10.32     10.70
# 37                 Bulki   Wt       Piec       19.27     19.52
# 38                 Bulki   Wt  Studzenie       19.52     20.00
# 4     Chleb_domowy_0_5kg   Wt   Garownia       10.70     11.70
# 5     Chleb_domowy_0_5kg   Wt       Piec       11.70     12.38
# 6     Chleb_domowy_0_5kg   Wt  Studzenie       12.38     14.18
# 7     Chleb_domowy_0_5kg   Wt  Pakowanie       18.84     19.40
# 16    Chleb_domowy_0_9kg   Wt   Garownia        0.00      1.50
# 17    Chleb_domowy_0_9kg   Wt       Piec       10.50     11.70
# 18    Chleb_domowy_0_9kg   Wt  Studzenie       14.60     17.10
# 19    Chleb_domowy_0_9kg   Wt  Pakowanie       18.27     18.84
# 28     Chleb_na_zakwasie   Wt   Garownia       14.70     16.10
# 29     Chleb_na_zakwasie   Wt       Piec       16.10     17.10
# 30     Chleb_na_zakwasie   Wt  Studzenie       17.10     19.40
# 31     Chleb_na_zakwasie   Wt  Pakowanie       19.40     20.00
#
# Machine Usage Timeline:
#
#       Machine  Day  \
# 0    Garownia  Pon
# 1        Piec  Pon
# 2   Studzenie  Pon
# 3   Pakowanie  Pon
# 4    Garownia   Wt
# 5        Piec   Wt
# 6   Studzenie   Wt
# 7   Pakowanie   Wt
# 8    Garownia   Sr
# 9        Piec   Sr
# 10  Studzenie   Sr
# 11  Pakowanie   Sr
#
#                                                                                                 Timeline
# 0   BBBBBBBAAAAA__________________FEECCCCCCC____________________________________________________________
# 1   _______________________________________ECCCCCBBBBBBAAAA_____________________________________________
# 2   _______________________________________________________FFFFFEEBBBBBBBBBBBBCCCCCCCCCCCCAAAAAAAAA_____
# 3   _________________________________________________________________________________________CCCBBBAAFFF
# 4   BBBBBBBEE__________________________________________DDAAAAA_______________CCCCCCC____________________
# 5   ____________________________________________________BBBBBBAAA________E__________CCCCC___________D___
# 6   _____________________________________________________________AAAAAAAAAEEEBBBBBBBBBBBBCCCCCCCCCCCCDDD
# 7   ___________________________________________________________________________________________BBBAACCCC
# 8   DBBBBBBBBFEE____________________________________AAAAA_________________CCCCCCC_______________________
# 9   ____________________________________________________FAAAAEDDBBBBBB___________CCCCC__________________
# 10  _________________________________________________________AAAAAAAAABBBBBBBBBBBBFFFFCCCCCCCCCCCC_DDEEE
# 11  _________________________________________________________________________________________BBBFFCCCAAA
#
# Legenda Produktów:
# A: Chleb_domowy_0_5kg
# B: Chleb_domowy_0_9kg
# C: Chleb_na_zakwasie
# D: Bulki
# E: Bagietki
# F: Rogaliki_z_czekolada
# 1.0
# 0
