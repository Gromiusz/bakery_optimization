# %%
import pulp as pl
import numpy as np
# from scipy.stats import multivariate_t

print("==============================================================================")

# Define the problem
model = pl.LpProblem("Maximize_Profit", pl.LpMaximize)

# Products, machines and days
subproducts = ['Ciasto_na_chleb_domowy_0_5kg', 'Ciasto_na_chleb_domowy_0_9kg', 'Ciasto_na_chleb_na_zakwasie', 'Ciasto_na_bulki', 'Ciasto_na_bagietki', 'Ciasto_na_rogaliki_z_czekolada']
products = ['Chleb_domowy_0_5kg', 'Chleb_domowy_0_9kg', 'Chleb_na_zakwasie', 'Bulki', 'Bagietki', 'Rogaliki_z_czekolada']
days = ['Pon', 'Wt', 'Sr']
sub_machines = ['Dzieza', 'Wazenie', 'Dzielarka', 'Tabula', 'Rogalikarka', 'Nadziewarka']
machines = ['Garownia', 'Piec', 'Studzenie', 'Pakowanie']

# Income from product sales and production cost in PLN/piece
product_income = {'Chleb_domowy_0_5kg': 5.2, 'Chleb_domowy_0_9kg': 7.9, 'Chleb_na_zakwasie': 6.2, 'Bulki': 1.4, 'Bagietki': 1.55, 'Rogaliki_z_czekolada': 2.1}
sub_product_cost = {'Ciasto_na_chleb_domowy_0_5kg': 1.6, 'Ciasto_na_chleb_domowy_0_9kg': 2.0, 'Ciasto_na_chleb_na_zakwasie': 2.0, 'Ciasto_na_bulki': 0.5, 'Ciasto_na_bagietki': 0.6, 'Ciasto_na_rogaliki_z_czekolada': 1.0}
product_cost = {'Chleb_domowy_0_5kg': 0.8, 'Chleb_domowy_0_9kg': 0.9, 'Chleb_na_zakwasie': 0.8, 'Bulki': 0.2, 'Bagietki': 0.2, 'Rogaliki_z_czekolada': 0.2}

# Time available
shifts_per_day = 2
hours_per_shift = 10
hours_per_day = shifts_per_day * hours_per_shift

max_batches = 1
large_number = 10000

sub_production_times = {
    'Ciasto_na_chleb_domowy_0_5kg': {'Dzieza': 4.7, 'Wazenie': 0.29, 'Dzielarka': 0.0, 'Tabula': 0.7, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_domowy_0_9kg': {'Dzieza': 5, 'Wazenie': 0.2, 'Dzielarka': 0.0, 'Tabula': 0.55, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_na_zakwasie': {'Dzieza': 8.6, 'Wazenie': 0.22, 'Dzielarka': 0.0, 'Tabula': 0.6, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bulki': {'Dzieza': 1, 'Wazenie': 0.0, 'Dzielarka': 0.23, 'Tabula': 0.34, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bagietki': {'Dzieza': 0.95, 'Wazenie': 0.0, 'Dzielarka': 0.24, 'Tabula': 0.0, 'Rogalikarka': 0.28, 'Nadziewarka': 0.0},
    'Ciasto_na_rogaliki_z_czekolada': {'Dzieza': 0.55, 'Wazenie': 0.0, 'Dzielarka': 0.28, 'Tabula': 0.0, 'Rogalikarka': 0.31, 'Nadziewarka': 0.4}
}

production_times = {
    'Chleb_domowy_0_5kg': {'Garownia': 1.0, 'Piec': 0.68, 'Studzenie': 1.8, 'Pakowanie': 0.56},
    'Chleb_domowy_0_9kg': {'Garownia': 1.5, 'Piec': 1.2, 'Studzenie': 2.5, 'Pakowanie': 0.57},
    'Chleb_na_zakwasie': {'Garownia': 1.4, 'Piec': 1.0, 'Studzenie': 2.3, 'Pakowanie': 0.6},
    'Bulki': {'Garownia': 0.38, 'Piec': 0.25, 'Studzenie': 0.48, 'Pakowanie': 0.0},
    'Bagietki': {'Garownia': 0.33, 'Piec': 0.23, 'Studzenie': 0.42, 'Pakowanie': 0.0},
    'Rogaliki_z_czekolada': {'Garownia': 0.25, 'Piec': 0.18, 'Studzenie': 0.82, 'Pakowanie': 0.42}
}


batch_size = {
    "Ciasto_na_chleb_domowy_0_5kg": 240,
    "Ciasto_na_chleb_domowy_0_9kg": 130,
    "Ciasto_na_chleb_na_zakwasie": 200,
    "Ciasto_na_bulki": 200,
    "Ciasto_na_bagietki": 200,
    "Ciasto_na_rogaliki_z_czekolada": 200,
    "Chleb_domowy_0_5kg": 240,
    "Chleb_domowy_0_9kg": 130,
    "Chleb_na_zakwasie": 200,
    "Bulki": 200,
    "Bagietki": 200,
    "Rogaliki_z_czekolada": 200,
}

market_limits = {
    "Chleb_domowy_0_5kg": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 420, "Pt": 530, "Sob": 680},
    "Chleb_domowy_0_9kg": {"Pon": 100, "Wt": 100, "Sr": 380, "Czw": 150, "Pt": 250, "Sob": 580},
    "Chleb_na_zakwasie": {"Pon": 100, "Wt": 100, "Sr": 320, "Czw": 180, "Pt": 280, "Sob": 418},
    "Bulki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 530, "Pt": 650, "Sob": 580},
    "Bagietki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 350, "Pt": 650, "Sob": 680},
    "Rogaliki_z_czekolada": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 310, "Pt": 400, "Sob": 280},
}

# Machines cost
fridge_cost_per_day = 0.281 * 24 * 1.4 * 0.2 # kW * 24h * price per hour * factor
furnace_cost_per_hour = 82.4 # https://giko.pl/kalkulator-zuzycia-energii-dla-piecow-piekarniczych/


fridge_count = 10
fridge_capacity = 160
end_stock = 0
storage_capacity = fridge_count * fridge_capacity

# Variables for production, sales, and storage of products each day
sub_production_vars = pl.LpVariable.dicts("Subproduct production", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
production_vars = pl.LpVariable.dicts("Production", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# batch_count_vars = pl.LpVariable.dicts("Batches Count", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# subbatch_count_vars = pl.LpVariable.dicts("Subproduct Batches Count", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
product_batch_start_time = pl.LpVariable.dicts("ProductStartTime",  [(product, machine, day) for product in products for machine in machines for day in days], lowBound=0, cat="Continuous")
subproduct_batch_start_time = pl.LpVariable.dicts("Subproduction start time for batch",  [(subproduct, machine, day) for subproduct in subproducts for machine in sub_machines for day in days], lowBound=0, cat="Continuous")
sales_vars = pl.LpVariable.dicts("Sales", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, idx) for (machine, idx) in specific_machines], cat="Binary")
# subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, day, batch) for subproduct in subproducts for day in days for batch in range(1, max_batches + 1)], cat="Binary")
subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, day) for subproduct in subproducts for day in days], cat="Binary")
batch_produced = pl.LpVariable.dicts("BatchProduced", [(product, day) for product in products for day in days], cat="Binary")
specific_sub_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, subproduct, day) for machine in sub_machines for subproduct in subproducts for day in days], cat="Binary")
specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, product, day) for machine in machines for product in products for day in days], cat="Binary")
storage_vars = pl.LpVariable.dicts("Storage", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, upBound=storage_capacity, cat='Integer')
fridge_count_usage_vars = pl.LpVariable.dicts("FridgeCount", ((day) for day in days), lowBound=0, upBound=fridge_count, cat='Integer')
all_from_storage = pl.LpVariable.dicts("AllFromStorage", [(subproduct, day) for subproduct in subproducts for day in days], cat="Binary")


# xij = pl.LpVariable.dicts("xij", [(machine, idx, i, j) for (machine, idx) in specific_machines for i in subproducts for j in subproducts if i != j], 0, 1, pl.LpBinary)
is_produced_sub = pl.LpVariable.dicts("is_produced",
                                     ((subproduct, machine, day) for subproduct in subproducts
                                                                      for machine in sub_machines
                                                                      for day in days),
                                     cat="Binary")
is_produced = pl.LpVariable.dicts("is_produced",
                                     ((product, machine, day) for product in products
                                                                      for machine in machines
                                                                      for day in days),
                                     cat="Binary")

for subproduct in subproducts:
    for day in days:
        for i, machine in enumerate(sub_machines[1:], start=1):  # Od ważenia do nadziewarki
            prev = 1
            prev_machine = sub_machines[i - prev]

            while sub_production_times[subproduct][prev_machine] == 0.0 or prev_machine == machine:
                prev += 1
                prev_machine = sub_machines[i - prev]

            model += subproduct_batch_start_time[subproduct, machine, day] >= (
                subproduct_batch_start_time[subproduct, prev_machine, day] + sub_production_times[subproduct][prev_machine]
            )

            model += subproduct_batch_start_time[subproduct, machine, day] <= specific_sub_machine_used[machine, subproduct, day] * hours_per_day

        last_machine = sub_machines[-1]
        model += hours_per_day >= (
            subproduct_batch_start_time[subproduct, last_machine, day] + sub_production_times[subproduct][last_machine]
        )

for product in products:
    for day in days:
        for i, machine in enumerate(machines[1:], start=1):  # Od ważenia do nadziewarki
            prev = 1
            prev_machine = machines[i - prev]

            while production_times[product][prev_machine] == 0.0 or prev_machine == machine:
                prev += 1
                prev_machine = machines[i - prev]

            model += product_batch_start_time[product, machine, day] >= (
                product_batch_start_time[product, prev_machine, day] + production_times[product][prev_machine]
            )

            model += product_batch_start_time[product, machine, day] <= specific_machine_used[machine, product, day] * hours_per_day

        last_machine = machines[-1]
        model += hours_per_day >= (
            product_batch_start_time[product, last_machine, day] + production_times[product][last_machine]
        )
'''
        model += subbatch_produced[subproduct, day] * large_number >= subproduct_batch_start_time[subproduct, last_machine, last_idx, day]

        # Brak nakładania się produkcji na maszynie
        for machine, idx in specific_machines[:6]:  # Zakres maszyn
            for subproduct1 in subproducts:
                for subproduct2 in subproducts:
                    if subproduct1 != subproduct2:
                        model += (subproduct_batch_start_time[subproduct1, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct2, machine, idx, day] + production_times[subproduct2][machine]) | \
                                 (subproduct_batch_start_time[subproduct2, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct1, machine, idx, day] + production_times[subproduct1][machine])

                        # model += specific_machine_used[machine, idx, subproduct1, day] + specific_machine_used[machine, idx, subproduct2, day] <= 1
'''
# Ograniczenie: produkcja subproduktu tylko na maszynach, gdzie czas produkcji > 0
for subproduct in subproducts:
    for machine in sub_machines:
        for day in days:
            if sub_production_times[subproduct][machine] == 0:
                model += is_produced_sub[subproduct, machine, day] == 0

# Ograniczenie: produkcja produktu tylko na maszynach, gdzie czas produkcji > 0
for product in products:
    for machine in machines:
        for day in days:
            if production_times[product][machine] == 0:
                model += is_produced[product, machine, day] == 0
                

# Warunek: jeśli subprodukt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for subproduct in subproducts:
    machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for machine in machines_with_production:
                    model += pl.lpSum(is_produced_sub[subproduct, m, day] for m in machines_with_production) == \
                            len(machines_with_production) * is_produced_sub[subproduct, machine, day]
        
        # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
        model += subbatch_produced[subproduct, day] <= pl.lpSum(is_produced_sub[subproduct, machine, day] for machine in machines_with_production)

# Warunek: jeśli produkt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for product in products:
    machines_with_production = [machine for machine in machines if production_times[product][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for machine in machines_with_production:
                    model += pl.lpSum(is_produced[product, m, day] for m in machines_with_production) == \
                            len(machines_with_production) * is_produced[product, machine, day]
        
        # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
        model += batch_produced[product, day] <= pl.lpSum(is_produced[product, machine, day] for machine in machines_with_production)

# Aktualizacja ograniczenia: brak nakładania się produkcji
big_M = 1000000
for subproduct1 in subproducts:
    for subproduct2 in subproducts:
        if subproduct1 != subproduct2:
            machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct1][machine] > 0 and sub_production_times[subproduct2][machine] > 0]
            for machine in machines_with_production: 
                for day in days:
                    # Dodanie binarnych zmiennych pomocniczych
                    y1 = pl.LpVariable(f"y1_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y2 = pl.LpVariable(f"y2_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y3 = pl.LpVariable(f"y3_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y4 = pl.LpVariable(f"y4_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")

                    # Powiązanie warunków logicznych z binarnymi zmiennymi
                    model += subproduct_batch_start_time[subproduct1, machine, day] >= \
                                subproduct_batch_start_time[subproduct2, machine, day] + sub_production_times[subproduct2][machine] - \
                                big_M * (1 - y1)
                    
                    model += subproduct_batch_start_time[subproduct2, machine, day] >= \
                                subproduct_batch_start_time[subproduct1, machine, day] + sub_production_times[subproduct1][machine] - \
                                big_M * (1 - y2)

                    model += is_produced_sub[subproduct1, machine, day] + y3 == 1
                    model += is_produced_sub[subproduct2, machine, day] + y4 == 1

                    # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                    model += y1 + y2 + y3 + y4 == 1

for product1 in products:
    for product2 in products:
        if product1 != product2:
            machines_with_production = [machine for machine in machines if production_times[product1][machine] > 0 and production_times[product2][machine] > 0]
            for machine in machines_with_production: 
                for day in days:
                    # Dodanie binarnych zmiennych pomocniczych
                    y1 = pl.LpVariable(f"y1_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y2 = pl.LpVariable(f"y2_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y3 = pl.LpVariable(f"y3_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y4 = pl.LpVariable(f"y4_{product1}_{product2}_{machine}_{day}", cat="Binary")

                    # Powiązanie warunków logicznych z binarnymi zmiennymi
                    model += product_batch_start_time[product1, machine, day] >= \
                                product_batch_start_time[product2, machine, day] + production_times[product2][machine] - \
                                big_M * (1 - y1)
                    
                    model += product_batch_start_time[product2, machine, day] >= \
                                product_batch_start_time[product1, machine, day] + production_times[product1][machine] - \
                                big_M * (1 - y2)

                    model += is_produced[product1, machine, day] + y3 == 1
                    model += is_produced[product2, machine, day] + y4 == 1

                    # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                    model += y1 + y2 + y3 + y4 == 1

M = 1000
for subproduct, product in zip(subproducts, products):
    model += storage_vars[subproduct, 'Pon'] == sub_production_vars[subproduct, 'Pon'] - production_vars[product, 'Pon']
    for i in range(1, len(days)):
        day = days[i]
        prev_day = days[i-1]
        # model += storage_vars[subproduct, day] == storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day]
        # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
        # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
        # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
        model += product_batch_start_time[product, machines[0], day] >= (subproduct_batch_start_time[subproduct, sub_machines[-1], day]) + sub_production_times[subproduct][sub_machines[-1]] - M * all_from_storage[subproduct, day]

expr1 = pl.LpVariable.dicts("expr1", [(s, d) for s in subproducts for d in days], lowBound=0)
expr2 = pl.LpVariable.dicts("expr2", [(s, d) for s in subproducts for d in days], lowBound=0)

# Dodaj ograniczenia dla zmiennych pomocniczych
for s, p in zip(subproducts, products):
    all_from_storage[s, 'Pon'] = 0
    for i in range(1, len(days)):
        d = days[i]
        prev_day = days[i-1]
        model += expr1[s, d] >= storage_vars[s, prev_day] - production_vars[p, d] - M * (1 - all_from_storage[s, d])
        model += expr1[s, d] <= storage_vars[s, prev_day] - production_vars[p, d]
        model += expr1[s, d] <= M * all_from_storage[s, d]
        model += expr1[s, d] >= 0
        
        model += expr2[s, d] >= storage_vars[s, prev_day] + sub_production_vars[s, d] - production_vars[p, d] - M * all_from_storage[s, d]
        model += expr2[s, d] <= storage_vars[s, prev_day] + sub_production_vars[s, d] - production_vars[p, d]
        model += expr2[s, d] <= M * (1 - all_from_storage[s, d])
        model += expr2[s, d] >= 0

        # Ograniczenie
        model += storage_vars[s, d] == expr1[s, d] + expr2[s, d]


for day in days:
    model += storage_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)
    model += fridge_count_usage_vars[day] * fridge_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)

for product, subproduct in zip(products, subproducts):
    for day in days:
        model += batch_produced[product, day] * batch_size[product] >= production_vars[product, day]
        model += production_vars[product, day] >= batch_produced[product, day]
        model += subbatch_produced[subproduct, day] * batch_size[subproduct] >= sub_production_vars[subproduct, day]
        model += sub_production_vars[subproduct, day] >= subbatch_produced[subproduct, day]

        # model += sub_production_vars[subproduct, day] >= production_vars[product, day]
        model += sales_vars[product, day] == production_vars[product, day]
    model += sales_vars[product, 'Sr'] >= 0.01*market_limits[product]['Wt'], f"Max_sales_{product}_{'Sr'}"


# Objective function: Maximize profit from sales minus costs
model += pl.lpSum([sales_vars[product, day] * product_income[product] for product in products for day in days]) \
                    - pl.lpSum([production_vars[product, day] * product_cost[product] for product in products for day in days]) \
                    - pl.lpSum([sub_production_vars[subproduct, day] * sub_product_cost[subproduct] for subproduct in subproducts for day in days]) \
                    - pl.lpSum([fridge_count_usage_vars[day] * fridge_cost_per_day for day in days]) \
                    - pl.lpSum([batch_produced[product, day] * production_times[product]['Piec'] * furnace_cost_per_hour for product in products for day in days]), "Total_Profit"


solver = pl.PULP_CBC_CMD(timeLimit=60)

model.solve(solver)

# model.solve()

# Results
print("Status:", pl.LpStatus[model.status])
if pl.LpStatus[model.status] == 'Optimal':
    print("Total Profit:", pl.value(model.objective))

    print(f"{'Product':<10} {'day':<10} {'SubProduction':<10} {'Production':<12} {'Sales':<10} {'Storage':<10}")

    for product, subproduct in zip(products, subproducts):
        for day in days:
            subproduction = sub_production_vars[subproduct, day].varValue
            production = production_vars[product, day].varValue
            sales = sales_vars[product, day].varValue
            storage = storage_vars[subproduct, day].varValue

            print(f"{product:<10} {day:<10} {subproduction:<12} {production:<12} {sales:<10} {storage:<10}")

    # print("\nProduction Time Usage per Product and Day:")
    # for day in days:
    #     print(f"\Day: {day}")
    #     for product in products:
    #         total_production_time = sum(
    #             batch_count_vars[product, day].varValue * production_times[product]s.get(machine, 0) 
    #             for machine in machines #.keys()
    #         )
    #         print(f"  Product: {product}, Total Production Time: {total_production_time:.2f} hours")

else:
    print("No optimal solution was found.")
    # Analiza ograniczeń
    for name, constraint in model.constraints.items():
        if constraint.pi < 0:
            print(f"Ograniczenie {name}: {constraint}")
# Out:
# ==============================================================================
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gromek/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/fe306a5a7b0d4e87be3aad046647b343-pulp.mps -max -sec 60 -timeMode elapsed -branch -printingOptions all -solution /tmp/fe306a5a7b0d4e87be3aad046647b343-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 3143 COLUMNS
# At line 16377 RHS
# At line 19516 BOUNDS
# At line 21860 ENDATA
# Problem MODEL has 3138 rows, 2547 columns and 8472 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 60
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 4363.04 - 0.01 seconds
# Cgl0002I 57 variables fixed
# Cgl0003I 22 fixed, 12 tightened bounds, 1002 strengthened rows, 278 substitutions
# Cgl0003I 0 fixed, 6 tightened bounds, 720 strengthened rows, 115 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 799 strengthened rows, 6 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 72 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 21 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1580 rows, 1107 columns (951 integer (900 of which binary)) and 7261 elements
# Cbc0038I Initial state - 420 integers unsatisfied sum - 93.1692
# Cbc0038I Pass   1: suminf.   40.16154 (469) obj. -3333.37 iterations 434
# Cbc0038I Pass   2: suminf.   35.99027 (501) obj. -3336.88 iterations 67
# Cbc0038I Pass   3: suminf.   34.41319 (505) obj. -3336.88 iterations 35
# Cbc0038I Pass   4: suminf.   33.56996 (497) obj. -3336.88 iterations 2
# Cbc0038I Pass   5: suminf.   26.23325 (423) obj. -3352.3 iterations 77
# Cbc0038I Pass   6: suminf.   25.86566 (431) obj. -3352.3 iterations 27
# Cbc0038I Pass   7: suminf.   20.20947 (431) obj. -3352.68 iterations 77
# Cbc0038I Pass   8: suminf.   20.14464 (422) obj. -3352.3 iterations 12
# Cbc0038I Pass   9: suminf.   16.26414 (404) obj. -3352.68 iterations 96
# Cbc0038I Pass  10: suminf.   12.05526 (276) obj. -2673.01 iterations 127
# Cbc0038I Pass  11: suminf.   11.60541 (273) obj. -2673.01 iterations 20
# Cbc0038I Pass  12: suminf.   11.09590 (281) obj. -2673.01 iterations 24
# Cbc0038I Pass  13: suminf.    8.68810 (237) obj. -1864.06 iterations 94
# Cbc0038I Pass  14: suminf.    8.65690 (246) obj. -1864.06 iterations 8
# Cbc0038I Pass  15: suminf.    7.29063 (217) obj. -1864.06 iterations 48
# Cbc0038I Pass  16: suminf.    6.28605 (194) obj. -1864.06 iterations 53
# Cbc0038I Pass  17: suminf.    6.22612 (196) obj. -1864.06 iterations 9
# Cbc0038I Pass  18: suminf.    4.94573 (163) obj. -1864.45 iterations 65
# Cbc0038I Pass  19: suminf.    4.88764 (165) obj. -1864.45 iterations 17
# Cbc0038I Pass  20: suminf.    3.69122 (113) obj. -1864.92 iterations 103
# Cbc0038I Pass  21: suminf.    3.61864 (125) obj. -1864.92 iterations 24
# Cbc0038I Pass  22: suminf.    3.59871 (108) obj. -1864.8 iterations 38
# Cbc0038I Pass  23: suminf.    3.34020 (106) obj. -1864.92 iterations 15
# Cbc0038I Pass  24: suminf.    2.93186 (92) obj. -1864.92 iterations 54
# Cbc0038I Pass  25: suminf.    3.01360 (93) obj. -1864.8 iterations 15
# Cbc0038I Pass  26: suminf.    2.06535 (45) obj. -1865.76 iterations 82
# Cbc0038I Pass  27: suminf.    1.76682 (36) obj. -1865.76 iterations 71
# Cbc0038I Pass  28: suminf.    1.76682 (36) obj. -1865.76 iterations 0
# Cbc0038I Pass  29: suminf.    1.40272 (14) obj. -1865.76 iterations 94
# Cbc0038I Pass  30: suminf.    1.40272 (14) obj. -1865.76 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 247 integers at bound fixed and 15 continuous of which 1 were internal integer and 0 internal continuous
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 1360 rows 764 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.31 seconds)
# Cbc0038I After 0.31 seconds - Feasibility pump exiting - took 0.15 seconds
# Cbc0031I 146 added rows had average density of 21.931507
# Cbc0013I At root node, 146 cuts changed objective from -4363.0355 to -4345.5014 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 492 row cuts average 2.5 elements, 0 column cuts (76 active)  in 0.045 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 400 row cuts average 26.9 elements, 0 column cuts (0 active)  in 0.036 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 20 row cuts average 5.2 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 256 row cuts average 3.3 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 15 row cuts average 3.3 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 1278 row cuts average 27.7 elements, 0 column cuts (0 active)  in 0.064 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 14 row cuts average 6.4 elements, 0 column cuts (0 active)  in 0.051 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible -4345.5014 (1.01 seconds)
# Cbc0010I After 100 nodes, 12 on tree, 1e+50 best solution, best possible -4345.5014 (5.01 seconds)
# Cbc0010I After 200 nodes, 27 on tree, 1e+50 best solution, best possible -4345.5014 (6.36 seconds)
# Cbc0010I After 300 nodes, 19 on tree, 1e+50 best solution, best possible -4345.5014 (7.42 seconds)
# Cbc0010I After 400 nodes, 27 on tree, 1e+50 best solution, best possible -4345.5014 (9.04 seconds)
# Cbc0010I After 500 nodes, 31 on tree, 1e+50 best solution, best possible -4345.5014 (9.61 seconds)
# Cbc0010I After 600 nodes, 54 on tree, 1e+50 best solution, best possible -4345.5014 (10.42 seconds)
# Cbc0010I After 700 nodes, 52 on tree, 1e+50 best solution, best possible -4345.5014 (11.02 seconds)
# Cbc0010I After 800 nodes, 50 on tree, 1e+50 best solution, best possible -4345.5014 (11.48 seconds)
# Cbc0010I After 900 nodes, 52 on tree, 1e+50 best solution, best possible -4345.5014 (11.98 seconds)
# Cbc0010I After 1000 nodes, 71 on tree, 1e+50 best solution, best possible -4345.5014 (12.35 seconds)
# Cbc0004I Integer solution of -2444.2698 found after 44577 iterations and 1082 nodes (13.01 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 643 rows 322 columns
# Cbc0010I After 1100 nodes, 63 on tree, -2444.2698 best solution, best possible -4345.5014 (13.27 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 519 rows 240 columns
# Cbc0010I After 1200 nodes, 103 on tree, -2444.2698 best solution, best possible -4345.5014 (14.43 seconds)
# Cbc0012I Integer solution of -3193.0048 found by rounding after 54891 iterations and 1284 nodes (14.97 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 619 rows 290 columns
# Cbc0010I After 1300 nodes, 92 on tree, -3193.0048 best solution, best possible -4345.5014 (15.21 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 543 rows 256 columns
# Cbc0010I After 1400 nodes, 135 on tree, -3193.0048 best solution, best possible -4345.5014 (16.38 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 465 rows 220 columns
# Cbc0010I After 1500 nodes, 166 on tree, -3193.0048 best solution, best possible -4345.5014 (17.27 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 572 rows 273 columns
# Cbc0010I After 1600 nodes, 198 on tree, -3193.0048 best solution, best possible -4345.5014 (18.23 seconds)
# Cbc0010I After 1700 nodes, 207 on tree, -3193.0048 best solution, best possible -4345.5014 (18.75 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 464 rows 229 columns
# Cbc0010I After 1800 nodes, 222 on tree, -3193.0048 best solution, best possible -4345.5014 (19.34 seconds)
# Cbc0010I After 1900 nodes, 223 on tree, -3193.0048 best solution, best possible -4345.5014 (19.83 seconds)
# Cbc0010I After 2000 nodes, 230 on tree, -3193.0048 best solution, best possible -4345.5014 (20.37 seconds)
# Cbc0010I After 2100 nodes, 237 on tree, -3193.0048 best solution, best possible -4345.5014 (20.87 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 494 rows 245 columns
# Cbc0010I After 2200 nodes, 246 on tree, -3193.0048 best solution, best possible -4345.5014 (21.49 seconds)
# Cbc0010I After 2300 nodes, 255 on tree, -3193.0048 best solution, best possible -4345.5014 (21.98 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 465 rows 223 columns
# Cbc0010I After 2400 nodes, 270 on tree, -3193.0048 best solution, best possible -4345.5014 (22.35 seconds)
# Cbc0010I After 2500 nodes, 281 on tree, -3193.0048 best solution, best possible -4345.5014 (22.86 seconds)
# Cbc0010I After 2600 nodes, 281 on tree, -3193.0048 best solution, best possible -4345.5014 (23.35 seconds)
# Cbc0010I After 2700 nodes, 276 on tree, -3193.0048 best solution, best possible -4345.5014 (23.82 seconds)
# Cbc0010I After 2800 nodes, 277 on tree, -3193.0048 best solution, best possible -4345.5014 (24.28 seconds)
# Cbc0010I After 2900 nodes, 286 on tree, -3193.0048 best solution, best possible -4345.5014 (25.05 seconds)
# Cbc0010I After 3000 nodes, 284 on tree, -3193.0048 best solution, best possible -4345.5014 (25.63 seconds)
# Cbc0010I After 3100 nodes, 298 on tree, -3193.0048 best solution, best possible -4345.5014 (26.16 seconds)
# Cbc0010I After 3200 nodes, 307 on tree, -3193.0048 best solution, best possible -4345.5014 (26.63 seconds)
# Cbc0010I After 3300 nodes, 311 on tree, -3193.0048 best solution, best possible -4345.5014 (27.10 seconds)
# Cbc0010I After 3400 nodes, 317 on tree, -3193.0048 best solution, best possible -4345.5014 (27.80 seconds)
# Cbc0010I After 3500 nodes, 327 on tree, -3193.0048 best solution, best possible -4345.5014 (28.38 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 500 rows 240 columns
# Cbc0010I After 3600 nodes, 319 on tree, -3193.0048 best solution, best possible -4345.5014 (28.92 seconds)
# Cbc0010I After 3700 nodes, 331 on tree, -3193.0048 best solution, best possible -4345.5014 (29.45 seconds)
# Cbc0010I After 3800 nodes, 327 on tree, -3193.0048 best solution, best possible -4345.5014 (29.85 seconds)
# Cbc0010I After 3900 nodes, 335 on tree, -3193.0048 best solution, best possible -4345.5014 (30.40 seconds)
# Cbc0010I After 4000 nodes, 344 on tree, -3193.0048 best solution, best possible -4345.5014 (30.97 seconds)
# Cbc0010I After 4100 nodes, 347 on tree, -3193.0048 best solution, best possible -4345.5014 (31.48 seconds)
# Cbc0010I After 4200 nodes, 341 on tree, -3193.0048 best solution, best possible -4345.5014 (32.03 seconds)
# Cbc0010I After 4300 nodes, 338 on tree, -3193.0048 best solution, best possible -4345.5014 (32.40 seconds)
# Cbc0010I After 4400 nodes, 343 on tree, -3193.0048 best solution, best possible -4345.5014 (32.94 seconds)
# Cbc0010I After 4500 nodes, 335 on tree, -3193.0048 best solution, best possible -4345.5014 (33.34 seconds)
# Cbc0010I After 4600 nodes, 335 on tree, -3193.0048 best solution, best possible -4345.5014 (33.80 seconds)
# Cbc0010I After 4700 nodes, 334 on tree, -3193.0048 best solution, best possible -4345.5014 (34.36 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 559 rows 275 columns
# Cbc0010I After 4800 nodes, 327 on tree, -3193.0048 best solution, best possible -4345.5014 (34.98 seconds)
# Cbc0010I After 4900 nodes, 322 on tree, -3193.0048 best solution, best possible -4345.5014 (35.42 seconds)
# Cbc0010I After 5000 nodes, 322 on tree, -3193.0048 best solution, best possible -4345.5014 (35.94 seconds)
# Cbc0010I After 5100 nodes, 293 on tree, -3193.0048 best solution, best possible -4345.5014 (36.24 seconds)
# Cbc0010I After 5200 nodes, 285 on tree, -3193.0048 best solution, best possible -4345.5014 (36.60 seconds)
# Cbc0010I After 5300 nodes, 266 on tree, -3193.0048 best solution, best possible -4345.5014 (36.99 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 617 rows 289 columns
# Cbc0010I After 5400 nodes, 255 on tree, -3193.0048 best solution, best possible -4345.5014 (37.36 seconds)
# Cbc0010I After 5500 nodes, 242 on tree, -3193.0048 best solution, best possible -4345.5014 (37.77 seconds)
# Cbc0010I After 5600 nodes, 239 on tree, -3193.0048 best solution, best possible -4345.5014 (38.16 seconds)
# Cbc0010I After 5700 nodes, 238 on tree, -3193.0048 best solution, best possible -4345.5014 (38.60 seconds)
# Cbc0010I After 5800 nodes, 234 on tree, -3193.0048 best solution, best possible -4345.5014 (39.01 seconds)
# Cbc0010I After 5900 nodes, 225 on tree, -3193.0048 best solution, best possible -4345.5014 (39.47 seconds)
# Cbc0010I After 6000 nodes, 218 on tree, -3193.0048 best solution, best possible -4345.5014 (39.82 seconds)
# Cbc0010I After 6100 nodes, 205 on tree, -3193.0048 best solution, best possible -4345.5014 (40.16 seconds)
# Cbc0010I After 6200 nodes, 206 on tree, -3193.0048 best solution, best possible -4345.5014 (40.71 seconds)
# Cbc0010I After 6300 nodes, 199 on tree, -3193.0048 best solution, best possible -4345.5014 (41.22 seconds)
# Cbc0010I After 6400 nodes, 198 on tree, -3193.0048 best solution, best possible -4345.5014 (41.77 seconds)
# Cbc0010I After 6500 nodes, 199 on tree, -3193.0048 best solution, best possible -4345.5014 (42.27 seconds)
# Cbc0010I After 6600 nodes, 197 on tree, -3193.0048 best solution, best possible -4345.5014 (42.61 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 519 rows 271 columns
# Cbc0010I After 6700 nodes, 194 on tree, -3193.0048 best solution, best possible -4345.5014 (43.04 seconds)
# Cbc0010I After 6800 nodes, 192 on tree, -3193.0048 best solution, best possible -4345.5014 (43.48 seconds)
# Cbc0010I After 6900 nodes, 182 on tree, -3193.0048 best solution, best possible -4345.5014 (43.86 seconds)
# Cbc0010I After 7000 nodes, 148 on tree, -3193.0048 best solution, best possible -4345.5014 (44.51 seconds)
# Cbc0010I After 7100 nodes, 125 on tree, -3193.0048 best solution, best possible -4345.5014 (45.09 seconds)
# Cbc0010I After 7200 nodes, 111 on tree, -3193.0048 best solution, best possible -4345.5014 (45.51 seconds)
# Cbc0010I After 7300 nodes, 97 on tree, -3193.0048 best solution, best possible -4345.5014 (46.03 seconds)
# Cbc0010I After 7400 nodes, 94 on tree, -3193.0048 best solution, best possible -4345.5014 (46.57 seconds)
# Cbc0010I After 7500 nodes, 89 on tree, -3193.0048 best solution, best possible -4345.5014 (47.10 seconds)
# Cbc0010I After 7600 nodes, 86 on tree, -3193.0048 best solution, best possible -4345.5014 (47.54 seconds)
# Cbc0010I After 7700 nodes, 76 on tree, -3193.0048 best solution, best possible -4345.5014 (48.05 seconds)
# Cbc0010I After 7800 nodes, 68 on tree, -3193.0048 best solution, best possible -4345.5014 (48.61 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 615 rows 294 columns
# Cbc0010I After 7900 nodes, 58 on tree, -3193.0048 best solution, best possible -4345.5014 (49.08 seconds)
# Cbc0010I After 8000 nodes, 29 on tree, -3193.0048 best solution, best possible -4345.5014 (49.66 seconds)
# Cbc0010I After 8100 nodes, 12 on tree, -3193.0048 best solution, best possible -4345.5014 (50.09 seconds)
# Cbc0010I After 8200 nodes, 10 on tree, -3193.0048 best solution, best possible -4345.5014 (50.76 seconds)
# Cbc0010I After 8300 nodes, 4 on tree, -3193.0048 best solution, best possible -4345.5014 (51.79 seconds)
# Cbc0012I Integer solution of -3194.8931 found by rounding after 283423 iterations and 8388 nodes (52.70 seconds)
# Cbc0010I After 8400 nodes, 4 on tree, -3194.8931 best solution, best possible -4345.5014 (52.84 seconds)
# Cbc0010I After 8500 nodes, 17 on tree, -3194.8931 best solution, best possible -4345.5014 (54.27 seconds)
# Cbc0010I After 8600 nodes, 30 on tree, -3194.8931 best solution, best possible -4345.5014 (54.88 seconds)
# Cbc0010I After 8700 nodes, 30 on tree, -3194.8931 best solution, best possible -4345.5014 (55.34 seconds)
# Cbc0010I After 8800 nodes, 31 on tree, -3194.8931 best solution, best possible -4345.5014 (55.79 seconds)
# Cbc0010I After 8900 nodes, 37 on tree, -3194.8931 best solution, best possible -4345.5014 (56.32 seconds)
# Cbc0010I After 9000 nodes, 35 on tree, -3194.8931 best solution, best possible -4345.5014 (56.74 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 587 rows 292 columns
# Cbc0010I After 9100 nodes, 21 on tree, -3194.8931 best solution, best possible -4345.5014 (57.10 seconds)
# Cbc0010I After 9200 nodes, 15 on tree, -3194.8931 best solution, best possible -4345.5014 (57.36 seconds)
# Cbc0010I After 9300 nodes, 7 on tree, -3194.8931 best solution, best possible -4345.5014 (57.68 seconds)
# Cbc0010I After 9400 nodes, 7 on tree, -3194.8931 best solution, best possible -4345.5014 (58.50 seconds)
# Cbc0010I After 9500 nodes, 14 on tree, -3194.8931 best solution, best possible -4345.5014 (59.24 seconds)
# Cbc0038I Full problem 1580 rows 1107 columns, reduced to 611 rows 296 columns
# Cbc0010I After 9600 nodes, 11 on tree, -3194.8931 best solution, best possible -4345.5014 (59.78 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective -3194.8931 (best possible -4345.5014), took 318968 iterations and 9618 nodes (59.86 seconds)
# Cbc0032I Strong branching done 16008 times (150073 iterations), fathomed 1105 nodes and fixed 752 variables
# Cbc0035I Maximum depth 74, 1372 variables fixed on reduced cost
# Cuts at root node changed objective from -4363.04 to -4345.5
# Probing was tried 2925 times and created 43320 cuts of which 76 were active after adding rounds of cuts (1.754 seconds)
# Gomory was tried 1498 times and created 14301 cuts of which 0 were active after adding rounds of cuts (2.751 seconds)
# Knapsack was tried 1498 times and created 1262 cuts of which 0 were active after adding rounds of cuts (1.162 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 1498 times and created 14337 cuts of which 0 were active after adding rounds of cuts (1.269 seconds)
# FlowCover was tried 10 times and created 15 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
# TwoMirCuts was tried 10 times and created 1278 cuts of which 0 were active after adding rounds of cuts (0.064 seconds)
# ZeroHalf was tried 10 times and created 14 cuts of which 0 were active after adding rounds of cuts (0.051 seconds)
# ImplicationCuts was tried 209 times and created 64 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                3194.89312000
# Upper bound:                    4345.501
# Gap:                            -0.26
# Enumerated nodes:               9618
# Total iterations:               318968
# Time (CPU seconds):             57.78
# Time (Wallclock seconds):       59.89
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       57.78   (Wallclock seconds):       59.91
#
# Status: Optimal
# Total Profit: 3194.8931199999993
# Product    day        SubProduction Production   Sales      Storage
# Chleb_domowy_0_5kg Pon        240.0        240.0        240.0      0.0
# Chleb_domowy_0_5kg Wt         240.0        0.0          0.0        240.0
# Chleb_domowy_0_5kg Sr         0.0          240.0        240.0      0.0
# Chleb_domowy_0_9kg Pon        130.0        0.0          0.0        130.0
# Chleb_domowy_0_9kg Wt         0.0          0.0          0.0        130.0
# Chleb_domowy_0_9kg Sr         0.0          130.0        130.0      0.0
# Chleb_na_zakwasie Pon        0.0          0.0          0.0        0.0
# Chleb_na_zakwasie Wt         200.0        0.0          0.0        200.0
# Chleb_na_zakwasie Sr         0.0          200.0        200.0      0.0
# Bulki      Pon        200.0        200.0        200.0      0.0
# Bulki      Wt         200.0        0.0          0.0        200.0
# Bulki      Sr         0.0          200.0        200.0      0.0
# Bagietki   Pon        200.0        200.0        200.0      0.0
# Bagietki   Wt         200.0        0.0          0.0        200.0
# Bagietki   Sr         0.0          200.0        200.0      0.0
# Rogaliki_z_czekolada Pon        200.0        200.0        200.0      0.0
# Rogaliki_z_czekolada Wt         200.0        0.0          0.0        200.0
# Rogaliki_z_czekolada Sr         0.0          200.0        200.0      0.0

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_colwidth', None)  # Ustaw brak limitu szerokości kolumny


# Po rozwiązaniu problemu upewnijmy się, że rozwiązanie jest optymalne
if pl.LpStatus[model.status] != 'Optimal':
    print("Model did not solve to optimality.")
    exit()

# Pobierz wartości czasu rozpoczęcia
start_times = {
    (subproduct, machine, day): subproduct_batch_start_time[subproduct, machine, day].varValue
    for subproduct in subproducts for machine in sub_machines for day in days
    if subproduct_batch_start_time[subproduct, machine, day].varValue is not None and is_produced_sub[subproduct, machine, day].varValue != 0 
}

# Oblicz czas zakończenia
end_times = {
    (subproduct, machine, day): start_times[subproduct, machine, day] + sub_production_times[subproduct][machine]
    for subproduct, machine, day in start_times
}

# Wersja 1: Widok z perspektywy subproduktu
subproduct_schedule = []
for subproduct in subproducts:
    for day in days:
        for machine in sub_machines:
            if (subproduct, machine, day) in start_times:
                start = start_times[(subproduct, machine, day)]
                end = end_times[(subproduct, machine, day)]
                subproduct_schedule.append({
                    'Subproduct': subproduct,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

subproduct_df = pd.DataFrame(subproduct_schedule)
print("\nSubproduct Schedule:\n")
print(subproduct_df.sort_values(['Day', 'Subproduct', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania subproduktów na litery
subproduct_mapping = {subproduct: chr(65 + i) for i, subproduct in enumerate(subproducts)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for subproduct in subproducts:
        if (subproduct, machine, day) in start_times:
            start = start_times[(subproduct, machine, day)]
            end = end_times[(subproduct, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = subproduct_mapping[subproduct]  # Wstaw literę dla subproduktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_subproduct = timeline[i]
                    prev_duration = (
                        end_times[(subproducts[ord(prev_subproduct) - 65], machine, day)] -
                        start_times[(subproducts[ord(prev_subproduct) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = subproduct_mapping[subproduct]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in sub_machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
subproduct_df.to_csv("subproduct_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Subproduktów:")
for subproduct, letter in subproduct_mapping.items():
    print(f"{letter}: {subproduct}")

print(subproduct_batch_start_time['Ciasto_na_chleb_domowy_0_5kg', 'Dzieza', 'Pon'].varValue)
print(subproduct_batch_start_time['Ciasto_na_chleb_domowy_0_5kg', 'Dzieza', 'Pon'].varValue + sub_production_times['Ciasto_na_chleb_domowy_0_5kg']['Dzieza'])
print(subproduct_batch_start_time['Ciasto_na_bulki', 'Dzieza', 'Pon'].varValue)

print(is_produced_sub['Ciasto_na_chleb_domowy_0_5kg', 'Dzieza', 'Pon'].varValue)
print(is_produced_sub['Ciasto_na_bulki', 'Dzieza', 'Pon'].varValue)
# Out:
# Subproduct Schedule:
#
#                         Subproduct  Day      Machine  Start Time  End Time
# 27              Ciasto_na_bagietki  Pon       Dzieza       17.54     18.49
# 28              Ciasto_na_bagietki  Pon    Dzielarka       18.49     18.73
# 29              Ciasto_na_bagietki  Pon  Rogalikarka       19.72     20.00
# 18                 Ciasto_na_bulki  Pon       Dzieza       16.54     17.54
# 19                 Ciasto_na_bulki  Pon    Dzielarka       18.73     18.96
# 20                 Ciasto_na_bulki  Pon       Tabula       18.96     19.30
# 0     Ciasto_na_chleb_domowy_0_5kg  Pon       Dzieza        5.55     10.25
# 1     Ciasto_na_chleb_domowy_0_5kg  Pon      Wazenie       19.01     19.30
# 2     Ciasto_na_chleb_domowy_0_5kg  Pon       Tabula       19.30     20.00
# 6     Ciasto_na_chleb_domowy_0_9kg  Pon       Dzieza        0.00      5.00
# 7     Ciasto_na_chleb_domowy_0_9kg  Pon      Wazenie       18.21     18.41
# 8     Ciasto_na_chleb_domowy_0_9kg  Pon       Tabula       18.41     18.96
# 36  Ciasto_na_rogaliki_z_czekolada  Pon       Dzieza        5.00      5.55
# 37  Ciasto_na_rogaliki_z_czekolada  Pon    Dzielarka       18.21     18.49
# 38  Ciasto_na_rogaliki_z_czekolada  Pon  Rogalikarka       19.29     19.60
# 39  Ciasto_na_rogaliki_z_czekolada  Pon  Nadziewarka       19.60     20.00
# 33              Ciasto_na_bagietki   Sr       Dzieza        8.60      9.55
# 34              Ciasto_na_bagietki   Sr    Dzielarka       18.77     19.01
# 35              Ciasto_na_bagietki   Sr  Rogalikarka       19.01     19.29
# 24                 Ciasto_na_bulki   Sr       Dzieza       11.94     12.94
# 25                 Ciasto_na_bulki   Sr    Dzielarka       18.26     18.49
# 26                 Ciasto_na_bulki   Sr       Tabula       18.51     18.85
# 9     Ciasto_na_chleb_domowy_0_9kg   Sr       Dzieza       12.94     17.94
# 10    Ciasto_na_chleb_domowy_0_9kg   Sr      Wazenie       18.43     18.63
# 11    Ciasto_na_chleb_domowy_0_9kg   Sr       Tabula       19.45     20.00
# 15     Ciasto_na_chleb_na_zakwasie   Sr       Dzieza        0.00      8.60
# 16     Ciasto_na_chleb_na_zakwasie   Sr      Wazenie       18.63     18.85
# 17     Ciasto_na_chleb_na_zakwasie   Sr       Tabula       18.85     19.45
# 44  Ciasto_na_rogaliki_z_czekolada   Sr       Dzieza       17.94     18.49
# 45  Ciasto_na_rogaliki_z_czekolada   Sr    Dzielarka       18.49     18.77
# 46  Ciasto_na_rogaliki_z_czekolada   Sr  Rogalikarka       19.29     19.60
# 47  Ciasto_na_rogaliki_z_czekolada   Sr  Nadziewarka       19.60     20.00
# 30              Ciasto_na_bagietki   Wt       Dzieza       15.16     16.11
# 31              Ciasto_na_bagietki   Wt    Dzielarka       16.87     17.11
# 32              Ciasto_na_bagietki   Wt  Rogalikarka       17.34     17.62
# 21                 Ciasto_na_bulki   Wt       Dzieza       16.11     17.11
# 22                 Ciasto_na_bulki   Wt    Dzielarka       17.11     17.34
# 23                 Ciasto_na_bulki   Wt       Tabula       19.66     20.00
# 3     Ciasto_na_chleb_domowy_0_5kg   Wt       Dzieza        0.55      5.25
# 4     Ciasto_na_chleb_domowy_0_5kg   Wt      Wazenie        9.71     10.00
# 5     Ciasto_na_chleb_domowy_0_5kg   Wt       Tabula       10.00     10.70
# 12     Ciasto_na_chleb_na_zakwasie   Wt       Dzieza        5.28     13.88
# 13     Ciasto_na_chleb_na_zakwasie   Wt      Wazenie       13.88     14.10
# 14     Ciasto_na_chleb_na_zakwasie   Wt       Tabula       14.10     14.70
# 40  Ciasto_na_rogaliki_z_czekolada   Wt       Dzieza        0.00      0.55
# 41  Ciasto_na_rogaliki_z_czekolada   Wt    Dzielarka       17.34     17.62
# 42  Ciasto_na_rogaliki_z_czekolada   Wt  Rogalikarka       17.62     17.93
# 43  Ciasto_na_rogaliki_z_czekolada   Wt  Nadziewarka       17.93     18.33
#
# Machine Usage Timeline:
#
#         Machine  Day  \
# 0        Dzieza  Pon
# 1       Wazenie  Pon
# 2     Dzielarka  Pon
# 3        Tabula  Pon
# 4   Rogalikarka  Pon
# 5   Nadziewarka  Pon
# 6        Dzieza   Wt
# 7       Wazenie   Wt
# 8     Dzielarka   Wt
# 9        Tabula   Wt
# 10  Rogalikarka   Wt
# 11  Nadziewarka   Wt
# 12       Dzieza   Sr
# 13      Wazenie   Sr
# 14    Dzielarka   Sr
# 15       Tabula   Sr
# 16  Rogalikarka   Sr
# 17  Nadziewarka   Sr
#
#                                                                                                 Timeline
# 0   BBBBBBBBBBBBBBBBBBBBBBBBBFFAAAAAAAAAAAAAAAAAAAAAAAA_______________________________DDDDDEEEEE________
# 1   ___________________________________________________________________________________________B___A____
# 2   ___________________________________________________________________________________________FED______
# 3   ____________________________________________________________________________________________BBDDAAAA
# 4   ________________________________________________________________________________________________F_EE
# 5   __________________________________________________________________________________________________FF
# 6   FFAAAAAAAAAAAAAAAAAAAAAAAACCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCC______EEEEEDDDDD_______________
# 7   ________________________________________________AA___________________C______________________________
# 8   ____________________________________________________________________________________EDFF____________
# 9   __________________________________________________AAA_________________CCC_________________________DD
# 10  ______________________________________________________________________________________EEF___________
# 11  _________________________________________________________________________________________FF_________
# 12  CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCEEEEE____________DDDDDBBBBBBBBBBBBBBBBBBBBBBBBBFFF________
# 13  ____________________________________________________________________________________________BC______
# 14  ___________________________________________________________________________________________DFEE_____
# 15  ____________________________________________________________________________________________DDCCCBBB
# 16  _______________________________________________________________________________________________EF___
# 17  __________________________________________________________________________________________________FF
#
# Legenda Subproduktów:
# A: Ciasto_na_chleb_domowy_0_5kg
# B: Ciasto_na_chleb_domowy_0_9kg
# C: Ciasto_na_chleb_na_zakwasie
# D: Ciasto_na_bulki
# E: Ciasto_na_bagietki
# F: Ciasto_na_rogaliki_z_czekolada
# 5.55
# 10.25
# 16.54
# 1.0
# 1.0

# %%
# Pobierz wartości czasu rozpoczęcia
start_times = {
    (product, machine, day): product_batch_start_time[product, machine, day].varValue
    for product in products for machine in machines for day in days
    if product_batch_start_time[product, machine, day].varValue is not None and is_produced[product, machine, day].varValue != 0 
}

# Oblicz czas zakończenia
end_times = {
    (product, machine, day): start_times[product, machine, day] + production_times[product][machine]
    for product, machine, day in start_times
}

# Wersja 1: Widok z perspektywy produktu
product_schedule = []
for product in products:
    for day in days:
        for machine in machines:
            if (product, machine, day) in start_times:
                start = start_times[(product, machine, day)]
                end = end_times[(product, machine, day)]
                product_schedule.append({
                    'Product': product,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

product_df = pd.DataFrame(product_schedule)
print("\nProduct Schedule:\n")
print(product_df.sort_values(['Day', 'Product', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania produktów na litery
product_mapping = {product: chr(65 + i) for i, product in enumerate(products)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for product in products:
        if (product, machine, day) in start_times:
            start = start_times[(product, machine, day)]
            end = end_times[(product, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = product_mapping[product]  # Wstaw literę dla produktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_product = timeline[i]
                    prev_duration = (
                        end_times[(products[ord(prev_product) - 65], machine, day)] -
                        start_times[(products[ord(prev_product) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = product_mapping[product]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
product_df.to_csv("product_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Produktów:")
for product, letter in product_mapping.items():
    print(f"{letter}: {product}")

print(is_produced['Chleb_domowy_0_5kg', 'Garownia', 'Pon'].varValue)
print(all_from_storage['Ciasto_na_chleb_domowy_0_5kg', 'Pon'])
# Out:
# Product Schedule:
#
#                  Product  Day    Machine  Start Time  End Time
# 42              Bagietki  Pon   Garownia        6.39      6.72
# 43              Bagietki  Pon       Piec        7.89      8.12
# 44              Bagietki  Pon  Studzenie       12.00     12.42
# 0     Chleb_domowy_0_5kg  Pon   Garownia        1.50      2.50
# 1     Chleb_domowy_0_5kg  Pon       Piec       10.32     11.00
# 2     Chleb_domowy_0_5kg  Pon  Studzenie       17.22     19.02
# 3     Chleb_domowy_0_5kg  Pon  Pakowanie       19.02     19.58
# 12    Chleb_domowy_0_9kg  Pon   Garownia        0.00      1.50
# 13    Chleb_domowy_0_9kg  Pon       Piec        9.12     10.32
# 14    Chleb_domowy_0_9kg  Pon  Studzenie       12.42     14.92
# 15    Chleb_domowy_0_9kg  Pon  Pakowanie       18.45     19.02
# 24     Chleb_na_zakwasie  Pon   Garownia        6.72      8.12
# 25     Chleb_na_zakwasie  Pon       Piec        8.12      9.12
# 26     Chleb_na_zakwasie  Pon  Studzenie       14.92     17.22
# 27     Chleb_na_zakwasie  Pon  Pakowanie       17.85     18.45
# 51  Rogaliki_z_czekolada  Pon   Garownia        6.14      6.39
# 52  Rogaliki_z_czekolada  Pon       Piec       11.00     11.18
# 53  Rogaliki_z_czekolada  Pon  Studzenie       11.18     12.00
# 54  Rogaliki_z_czekolada  Pon  Pakowanie       19.58     20.00
# 48              Bagietki   Sr   Garownia        2.13      2.46
# 49              Bagietki   Sr       Piec       11.54     11.77
# 50              Bagietki   Sr  Studzenie       19.58     20.00
# 39                 Bulki   Sr   Garownia        0.00      0.38
# 40                 Bulki   Sr       Piec       11.77     12.02
# 41                 Bulki   Sr  Studzenie       19.10     19.58
# 8     Chleb_domowy_0_5kg   Sr   Garownia        9.74     10.74
# 9     Chleb_domowy_0_5kg   Sr       Piec       10.74     11.42
# 10    Chleb_domowy_0_5kg   Sr  Studzenie       11.42     13.22
# 11    Chleb_domowy_0_5kg   Sr  Pakowanie       19.44     20.00
# 20    Chleb_domowy_0_9kg   Sr   Garownia        0.38      1.88
# 21    Chleb_domowy_0_9kg   Sr       Piec       12.02     13.22
# 22    Chleb_domowy_0_9kg   Sr  Studzenie       13.22     15.72
# 23    Chleb_domowy_0_9kg   Sr  Pakowanie       17.85     18.42
# 32     Chleb_na_zakwasie   Sr   Garownia       14.14     15.54
# 33     Chleb_na_zakwasie   Sr       Piec       15.54     16.54
# 34     Chleb_na_zakwasie   Sr  Studzenie       16.54     18.84
# 35     Chleb_na_zakwasie   Sr  Pakowanie       18.84     19.44
# 55  Rogaliki_z_czekolada   Sr   Garownia        1.88      2.13
# 56  Rogaliki_z_czekolada   Sr       Piec       10.56     10.74
# 57  Rogaliki_z_czekolada   Sr  Studzenie       15.72     16.54
# 58  Rogaliki_z_czekolada   Sr  Pakowanie       18.42     18.84
# 45              Bagietki   Wt   Garownia        1.50      1.83
# 46              Bagietki   Wt       Piec       13.95     14.18
# 47              Bagietki   Wt  Studzenie       14.18     14.60
# 36                 Bulki   Wt   Garownia       10.32     10.70
# 37                 Bulki   Wt       Piec       19.27     19.52
# 38                 Bulki   Wt  Studzenie       19.52     20.00
# 4     Chleb_domowy_0_5kg   Wt   Garownia       10.70     11.70
# 5     Chleb_domowy_0_5kg   Wt       Piec       11.70     12.38
# 6     Chleb_domowy_0_5kg   Wt  Studzenie       12.38     14.18
# 7     Chleb_domowy_0_5kg   Wt  Pakowanie       18.84     19.40
# 16    Chleb_domowy_0_9kg   Wt   Garownia        0.00      1.50
# 17    Chleb_domowy_0_9kg   Wt       Piec       10.50     11.70
# 18    Chleb_domowy_0_9kg   Wt  Studzenie       14.60     17.10
# 19    Chleb_domowy_0_9kg   Wt  Pakowanie       18.27     18.84
# 28     Chleb_na_zakwasie   Wt   Garownia       14.70     16.10
# 29     Chleb_na_zakwasie   Wt       Piec       16.10     17.10
# 30     Chleb_na_zakwasie   Wt  Studzenie       17.10     19.40
# 31     Chleb_na_zakwasie   Wt  Pakowanie       19.40     20.00
#
# Machine Usage Timeline:
#
#       Machine  Day  \
# 0    Garownia  Pon
# 1        Piec  Pon
# 2   Studzenie  Pon
# 3   Pakowanie  Pon
# 4    Garownia   Wt
# 5        Piec   Wt
# 6   Studzenie   Wt
# 7   Pakowanie   Wt
# 8    Garownia   Sr
# 9        Piec   Sr
# 10  Studzenie   Sr
# 11  Pakowanie   Sr
#
#                                                                                                 Timeline
# 0   BBBBBBBAAAAA__________________FEECCCCCCC____________________________________________________________
# 1   _______________________________________ECCCCCBBBBBBAAAA_____________________________________________
# 2   _______________________________________________________FFFFFEEBBBBBBBBBBBBCCCCCCCCCCCCAAAAAAAAA_____
# 3   _________________________________________________________________________________________CCCBBBAAFFF
# 4   BBBBBBBEE__________________________________________DDAAAAA_______________CCCCCCC____________________
# 5   ____________________________________________________BBBBBBAAA________E__________CCCCC___________D___
# 6   _____________________________________________________________AAAAAAAAAEEEBBBBBBBBBBBBCCCCCCCCCCCCDDD
# 7   ___________________________________________________________________________________________BBBAACCCC
# 8   DBBBBBBBBFEE____________________________________AAAAA_________________CCCCCCC_______________________
# 9   ____________________________________________________FAAAAEDDBBBBBB___________CCCCC__________________
# 10  _________________________________________________________AAAAAAAAABBBBBBBBBBBBFFFFCCCCCCCCCCCC_DDEEE
# 11  _________________________________________________________________________________________BBBFFCCCAAA
#
# Legenda Produktów:
# A: Chleb_domowy_0_5kg
# B: Chleb_domowy_0_9kg
# C: Chleb_na_zakwasie
# D: Bulki
# E: Bagietki
# F: Rogaliki_z_czekolada
# 1.0
# 0
