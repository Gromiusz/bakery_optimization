# %%
import pulp as pl
import numpy as np
# from scipy.stats import multivariate_t

print("==============================================================================")

# Define the problem
model = pl.LpProblem("Maximize_Profit", pl.LpMaximize)

# Products, machines and days
subproducts = ['Ciasto_na_chleb_domowy_0_5kg', 'Ciasto_na_chleb_domowy_0_9kg', 'Ciasto_na_chleb_na_zakwasie', 'Ciasto_na_bulki', 'Ciasto_na_bagietki', 'Ciasto_na_rogaliki_z_czekolada']
products = ['Chleb_domowy_0_5kg', 'Chleb_domowy_0_9kg', 'Chleb_na_zakwasie', 'Bulki', 'Bagietki', 'Rogaliki_z_czekolada']
days = ['Pon', 'Wt', 'Sr']
sub_machines = ['Dzieza', 'Wazenie', 'Dzielarka', 'Tabula', 'Rogalikarka', 'Nadziewarka']
machines = ['Garownia', 'Piec', 'Studzenie', 'Pakowanie']

# Income from product sales and production cost in PLN/piece
product_income = {'Chleb_domowy_0_5kg': 5.2, 'Chleb_domowy_0_9kg': 7.9, 'Chleb_na_zakwasie': 6.2, 'Bulki': 1.4, 'Bagietki': 1.55, 'Rogaliki_z_czekolada': 2.1}
sub_product_cost = {'Ciasto_na_chleb_domowy_0_5kg': 1.6, 'Ciasto_na_chleb_domowy_0_9kg': 2.0, 'Ciasto_na_chleb_na_zakwasie': 2.0, 'Ciasto_na_bulki': 0.5, 'Ciasto_na_bagietki': 0.6, 'Ciasto_na_rogaliki_z_czekolada': 1.0}
product_cost = {'Chleb_domowy_0_5kg': 0.8, 'Chleb_domowy_0_9kg': 0.9, 'Chleb_na_zakwasie': 0.8, 'Bulki': 0.2, 'Bagietki': 0.2, 'Rogaliki_z_czekolada': 0.2}

# Time available
shifts_per_day = 2
hours_per_shift = 10
hours_per_day = shifts_per_day * hours_per_shift

max_batches = 1
large_number = 10000

sub_production_times = {
    'Ciasto_na_chleb_domowy_0_5kg': {'Dzieza': 4.7, 'Wazenie': 0.29, 'Dzielarka': 0.0, 'Tabula': 0.7, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_domowy_0_9kg': {'Dzieza': 5, 'Wazenie': 0.2, 'Dzielarka': 0.0, 'Tabula': 0.55, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_na_zakwasie': {'Dzieza': 8.6, 'Wazenie': 0.22, 'Dzielarka': 0.0, 'Tabula': 0.6, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bulki': {'Dzieza': 1, 'Wazenie': 0.0, 'Dzielarka': 0.23, 'Tabula': 0.34, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bagietki': {'Dzieza': 0.95, 'Wazenie': 0.0, 'Dzielarka': 0.24, 'Tabula': 0.0, 'Rogalikarka': 0.28, 'Nadziewarka': 0.0},
    'Ciasto_na_rogaliki_z_czekolada': {'Dzieza': 0.55, 'Wazenie': 0.0, 'Dzielarka': 0.28, 'Tabula': 0.0, 'Rogalikarka': 0.31, 'Nadziewarka': 0.4}
}

production_times = {
    'Chleb_domowy_0_5kg': {'Garownia': 1.0, 'Piec': 0.68, 'Studzenie': 1.8, 'Pakowanie': 0.56},
    'Chleb_domowy_0_9kg': {'Garownia': 1.5, 'Piec': 1.2, 'Studzenie': 2.5, 'Pakowanie': 0.57},
    'Chleb_na_zakwasie': {'Garownia': 1.4, 'Piec': 1.0, 'Studzenie': 2.3, 'Pakowanie': 0.6},
    'Bulki': {'Garownia': 0.38, 'Piec': 0.25, 'Studzenie': 0.48, 'Pakowanie': 0.0},
    'Bagietki': {'Garownia': 0.33, 'Piec': 0.23, 'Studzenie': 0.42, 'Pakowanie': 0.0},
    'Rogaliki_z_czekolada': {'Garownia': 0.25, 'Piec': 0.18, 'Studzenie': 0.82, 'Pakowanie': 0.42}
}


batch_size = {
    "Ciasto_na_chleb_domowy_0_5kg": 240,
    "Ciasto_na_chleb_domowy_0_9kg": 130,
    "Ciasto_na_chleb_na_zakwasie": 200,
    "Ciasto_na_bulki": 200,
    "Ciasto_na_bagietki": 200,
    "Ciasto_na_rogaliki_z_czekolada": 200,
    "Chleb_domowy_0_5kg": 240,
    "Chleb_domowy_0_9kg": 130,
    "Chleb_na_zakwasie": 200,
    "Bulki": 200,
    "Bagietki": 200,
    "Rogaliki_z_czekolada": 200,
}

market_limits = {
    "Chleb_domowy_0_5kg": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 420, "Pt": 530, "Sob": 680},
    "Chleb_domowy_0_9kg": {"Pon": 100, "Wt": 100, "Sr": 380, "Czw": 150, "Pt": 250, "Sob": 580},
    "Chleb_na_zakwasie": {"Pon": 100, "Wt": 100, "Sr": 320, "Czw": 180, "Pt": 280, "Sob": 418},
    "Bulki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 530, "Pt": 650, "Sob": 580},
    "Bagietki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 350, "Pt": 650, "Sob": 680},
    "Rogaliki_z_czekolada": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 310, "Pt": 400, "Sob": 280},
}

# Machines cost
fridge_cost_per_day = 0.281 * 24 * 1.4 * 0.2 # kW * 24h * price per hour * factor
furnace_cost_per_hour = 82.4 # https://giko.pl/kalkulator-zuzycia-energii-dla-piecow-piekarniczych/


fridge_count = 10
fridge_capacity = 160
end_stock = 0
storage_capacity = fridge_count * fridge_capacity

# Variables for production, sales, and storage of products each day
sub_production_vars = pl.LpVariable.dicts("Subproduct production", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
production_vars = pl.LpVariable.dicts("Production", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# batch_count_vars = pl.LpVariable.dicts("Batches Count", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# subbatch_count_vars = pl.LpVariable.dicts("Subproduct Batches Count", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
product_batch_start_time = pl.LpVariable.dicts("ProductStartTime",  [(product, machine, day) for product in products for machine in machines for day in days], lowBound=0, cat="Continuous")
subproduct_batch_start_time = pl.LpVariable.dicts("Subproduction start time for batch",  [(subproduct, machine, day) for subproduct in subproducts for machine in sub_machines for day in days], lowBound=0, cat="Continuous")
sales_vars = pl.LpVariable.dicts("Sales", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, idx) for (machine, idx) in specific_machines], cat="Binary")
# subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, day, batch) for subproduct in subproducts for day in days for batch in range(1, max_batches + 1)], cat="Binary")
subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, day) for subproduct in subproducts for day in days], cat="Binary")
batch_produced = pl.LpVariable.dicts("BatchProduced", [(product, day) for product in products for day in days], cat="Binary")
specific_sub_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, subproduct, day) for machine in sub_machines for subproduct in subproducts for day in days], cat="Binary")
specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, product, day) for machine in machines for product in products for day in days], cat="Binary")
storage_vars = pl.LpVariable.dicts("Storage", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, upBound=storage_capacity, cat='Integer')
fridge_count_usage_vars = pl.LpVariable.dicts("FridgeCount", ((day) for day in days), lowBound=0, upBound=fridge_count, cat='Integer')
all_from_storage = pl.LpVariable.dicts("AllFromStorage", [(subproduct, day) for subproduct in subproducts for day in days], cat="Binary")


# xij = pl.LpVariable.dicts("xij", [(machine, idx, i, j) for (machine, idx) in specific_machines for i in subproducts for j in subproducts if i != j], 0, 1, pl.LpBinary)
is_produced_sub = pl.LpVariable.dicts("is_produced",
                                     ((subproduct, machine, day) for subproduct in subproducts
                                                                      for machine in sub_machines
                                                                      for day in days),
                                     cat="Binary")
is_produced = pl.LpVariable.dicts("is_produced",
                                     ((product, machine, day) for product in products
                                                                      for machine in machines
                                                                      for day in days),
                                     cat="Binary")

for subproduct in subproducts:
    for day in days:
        for i, machine in enumerate(sub_machines[1:], start=1):  # Od ważenia do nadziewarki
            prev = 1
            prev_machine = sub_machines[i - prev]

            while sub_production_times[subproduct][prev_machine] == 0.0 or prev_machine == machine:
                prev += 1
                prev_machine = sub_machines[i - prev]

            model += subproduct_batch_start_time[subproduct, machine, day] >= (
                subproduct_batch_start_time[subproduct, prev_machine, day] + sub_production_times[subproduct][prev_machine]
            )

            model += subproduct_batch_start_time[subproduct, machine, day] <= specific_sub_machine_used[machine, subproduct, day] * hours_per_day

        last_machine = sub_machines[-1]
        model += hours_per_day >= (
            subproduct_batch_start_time[subproduct, last_machine, day] + sub_production_times[subproduct][last_machine]
        )

for product in products:
    for day in days:
        for i, machine in enumerate(machines[1:], start=1):  # Od ważenia do nadziewarki
            prev = 1
            prev_machine = machines[i - prev]

            while production_times[product][prev_machine] == 0.0 or prev_machine == machine:
                prev += 1
                prev_machine = machines[i - prev]

            model += product_batch_start_time[product, machine, day] >= (
                product_batch_start_time[product, prev_machine, day] + production_times[product][prev_machine]
            )

            model += product_batch_start_time[product, machine, day] <= specific_machine_used[machine, product, day] * hours_per_day

        last_machine = machines[-1]
        model += hours_per_day >= (
            product_batch_start_time[product, last_machine, day] + production_times[product][last_machine]
        )
'''
        model += subbatch_produced[subproduct, day] * large_number >= subproduct_batch_start_time[subproduct, last_machine, last_idx, day]

        # Brak nakładania się produkcji na maszynie
        for machine, idx in specific_machines[:6]:  # Zakres maszyn
            for subproduct1 in subproducts:
                for subproduct2 in subproducts:
                    if subproduct1 != subproduct2:
                        model += (subproduct_batch_start_time[subproduct1, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct2, machine, idx, day] + production_times[subproduct2][machine]) | \
                                 (subproduct_batch_start_time[subproduct2, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct1, machine, idx, day] + production_times[subproduct1][machine])

                        # model += specific_machine_used[machine, idx, subproduct1, day] + specific_machine_used[machine, idx, subproduct2, day] <= 1
'''
# Ograniczenie: produkcja subproduktu tylko na maszynach, gdzie czas produkcji > 0
for subproduct in subproducts:
    for machine in sub_machines:
        for day in days:
            if sub_production_times[subproduct][machine] == 0:
                model += is_produced_sub[subproduct, machine, day] == 0

# Ograniczenie: produkcja produktu tylko na maszynach, gdzie czas produkcji > 0
for product in products:
    for machine in machines:
        for day in days:
            if production_times[product][machine] == 0:
                model += is_produced[product, machine, day] == 0
                

# Warunek: jeśli subprodukt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for subproduct in subproducts:
    machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for machine in machines_with_production:
                    model += pl.lpSum(is_produced_sub[subproduct, m, day] for m in machines_with_production) == \
                            len(machines_with_production) * is_produced_sub[subproduct, machine, day]
        
        # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
        model += subbatch_produced[subproduct, day] <= pl.lpSum(is_produced_sub[subproduct, machine, day] for machine in machines_with_production)

# Warunek: jeśli produkt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for product in products:
    machines_with_production = [machine for machine in machines if production_times[product][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for machine in machines_with_production:
                    model += pl.lpSum(is_produced[product, m, day] for m in machines_with_production) == \
                            len(machines_with_production) * is_produced[product, machine, day]
        
        # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
        model += batch_produced[product, day] <= pl.lpSum(is_produced[product, machine, day] for machine in machines_with_production)

# Aktualizacja ograniczenia: brak nakładania się produkcji
big_M = 1000000
for subproduct1 in subproducts:
    for subproduct2 in subproducts:
        if subproduct1 != subproduct2:
            machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct1][machine] > 0 and sub_production_times[subproduct2][machine] > 0]
            for machine in machines_with_production: 
                for day in days:
                    # Dodanie binarnych zmiennych pomocniczych
                    y1 = pl.LpVariable(f"y1_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y2 = pl.LpVariable(f"y2_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y3 = pl.LpVariable(f"y3_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y4 = pl.LpVariable(f"y4_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")

                    # Powiązanie warunków logicznych z binarnymi zmiennymi
                    model += subproduct_batch_start_time[subproduct1, machine, day] >= \
                                subproduct_batch_start_time[subproduct2, machine, day] + sub_production_times[subproduct2][machine] - \
                                big_M * (1 - y1)
                    
                    model += subproduct_batch_start_time[subproduct2, machine, day] >= \
                                subproduct_batch_start_time[subproduct1, machine, day] + sub_production_times[subproduct1][machine] - \
                                big_M * (1 - y2)

                    model += is_produced_sub[subproduct1, machine, day] + y3 == 1
                    model += is_produced_sub[subproduct2, machine, day] + y4 == 1

                    # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                    model += y1 + y2 + y3 + y4 == 1

for product1 in products:
    for product2 in products:
        if product1 != product2:
            machines_with_production = [machine for machine in machines if production_times[product1][machine] > 0 and production_times[product2][machine] > 0]
            for machine in machines_with_production: 
                for day in days:
                    # Dodanie binarnych zmiennych pomocniczych
                    y1 = pl.LpVariable(f"y1_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y2 = pl.LpVariable(f"y2_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y3 = pl.LpVariable(f"y3_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y4 = pl.LpVariable(f"y4_{product1}_{product2}_{machine}_{day}", cat="Binary")

                    # Powiązanie warunków logicznych z binarnymi zmiennymi
                    model += product_batch_start_time[product1, machine, day] >= \
                                product_batch_start_time[product2, machine, day] + production_times[product2][machine] - \
                                big_M * (1 - y1)
                    
                    model += product_batch_start_time[product2, machine, day] >= \
                                product_batch_start_time[product1, machine, day] + production_times[product1][machine] - \
                                big_M * (1 - y2)

                    model += is_produced[product1, machine, day] + y3 == 1
                    model += is_produced[product2, machine, day] + y4 == 1

                    # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                    model += y1 + y2 + y3 + y4 == 1

M = 1000
for subproduct, product in zip(subproducts, products):
    model += storage_vars[subproduct, 'Pon'] == sub_production_vars[subproduct, 'Pon'] - production_vars[product, 'Pon']
    for i in range(1, len(days)):
        day = days[i]
        prev_day = days[i-1]
        # model += storage_vars[subproduct, day] == storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day]
        # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
        # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
        # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
        model += product_batch_start_time[product, machines[0], day] >= (subproduct_batch_start_time[subproduct, sub_machines[-1], day]) + sub_production_times[subproduct][sub_machines[-1]] - M * all_from_storage[subproduct, day]

expr1 = pl.LpVariable.dicts("expr1", [(s, d) for s in subproducts for d in days], lowBound=0)
expr2 = pl.LpVariable.dicts("expr2", [(s, d) for s in subproducts for d in days], lowBound=0)

# Dodaj ograniczenia dla zmiennych pomocniczych
for s, p in zip(subproducts, products):
    for i in range(1, len(days)):
        d = days[i]
        prev_day = days[i-1]
        model += expr1[s, d] >= storage_vars[s, prev_day] - production_vars[p, d] - M * (1 - all_from_storage[s, d])
        model += expr1[(s, d)] <= storage_vars[(s, prev_day)] - production_vars[(p, d)] + M * all_from_storage[(s, d)]
        model += expr1[(s, d)] <= M * all_from_storage[(s, d)]
        model += expr1[(s, d)] >= 0
        
        model += expr2[(s, d)] >= storage_vars[(s, prev_day)] + sub_production_vars[(s, d)] - production_vars[(p, d)] - M * all_from_storage[(s, d)]
        model += expr2[(s, d)] <= storage_vars[(s, prev_day)] + sub_production_vars[(s, d)] - production_vars[(p, d)] + M * (1 - all_from_storage[(s, d)])
        model += expr2[(s, d)] <= M * (1 - all_from_storage[(s, d)])
        model += expr2[(s, d)] >= 0

        # Ograniczenie
        model += storage_vars[(s, d)] == expr1[(s, d)] + expr2[(s, d)]


for day in days:
    model += storage_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)
    model += fridge_count_usage_vars[day] * fridge_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)

for product, subproduct in zip(products, subproducts):
    for day in days:
        model += batch_produced[product, day] * batch_size[product] >= production_vars[product, day]
        model += subbatch_produced[subproduct, day] * batch_size[subproduct] >= sub_production_vars[subproduct, day]
        # model += sub_production_vars[subproduct, day] >= production_vars[product, day]
        model += sales_vars[product, day] == production_vars[product, day]
    model += sales_vars[product, 'Sr'] >= 0.01*market_limits[product]['Wt'], f"Max_sales_{product}_{'Sr'}"


# Objective function: Maximize profit from sales minus costs
model += pl.lpSum([sales_vars[product, day] * product_income[product] for product in products for day in days]) \
                    - pl.lpSum([production_vars[product, day] * product_cost[product] for product in products for day in days]) \
                    - pl.lpSum([sub_production_vars[subproduct, day] * sub_product_cost[subproduct] for subproduct in subproducts for day in days])


solver = pl.PULP_CBC_CMD(timeLimit=60)

model.solve(solver)

# model.solve()

# Results
print("Status:", pl.LpStatus[model.status])
if pl.LpStatus[model.status] == 'Optimal':
    print("Total Profit:", pl.value(model.objective))

    print(f"{'Product':<10} {'day':<10} {'SubProduction':<10} {'Production':<12} {'Sales':<10} {'Storage':<10}")

    for product, subproduct in zip(products, subproducts):
        for day in days:
            subproduction = sub_production_vars[subproduct, day].varValue
            production = production_vars[product, day].varValue
            sales = sales_vars[product, day].varValue
            storage = storage_vars[subproduct, day].varValue

            print(f"{product:<10} {day:<10} {subproduction:<12} {production:<12} {sales:<10} {storage:<10}")

    # print("\nProduction Time Usage per Product and Day:")
    # for day in days:
    #     print(f"\Day: {day}")
    #     for product in products:
    #         total_production_time = sum(
    #             batch_count_vars[product, day].varValue * production_times[product]s.get(machine, 0) 
    #             for machine in machines #.keys()
    #         )
    #         print(f"  Product: {product}, Total Production Time: {total_production_time:.2f} hours")

else:
    print("No optimal solution was found.")
    # Analiza ograniczeń
    for name, constraint in model.constraints.items():
        if constraint.pi < 0:
            print(f"Ograniczenie {name}: {constraint}")
# Out:
# ==============================================================================
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gromiusz/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/451ecaded09d403bb9728336a76d3fc7-pulp.mps -max -sec 60 -timeMode elapsed -branch -printingOptions all -solution /tmp/451ecaded09d403bb9728336a76d3fc7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 3107 COLUMNS
# At line 16272 RHS
# At line 19375 BOUNDS
# At line 21719 ENDATA
# Problem MODEL has 3102 rows, 2547 columns and 8424 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 60
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 10344 - 0.01 seconds
# Cgl0002I 57 variables fixed
# Cgl0003I 22 fixed, 12 tightened bounds, 984 strengthened rows, 280 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 754 strengthened rows, 108 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 799 strengthened rows, 6 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 42 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1525 rows, 1104 columns (948 integer (900 of which binary)) and 7121 elements
# Cbc0038I Initial state - 426 integers unsatisfied sum - 104.207
# Cbc0038I Pass   1: suminf.   38.38648 (493) obj. -3776.89 iterations 431
# Cbc0038I Pass   2: suminf.   25.75404 (466) obj. -3768.56 iterations 134
# Cbc0038I Pass   3: suminf.   25.15434 (461) obj. -4012.85 iterations 16
# Cbc0038I Pass   4: suminf.   24.12693 (455) obj. -4353.85 iterations 6
# Cbc0038I Pass   5: suminf.   17.61830 (346) obj. -5227.05 iterations 100
# Cbc0038I Pass   6: suminf.   17.54923 (348) obj. -5227.16 iterations 9
# Cbc0038I Pass   7: suminf.   15.36411 (330) obj. -4037.2 iterations 96
# Cbc0038I Pass   8: suminf.   15.06023 (329) obj. -4038.05 iterations 1
# Cbc0038I Pass   9: suminf.   13.23761 (302) obj. -3983.64 iterations 126
# Cbc0038I Pass  10: suminf.   12.80122 (302) obj. -3982.21 iterations 23
# Cbc0038I Pass  11: suminf.   10.62182 (243) obj. -4071.63 iterations 79
# Cbc0038I Pass  12: suminf.   10.29813 (249) obj. -4071.63 iterations 12
# Cbc0038I Pass  13: suminf.    6.04293 (163) obj. -4111.8 iterations 80
# Cbc0038I Pass  14: suminf.    6.03581 (174) obj. -4111.8 iterations 7
# Cbc0038I Pass  15: suminf.    5.34800 (146) obj. -4111.8 iterations 37
# Cbc0038I Pass  16: suminf.    5.15714 (164) obj. -4111.8 iterations 21
# Cbc0038I Pass  17: suminf.    4.50084 (112) obj. -4111.8 iterations 42
# Cbc0038I Pass  18: suminf.    4.49373 (123) obj. -4111.8 iterations 10
# Cbc0038I Pass  19: suminf.    3.54885 (90) obj. -4111.8 iterations 51
# Cbc0038I Pass  20: suminf.    2.55736 (67) obj. -4111.8 iterations 44
# Cbc0038I Pass  21: suminf.    1.66552 (48) obj. -4111.8 iterations 47
# Cbc0038I Pass  22: suminf.    1.65653 (48) obj. -4111.8 iterations 2
# Cbc0038I Pass  23: suminf.    0.79940 (22) obj. -4111.8 iterations 57
# Cbc0038I Pass  24: suminf.    0.50064 (6) obj. -4111.8 iterations 50
# Cbc0038I Pass  25: suminf.    0.50064 (6) obj. -4111.8 iterations 2
# Cbc0038I Pass  26: suminf.    0.50280 (6) obj. -4111.8 iterations 22
# Cbc0038I Pass  27: suminf.   13.62872 (140) obj. -2974.6 iterations 291
# Cbc0038I Pass  28: suminf.   11.13472 (148) obj. -2974.6 iterations 109
# Cbc0038I Pass  29: suminf.    7.91992 (131) obj. -2974.6 iterations 32
# Cbc0038I Pass  30: suminf.    5.79320 (106) obj. -2974.6 iterations 35
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 202 integers at bound fixed and 11 continuous
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 1204 rows 717 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.36 seconds)
# Cbc0038I After 0.36 seconds - Feasibility pump exiting - took 0.18 seconds
# Cbc0031I 173 added rows had average density of 18.682081
# Cbc0013I At root node, 173 cuts changed objective from -10344 to -8880 in 10 passes
# Cbc000014I Cut generator 0 (Probing) - 521 row cuts average 2.1 elements, 0 column cuts (145 active)  in 0.044 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 311 row cuts average 20.1 elements, 0 column cuts (0 active)  in 0.028 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 33 row cuts average 8.3 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 289 row cuts average 2.6 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 8 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 1044 row cuts average 24.1 elements, 0 column cuts (0 active)  in 0.054 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 79 row cuts average 7.3 elements, 0 column cuts (0 active)  in 0.043 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible -8880 (0.72 seconds)
# Cbc0010I After 100 nodes, 52 on tree, 1e+50 best solution, best possible -8880 (3.00 seconds)
# Cbc0010I After 200 nodes, 92 on tree, 1e+50 best solution, best possible -8880 (3.82 seconds)
# Cbc0010I After 300 nodes, 135 on tree, 1e+50 best solution, best possible -8880 (4.61 seconds)
# Cbc0010I After 400 nodes, 168 on tree, 1e+50 best solution, best possible -8880 (5.50 seconds)
# Cbc0010I After 500 nodes, 208 on tree, 1e+50 best solution, best possible -8880 (6.46 seconds)
# Cbc0010I After 600 nodes, 238 on tree, 1e+50 best solution, best possible -8880 (7.47 seconds)
# Cbc0010I After 700 nodes, 271 on tree, 1e+50 best solution, best possible -8880 (11.59 seconds)
# Cbc0010I After 800 nodes, 306 on tree, 1e+50 best solution, best possible -8880 (12.67 seconds)
# Cbc0010I After 900 nodes, 331 on tree, 1e+50 best solution, best possible -8880 (13.65 seconds)
# Cbc0012I Integer solution of -7550 found by rounding after 41887 iterations and 985 nodes (14.45 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 170 rows 82 columns
# Cbc0010I After 1000 nodes, 357 on tree, -7550 best solution, best possible -8880 (14.62 seconds)
# Cbc0004I Integer solution of -7558 found after 43424 iterations and 1054 nodes (14.95 seconds)
# Cbc0010I After 1100 nodes, 374 on tree, -7558 best solution, best possible -8880 (15.43 seconds)
# Cbc0010I After 1200 nodes, 396 on tree, -7558 best solution, best possible -8880 (16.48 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 271 rows 139 columns
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 345 rows 166 columns
# Cbc0010I After 1300 nodes, 428 on tree, -7558 best solution, best possible -8880 (18.01 seconds)
# Cbc0010I After 1400 nodes, 455 on tree, -7558 best solution, best possible -8880 (19.43 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 295 rows 146 columns
# Cbc0010I After 1500 nodes, 481 on tree, -7558 best solution, best possible -8880 (20.89 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 315 rows 156 columns
# Cbc0010I After 1600 nodes, 509 on tree, -7558 best solution, best possible -8880 (22.03 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 275 rows 135 columns
# Cbc0010I After 1700 nodes, 535 on tree, -7558 best solution, best possible -8880 (23.45 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 388 rows 185 columns
# Cbc0010I After 1800 nodes, 567 on tree, -7558 best solution, best possible -8880 (25.11 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 291 rows 139 columns
# Cbc0010I After 1900 nodes, 604 on tree, -7558 best solution, best possible -8880 (26.60 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 393 rows 194 columns
# Cbc0010I After 2000 nodes, 637 on tree, -7558 best solution, best possible -8880 (27.88 seconds)
# Cbc0010I After 2100 nodes, 665 on tree, -7558 best solution, best possi14I Cut generator 0 (Probing) - 521 row cuts average 2.1 elements, 0 column cuts (145 active)  in 0.055 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 311 row cuts average 20.1 elements, 0 column cuts (0 active)  in 0.042 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 33 row cuts average 8.3 elements, 0 column cuts (0 active)  in 0.015 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 289 row cuts average 2.6 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 8 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 1044 row cuts average 24.1 elements, 0 column cuts (0 active)  in 0.062 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 79 row cuts average 7.3 elements, 0 column cuts (0 active)  in 0.048 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible -8880 (0.80 seconds)
# Cbc0010I After 100 nodes, 52 on tree, 1e+50 best solution, best possible -8880 (3.27 seconds)
# Cbc0010I After 200 nodes, 92 on tree, 1e+50 best solution, best possible -8880 (4.09 seconds)
# Cbc0010I After 300 nodes, 135 on tree, 1e+50 best solution, best possible -8880 (4.93 seconds)
# Cbc0010I After 400 nodes, 168 on tree, 1e+50 best solution, best possible -8880 (5.78 seconds)
# Cbc0010I After 500 nodes, 208 on tree, 1e+50 best solution, best possible -8880 (6.81 seconds)
# Cbc0010I After 600 nodes, 238 on tree, 1e+50 best solution, best possible -8880 (7.92 seconds)
# Cbc0010I After 700 nodes, 271 on tree, 1e+50 best solution, best possible -8880 (9.14 seconds)
# Cbc0010I After 800 nodes, 306 on tree, 1e+50 best solution, best possible -8880 (10.26 seconds)
# Cbc0010I After 900 nodes, 331 on tree, 1e+50 best solution, best possible -8880 (11.27 seconds)
# Cbc0012I Integer solution of -7550 found by rounding after 41887 iterations and 985 nodes (12.13 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 170 rows 82 columns
# Cbc0010I After 1000 nodes, 357 on tree, -7550 best solution, best possible -8880 (12.31 seconds)
# Cbc0004I Integer solution of -7558 found after 43424 iterations and 1054 nodes (12.71 seconds)
# Cbc0010I After 1100 nodes, 374 on tree, -7558 best solution, best possible -8880 (13.25 seconds)
# Cbc0010I After 1200 nodes, 396 on tree, -7558 best solution, best possible -8880 (14.40 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 271 rows 139 columns
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 345 rows 166 columns
# Cbc0010I After 1300 nodes, 428 on tree, -7558 best solution, best possible -8880 (16.00 seconds)
# Cbc0010I After 1400 nodes, 455 on tree, -7558 best solution, best possible -8880 (17.39 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 295 rows 146 columns
# Cbc0010I After 1500 nodes, 481 on tree, -7558 best solution, best possible -8880 (22.03 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 315 rows 156 columns
# Cbc0010I After 1600 nodes, 509 on tree, -7558 best solution, best possible -8880 (23.34 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 275 rows 135 columns
# Cbc0010I After 1700 nodes, 535 on tree, -7558 best solution, best possible -8880 (24.76 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 388 rows 185 columns
# Cbc0010I After 1800 nodes, 567 on tree, -7558 best solution, best possible -8880 (26.33 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 291 rows 139 columns
# Cbc0010I After 1900 nodes, 604 on tree, -7558 best solution, best possible -8880 (27.80 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 393 rows 194 columns
# Cbc0010I After 2000 nodes, 637 on tree, -7558 best solution, best possible -8880 (29.05 seconds)
# Cbc0010I After 2100 nodes, 665 on tree, -7558 best solution, best possibleble -8880 (29.04 seconds)
# Cbc0010I After 2200 nodes, 691 on tree, -7558 best solution, best possible -8880 (30.30 seconds)
# Cbc0010I After 2300 nodes, 715 on tree, -7558 best solution, best possible -8880 (31.51 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 305 rows 151 columns
# Cbc0010I After 2400 nodes, 735 on tree, -7558 best solution, best possible -8880 (32.72 seconds)
# Cbc0010I After 2500 nodes, 758 on tree, -7558 best solution, best possible -8880 (34.02 seconds)
# Cbc0010I After 2600 nodes, 772 on tree, -7558 best solution, best possible -8880 (35.07 seconds)
# Cbc0010I After 2700 nodes, 775 on tree, -7558 best solution, best possible -8880 (36.29 seconds)
# Cbc0010I After 2800 nodes, 800 on tree, -7558 best solution, best possible -8880 (37.71 seconds)
# Cbc0010I After 2900 nodes, 810 on tree, -7558 best solution, best possible -8880 (38.82 seconds)
# Cbc0010I After 3000 nodes, 817 on tree, -7558 best solution, best possible -8880 (39.92 seconds)
# Cbc0010I After 3100 nodes, 822 on tree, -7558 best solution, best possible -8880 (40.91 seconds)
# Cbc0010I After 3200 nodes, 830 on tree, -7558 best solution, best possible -8880 (41.96 seconds)
# Cbc0010I After 3300 nodes, 855 on tree, -7558 best solution, best possible -8880 (46.07 seconds)
# Cbc0010I After 3400 nodes, 877 on tree, -7558 best solution, best possible -8880 (47.36 seconds)
# Cbc0010I After 3500 nodes, 903 on tree, -7558 best solution, best possible -8880 (48.37 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 278 rows 133 columns
# Cbc0010I After 3600 nodes, 921 on tree, -7558 best solution, best possible -8880 (49.57 seconds)
# Cbc0010I After 3700 nodes, 935 on tree, -7558 best solution, best possible -8880 (50.69 seconds)
# Cbc0010I After 3800 nodes, 944 on tree, -7558 best solution, best possible -8880 (51.86 seconds)
# Cbc0010I After 3900 nodes, 979 on tree, -7558 best solution, best possible -8880 (52.93 seconds)
# Cbc0010I After 4000 nodes, 988 on tree, -7558 best solution, best possible -8880 (54.08 seconds)
# Cbc0010I After 4100 nodes, 1011 on tree, -7558 best solution, best possible -8880 (55.22 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 245 rows 120 columns
# Cbc0010I After 4200 nodes, 1039 on tree, -7558 best solution, best possible -8880 (56.24 seconds)
# Cbc0010I After 4300 nodes, 1063 on tree, -7558 best solution, best possible -8880 (57.25 seconds)
# Cbc0010I After 4400 nodes, 1101 on tree, -7558 best solution, best possible -8880 (58.57 seconds)
# Cbc0010I After 4500 nodes, 1116 on tree, -7558 best solution, best possible -8880 (59.54 seconds)
# Cbc0010I After 4600 nodes, 1142 on tree, -7558 best solution, best possible -8880 (60.68 seconds)
# Cbc0010I After 4700 nodes, 1164 on tree, -7558 best solution, best possible -8880 (61.76 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 242 rows 123 columns
# Cbc0010I After 4800 nodes, 1187 on tree, -7558 best solution, best possible -8880 (62.89 seconds)
# Cbc0010I After 4900 nodes, 1207 on tree, -7558 best solution, best possible -8880 (64.07 seconds)
# Cbc0010I After 5000 nodes, 1237 on tree, -7558 best solution, best possible -8880 (64.92 seconds)
# Cbc0004I Integer solution of -7580 found after 279683 iterations and 5027 nodes (65.13 seconds)
# Cbc0010I After 5100 nodes, 1196 on tree, -7580 best solution, best possible -8880 (65.95 seconds)
# Cbc0010I After 5200 nodes, 1197 on tree, -7580 best solution, best possible -8880 (66.61 seconds)
# Cbc0010I After 5300 nodes, 1195 on tree, -7580 best solution, best possible -8880 (67.73 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 280 rows 133 columns
# Cbc0010I After 5400 nodes, 1219 on tree, -7580 best solution, best possible -8880 (68.61 seconds)
# Cbc0010I After 5500 nodes, 1228 on tree, -7580 best solution, best possible -8880 (69.46 seconds)
# Cbc0010I After 5600 nodes, 1244 on tree, -7580 best solution, best possible -8880 (70.39 seconds)
# Cbc0010I After 5700 nodes, 1273 on tree, -7580 best solution, best possible -8880 (71.25 seconds)
# Cbc0010I After 5800 nodes, 1279 on tree, -7580 best solution, best possible -8880 (30.21 seconds)
# Cbc0010I After 2200 nodes, 691 on tree, -7558 best solution, best possible -8880 (31.54 seconds)
# Cbc0010I After 2300 nodes, 715 on tree, -7558 best solution, best possible -8880 (32.71 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 305 rows 151 columns
# Cbc0010I After 2400 nodes, 735 on tree, -7558 best solution, best possible -8880 (33.87 seconds)
# Cbc0010I After 2500 nodes, 758 on tree, -7558 best solution, best possible -8880 (35.27 seconds)
# Cbc0010I After 2600 nodes, 772 on tree, -7558 best solution, best possible -8880 (36.36 seconds)
# Cbc0010I After 2700 nodes, 775 on tree, -7558 best solution, best possible -8880 (37.60 seconds)
# Cbc0010I After 2800 nodes, 800 on tree, -7558 best solution, best possible -8880 (38.94 seconds)
# Cbc0010I After 2900 nodes, 810 on tree, -7558 best solution, best possible -8880 (40.01 seconds)
# Cbc0010I After 3000 nodes, 817 on tree, -7558 best solution, best possible -8880 (41.12 seconds)
# Cbc0010I After 3100 nodes, 822 on tree, -7558 best solution, best possible -8880 (42.11 seconds)
# Cbc0010I After 3200 nodes, 830 on tree, -7558 best solution, best possible -8880 (43.16 seconds)
# Cbc0010I After 3300 nodes, 855 on tree, -7558 best solution, best possible -8880 (44.16 seconds)
# Cbc0010I After 3400 nodes, 877 on tree, -7558 best solution, best possible -8880 (45.29 seconds)
# Cbc0010I After 3500 nodes, 903 on tree, -7558 best solution, best possible -8880 (46.31 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 278 rows 133 columns
# Cbc0010I After 3600 nodes, 921 on tree, -7558 best solution, best possible -8880 (47.52 seconds)
# Cbc0010I After 3700 nodes, 935 on tree, -7558 best solution, best possible -8880 (48.61 seconds)
# Cbc0010I After 3800 nodes, 944 on tree, -7558 best solution, best possible -8880 (49.76 seconds)
# Cbc0010I After 3900 nodes, 979 on tree, -7558 best solution, best possible -8880 (50.85 seconds)
# Cbc0010I After 4000 nodes, 988 on tree, -7558 best solution, best possible -8880 (51.99 seconds)
# Cbc0010I After 4100 nodes, 1011 on tree, -7558 best solution, best possible -8880 (53.15 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 245 rows 120 columns
# Cbc0010I After 4200 nodes, 1039 on tree, -7558 best solution, best possible -8880 (57.13 seconds)
# Cbc0010I After 4300 nodes, 1063 on tree, -7558 best solution, best possible -8880 (58.17 seconds)
# Cbc0010I After 4400 nodes, 1101 on tree, -7558 best solution, best possible -8880 (59.41 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective -7558 (best possible -8880), took 249017 iterations and 4441 nodes (59.86 seconds)
# Cbc0032I Strong branching done 9368 times (130537 iterations), fathomed 8 nodes and fixed 475 variables
# Cbc0035I Maximum depth 74, 897 variables fixed on reduced cost
# Cuts at root node changed objective from -10344 to -8880
# Probing was tried 5534 times and created 153748 cuts of which 145 were active after adding rounds of cuts (3.553 seconds)
# Gomory was tried 4755 times and created 18970 cuts of which 0 were active after adding rounds of cuts (3.665 seconds)
# Knapsack was tried 4755 times and created 2052 cuts of which 0 were active after adding rounds of cuts (4.610 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 4755 times and created 11665 cuts of which 0 were active after adding rounds of cuts (3.420 seconds)
# FlowCover was tried 10 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# TwoMirCuts was tried 4755 times and created 2506 cuts of which 0 were active after adding rounds of cuts (1.508 seconds)
# ZeroHalf was tried 4755 times and created 645 cuts of which 0 were active after adding rounds of cuts (2.807 seconds)
# ImplicationCuts was tried 27 times and created 19 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                7558.00000000
# Upper bound:                    8880.000
# Gap:                            -0.15
# Enumerated nodes:               4441
# Total iterations:               249017
# Time (CPU seconds):             57.65
# Time (Wallclock seconds):       59.88
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       57.67   (Wallclock seconds):       59.90
#
# Status: Optimal
# Total Profit: 7558.0
# Product    day        SubProduction Production   Sales      Storage
# Chleb_domowy_0_5kg Pon        240.0        240.0        240.0      0.0
# Chleb_domowy_0_5kg Wt         0.0          0.0          0.0        240.0
# Chleb_domowy_0_5kg Sr         0.0          240.0        240.0      0.0
# Chleb_domowy_0_9kg Pon        0.0          0.0          0.0        0.0
# Chleb_domowy_0_9kg Wt         130.0        130.0        130.0      130.0
# Chleb_domowy_0_9kg Sr         0.0          130.0        130.0      0.0
# Chleb_na_zakwasie Pon        200.0        200.0        200.0      0.0
# Chleb_na_zakwasie Wt         200.0        200.0        200.0      200.0
# Chleb_na_zakwasie Sr         0.0          200.0        200.0      0.0
# Bulki      Pon        200.0        200.0        200.0      0.0
# Bulki      Wt         200.0        200.0        200.0      200.0
# Bulki      Sr         0.0          200.0        200.0      0.0
# Bagietki   Pon        200.0        200.0        200.0      0.0
# Bagietki   Wt         200.0        200.0        200.0      200.0
# Bagietki   Sr         0.0          200.0        200.0      0.0
# Rogaliki_z_czekolada Pon        200.0        200.0        200.0      0.0
# Rogaliki_z_czekolada Wt         200.0        200.0        200.0      200.0
# Rogaliki_z_czekolada Sr         0.0          200.0        200.0      0.0

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_colwidth', None)  # Ustaw brak limitu szerokości kolumny


# Po rozwiązaniu problemu upewnijmy się, że rozwiązanie jest optymalne
if pl.LpStatus[model.status] != 'Optimal':
    print("Model did not solve to optimality.")
    exit()

# Pobierz wartości czasu rozpoczęcia
start_times = {
    (subproduct, machine, day): subproduct_batch_start_time[subproduct, machine, day].varValue
    for subproduct in subproducts for machine in sub_machines for day in days
    if subproduct_batch_start_time[subproduct, machine, day].varValue is not None
}

# Oblicz czas zakończenia
end_times = {
    (subproduct, machine, day): start_times[subproduct, machine, day] + sub_production_times[subproduct][machine]
    for subproduct, machine, day in start_times
}

# Wersja 1: Widok z perspektywy subproduktu
subproduct_schedule = []
for subproduct in subproducts:
    for day in days:
        for machine in sub_machines:
            if (subproduct, machine, day) in start_times:
                start = start_times[(subproduct, machine, day)]
                end = end_times[(subproduct, machine, day)]
                subproduct_schedule.append({
                    'Subproduct': subproduct,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

subproduct_df = pd.DataFrame(subproduct_schedule)
print("\nSubproduct Schedule:\n")
print(subproduct_df.sort_values(['Day', 'Subproduct', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania subproduktów na litery
subproduct_mapping = {subproduct: chr(65 + i) for i, subproduct in enumerate(subproducts)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for subproduct in subproducts:
        if (subproduct, machine, day) in start_times:
            start = start_times[(subproduct, machine, day)]
            end = end_times[(subproduct, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = subproduct_mapping[subproduct]  # Wstaw literę dla subproduktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_subproduct = timeline[i]
                    prev_duration = (
                        end_times[(subproducts[ord(prev_subproduct) - 65], machine, day)] -
                        start_times[(subproducts[ord(prev_subproduct) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = subproduct_mapping[subproduct]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in sub_machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
subproduct_df.to_csv("subproduct_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Subproduktów:")
for subproduct, letter in subproduct_mapping.items():
    print(f"{letter}: {subproduct}")
# Out:
# Subproduct Schedule:
#
#                          Subproduct  Day      Machine  Start Time  End Time
# 72               Ciasto_na_bagietki  Pon       Dzieza        0.55      1.50
# 74               Ciasto_na_bagietki  Pon    Dzielarka       19.48     19.72
# 76               Ciasto_na_bagietki  Pon  Rogalikarka       19.72     20.00
# 73               Ciasto_na_bagietki  Pon      Wazenie       20.00     20.00
# 75               Ciasto_na_bagietki  Pon       Tabula       20.00     20.00
# ..                              ...  ...          ...         ...       ...
# 98   Ciasto_na_rogaliki_z_czekolada   Wt    Dzielarka       19.01     19.29
# 100  Ciasto_na_rogaliki_z_czekolada   Wt  Rogalikarka       19.29     19.60
# 101  Ciasto_na_rogaliki_z_czekolada   Wt  Nadziewarka       19.60     20.00
# 97   Ciasto_na_rogaliki_z_czekolada   Wt      Wazenie       20.00     20.00
# 99   Ciasto_na_rogaliki_z_czekolada   Wt       Tabula       20.00     20.00
#
# [108 rows x 5 columns]
#
# Machine Usage Timeline:
#
#         Machine  Day  \
# 0        Dzieza  Pon
# 1       Wazenie  Pon
# 2     Dzielarka  Pon
# 3        Tabula  Pon
# 4   Rogalikarka  Pon
# 5   Nadziewarka  Pon
# 6        Dzieza   Wt
# 7       Wazenie   Wt
# 8     Dzielarka   Wt
# 9        Tabula   Wt
# 10  Rogalikarka   Wt
# 11  Nadziewarka   Wt
# 12       Dzieza   Sr
# 13      Wazenie   Sr
# 14    Dzielarka   Sr
# 15       Tabula   Sr
# 16  Rogalikarka   Sr
# 17  Nadziewarka   Sr
#
#                                                                                                 Timeline
# 0   FFEEEEE________________CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCDDDDDAAAAAAAAAAAAAAAAAAAAAAAAB____
# 1   ____________________________________________________________________________________________C__AB___
# 2   __________________________________________________________________________________________D____F_E__
# 3   ___________________________________________________________________________________________DDCCCABBB
# 4   ________________________________________________________________________________________________F_EE
# 5   __________________________________________________________________________________________________FF
# 6   AAAAAAAAAAAAAAAAAAAAAAACCCCCCCCCCCCCCCCCCCFFF______________BBBBBBBBBBBBBBBBBBBBBBBBBDDDDDEEEE_______
# 7   _______________________A___________________________________________________________________C__B_____
# 8   _____________________________________________________________________________________________EEF_D__
# 9   ________________________AAAA________________________________________________________________CCCBBBDD
# 10  ________________________________________________________________________________________________F_EE
# 11  __________________________________________________________________________________________________FF
# 12  EEEEFFFDDDDD__________AAAAAAAAAAAAAAAAAAAAAAAACCCCCCCCCCCCCCCCCCCCCCCCCBBBBBBBBBBBBBBBBBBBBBBBBB____
# 13  _________________________________________________________________________________________CA_____B___
# 14  ____________________________________________________________________________________________FEE__D__
# 15  ___________________________________________________________________________________________AAAACCBDD
# 16  _______________________________________________________________________________________________EF___
# 17  __________________________________________________________________________________________________FF
#
# Legenda Subproduktów:
# A: Ciasto_na_chleb_domowy_0_5kg
# B: Ciasto_na_chleb_domowy_0_9kg
# C: Ciasto_na_chleb_na_zakwasie
# D: Ciasto_na_bulki
# E: Ciasto_na_bagietki
# F: Ciasto_na_rogaliki_z_czekolada

# %%
# Pobierz wartości czasu rozpoczęcia
start_times = {
    (product, machine, day): product_batch_start_time[product, machine, day].varValue
    for product in products for machine in machines for day in days
    if product_batch_start_time[product, machine, day].varValue is not None
}

# Oblicz czas zakończenia
end_times = {
    (product, machine, day): start_times[product, machine, day] + production_times[product][machine]
    for product, machine, day in start_times
}

# Wersja 1: Widok z perspektywy produktu
product_schedule = []
for product in products:
    for day in days:
        for machine in machines:
            if (product, machine, day) in start_times:
                start = start_times[(product, machine, day)]
                end = end_times[(product, machine, day)]
                product_schedule.append({
                    'Product': product,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

product_df = pd.DataFrame(product_schedule)
print("\nProduct Schedule:\n")
print(product_df.sort_values(['Day', 'Product', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania produktów na litery
product_mapping = {product: chr(65 + i) for i, product in enumerate(products)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for product in products:
        if (product, machine, day) in start_times:
            start = start_times[(product, machine, day)]
            end = end_times[(product, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = product_mapping[product]  # Wstaw literę dla produktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_product = timeline[i]
                    prev_duration = (
                        end_times[(products[ord(prev_product) - 65], machine, day)] -
                        start_times[(products[ord(prev_product) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = product_mapping[product]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
product_df.to_csv("product_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Produktów:")
for product, letter in product_mapping.items():
    print(f"{letter}: {product}")
# Out:
# Product Schedule:
#
#                  Product  Day    Machine  Start Time  End Time
# 48              Bagietki  Pon   Garownia        1.40      1.73
# 49              Bagietki  Pon       Piec        8.69      8.92
# 50              Bagietki  Pon  Studzenie       17.22     17.64
# 51              Bagietki  Pon  Pakowanie       20.00     20.00
# 36                 Bulki  Pon   Garownia        7.20      7.58
# ..                   ...  ...        ...         ...       ...
# 31     Chleb_na_zakwasie   Wt  Pakowanie       18.84     19.44
# 64  Rogaliki_z_czekolada   Wt   Garownia        7.30      7.55
# 65  Rogaliki_z_czekolada   Wt       Piec        8.09      8.27
# 66  Rogaliki_z_czekolada   Wt  Studzenie       13.15     13.97
# 67  Rogaliki_z_czekolada   Wt  Pakowanie       17.85     18.27
#
# [72 rows x 5 columns]
#
# Machine Usage Timeline:
#
#       Machine  Day  \
# 0    Garownia  Pon
# 1        Piec  Pon
# 2   Studzenie  Pon
# 3   Pakowanie  Pon
# 4    Garownia   Wt
# 5        Piec   Wt
# 6   Studzenie   Wt
# 7   Pakowanie   Wt
# 8    Garownia   Sr
# 9        Piec   Sr
# 10  Studzenie   Sr
# 11  Pakowanie   Sr
#
#                                                                                                 Timeline
# 0   CCCCCCEEAAAAA______________BBBBBBBFFD_______________________________________________________________
# 1   _____________________________________DDFAAAEBBBBBBCCCCC_____________________________________________
# 2   _______________________________________________________CCCCCCCCCCCCDDBBBBBBBBBBBBFFFFFEEAAAAAAAAA___
# 3   _________________________________________________________________________________________BBBCCCFFAAA
# 4   BBBBBBBEE___________________AAAAA_DDFCCCCCCC________________________________________________________
# 5   ________________________________________FAAACCCCCDEE____________________BBBBBB______________________
# 6   ____________________________________________________EECCCCCCCCCCCFFFFAAAAAAAAABBBBBBBBBBBBB______DDD
# 7   _________________________________________________________________________________________FFBBBCCCAAA
# 8   EBBBBBBBBCCCCCCC__________________________FAAAAA__D_________________________________________________
# 9   _______________________________________________EAAADDBBBBBBF___________CCCCC________________________
# 10  _______________________________________________________DDEEEFFFFBBBBBBBBBBBBCCCCCCCCCCCCAAAAAAAAA___
# 11  _________________________________________________________________________________________BBBCCCFFAAA
#
# Legenda Produktów:
# A: Chleb_domowy_0_5kg
# B: Chleb_domowy_0_9kg
# C: Chleb_na_zakwasie
# D: Bulki
# E: Bagietki
# F: Rogaliki_z_czekolada
#  -8880 (71.93 seconds)
# Cbc0010I After 5900 nodes, 1281 on tree, -7580 best solution, best possible -8880 (72.70 seconds)
# Cbc0010I After 6000 nodes, 1299 on tree, -7580 best solution, best possible -8880 (73.79 seconds)
# Cbc0010I After 6100 nodes, 1309 on tree, -7580 best solution, best possible -8880 (74.77 seconds)
# Cbc0010I After 6200 nodes, 1333 on tree, -7580 best solution, best possible -8880 (75.69 seconds)
# Cbc0010I After 6300 nodes, 1346 on tree, -7580 best solution, best possible -8880 (76.50 seconds)
# Cbc0010I After 6400 nodes, 1357 on tree, -7580 best solution, best possible -8880 (77.38 seconds)
# Cbc0010I After 6500 nodes, 1370 on tree, -7580 best solution, best possible -8880 (81.22 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 326 rows 160 columns
# Cbc0010I After 6600 nodes, 1380 on tree, -7580 best solution, best possible -8880 (82.10 seconds)
# Cbc0010I After 6700 nodes, 1411 on tree, -7580 best solution, best possible -8880 (82.98 seconds)
# Cbc0010I After 6800 nodes, 1427 on tree, -7580 best solution, best possible -8880 (83.64 seconds)
# Cbc0010I After 6900 nodes, 1447 on tree, -7580 best solution, best possible -8880 (84.39 seconds)
# Cbc0010I After 7000 nodes, 1479 on tree, -7580 best solution, best possible -8880 (85.26 seconds)
# Cbc0010I After 7100 nodes, 1480 on tree, -7580 best solution, best possible -8880 (85.92 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 285 rows 133 columns
# Cbc0010I After 7200 nodes, 1485 on tree, -7580 best solution, best possible -8880 (86.79 seconds)
# Cbc0010I After 7300 nodes, 1494 on tree, -7580 best solution, best possible -8880 (87.85 seconds)
# Cbc0010I After 7400 nodes, 1503 on tree, -7580 best solution, best possible -8880 (88.56 seconds)
# Cbc0010I After 7500 nodes, 1532 on tree, -7580 best solution, best possible -8880 (89.30 seconds)
# Cbc0010I After 7600 nodes, 1539 on tree, -7580 best solution, best possible -8880 (90.01 seconds)
# Cbc0010I After 7700 nodes, 1558 on tree, -7580 best solution, best possible -8880 (90.86 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 339 rows 168 columns
# Cbc0010I After 7800 nodes, 1570 on tree, -7580 best solution, best possible -8880 (91.61 seconds)
# Cbc0010I After 7900 nodes, 1589 on tree, -7580 best solution, best possible -8880 (92.45 seconds)
# Cbc0010I After 8000 nodes, 1607 on tree, -7580 best solution, best possible -8880 (93.21 seconds)
# Cbc0010I After 8100 nodes, 1636 on tree, -7580 best solution, best possible -8880 (94.06 seconds)
# Cbc0010I After 8200 nodes, 1663 on tree, -7580 best solution, best possible -8880 (94.86 seconds)
# Cbc0010I After 8300 nodes, 1686 on tree, -7580 best solution, best possible -8880 (95.63 seconds)
# Cbc0010I After 8400 nodes, 1708 on tree, -7580 best solution, best possible -8880 (96.44 seconds)
# Cbc0010I After 8500 nodes, 1707 on tree, -7580 best solution, best possible -8880 (97.23 seconds)
# Cbc0010I After 8600 nodes, 1715 on tree, -7580 best solution, best possible -8880 (98.24 seconds)
# Cbc0010I After 8700 nodes, 1718 on tree, -7580 best solution, best possible -8880 (99.02 seconds)
# Cbc0010I After 8800 nodes, 1733 on tree, -7580 best solution, best possible -8880 (99.83 seconds)
# Cbc0010I After 8900 nodes, 1769 on tree, -7580 best solution, best possible -8880 (100.67 seconds)
# Cbc0010I After 9000 nodes, 1796 on tree, -7580 best solution, best possible -8880 (101.49 seconds)
# Cbc0010I After 9100 nodes, 1801 on tree, -7580 best solution, best possible -8880 (102.34 seconds)
# Cbc0010I After 9200 nodes, 1776 on tree, -7580 best solution, best possible -8880 (102.94 seconds)
# Cbc0010I After 9300 nodes, 1745 on tree, -7580 best solution, best possible -8880 (103.50 seconds)
# Cbc0010I After 9400 nodes, 1727 on tree, -7580 best solution, best possible -8880 (104.08 seconds)
# Cbc0010I After 9500 nodes, 1708 on tree, -7580 best solution, best possible -8880 (104.87 seconds)
# Cbc0010I After 9600 nodes, 1692 on tree, -7580 best solution, best possible -8880 (105.65 seconds)
# Cbc0010I After 9700 nodes, 1681 on tree, -7580 best solution, best possible -8880 (106.37 seconds)
# Cbc0010I After 9800 nodes, 1681 on tree, -7580 best solution, best possible -8880 (107.11 seconds)
# Cbc0010I After 9900 nodes, 1681 on tree, -7580 best solution, best possible -8880 (107.90 seconds)
# Cbc0010I After 10000 nodes, 1670 on tree, -7580 best solution, best possible -8880 (108.72 seconds)
# Cbc0010I After 10100 nodes, 1662 on tree, -7580 best solution, best possible -8880 (109.46 seconds)
# Cbc0010I After 10200 nodes, 1633 on tree, -7580 best solution, best possible -8880 (110.03 seconds)
# Cbc0010I After 10300 nodes, 1633 on tree, -7580 best solution, best possible -8880 (110.77 seconds)
# Cbc0010I After 10400 nodes, 1627 on tree, -7580 best solution, best possible -8880 (111.57 seconds)
# Cbc0010I After 10500 nodes, 1616 on tree, -7580 best solution, best possible -8880 (112.29 seconds)
# Cbc0010I After 10600 nodes, 1609 on tree, -7580 best solution, best possible -8880 (113.12 seconds)
# Cbc0010I After 10700 nodes, 1598 on tree, -7580 best solution, best possible -8880 (116.63 seconds)
# Cbc0010I After 10800 nodes, 1595 on tree, -7580 best solution, best possible -8880 (117.49 seconds)
# Cbc0010I After 10900 nodes, 1592 on tree, -7580 best solution, best possible -8880 (118.34 seconds)
# Cbc0010I After 11000 nodes, 1586 on tree, -7580 best solution, best possible -8880 (119.07 seconds)
# Cbc0010I After 11100 nodes, 1622 on tree, -7580 best solution, best possible -8880 (122.00 seconds)
# Cbc0010I After 11200 nodes, 1647 on tree, -7580 best solution, best possible -8880 (123.19 seconds)
# Cbc0010I After 11300 nodes, 1675 on tree, -7580 best solution, best possible -8880 (124.62 seconds)
# Cbc0010I After 11400 nodes, 1701 on tree, -7580 best solution, best possible -8880 (126.22 seconds)
# Cbc0010I After 11500 nodes, 1730 on tree, -7580 best solution, best possible -8880 (128.04 seconds)
# Cbc0010I After 11600 nodes, 1767 on tree, -7580 best solution, best possible -8880 (129.25 seconds)
# Cbc0010I After 11700 nodes, 1790 on tree, -7580 best solution, best possible -8880 (130.86 seconds)
# Cbc0010I After 11800 nodes, 1825 on tree, -7580 best solution, best possible -8880 (133.04 seconds)
# Cbc0010I After 11900 nodes, 1852 on tree, -7580 best solution, best possible -8880 (134.20 seconds)
# Cbc0010I After 12000 nodes, 1881 on tree, -7580 best solution, best possible -8880 (135.70 seconds)
# Cbc0010I After 12100 nodes, 1912 on tree, -7580 best solution, best possible -8880 (136.94 seconds)
# Cbc0010I After 12200 nodes, 1943 on tree, -7580 best solution, best possible -8880 (138.22 seconds)
# Cbc0010I After 12300 nodes, 1963 on tree, -7580 best solution, best possible -8880 (139.41 seconds)
# Cbc0010I After 12400 nodes, 1978 on tree, -7580 best solution, best possible -8879.8187 (140.83 seconds)
# Cbc0010I After 12500 nodes, 2005 on tree, -7580 best solution, best possible -8879.1813 (142.00 seconds)
# Cbc0010I After 12600 nodes, 2046 on tree, -7580 best solution, best possible -8876.6332 (143.43 seconds)
# Cbc0010I After 12700 nodes, 2078 on tree, -7580 best solution, best possible -8872.3517 (145.16 seconds)
# Cbc0010I After 12800 nodes, 2102 on tree, -7580 best solution, best possible -8858.663 (146.43 seconds)
# Cbc0010I After 12900 nodes, 2131 on tree, -7580 best solution, best possible -8743.6774 (148.09 seconds)
# Cbc0010I After 13000 nodes, 2145 on tree, -7580 best solution, best possible -8740 (152.03 seconds)
# Cbc0010I After 13100 nodes, 2139 on tree, -7580 best solution, best possible -8740 (152.77 seconds)
# Cbc0010I After 13200 nodes, 2141 on tree, -7580 best solution, best possible -8740 (153.42 seconds)
# Cbc0010I After 13300 nodes, 2136 on tree, -7580 best solution, best possible -8740 (154.34 seconds)
# Cbc0010I After 13400 nodes, 2127 on tree, -7580 best solution, best possible -8740 (155.18 seconds)
# Cbc0010I After 13500 nodes, 2119 on tree, -7580 best solution, best possible -8740 (155.70 seconds)
# Cbc0010I After 13600 nodes, 2107 on tree, -7580 best solution, best possible -8740 (156.61 seconds)
# Cbc0010I After 13700 nodes, 2103 on tree, -7580 best solution, best possible -8740 (157.35 seconds)
# Cbc0010I After 13800 nodes, 2092 on tree, -7580 best solution, best possible -8740 (157.93 seconds)
# Cbc0010I After 13900 nodes, 2094 on tree, -7580 best solution, best possible -8740 (158.68 seconds)
# Cbc0010I After 14000 nodes, 2094 on tree, -7580 best solution, best possible -8740 (159.27 seconds)
# Cbc0010I After 14100 nodes, 2105 on tree, -7580 best solution, best possible -8740 (160.06 seconds)
# Cbc0010I After 14200 nodes, 2133 on tree, -7580 best solution, best possible -8740 (161.21 seconds)
# Cbc0010I After 14300 nodes, 2158 on tree, -7580 best solution, best possible -8740 (162.07 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 410 rows 199 columns
# Cbc0010I After 14400 nodes, 2173 on tree, -7580 best solution, best possible -8740 (162.80 seconds)
# Cbc0010I After 14500 nodes, 2195 on tree, -7580 best solution, best possible -8740 (163.56 seconds)
# Cbc0010I After 14600 nodes, 2221 on tree, -7580 best solution, best possible -8740 (164.46 seconds)
# Cbc0010I After 14700 nodes, 2246 on tree, -7580 best solution, best possible -8740 (165.18 seconds)
# Cbc0010I After 14800 nodes, 2259 on tree, -7580 best solution, best possible -8740 (165.87 seconds)
# Cbc0010I After 14900 nodes, 2276 on tree, -7580 best solution, best possible -8740 (166.58 seconds)
# Cbc0010I After 15000 nodes, 2297 on tree, -7580 best solution, best possible -8740 (167.50 seconds)
# Cbc0010I After 15100 nodes, 2313 on tree, -7580 best solution, best possible -8740 (168.35 seconds)
# Cbc0010I After 15200 nodes, 2331 on tree, -7580 best solution, best possible -8740 (169.28 seconds)
# Cbc0010I After 15300 nodes, 2359 on tree, -7580 best solution, best possible -8740 (170.03 seconds)
# Cbc0010I After 15400 nodes, 2381 on tree, -7580 best solution, best possible -8740 (170.82 seconds)
# Cbc0010I After 15500 nodes, 2402 on tree, -7580 best solution, best possible -8740 (171.70 seconds)
# Cbc0010I After 15600 nodes, 2435 on tree, -7580 best solution, best possible -8740 (172.55 seconds)
# Cbc0010I After 15700 nodes, 2457 on tree, -7580 best solution, best possible -8740 (173.55 seconds)
# Cbc0010I After 15800 nodes, 2460 on tree, -7580 best solution, best possible -8740 (174.46 seconds)
# Cbc0010I After 15900 nodes, 2482 on tree, -7580 best solution, best possible -8740 (175.62 seconds)
# Cbc0010I After 16000 nodes, 2503 on tree, -7580 best solution, best possible -8740 (176.76 seconds)
# Cbc0010I After 16100 nodes, 2533 on tree, -7580 best solution, best possible -8740 (177.89 seconds)
# Cbc0010I After 16200 nodes, 2550 on tree, -7580 best solution, best possible -8740 (178.98 seconds)
# Cbc0010I After 16300 nodes, 2564 on tree, -7580 best solution, best possible -8740 (179.95 seconds)
# Cbc0010I After 16400 nodes, 2577 on tree, -7580 best solution, best possible -8740 (180.95 seconds)
# Cbc0010I After 16500 nodes, 2595 on tree, -7580 best solution, best possible -8740 (182.00 seconds)
# Cbc0010I After 16600 nodes, 2603 on tree, -7580 best solution, best possible -8740 (183.09 seconds)
# Cbc0010I After 16700 nodes, 2610 on tree, -7580 best solution, best possible -8740 (187.06 seconds)
# Cbc0010I After 16800 nodes, 2624 on tree, -7580 best solution, best possible -8740 (187.97 seconds)
# Cbc0010I After 16900 nodes, 2626 on tree, -7580 best solution, best possible -8740 (188.96 seconds)
# Cbc0010I After 17000 nodes, 2643 on tree, -7580 best solution, best possible -8740 (189.93 seconds)
# Cbc0010I After 17100 nodes, 2637 on tree, -7580 best solution, best possible -8740 (190.48 seconds)
# Cbc0010I After 17200 nodes, 2640 on tree, -7580 best solution, best possible -8740 (191.14 seconds)
# Cbc0010I After 17300 nodes, 2634 on tree, -7580 best solution, best possible -8740 (191.70 seconds)
# Cbc0010I After 17400 nodes, 2628 on tree, -7580 best solution, best possible -8740 (192.52 seconds)
# Cbc0010I After 17500 nodes, 2628 on tree, -7580 best solution, best possible -8740 (193.41 seconds)
# Cbc0010I After 17600 nodes, 2613 on tree, -7580 best solution, best possible -8740 (193.99 seconds)
# Cbc0010I After 17700 nodes, 2610 on tree, -7580 best solution, best possible -8740 (194.72 seconds)
# Cbc0010I After 17800 nodes, 2588 on tree, -7580 best solution, best possible -8740 (195.35 seconds)
# Cbc0010I After 17900 nodes, 2580 on tree, -7580 best solution, best possible -8740 (196.00 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 337 rows 156 columns
# Cbc0010I After 18000 nodes, 2564 on tree, -7580 best solution, best possible -8740 (196.65 seconds)
# Cbc0010I After 18100 nodes, 2583 on tree, -7580 best solution, best possible -8740 (197.79 seconds)
# Cbc0010I After 18200 nodes, 2595 on tree, -7580 best solution, best possible -8740 (198.91 seconds)
# Cbc0010I After 18300 nodes, 2618 on tree, -7580 best solution, best possible -8740 (200.06 seconds)
# Cbc0010I After 18400 nodes, 2640 on tree, -7580 best solution, best possible -8740 (201.31 seconds)
# Cbc0010I After 18500 nodes, 2644 on tree, -7580 best solution, best possible -8739.7866 (202.39 seconds)
# Cbc0010I After 18600 nodes, 2649 on tree, -7580 best solution, best possible -8739.563 (203.58 seconds)
# Cbc0010I After 18700 nodes, 2659 on tree, -7580 best solution, best possible -8739.247 (204.76 seconds)
# Cbc0010I After 18800 nodes, 2675 on tree, -7580 best solution, best possible -8737.8596 (206.18 seconds)
# Cbc0010I After 18900 nodes, 2699 on tree, -7580 best solution, best possible -8736.0717 (207.43 seconds)
# Cbc0010I After 19000 nodes, 2719 on tree, -7580 best solution, best possible -8732.1538 (208.84 seconds)
# Cbc0010I After 19100 nodes, 2737 on tree, -7580 best solution, best possible -8730 (210.02 seconds)
# Cbc0010I After 19200 nodes, 2762 on tree, -7580 best solution, best possible -8730 (211.50 seconds)
# Cbc0010I After 19300 nodes, 2788 on tree, -7580 best solution, best possible -8730 (212.49 seconds)
# Cbc0010I After 19400 nodes, 2816 on tree, -7580 best solution, best possible -8730 (213.47 seconds)
# Cbc0010I After 19500 nodes, 2837 on tree, -7580 best solution, best possible -8730 (214.44 seconds)
# Cbc0010I After 19600 nodes, 2862 on tree, -7580 best solution, best possible -8730 (215.71 seconds)
# Cbc0010I After 19700 nodes, 2877 on tree, -7580 best solution, best possible -8728.1882 (217.17 seconds)
# Cbc0010I After 19800 nodes, 2893 on tree, -7580 best solution, best possible -8722.0182 (218.20 seconds)
# Cbc0010I After 19900 nodes, 2904 on tree, -7580 best solution, best possible -8712.3364 (221.99 seconds)
# Cbc0010I After 20000 nodes, 2902 on tree, -7580 best solution, best possible -8700 (222.92 seconds)
# Cbc0010I After 20100 nodes, 2908 on tree, -7580 best solution, best possible -8685.9549 (223.93 seconds)
# Cbc0010I After 20200 nodes, 2927 on tree, -7580 best solution, best possible -8600.2703 (225.00 seconds)
# Cbc0010I After 20300 nodes, 2928 on tree, -7580 best solution, best possible -8600 (225.78 seconds)
# Cbc0010I After 20400 nodes, 2924 on tree, -7580 best solution, best possible -8600 (226.41 seconds)
# Cbc0010I After 20500 nodes, 2915 on tree, -7580 best solution, best possible -8600 (226.99 seconds)
# Cbc0010I After 20600 nodes, 2927 on tree, -7580 best solution, best possible -8600 (227.91 seconds)
# Cbc0010I After 20700 nodes, 2924 on tree, -7580 best solution, best possible -8600 (228.83 seconds)
# Cbc0010I After 20800 nodes, 2918 on tree, -7580 best solution, best possible -8598.9396 (229.63 seconds)
# Cbc0010I After 20900 nodes, 2924 on tree, -7580 best solution, best possible -8590 (230.53 seconds)
# Cbc0010I After 21000 nodes, 2926 on tree, -7580 best solution, best possible -8590 (231.38 seconds)
# Cbc0010I After 21100 nodes, 2915 on tree, -7580 best solution, best possible -8590 (231.90 seconds)
# Cbc0010I After 21200 nodes, 2891 on tree, -7580 best solution, best possible -8590 (232.40 seconds)
# Cbc0010I After 21300 nodes, 2881 on tree, -7580 best solution, best possible -8590 (233.00 seconds)
# Cbc0010I After 21400 nodes, 2874 on tree, -7580 best solution, best possible -8590 (233.55 seconds)
# Cbc0010I After 21500 nodes, 2861 on tree, -7580 best solution, best possible -8590 (234.02 seconds)
# Cbc0010I After 21600 nodes, 2856 on tree, -7580 best solution, best possible -8590 (234.49 seconds)
# Cbc0010I After 21700 nodes, 2851 on tree, -7580 best solution, best possible -8590 (235.06 seconds)
# Cbc0010I After 21800 nodes, 2849 on tree, -7580 best solution, best possible -8590 (235.62 seconds)
# Cbc0010I After 21900 nodes, 2842 on tree, -7580 best solution, best possible -8590 (236.27 seconds)
# Cbc0010I After 22000 nodes, 2836 on tree, -7580 best solution, best possible -8590 (236.72 seconds)
# Cbc0010I After 22100 nodes, 2846 on tree, -7580 best solution, best possible -8590 (237.81 seconds)
# Cbc0010I After 22200 nodes, 2855 on tree, -7580 best solution, best possible -8580 (238.82 seconds)
# Cbc0010I After 22300 nodes, 2883 on tree, -7580 best solution, best possible -8569.1338 (239.97 seconds)
# Cbc0010I After 22400 nodes, 2881 on tree, -7580 best solution, best possible -8560 (240.63 seconds)
# Cbc0010I After 22500 nodes, 2875 on tree, -7580 best solution, best possible -8560 (241.14 seconds)
# Cbc0010I After 22600 nodes, 2865 on tree, -7580 best solution, best possible -8560 (241.68 seconds)
# Cbc0010I After 22700 nodes, 2866 on tree, -7580 best solution, best possible -8514.0472 (242.51 seconds)
# Cbc0010I After 22800 nodes, 2893 on tree, -7580 best solution, best possible -8355.9469 (243.76 seconds)
# Cbc0010I After 22900 nodes, 2921 on tree, -7580 best solution, best possible -8256 (244.67 seconds)
# Cbc0010I After 23000 nodes, 2946 on tree, -7580 best solution, best possible -8230 (245.30 seconds)
# Cbc0010I After 23100 nodes, 2966 on tree, -7580 best solution, best possible -8230 (245.94 seconds)
# Cbc0010I After 23200 nodes, 2992 on tree, -7580 best solution, best possible -8230 (246.79 seconds)
# Cbc0010I After 23300 nodes, 3001 on tree, -7580 best solution, best possible -8230 (247.53 seconds)
# Cbc0010I After 23400 nodes, 3012 on tree, -7580 best solution, best possible -8230 (248.16 seconds)
# Cbc0010I After 23500 nodes, 3046 on tree, -7580 best solution, best possible -8230 (249.00 seconds)
# Cbc0010I After 23600 nodes, 3066 on tree, -7580 best solution, best possible -8230 (249.67 seconds)
# Cbc0010I After 23700 nodes, 3099 on tree, -7580 best solution, best possible -8230 (250.34 seconds)
# Cbc0010I After 23800 nodes, 3116 on tree, -7580 best solution, best possible -8230 (250.99 seconds)
# Cbc0010I After 23900 nodes, 3155 on tree, -7580 best solution, best possible -8230 (251.70 seconds)
# Cbc0010I After 24000 nodes, 3178 on tree, -7580 best solution, best possible -8230 (252.48 seconds)
# Cbc0010I After 24100 nodes, 3201 on tree, -7580 best solution, best possible -8230 (253.25 seconds)
# Cbc0010I After 24200 nodes, 3212 on tree, -7580 best solution, best possible -8230 (253.88 seconds)
# Cbc0010I After 24300 nodes, 3217 on tree, -7580 best solution, best possible -8230 (257.40 seconds)
# Cbc0010I After 24400 nodes, 3218 on tree, -7580 best solution, best possible -8230 (258.05 seconds)
# Cbc0010I After 24500 nodes, 3227 on tree, -7580 best solution, best possible -8230 (258.82 seconds)
# Cbc0010I After 24600 nodes, 3242 on tree, -7580 best solution, best possible -8230 (259.47 seconds)
# Cbc0010I After 24700 nodes, 3251 on tree, -7580 best solution, best possible -8230 (260.18 seconds)
# Cbc0010I After 24800 nodes, 3272 on tree, -7580 best solution, best possible -8230 (260.94 seconds)
# Cbc0010I After 24900 nodes, 3304 on tree, -7580 best solution, best possible -8230 (261.67 seconds)
# Cbc0010I After 25000 nodes, 3323 on tree, -7580 best solution, best possible -8230 (262.35 seconds)
# Cbc0010I After 25100 nodes, 3311 on tree, -7580 best solution, best possible -8230 (262.84 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 233 rows 114 columns
# Cbc0010I After 25200 nodes, 3298 on tree, -7580 best solution, best possible -8230 (263.45 seconds)
# Cbc0010I After 25300 nodes, 3281 on tree, -7580 best solution, best possible -8230 (263.93 seconds)
# Cbc0010I After 25400 nodes, 3269 on tree, -7580 best solution, best possible -8230 (264.45 seconds)
# Cbc0010I After 25500 nodes, 3261 on tree, -7580 best solution, best possible -8230 (264.93 seconds)
# Cbc0010I After 25600 nodes, 3249 on tree, -7580 best solution, best possible -8230 (265.58 seconds)
# Cbc0010I After 25700 nodes, 3235 on tree, -7580 best solution, best possible -8230 (266.17 seconds)
# Cbc0010I After 25800 nodes, 3219 on tree, -7580 best solution, best possible -8230 (266.67 seconds)
# Cbc0010I After 25900 nodes, 3213 on tree, -7580 best solution, best possible -8230 (267.14 seconds)
# Cbc0010I After 26000 nodes, 3198 on tree, -7580 best solution, best possible -8230 (267.67 seconds)
# Cbc0010I After 26100 nodes, 3207 on tree, -7580 best solution, best possible -8230 (268.47 seconds)
# Cbc0010I After 26200 nodes, 3222 on tree, -7580 best solution, best possible -8230 (269.22 seconds)
# Cbc0010I After 26300 nodes, 3251 on tree, -7580 best solution, best possible -8230 (270.03 seconds)
# Cbc0010I After 26400 nodes, 3275 on tree, -7580 best solution, best possible -8230 (270.77 seconds)
# Cbc0010I After 26500 nodes, 3304 on tree, -7580 best solution, best possible -8230 (271.46 seconds)
# Cbc0010I After 26600 nodes, 3327 on tree, -7580 best solution, best possible -8230 (272.20 seconds)
# Cbc0010I After 26700 nodes, 3357 on tree, -7580 best solution, best possible -8230 (272.95 seconds)
# Cbc0010I After 26800 nodes, 3374 on tree, -7580 best solution, best possible -8230 (273.61 seconds)
# Cbc0010I After 26900 nodes, 3390 on tree, -7580 best solution, best possible -8230 (274.37 seconds)
# Cbc0010I After 27000 nodes, 3405 on tree, -7580 best solution, best possible -8230 (275.07 seconds)
# Cbc0010I After 27100 nodes, 3423 on tree, -7580 best solution, best possible -8230 (275.76 seconds)
# Cbc0010I After 27200 nodes, 3430 on tree, -7580 best solution, best possible -8230 (276.34 seconds)
# Cbc0010I After 27300 nodes, 3437 on tree, -7580 best solution, best possible -8230 (276.92 seconds)
# Cbc0010I After 27400 nodes, 3439 on tree, -7580 best solution, best possible -8230 (277.51 seconds)
# Cbc0010I After 27500 nodes, 3448 on tree, -7580 best solution, best possible -8230 (278.23 seconds)
# Cbc0010I After 27600 nodes, 3456 on tree, -7580 best solution, best possible -8230 (278.94 seconds)
# Cbc0010I After 27700 nodes, 3475 on tree, -7580 best solution, best possible -8230 (279.61 seconds)
# Cbc0010I After 27800 nodes, 3506 on tree, -7580 best solution, best possible -8230 (280.35 seconds)
# Cbc0010I After 27900 nodes, 3534 on tree, -7580 best solution, best possible -8230 (280.95 seconds)
# Cbc0010I After 28000 nodes, 3565 on tree, -7580 best solution, best possible -8230 (281.58 seconds)
# Cbc0010I After 28100 nodes, 3583 on tree, -7580 best solution, best possible -8230 (282.20 seconds)
# Cbc0010I After 28200 nodes, 3605 on tree, -7580 best solution, best possible -8230 (282.91 seconds)
# Cbc0010I After 28300 nodes, 3624 on tree, -7580 best solution, best possible -8230 (283.57 seconds)
# Cbc0010I After 28400 nodes, 3639 on tree, -7580 best solution, best possible -8230 (284.23 seconds)
# Cbc0010I After 28500 nodes, 3660 on tree, -7580 best solution, best possible -8230 (284.96 seconds)
# Cbc0010I After 28600 nodes, 3669 on tree, -7580 best solution, best possible -8230 (285.71 seconds)
# Cbc0010I After 28700 nodes, 3682 on tree, -7580 best solution, best possible -8230 (286.36 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 278 rows 131 columns
# Cbc0010I After 28800 nodes, 3705 on tree, -7580 best solution, best possible -8230 (287.17 seconds)
# Cbc0010I After 28900 nodes, 3734 on tree, -7580 best solution, best possible -8230 (287.85 seconds)
# Cbc0010I After 29000 nodes, 3755 on tree, -7580 best solution, best possible -8230 (288.51 seconds)
# Cbc0010I After 29100 nodes, 3732 on tree, -7580 best solution, best possible -8230 (289.10 seconds)
# Cbc0010I After 29200 nodes, 3723 on tree, -7580 best solution, best possible -8230 (292.60 seconds)
# Cbc0010I After 29300 nodes, 3708 on tree, -7580 best solution, best possible -8230 (293.15 seconds)
# Cbc0010I After 29400 nodes, 3689 on tree, -7580 best solution, best possible -8230 (293.74 seconds)
# Cbc0010I After 29500 nodes, 3674 on tree, -7580 best solution, best possible -8230 (294.18 seconds)
# Cbc0010I After 29600 nodes, 3656 on tree, -7580 best solution, best possible -8230 (294.72 seconds)
# Cbc0010I After 29700 nodes, 3654 on tree, -7580 best solution, best possible -8230 (295.47 seconds)
# Cbc0010I After 29800 nodes, 3642 on tree, -7580 best solution, best possible -8230 (296.22 seconds)
# Cbc0010I After 29900 nodes, 3630 on tree, -7580 best solution, best possible -8230 (296.82 seconds)
# Cbc0010I After 30000 nodes, 3618 on tree, -7580 best solution, best possible -8230 (297.47 seconds)
# Cbc0010I After 30100 nodes, 3635 on tree, -7580 best solution, best possible -8230 (298.09 seconds)
# Cbc0010I After 30200 nodes, 3659 on tree, -7580 best solution, best possible -8230 (298.81 seconds)
# Cbc0010I After 30300 nodes, 3684 on tree, -7580 best solution, best possible -8230 (299.55 seconds)
# Cbc0010I After 30400 nodes, 3710 on tree, -7580 best solution, best possible -8230 (300.27 seconds)
# Cbc0010I After 30500 nodes, 3731 on tree, -7580 best solution, best possible -8230 (300.97 seconds)
# Cbc0010I After 30600 nodes, 3757 on tree, -7580 best solution, best possible -8230 (301.61 seconds)
# Cbc0010I After 30700 nodes, 3792 on tree, -7580 best solution, best possible -8230 (302.30 seconds)
# Cbc0010I After 30800 nodes, 3824 on tree, -7580 best solution, best possible -8230 (302.95 seconds)
# Cbc0010I After 30900 nodes, 3852 on tree, -7580 best solution, best possible -8230 (303.64 seconds)
# Cbc0010I After 31000 nodes, 3876 on tree, -7580 best solution, best possible -8230 (304.22 seconds)
# Cbc0010I After 31100 nodes, 3892 on tree, -7580 best solution, best possible -8230 (304.79 seconds)
# Cbc0010I After 31200 nodes, 3920 on tree, -7580 best solution, best possible -8230 (305.44 seconds)
# Cbc0010I After 31300 nodes, 3949 on tree, -7580 best solution, best possible -8230 (306.06 seconds)
# Cbc0010I After 31400 nodes, 3965 on tree, -7580 best solution, best possible -8230 (306.70 seconds)
# Cbc0010I After 31500 nodes, 3985 on tree, -7580 best solution, best possible -8230 (307.34 seconds)
# Cbc0010I After 31600 nodes, 4000 on tree, -7580 best solution, best possible -8230 (307.91 seconds)
# Cbc0010I After 31700 nodes, 4018 on tree, -7580 best solution, best possible -8230 (308.50 seconds)
# Cbc0010I After 31800 nodes, 4039 on tree, -7580 best solution, best possible -8230 (309.23 seconds)
# Cbc0010I After 31900 nodes, 4047 on tree, -7580 best solution, best possible -8230 (309.90 seconds)
# Cbc0010I After 32000 nodes, 4058 on tree, -7580 best solution, best possible -8230 (310.58 seconds)
# Cbc0010I After 32100 nodes, 4071 on tree, -7580 best solution, best possible -8230 (311.20 seconds)
# Cbc0010I After 32200 nodes, 4089 on tree, -7580 best solution, best possible -8230 (311.90 seconds)
# Cbc0010I After 32300 nodes, 4104 on tree, -7580 best solution, best possible -8230 (312.54 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 304 rows 145 columns
# Cbc0010I After 32400 nodes, 4117 on tree, -7580 best solution, best possible -8230 (313.21 seconds)
# Cbc0010I After 32500 nodes, 4105 on tree, -7580 best solution, best possible -8230 (313.79 seconds)
# Cbc0010I After 32600 nodes, 4116 on tree, -7580 best solution, best possible -8230 (314.51 seconds)
# Cbc0010I After 32700 nodes, 4143 on tree, -7580 best solution, best possible -8230 (315.31 seconds)
# Cbc0010I After 32800 nodes, 4166 on tree, -7580 best solution, best possible -8230 (316.03 seconds)
# Cbc0010I After 32900 nodes, 4194 on tree, -7580 best solution, best possible -8230 (316.71 seconds)
# Cbc0010I After 33000 nodes, 4223 on tree, -7580 best solution, best possible -8230 (317.46 seconds)
# Cbc0010I After 33100 nodes, 4194 on tree, -7580 best solution, best possible -8230 (317.95 seconds)
# Cbc0010I After 33200 nodes, 4171 on tree, -7580 best solution, best possible -8230 (318.46 seconds)
# Cbc0010I After 33300 nodes, 4153 on tree, -7580 best solution, best possible -8230 (319.03 seconds)
# Cbc0010I After 33400 nodes, 4124 on tree, -7580 best solution, best possible -8230 (319.48 seconds)
# Cbc0010I After 33500 nodes, 4099 on tree, -7580 best solution, best possible -8230 (320.10 seconds)
# Cbc0010I After 33600 nodes, 4070 on tree, -7580 best solution, best possible -8230 (320.69 seconds)
# Cbc0010I After 33700 nodes, 4059 on tree, -7580 best solution, best possible -8230 (321.46 seconds)
# Cbc0010I After 33800 nodes, 4044 on tree, -7580 best solution, best possible -8230 (322.16 seconds)
# Cbc0010I After 33900 nodes, 4038 on tree, -7580 best solution, best possible -8230 (322.87 seconds)
# Cbc0010I After 34000 nodes, 4023 on tree, -7580 best solution, best possible -8230 (323.43 seconds)
# Cbc0010I After 34100 nodes, 4045 on tree, -7580 best solution, best possible -8230 (324.28 seconds)
# Cbc0010I After 34200 nodes, 4055 on tree, -7580 best solution, best possible -8230 (328.06 seconds)
# Cbc0010I After 34300 nodes, 4073 on tree, -7580 best solution, best possible -8230 (328.82 seconds)
# Cbc0010I After 34400 nodes, 4065 on tree, -7580 best solution, best possible -8230 (329.57 seconds)
# Cbc0010I After 34500 nodes, 4071 on tree, -7580 best solution, best possible -8230 (330.29 seconds)
# Cbc0010I After 34600 nodes, 4089 on tree, -7580 best solution, best possible -8230 (330.96 seconds)
# Cbc0010I After 34700 nodes, 4102 on tree, -7580 best solution, best possible -8230 (331.65 seconds)
# Cbc0010I After 34800 nodes, 4116 on tree, -7580 best solution, best possible -8230 (332.31 seconds)
# Cbc0010I After 34900 nodes, 4132 on tree, -7580 best solution, best possible -8230 (333.01 seconds)
# Cbc0010I After 35000 nodes, 4157 on tree, -7580 best solution, best possible -8230 (333.70 seconds)
# Cbc0010I After 35100 nodes, 4178 on tree, -7580 best solution, best possible -8230 (334.38 seconds)
# Cbc0010I After 35200 nodes, 4198 on tree, -7580 best solution, best possible -8230 (334.97 seconds)
# Cbc0010I After 35300 nodes, 4225 on tree, -7580 best solution, best possible -8230 (335.74 seconds)
# Cbc0010I After 35400 nodes, 4256 on tree, -7580 best solution, best possible -8230 (336.42 seconds)
# Cbc0010I After 35500 nodes, 4285 on tree, -7580 best solution, best possible -8230 (337.22 seconds)
# Cbc0010I After 35600 nodes, 4314 on tree, -7580 best solution, best possible -8230 (337.92 seconds)
# Cbc0010I After 35700 nodes, 4344 on tree, -7580 best solution, best possible -8230 (338.67 seconds)
# Cbc0010I After 35800 nodes, 4354 on tree, -7580 best solution, best possible -8230 (339.41 seconds)
# Cbc0010I After 35900 nodes, 4362 on tree, -7580 best solution, best possible -8230 (340.13 seconds)
# Cbc0010I After 36000 nodes, 4380 on tree, -7580 best solution, best possible -8230 (340.82 seconds)
# Cbc0010I After 36100 nodes, 4393 on tree, -7580 best solution, best possible -8230 (341.56 seconds)
# Cbc0010I After 36200 nodes, 4409 on tree, -7580 best solution, best possible -8230 (342.36 seconds)
# Cbc0010I After 36300 nodes, 4416 on tree, -7580 best solution, best possible -8230 (343.06 seconds)
# Cbc0010I After 36400 nodes, 4425 on tree, -7580 best solution, best possible -8230 (343.82 seconds)
# Cbc0010I After 36500 nodes, 4414 on tree, -7580 best solution, best possible -8230 (344.51 seconds)
# Cbc0010I After 36600 nodes, 4393 on tree, -7580 best solution, best possible -8230 (345.24 seconds)
# Cbc0010I After 36700 nodes, 4396 on tree, -7580 best solution, best possible -8230 (346.01 seconds)
# Cbc0010I After 36800 nodes, 4394 on tree, -7580 best solution, best possible -8230 (346.85 seconds)
# Cbc0010I After 36900 nodes, 4423 on tree, -7580 best solution, best possible -8230 (347.58 seconds)
# Cbc0010I After 37000 nodes, 4462 on tree, -7580 best solution, best possible -8230 (348.38 seconds)
# Cbc0010I After 37100 nodes, 4441 on tree, -7580 best solution, best possible -8230 (349.00 seconds)
# Cbc0010I After 37200 nodes, 4422 on tree, -7580 best solution, best possible -8230 (349.76 seconds)
# Cbc0010I After 37300 nodes, 4404 on tree, -7580 best solution, best possible -8230 (350.38 seconds)
# Cbc0010I After 37400 nodes, 4397 on tree, -7580 best solution, best possible -8230 (351.08 seconds)
# Cbc0010I After 37500 nodes, 4378 on tree, -7580 best solution, best possible -8230 (351.61 seconds)
# Cbc0010I After 37600 nodes, 4365 on tree, -7580 best solution, best possible -8230 (352.26 seconds)
# Cbc0010I After 37700 nodes, 4358 on tree, -7580 best solution, best possible -8230 (353.07 seconds)
# Cbc0010I After 37800 nodes, 4349 on tree, -7580 best solution, best possible -8230 (353.77 seconds)
# Cbc0010I After 37900 nodes, 4339 on tree, -7580 best solution, best possible -8230 (354.40 seconds)
# Cbc0010I After 38000 nodes, 4326 on tree, -7580 best solution, best possible -8230 (355.11 seconds)
# Cbc0010I After 38100 nodes, 4352 on tree, -7580 best solution, best possible -8230 (355.92 seconds)
# Cbc0010I After 38200 nodes, 4374 on tree, -7580 best solution, best possible -8230 (356.65 seconds)
# Cbc0010I After 38300 nodes, 4383 on tree, -7580 best solution, best possible -8230 (357.44 seconds)
# Cbc0010I After 38400 nodes, 4377 on tree, -7580 best solution, best possible -8230 (358.28 seconds)
# Cbc0010I After 38500 nodes, 4377 on tree, -7580 best solution, best possible -8230 (359.01 seconds)
# Cbc0010I After 38600 nodes, 4395 on tree, -7580 best solution, best possible -8230 (362.80 seconds)
# Cbc0010I After 38700 nodes, 4426 on tree, -7580 best solution, best possible -8230 (363.64 seconds)
# Cbc0010I After 38800 nodes, 4450 on tree, -7580 best solution, best possible -8230 (364.53 seconds)
# Cbc0010I After 38900 nodes, 4474 on tree, -7580 best solution, best possible -8230 (365.29 seconds)
# Cbc0010I After 39000 nodes, 4507 on tree, -7580 best solution, best possible -8230 (366.21 seconds)
# Cbc0010I After 39100 nodes, 4525 on tree, -7580 best solution, best possible -8230 (366.94 seconds)
# Cbc0010I After 39200 nodes, 4550 on tree, -7580 best solution, best possible -8230 (367.78 seconds)
# Cbc0010I After 39300 nodes, 4578 on tree, -7580 best solution, best possible -8230 (368.57 seconds)
# Cbc0010I After 39400 nodes, 4610 on tree, -7580 best solution, best possible -8230 (369.35 seconds)
# Cbc0010I After 39500 nodes, 4614 on tree, -7580 best solution, best possible -8230 (370.12 seconds)
# Cbc0010I After 39600 nodes, 4616 on tree, -7580 best solution, best possible -8230 (370.92 seconds)
# Cbc0010I After 39700 nodes, 4633 on tree, -7580 best solution, best possible -8230 (371.63 seconds)
# Cbc0010I After 39800 nodes, 4639 on tree, -7580 best solution, best possible -8230 (372.47 seconds)
# Cbc0010I After 39900 nodes, 4620 on tree, -7580 best solution, best possible -8230 (373.27 seconds)
# Cbc0010I After 40000 nodes, 4620 on tree, -7580 best solution, best possible -8230 (374.21 seconds)
# Cbc0010I After 40100 nodes, 4621 on tree, -7580 best solution, best possible -8230 (375.05 seconds)
# Cbc0010I After 40200 nodes, 4632 on tree, -7580 best solution, best possible -8230 (375.71 seconds)
# Cbc0010I After 40300 nodes, 4655 on tree, -7580 best solution, best possible -8230 (376.49 seconds)
# Cbc0010I After 40400 nodes, 4678 on tree, -7580 best solution, best possible -8230 (377.22 seconds)
# Cbc0010I After 40500 nodes, 4693 on tree, -7580 best solution, best possible -8230 (377.90 seconds)
# Cbc0010I After 40600 nodes, 4709 on tree, -7580 best solution, best possible -8230 (378.62 seconds)
# Cbc0010I After 40700 nodes, 4734 on tree, -7580 best solution, best possible -8230 (379.38 seconds)
# Cbc0010I After 40800 nodes, 4759 on tree, -7580 best solution, best possible -8230 (380.07 seconds)
# Cbc0010I After 40900 nodes, 4767 on tree, -7580 best solution, best possible -8230 (380.61 seconds)
# Cbc0010I After 41000 nodes, 4781 on tree, -7580 best solution, best possible -8230 (381.18 seconds)
# Cbc0010I After 41100 nodes, 4769 on tree, -7580 best solution, best possible -8230 (381.68 seconds)
# Cbc0010I After 41200 nodes, 4755 on tree, -7580 best solution, best possible -8230 (382.24 seconds)
# Cbc0010I After 41300 nodes, 4740 on tree, -7580 best solution, best possible -8230 (382.80 seconds)
# Cbc0010I After 41400 nodes, 4730 on tree, -7580 best solution, best possible -8230 (383.47 seconds)
# Cbc0010I After 41500 nodes, 4727 on tree, -7580 best solution, best possible -8230 (384.16 seconds)
# Cbc0010I After 41600 nodes, 4723 on tree, -7580 best solution, best possible -8230 (384.77 seconds)
# Cbc0010I After 41700 nodes, 4711 on tree, -7580 best solution, best possible -8230 (385.31 seconds)
# Cbc0010I After 41800 nodes, 4701 on tree, -7580 best solution, best possible -8230 (385.91 seconds)
# Cbc0010I After 41900 nodes, 4691 on tree, -7580 best solution, best possible -8230 (386.40 seconds)
# Cbc0010I After 42000 nodes, 4681 on tree, -7580 best solution, best possible -8230 (387.02 seconds)
# Cbc0010I After 42100 nodes, 4707 on tree, -7580 best solution, best possible -8230 (387.76 seconds)
# Cbc0010I After 42200 nodes, 4723 on tree, -7580 best solution, best possible -8230 (388.38 seconds)
# Cbc0010I After 42300 nodes, 4741 on tree, -7580 best solution, best possible -8230 (389.10 seconds)
# Cbc0010I After 42400 nodes, 4757 on tree, -7580 best solution, best possible -8230 (389.84 seconds)
# Cbc0010I After 42500 nodes, 4766 on tree, -7580 best solution, best possible -8230 (390.56 seconds)
# Cbc0010I After 42600 nodes, 4762 on tree, -7580 best solution, best possible -8230 (391.21 seconds)
# Cbc0010I After 42700 nodes, 4765 on tree, -7580 best solution, best possible -8230 (391.92 seconds)
# Cbc0010I After 42800 nodes, 4781 on tree, -7580 best solution, best possible -8230 (392.60 seconds)
# Cbc0010I After 42900 nodes, 4790 on tree, -7580 best solution, best possible -8230 (393.27 seconds)
# Cbc0010I After 43000 nodes, 4794 on tree, -7580 best solution, best possible -8230 (393.89 seconds)
# Cbc0010I After 43100 nodes, 4810 on tree, -7580 best solution, best possible -8230 (394.56 seconds)
# Cbc0038I Full problem 1525 rows 1104 columns, reduced to 321 rows 162 columns
# Cbc0010I After 43200 nodes, 4825 on tree, -7580 best solution, best possible -8230 (398.17 seconds)
# Cbc0010I After 43300 nodes, 4848 on tree, -7580 best solution, best possible -8230 (398.76 seconds)
# Cbc0010I After 43400 nodes, 4881 on tree, -7580 best solution, best possible -8230 (399.45 seconds)
# Cbc0010I After 43500 nodes, 4894 on tree, -7580 best solution, best possible -8230 (399.95 seconds)
# Cbc0010I After 43600 nodes, 4918 on tree, -7580 best solution, best possible -8230 (400.52 seconds)
# Cbc0010I After 43700 nodes, 4938 on tree, -7580 best solution, best possible -8230 (401.15 seconds)
# Cbc0010I After 43800 nodes, 4959 on tree, -7580 best solution, best possible -8230 (401.74 seconds)
# Cbc0010I After 43900 nodes, 4986 on tree, -7580 best solution, best possible -8230 (402.58 seconds)
# Cbc0010I After 44000 nodes, 5007 on tree, -7580 best solution, best possible -8230 (403.37 seconds)
# Cbc0010I After 44100 nodes, 5030 on tree, -7580 best solution, best possible -8230 (404.15 seconds)
# Cbc0010I After 44200 nodes, 5063 on tree, -7580 best solution, best possible -8230 (404.88 seconds)
# Cbc0010I After 44300 nodes, 5088 on tree, -7580 best solution, best possible -8230 (405.71 seconds)
# Cbc0010I After 44400 nodes, 5118 on tree, -7580 best solution, best possible -8230 (406.52 seconds)
# Cbc0010I After 44500 nodes, 5147 on tree, -7580 best solution, best possible -8230 (407.27 seconds)
# Cbc0010I After 44600 nodes, 5172 on tree, -7580 best solution, best possible -8230 (407.97 seconds)
# Cbc0010I After 44700 nodes, 5184 on tree, -7580 best solution, best possible -8230 (408.67 seconds)
# Cbc0010I After 44800 nodes, 5193 on tree, -7580 best solution, best possible -8230 (409.43 seconds)
# Cbc0010I After 44900 nodes, 5205 on tree, -7580 best solution, best possible -8230 (410.20 seconds)
# Cbc0010I After 45000 nodes, 5222 on tree, -7580 best solution, best possible -8230 (411.02 seconds)
# Cbc0010I After 45100 nodes, 5207 on tree, -7580 best solution, best possible -8230 (411.83 seconds)
# Cbc0010I After 45200 nodes, 5182 on tree, -7580 best solution, best possible -8230 (412.45 seconds)
# Cbc0010I After 45300 nodes, 5167 on tree, -7580 best solution, best possible -8230 (413.09 seconds)
# Cbc0010I After 45400 nodes, 5144 on tree, -7580 best solution, best possible -8230 (413.82 seconds)
# Cbc0010I After 45500 nodes, 5121 on tree, -7580 best solution, best possible -8230 (414.52 seconds)
# Cbc0010I After 45600 nodes, 5111 on tree, -7580 best solution, best possible -8230 (415.26 seconds)
# Cbc0010I After 45700 nodes, 5087 on tree, -7580 best solution, best possible -8230 (415.83 seconds)
# Cbc0010I After 45800 nodes, 5076 on tree, -7580 best solution, best possible -8230 (416.65 seconds)
# Cbc0010I After 45900 nodes, 5066 on tree, -7580 best solution, best possible -8230 (417.51 seconds)
# Cbc0010I After 46000 nodes, 5057 on tree, -7580 best solution, best possible -8230 (418.21 seconds)
# Cbc0
