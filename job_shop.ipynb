# %%
import pulp as pl
import numpy as np
# from scipy.stats import multivariate_t

print("==============================================================================")

# Define the problem
model = pl.LpProblem("Maximize_Profit", pl.LpMaximize)

# Products, machines and days
subproducts = ['Ciasto_na_chleb_domowy_0_5kg', 'Ciasto_na_chleb_domowy_0_9kg', 'Ciasto_na_chleb_na_zakwasie', 'Ciasto_na_bulki', 'Ciasto_na_bagietki', 'Ciasto_na_rogaliki_z_czekolada']
products = ['Chleb_domowy_0_5kg', 'Chleb_domowy_0_9kg', 'Chleb_na_zakwasie', 'Bulki', 'Bagietki', 'Rogaliki_z_czekolada']
days = ['Pon', 'Wt', 'Sr']
sub_machines = ['Dzieza', 'Wazenie', 'Dzielarka', 'Tabula', 'Rogalikarka', 'Nadziewarka']
machines = ['Garownia', 'Piec', 'Studzenie', 'Pakowanie']

# Income from product sales and production cost in PLN/piece
product_income = {'Chleb_domowy_0_5kg': 5.2, 'Chleb_domowy_0_9kg': 7.9, 'Chleb_na_zakwasie': 6.2, 'Bulki': 1.4, 'Bagietki': 1.55, 'Rogaliki_z_czekolada': 2.1}
sub_product_cost = {'Ciasto_na_chleb_domowy_0_5kg': 1.6, 'Ciasto_na_chleb_domowy_0_9kg': 2.0, 'Ciasto_na_chleb_na_zakwasie': 2.0, 'Ciasto_na_bulki': 0.5, 'Ciasto_na_bagietki': 0.6, 'Ciasto_na_rogaliki_z_czekolada': 1.0}
product_cost = {'Chleb_domowy_0_5kg': 0.8, 'Chleb_domowy_0_9kg': 0.9, 'Chleb_na_zakwasie': 0.8, 'Bulki': 0.2, 'Bagietki': 0.2, 'Rogaliki_z_czekolada': 0.2}

# Time available
shifts_per_day = 2
hours_per_shift = 10
hours_per_day = shifts_per_day * hours_per_shift

max_batches = 1
large_number = 10000

sub_production_times = {
    'Ciasto_na_chleb_domowy_0_5kg': {'Dzieza': 4.7, 'Wazenie': 0.29, 'Dzielarka': 0.0, 'Tabula': 0.7, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_domowy_0_9kg': {'Dzieza': 5, 'Wazenie': 0.2, 'Dzielarka': 0.0, 'Tabula': 0.55, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_chleb_na_zakwasie': {'Dzieza': 8.6, 'Wazenie': 0.22, 'Dzielarka': 0.0, 'Tabula': 0.6, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bulki': {'Dzieza': 1, 'Wazenie': 0.0, 'Dzielarka': 0.23, 'Tabula': 0.34, 'Rogalikarka': 0.0, 'Nadziewarka': 0.0},
    'Ciasto_na_bagietki': {'Dzieza': 0.95, 'Wazenie': 0.0, 'Dzielarka': 0.24, 'Tabula': 0.0, 'Rogalikarka': 0.28, 'Nadziewarka': 0.0},
    'Ciasto_na_rogaliki_z_czekolada': {'Dzieza': 0.55, 'Wazenie': 0.0, 'Dzielarka': 0.28, 'Tabula': 0.0, 'Rogalikarka': 0.31, 'Nadziewarka': 0.4}
}

production_times = {
    'Chleb_domowy_0_5kg': {'Garownia': 1.0, 'Piec': 0.68, 'Studzenie': 1.8, 'Pakowanie': 0.56},
    'Chleb_domowy_0_9kg': {'Garownia': 1.5, 'Piec': 1.2, 'Studzenie': 2.5, 'Pakowanie': 0.57},
    'Chleb_na_zakwasie': {'Garownia': 1.4, 'Piec': 1.0, 'Studzenie': 2.3, 'Pakowanie': 0.6},
    'Bulki': {'Garownia': 0.38, 'Piec': 0.25, 'Studzenie': 0.48, 'Pakowanie': 0.0},
    'Bagietki': {'Garownia': 0.33, 'Piec': 0.23, 'Studzenie': 0.42, 'Pakowanie': 0.0},
    'Rogaliki_z_czekolada': {'Garownia': 0.25, 'Piec': 0.18, 'Studzenie': 0.82, 'Pakowanie': 0.42}
}


batch_size = {
    "Ciasto_na_chleb_domowy_0_5kg": 240,
    "Ciasto_na_chleb_domowy_0_9kg": 130,
    "Ciasto_na_chleb_na_zakwasie": 200,
    "Ciasto_na_bulki": 200,
    "Ciasto_na_bagietki": 200,
    "Ciasto_na_rogaliki_z_czekolada": 200,
    "Chleb_domowy_0_5kg": 240,
    "Chleb_domowy_0_9kg": 130,
    "Chleb_na_zakwasie": 200,
    "Bulki": 200,
    "Bagietki": 200,
    "Rogaliki_z_czekolada": 200,
}

market_limits = {
    "Chleb_domowy_0_5kg": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 420, "Pt": 530, "Sob": 680},
    "Chleb_domowy_0_9kg": {"Pon": 100, "Wt": 100, "Sr": 380, "Czw": 150, "Pt": 250, "Sob": 580},
    "Chleb_na_zakwasie": {"Pon": 100, "Wt": 100, "Sr": 320, "Czw": 180, "Pt": 280, "Sob": 418},
    "Bulki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 530, "Pt": 650, "Sob": 580},
    "Bagietki": {"Pon": 100, "Wt": 100, "Sr": 100, "Czw": 350, "Pt": 650, "Sob": 680},
    "Rogaliki_z_czekolada": {"Pon": 100, "Wt": 100, "Sr": 240, "Czw": 310, "Pt": 400, "Sob": 280},
}

# Machines cost
fridge_cost_per_day = 0.281 * 24 * 1.4 * 0.2 # kW * 24h * price per hour * factor
furnace_cost_per_hour = 82.4 # https://giko.pl/kalkulator-zuzycia-energii-dla-piecow-piekarniczych/


fridge_count = 10
fridge_capacity = 160
end_stock = 0
storage_capacity = fridge_count * fridge_capacity

# Variables for production, sales, and storage of products each day
sub_production_vars = pl.LpVariable.dicts("Subproduct production", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
production_vars = pl.LpVariable.dicts("Production", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# batch_count_vars = pl.LpVariable.dicts("Batches Count", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# subbatch_count_vars = pl.LpVariable.dicts("Subproduct Batches Count", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, cat='Integer')
product_batch_start_time = pl.LpVariable.dicts("ProductStartTime",  [(product, machine, day) for product in products for machine in machines for day in days], lowBound=0, cat="Continuous")
subproduct_batch_start_time = pl.LpVariable.dicts("Subproduction start time for batch",  [(subproduct, machine, day) for subproduct in subproducts for machine in sub_machines for day in days], lowBound=0, cat="Continuous")
sales_vars = pl.LpVariable.dicts("Sales", ((product, day) for product in products for day in days), lowBound=0, cat='Integer')
# specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, idx) for (machine, idx) in specific_machines], cat="Binary")
# subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, day, batch) for subproduct in subproducts for day in days for batch in range(1, max_batches + 1)], cat="Binary")
subbatch_produced = pl.LpVariable.dicts("BatchProducedSubproduct", [(subproduct, day) for subproduct in subproducts for day in days], cat="Binary")
batch_produced = pl.LpVariable.dicts("BatchProduced", [(product, day) for product in products for day in days], cat="Binary")
specific_sub_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, subproduct, day) for machine in sub_machines for subproduct in subproducts for day in days], cat="Binary")
specific_machine_used = pl.LpVariable.dicts("SpecificMachineUsed", [(machine, product, day) for machine in machines for product in products for day in days], cat="Binary")
storage_vars = pl.LpVariable.dicts("Storage", ((subproduct, day) for subproduct in subproducts for day in days), lowBound=0, upBound=storage_capacity, cat='Integer')
fridge_count_usage_vars = pl.LpVariable.dicts("FridgeCount", ((day) for day in days), lowBound=0, upBound=fridge_count, cat='Integer')
all_from_storage = pl.LpVariable.dicts("AllFromStorage", [(subproduct, day) for subproduct in subproducts for day in days], cat="Binary")


# xij = pl.LpVariable.dicts("xij", [(machine, idx, i, j) for (machine, idx) in specific_machines for i in subproducts for j in subproducts if i != j], 0, 1, pl.LpBinary)
is_produced_sub = pl.LpVariable.dicts("is_produced",
                                     ((subproduct, machine, day) for subproduct in subproducts
                                                                      for machine in sub_machines
                                                                      for day in days),
                                     cat="Binary")
is_produced = pl.LpVariable.dicts("is_produced",
                                     ((product, machine, day) for product in products
                                                                      for machine in machines
                                                                      for day in days),
                                     cat="Binary")

for subproduct in subproducts:
    for day in days:
        for i, machine in enumerate(sub_machines[1:], start=1):  # Od ważenia do nadziewarki
            prev = 1
            prev_machine = sub_machines[i - prev]

            while sub_production_times[subproduct][prev_machine] == 0.0 or prev_machine == machine:
                prev += 1
                prev_machine = sub_machines[i - prev]

            model += subproduct_batch_start_time[subproduct, machine, day] >= (
                subproduct_batch_start_time[subproduct, prev_machine, day] + sub_production_times[subproduct][prev_machine]
            )

            model += subproduct_batch_start_time[subproduct, machine, day] <= specific_sub_machine_used[machine, subproduct, day] * hours_per_day

        last_machine = sub_machines[-1]
        model += hours_per_day >= (
            subproduct_batch_start_time[subproduct, last_machine, day] + sub_production_times[subproduct][last_machine]
        )

for product in products:
    for day in days:
        for i, machine in enumerate(machines[1:], start=1):  # Od ważenia do nadziewarki
            prev = 1
            prev_machine = machines[i - prev]

            while production_times[product][prev_machine] == 0.0 or prev_machine == machine:
                prev += 1
                prev_machine = machines[i - prev]

            model += product_batch_start_time[product, machine, day] >= (
                product_batch_start_time[product, prev_machine, day] + production_times[product][prev_machine]
            )

            model += product_batch_start_time[product, machine, day] <= specific_machine_used[machine, product, day] * hours_per_day

        last_machine = machines[-1]
        model += hours_per_day >= (
            product_batch_start_time[product, last_machine, day] + production_times[product][last_machine]
        )
'''
        model += subbatch_produced[subproduct, day] * large_number >= subproduct_batch_start_time[subproduct, last_machine, last_idx, day]

        # Brak nakładania się produkcji na maszynie
        for machine, idx in specific_machines[:6]:  # Zakres maszyn
            for subproduct1 in subproducts:
                for subproduct2 in subproducts:
                    if subproduct1 != subproduct2:
                        model += (subproduct_batch_start_time[subproduct1, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct2, machine, idx, day] + production_times[subproduct2][machine]) | \
                                 (subproduct_batch_start_time[subproduct2, machine, idx, day]
                                  >= subproduct_batch_start_time[subproduct1, machine, idx, day] + production_times[subproduct1][machine])

                        # model += specific_machine_used[machine, idx, subproduct1, day] + specific_machine_used[machine, idx, subproduct2, day] <= 1
'''
# Ograniczenie: produkcja subproduktu tylko na maszynach, gdzie czas produkcji > 0
for subproduct in subproducts:
    for machine in sub_machines:
        for day in days:
            if sub_production_times[subproduct][machine] == 0:
                model += is_produced_sub[subproduct, machine, day] == 0

# Ograniczenie: produkcja produktu tylko na maszynach, gdzie czas produkcji > 0
for product in products:
    for machine in machines:
        for day in days:
            if production_times[product][machine] == 0:
                model += is_produced[product, machine, day] == 0
                

# Warunek: jeśli subprodukt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for subproduct in subproducts:
    machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for machine in machines_with_production:
                    model += pl.lpSum(is_produced_sub[subproduct, m, day] for m in machines_with_production) == \
                            len(machines_with_production) * is_produced_sub[subproduct, machine, day]
        
            # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
            model += subbatch_produced[subproduct, day] <= pl.lpSum(is_produced_sub[subproduct, machine, day] for machine in machines_with_production)
            model += subbatch_produced[subproduct, day] >= is_produced_sub[subproduct, machines_with_production[0], day]

# Warunek: jeśli produkt jest produkowany, to na wszystkich maszynach (z czasem > 0)
for product in products:
    machines_with_production = [machine for machine in machines if production_times[product][machine] > 0]
    for day in days:
        if machines_with_production:
            # Ograniczenie wymuszające produkcję na wszystkich maszynach albo na żadnej
            for machine in machines_with_production:
                    model += pl.lpSum(is_produced[product, m, day] for m in machines_with_production) == \
                            len(machines_with_production) * is_produced[product, machine, day]
        
            # pozowolenie subbatch_produced na wartość 1 jeżeli na maszyny działały dla danego wyrobu
            model += batch_produced[product, day] <= pl.lpSum(is_produced[product, machine, day] for machine in machines_with_production)
            model += batch_produced[product, day] >= is_produced[product, machines_with_production[0], day]

# Aktualizacja ograniczenia: brak nakładania się produkcji
big_M = 1000000
for subproduct1 in subproducts:
    for subproduct2 in subproducts:
        if subproduct1 != subproduct2:
            machines_with_production = [machine for machine in sub_machines if sub_production_times[subproduct1][machine] > 0 and sub_production_times[subproduct2][machine] > 0]
            for machine in machines_with_production: 
                for day in days:
                    # Dodanie binarnych zmiennych pomocniczych
                    y0 = pl.LpVariable(f"y0_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y1 = pl.LpVariable(f"y1_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y2 = pl.LpVariable(f"y2_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y3 = pl.LpVariable(f"y3_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")
                    y4 = pl.LpVariable(f"y4_{subproduct1}_{subproduct2}_{machine}_{day}", cat="Binary")

                    # Powiązanie warunków logicznych z binarnymi zmiennymi
                    model += subproduct_batch_start_time[subproduct1, machine, day] >= \
                                subproduct_batch_start_time[subproduct2, machine, day] + sub_production_times[subproduct2][machine] - \
                                big_M * (1 - y1)
                    
                    model += subproduct_batch_start_time[subproduct2, machine, day] >= \
                                subproduct_batch_start_time[subproduct1, machine, day] + sub_production_times[subproduct1][machine] - \
                                big_M * (1 - y2)

                    model += is_produced_sub[subproduct1, machine, day] + y3 == 1
                    model += is_produced_sub[subproduct2, machine, day] + y4 == 1

                    model += y0 <= 1 - is_produced_sub[subproduct1, machine, day]
                    model += y0 <= 1 - is_produced_sub[subproduct2, machine, day]

                    # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                    model += y0 + y1 + y2 + y3 + y4 == 1

for product1 in products:
    for product2 in products:
        if product1 != product2:
            machines_with_production = [machine for machine in machines if production_times[product1][machine] > 0 and production_times[product2][machine] > 0]
            for machine in machines_with_production: 
                for day in days:
                    # Dodanie binarnych zmiennych pomocniczych
                    y0 = pl.LpVariable(f"y0_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y1 = pl.LpVariable(f"y1_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y2 = pl.LpVariable(f"y2_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y3 = pl.LpVariable(f"y3_{product1}_{product2}_{machine}_{day}", cat="Binary")
                    y4 = pl.LpVariable(f"y4_{product1}_{product2}_{machine}_{day}", cat="Binary")

                    # Powiązanie warunków logicznych z binarnymi zmiennymi
                    model += product_batch_start_time[product1, machine, day] >= \
                                product_batch_start_time[product2, machine, day] + production_times[product2][machine] - \
                                big_M * (1 - y1)
                    
                    model += product_batch_start_time[product2, machine, day] >= \
                                product_batch_start_time[product1, machine, day] + production_times[product1][machine] - \
                                big_M * (1 - y2)

                    model += is_produced[product1, machine, day] + y3 == 1
                    model += is_produced[product2, machine, day] + y4 == 1

                    model += y0 <= 1 - is_produced[product1, machine, day]
                    model += y0 <= 1 - is_produced[product2, machine, day]

                    # Zapewnienie, że przynajmniej jedno ograniczenie jest spełnione
                    model += y0 + y1 + y2 + y3 + y4 == 1

M = 1000
for subproduct, product in zip(subproducts, products):
    model += storage_vars[subproduct, 'Pon'] == sub_production_vars[subproduct, 'Pon'] - production_vars[product, 'Pon']
    model += product_batch_start_time[product, machines[0], 'Pon'] >= (subproduct_batch_start_time[subproduct, sub_machines[-1], 'Pon']) + sub_production_times[subproduct][sub_machines[-1]]
    for i in range(1, len(days)):
        day = days[i]
        # prev_day = days[i-1]
        # model += storage_vars[subproduct, day] == storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day]
        # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
        # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
        # model += storage_vars[subproduct, day] == all_from_storage[product, day] * (storage_vars[subproduct, prev_day] - production_vars[product, day]) + (1 - all_from_storage[product, day]) * (storage_vars[subproduct, prev_day] + sub_production_vars[subproduct, day] - production_vars[product, day])
        model += product_batch_start_time[product, machines[0], day] >= (subproduct_batch_start_time[subproduct, sub_machines[-1], day]) + sub_production_times[subproduct][sub_machines[-1]] - M * all_from_storage[subproduct, day]

expr1 = pl.LpVariable.dicts("expr1", [(s, d) for s in subproducts for d in days], lowBound=0)
expr2 = pl.LpVariable.dicts("expr2", [(s, d) for s in subproducts for d in days], lowBound=0)

# Dodaj ograniczenia dla zmiennych pomocniczych
for s, p in zip(subproducts, products):
    all_from_storage[s, 'Pon'] = 0
    for i in range(1, len(days)):
        d = days[i]
        prev_day = days[i-1]
        model += expr1[s, d] >= storage_vars[s, prev_day] - production_vars[p, d] - M * (1 - all_from_storage[s, d])
        model += expr1[s, d] <= storage_vars[s, prev_day] - production_vars[p, d]
        model += expr1[s, d] <= M * all_from_storage[s, d]
        model += expr1[s, d] >= 0
        
        model += expr2[s, d] >= storage_vars[s, prev_day] + sub_production_vars[s, d] - production_vars[p, d] - M * all_from_storage[s, d]
        model += expr2[s, d] <= storage_vars[s, prev_day] + sub_production_vars[s, d] - production_vars[p, d]
        model += expr2[s, d] <= M * (1 - all_from_storage[s, d])
        model += expr2[s, d] >= 0

        # Ograniczenie
        model += storage_vars[s, d] == expr1[s, d] + expr2[s, d]


for day in days:
    model += storage_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)
    model += fridge_count_usage_vars[day] * fridge_capacity >= sum(storage_vars[subproduct, day] for subproduct in subproducts)

for product, subproduct in zip(products, subproducts):
    for day in days:
        model += batch_produced[product, day] * batch_size[product] >= production_vars[product, day]
        model += production_vars[product, day] >= batch_produced[product, day]
        model += subbatch_produced[subproduct, day] * batch_size[subproduct] >= sub_production_vars[subproduct, day]
        model += sub_production_vars[subproduct, day] >= subbatch_produced[subproduct, day]

        # model += sub_production_vars[subproduct, day] >= production_vars[product, day]
        model += sales_vars[product, day] == production_vars[product, day]
    model += sales_vars[product, 'Sr'] >= 0.2*market_limits[product]['Wt'], f"Max_sales_{product}_{'Sr'}"


# Objective function: Maximize profit from sales minus costs
model += pl.lpSum([sales_vars[product, day] * product_income[product] for product in products for day in days]) \
                    - pl.lpSum([production_vars[product, day] * product_cost[product] for product in products for day in days]) \
                    - pl.lpSum([sub_production_vars[subproduct, day] * sub_product_cost[subproduct] for subproduct in subproducts for day in days]) \
                    - pl.lpSum([fridge_count_usage_vars[day] * fridge_cost_per_day for day in days]) \
                    - pl.lpSum([batch_produced[product, day] * production_times[product]['Piec'] * furnace_cost_per_hour for product in products for day in days]), "Total_Profit"


solver = pl.PULP_CBC_CMD(timeLimit=60)

model.solve(solver)

# model.solve()

# Results
print("Status:", pl.LpStatus[model.status])
if pl.LpStatus[model.status] == 'Optimal':
    print("Total Profit:", pl.value(model.objective))

    print(f"{'Product':<10} {'day':<10} {'SubProduction':<10} {'Production':<12} {'Sales':<10} {'Storage':<10}")

    for product, subproduct in zip(products, subproducts):
        for day in days:
            subproduction = sub_production_vars[subproduct, day].varValue
            production = production_vars[product, day].varValue
            sales = sales_vars[product, day].varValue
            storage = storage_vars[subproduct, day].varValue

            print(f"{product:<10} {day:<10} {subproduction:<12} {production:<12} {sales:<10} {storage:<10}")

    # print("\nProduction Time Usage per Product and Day:")
    # for day in days:
    #     print(f"\Day: {day}")
    #     for product in products:
    #         total_production_time = sum(
    #             batch_count_vars[product, day].varValue * production_times[product]s.get(machine, 0) 
    #             for machine in machines #.keys()
    #         )
    #         print(f"  Product: {product}, Total Production Time: {total_production_time:.2f} hours")

else:
    print("No optimal solution was found.")
    # Analiza ograniczeń
    for name, constraint in model.constraints.items():
        if constraint.pi < 0:
            print(f"Ograniczenie {name}: {constraint}")
# Out:
# ==============================================================================
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gromiusz/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2cb559054f9d43eaa64a28dbae24f29a-pulp.mps -max -sec 60 -timeMode elapsed -branch -printingOptions all -solution /tmp/2cb559054f9d43eaa64a28dbae24f29a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 4133 COLUMNS
# At line 20769 RHS
# At line 24898 BOUNDS
# At line 27716 ENDATA
# Problem MODEL has 4128 rows, 3021 columns and 10926 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 60
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 4346.04 - 0.02 seconds
# Cgl0002I 57 variables fixed
# Cgl0003I 502 fixed, 12 tightened bounds, 1496 strengthened rows, 504 substitutions
# Cgl0003I 0 fixed, 6 tightened bounds, 579 strengthened rows, 127 substitutions
# Cgl0003I 7 fixed, 0 tightened bounds, 761 strengthened rows, 34 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 103 strengthened rows, 0 substitutions
# Cgl0003I 3 fixed, 0 tightened bounds, 146 strengthened rows, 13 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 34 strengthened rows, 13 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 28 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 6 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1539 rows, 1029 columns (867 integer (816 of which binary)) and 6871 elements
# Cbc0038I Initial state - 290 integers unsatisfied sum - 39.2986
# Cbc0038I Pass   1: suminf.   21.80329 (252) obj. -2719.3 iterations 263
# Cbc0038I Pass   2: suminf.   20.90333 (257) obj. -2719.32 iterations 12
# Cbc0038I Pass   3: suminf.   15.64377 (210) obj. -2682.96 iterations 38
# Cbc0038I Pass   4: suminf.   15.64377 (210) obj. -2682.96 iterations 3
# Cbc0038I Pass   5: suminf.   12.57110 (193) obj. -2041.07 iterations 88
# Cbc0038I Pass   6: suminf.   11.42483 (163) obj. -2013.89 iterations 68
# Cbc0038I Pass   7: suminf.   10.68727 (150) obj. -2003.4 iterations 51
# Cbc0038I Pass   8: suminf.    6.98541 (109) obj. -1797.73 iterations 94
# Cbc0038I Pass   9: suminf.    6.98541 (109) obj. -1797.73 iterations 0
# Cbc0038I Pass  10: suminf.    5.88565 (101) obj. -1671.23 iterations 42
# Cbc0038I Pass  11: suminf.    5.66100 (93) obj. -1671.23 iterations 40
# Cbc0038I Pass  12: suminf.    5.66100 (93) obj. -1671.23 iterations 0
# Cbc0038I Pass  13: suminf.    4.02350 (78) obj. -1671.23 iterations 38
# Cbc0038I Pass  14: suminf.    4.02350 (80) obj. -1671.23 iterations 0
# Cbc0038I Pass  15: suminf.    4.23733 (53) obj. -1661.65 iterations 45
# Cbc0038I Pass  16: suminf.    1.29331 (24) obj. -1781.5 iterations 69
# Cbc0038I Pass  17: suminf.    1.29331 (24) obj. -1781.5 iterations 2
# Cbc0038I Pass  18: suminf.    1.32598 (18) obj. -1781.5 iterations 34
# Cbc0038I Pass  19: suminf.    1.10809 (20) obj. -1781.5 iterations 27
# Cbc0038I Pass  20: suminf.    1.10809 (22) obj. -1781.5 iterations 2
# Cbc0038I Pass  21: suminf.    1.32407 (18) obj. -1781.5 iterations 26
# Cbc0038I Pass  22: suminf.    1.38975 (20) obj. -1781.5 iterations 28
# Cbc0038I Pass  23: suminf.    1.48213 (22) obj. -1781.5 iterations 35
# Cbc0038I Pass  24: suminf.    1.41522 (21) obj. -1781.5 iterations 32
# Cbc0038I Pass  25: suminf.    1.40833 (20) obj. -1781.5 iterations 32
# Cbc0038I Pass  26: suminf.    1.46428 (22) obj. -1781.5 iterations 33
# Cbc0038I Pass  27: suminf.    1.40188 (20) obj. -1781.5 iterations 36
# Cbc0038I Pass  28: suminf.    1.43656 (20) obj. -1781.5 iterations 32
# Cbc0038I Pass  29: suminf.   18.70972 (192) obj. -1699.76 iterations 224
# Cbc0038I Pass  30: suminf.   14.27851 (234) obj. -1697.27 iterations 129
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 317 integers at bound fixed and 11 continuous of which 9 were internal integer and 0 internal continuous
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 837 rows 425 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (4.08 seconds)
# Cbc0038I After 4.08 seconds - Feasibility pump exiting - took 0.10 seconds
# Cbc0031I 159 added rows had average density of 14.918239
# Cbc0013I At root node, 159 cuts changed objective from -3605.9244 to -3587.5073 in 23 passes
# Cbc0014I Cut generator 0 (Probing) - 759 row cuts average 2.7 elements, 0 column cuts (0 active)  in 0.092 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 613 row cuts average 32.2 elements, 0 column cuts (0 active)  in 0.077 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 33 row cuts average 8.9 elements, 0 column cuts (0 active)  in 0.032 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 244 row cuts average 3.7 elements, 0 column cuts (0 active)  in 0.021 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 52 row cuts average 2.2 elements, 0 column cuts (0 active)  in 0.025 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 1027 row cuts average 26.7 elements, 0 column cuts (0 active)  in 0.055 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible -3587.5073 (4.80 seconds)
# Cbc0010I After 100 nodes, 42 on tree, 1e+50 best solution, best possible -3587.5073 (8.12 seconds)
# Cbc0010I After 200 nodes, 69 on tree, 1e+50 best solution, best possible -3587.5073 (8.81 seconds)
# Cbc0010I After 300 nodes, 79 on tree, 1e+50 best solution, best possible -3587.5073 (9.19 seconds)
# Cbc0010I After 400 nodes, 89 on tree, 1e+50 best solution, best possible -3587.5073 (9.63 seconds)
# Cbc0010I After 500 nodes, 94 on tree, 1e+50 best solution, best possible -3587.5073 (10.04 seconds)
# Cbc0010I After 600 nodes, 101 on tree, 1e+50 best solution, best possible -3587.5073 (10.38 seconds)
# Cbc0010I After 700 nodes, 115 on tree, 1e+50 best solution, best possible -3587.5073 (10.75 seconds)
# Cbc0010I After 800 nodes, 125 on tree, 1e+50 best solution, best possible -3587.5073 (11.10 seconds)
# Cbc0010I After 900 nodes, 131 on tree, 1e+50 best solution, best possible -3587.5073 (11.49 seconds)
# Cbc0010I After 1000 nodes, 105 on tree, 1e+50 best solution, best possible -3587.5073 (11.73 seconds)
# Cbc0012I Integer solution of -2211.1938 found by rounding after 26259 iterations and 1076 nodes (13.15 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 23 rows 12 columns
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 471 rows 241 columns
# Cbc0010I After 1100 nodes, 127 on tree, -2211.1938 best solution, best possible -3586.661 (13.40 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 412 rows 201 columns
# Cbc0010I After 1200 nodes, 170 on tree, -2211.1938 best solution, best possible -3586.661 (14.29 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 415 rows 206 columns
# Cbc0010I After 1300 nodes, 193 on tree, -2211.1938 best solution, best possible -3586.661 (14.77 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 412 rows 200 columns
# Cbc0010I After 1400 nodes, 226 on tree, -2211.1938 best solution, best possible -3586.661 (15.21 seconds)
# Cbc0012I Integer solution of -2850.3288 found by rounding after 38431 iterations and 1463 nodes (15.42 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 470 rows 246 columns
# Cbc0010I After 1500 nodes, 81 on tree, -2850.3288 best solution, best possible -3586.661 (15.88 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 478 rows 232 columns
# Cbc0010I After 1600 nodes, 122 on tree, -2850.3288 best solution, best possible -3586.661 (17.18 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 544 rows 246 columns
# Cbc0010I After 1700 nodes, 153 on tree, -2850.3288 best solution, best possible -3586.661 (18.26 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 450 rows 231 columns
# Cbc0010I After 1800 nodes, 163 on tree, -2850.3288 best solution, best possible -3586.661 (19.50 seconds)
# Cbc0010I After 1900 nodes, 169 on tree, -2850.3288 best solution, best possible -3586.661 (19.89 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 275 rows 135 columns
# Cbc0010I After 2000 nodes, 213 on tree, -2850.3288 best solution, best possible -3586.661 (20.28 seconds)
# Cbc0010I After 2100 nodes, 256 on tree, -2850.3288 best solution, best possible -3586.661 (20.65 seconds)
# Cbc0010I After 2200 nodes, 300 on tree, -2850.3288 best solution, best possible -3586.661 (21.05 seconds)
# Cbc0010I After 2300 nodes, 345 on tree, -2850.3288 best solution, best possible -3586.661 (21.48 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 371 rows 181 columns
# Cbc0010I After 2400 nodes, 391 on tree, -2850.3288 best solution, best possible -3586.661 (21.83 seconds)
# Cbc0010I After 2500 nodes, 427 on tree, -2850.3288 best solution, best possible -3586.661 (22.16 seconds)
# Cbc0010I After 2600 nodes, 462 on tree, -2850.3288 best solution, best possible -3586.661 (22.59 seconds)
# Cbc0010I After 2700 nodes, 498 on tree, -2850.3288 best solution, best possible -3586.661 (22.95 seconds)
# Cbc0010I After 2800 nodes, 534 on tree, -2850.3288 best solution, best possible -3586.661 (23.30 seconds)
# Cbc0010I After 2900 nodes, 569 on tree, -2850.3288 best solution, best possible -3586.661 (23.76 seconds)
# Cbc0004I Integer solution of -2872.3288 found after 104940 iterations and 2982 nodes (24.01 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 462 rows 226 columns
# Cbc0010I After 3000 nodes, 138 on tree, -2872.3288 best solution, best possible -3586.661 (24.20 seconds)
# Cbc0012I Integer solution of -2882.9054 found by rounding after 106011 iterations and 3030 nodes (24.37 seconds)
# Cbc0010I After 3100 nodes, 28 on tree, -2882.9054 best solution, best possible -3586.661 (24.92 seconds)
# Cbc0010I After 3200 nodes, 26 on tree, -2882.9054 best solution, best possible -3586.661 (25.58 seconds)
# Cbc0010I After 3300 nodes, 27 on tree, -2882.9054 best solution, best possible -3586.661 (26.00 seconds)
# Cbc0010I After 3400 nodes, 30 on tree, -2882.9054 best solution, best possible -3586.661 (26.55 seconds)
# Cbc0012I Integer solution of -2915.8654 found by rounding after 122279 iterations and 3448 nodes (26.76 seconds)
# Cbc0010I After 3500 nodes, 28 on tree, -2915.8654 best solution, best possible -3586.661 (27.12 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 480 rows 208 columns
# Cbc0010I After 3600 nodes, 37 on tree, -2915.8654 best solution, best possible -3586.661 (27.82 seconds)
# Cbc0010I After 3700 nodes, 33 on tree, -2915.8654 best solution, best possible -3586.661 (28.44 seconds)
# Cbc0010I After 3800 nodes, 33 on tree, -2915.8654 best solution, best possible -3586.661 (29.01 seconds)
# Cbc0010I After 3900 nodes, 36 on tree, -2915.8654 best solution, best possible -3586.661 (29.60 seconds)
# Cbc0010I After 4000 nodes, 29 on tree, -2915.8654 best solution, best possible -3586.661 (30.16 seconds)
# Cbc0010I After 4100 nodes, 32 on tree, -2915.8654 best solution, best possible -3586.661 (30.86 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 357 rows 170 columns
# Cbc0010I After 4200 nodes, 29 on tree, -2915.8654 best solution, best possible -3586.661 (31.51 seconds)
# Cbc0010I After 4300 nodes, 27 on tree, -2915.8654 best solution, best possible -3586.661 (32.01 seconds)
# Cbc0010I After 4400 nodes, 26 on tree, -2915.8654 best solution, best possible -3586.661 (32.44 seconds)
# Cbc0010I After 4500 nodes, 39 on tree, -2915.8654 best solution, best possible -3586.661 (32.97 seconds)
# Cbc0010I After 4600 nodes, 29 on tree, -2915.8654 best solution, best possible -3586.661 (33.47 seconds)
# Cbc0010I After 4700 nodes, 31 on tree, -2915.8654 best solution, best possible -3586.661 (33.96 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 464 rows 234 columns
# Cbc0010I After 4800 nodes, 29 on tree, -2915.8654 best solution, best possible -3586.661 (34.75 seconds)
# Cbc0010I After 4900 nodes, 27 on tree, -2915.8654 best solution, best possible -3586.661 (35.42 seconds)
# Cbc0010I After 5000 nodes, 32 on tree, -2915.8654 best solution, best possible -3586.661 (39.74 seconds)
# Cbc0010I After 5100 nodes, 28 on tree, -2915.8654 best solution, best possible -3586.661 (40.24 seconds)
# Cbc0010I After 5200 nodes, 26 on tree, -2915.8654 best solution, best possible -3586.661 (40.79 seconds)
# Cbc0010I After 5300 nodes, 26 on tree, -2915.8654 best solution, best possible -3586.661 (41.46 seconds)
# Cbc0010I After 5400 nodes, 23 on tree, -2915.8654 best solution, best possible -3586.661 (42.05 seconds)
# Cbc0010I After 5500 nodes, 25 on tree, -2915.8654 best solution, best possible -3586.661 (42.61 seconds)
# Cbc0010I After 5600 nodes, 25 on tree, -2915.8654 best solution, best possible -3586.661 (43.25 seconds)
# Cbc0010I After 5700 nodes, 27 on tree, -2915.8654 best solution, best possible -3586.661 (43.85 seconds)
# Cbc0010I After 5800 nodes, 26 on tree, -2915.8654 best solution, best possible -3586.661 (44.41 seconds)
# Cbc0010I After 5900 nodes, 23 on tree, -2915.8654 best solution, best possible -3586.661 (45.03 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 423 rows 216 columns
# Cbc0010I After 6000 nodes, 22 on tree, -2915.8654 best solution, best possible -3586.661 (45.64 seconds)
# Cbc0010I After 6100 nodes, 13 on tree, -2915.8654 best solution, best possible -3586.661 (46.11 seconds)
# Cbc0010I After 6200 nodes, 18 on tree, -2915.8654 best solution, best possible -3586.661 (46.79 seconds)
# Cbc0010I After 6300 nodes, 19 on tree, -2915.8654 best solution, best possible -3586.661 (47.44 seconds)
# Cbc0010I After 6400 nodes, 17 on tree, -2915.8654 best solution, best possible -3586.661 (48.06 seconds)
# Cbc0010I After 6500 nodes, 17 on tree, -2915.8654 best solution, best possible -3586.661 (48.76 seconds)
# Cbc0010I After 6600 nodes, 17 on tree, -2915.8654 best solution, best possible -3586.661 (49.51 seconds)
# Cbc0010I After 6700 nodes, 16 on tree, -2915.8654 best solution, best possible -3586.661 (50.11 seconds)
# Cbc0010I After 6800 nodes, 13 on tree, -2915.8654 best solution, best possible -3586.661 (50.78 seconds)
# Cbc0010I After 6900 nodes, 20 on tree, -2915.8654 best solution, best possible -3586.661 (51.36 seconds)
# Cbc0010I After 7000 nodes, 16 on tree, -2915.8654 best solution, best possible -3586.661 (51.97 seconds)
# Cbc0010I After 7100 nodes, 16 on tree, -2915.8654 best solution, best possible -3586.661 (52.82 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 428 rows 209 columns
# Cbc0010I After 7200 nodes, 22 on tree, -2915.8654 best solution, best possible -3586.661 (53.47 seconds)
# Cbc0010I After 7300 nodes, 21 on tree, -2915.8654 best solution, best possible -3586.661 (54.04 seconds)
# Cbc0010I After 7400 nodes, 20 on tree, -2915.8654 best solution, best possible -3586.661 (54.54 seconds)
# Cbc0010I After 7500 nodes, 18 on tree, -2915.8654 best solution, best possible -3586.661 (55.25 seconds)
# Cbc0010I After 7600 nodes, 15 on tree, -2915.8654 best solution, best possible -3586.661 (55.82 seconds)
# Cbc0010I After 7700 nodes, 22 on tree, -2915.8654 best solution, best possible -3586.661 (56.37 seconds)
# Cbc0038I Full problem 1539 rows 1029 columns, reduced to 451 rows 226 columns
# Cbc0010I After 7800 nodes, 18 on tree, -2915.8654 best solution, best possible -3586.661 (57.00 seconds)
# Cbc0010I After 7900 nodes, 20 on tree, -2915.8654 best solution, best possible -3586.661 (57.54 seconds)
# Cbc0010I After 8000 nodes, 21 on tree, -2915.8654 best solution, best possible -3586.661 (58.09 seconds)
# Cbc0010I After 8100 nodes, 14 on tree, -2915.8654 best solution, best possible -3586.661 (58.75 seconds)
# Cbc0010I After 8200 nodes, 10 on tree, -2915.8654 best solution, best possible -3586.661 (59.35 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective -2915.8654 (best possible -3586.661), took 315528 iterations and 8226 nodes (59.61 seconds)
# Cbc0032I Strong branching done 27688 times (292481 iterations), fathomed 1440 nodes and fixed 3815 variables
# Cbc0035I Maximum depth 77, 468 variables fixed on reduced cost
# Cuts at root node changed objective from -3605.92 to -3587.51
# Probing was tried 1907 times and created 166635 cuts of which 0 were active after adding rounds of cuts (1.857 seconds)
# Gomory was tried 1504 times and created 13953 cuts of which 0 were active after adding rounds of cuts (1.250 seconds)
# Knapsack was tried 1504 times and created 776 cuts of which 0 were active after adding rounds of cuts (0.967 seconds)
# Clique was tried 23 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 1504 times and created 7390 cuts of which 0 were active after adding rounds of cuts (0.940 seconds)
# FlowCover was tried 23 times and created 52 cuts of which 0 were active after adding rounds of cuts (0.025 seconds)
# TwoMirCuts was tried 1504 times and created 4552 cuts of which 0 were active after adding rounds of cuts (0.666 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# ImplicationCuts was tried 99 times and created 188 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                2915.86544000
# Upper bound:                    3586.661
# Gap:                            -0.19
# Enumerated nodes:               8226
# Total iterations:               315528
# Time (CPU seconds):             57.44
# Time (Wallclock seconds):       59.65
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       57.45   (Wallclock seconds):       59.66
#
# Status: Optimal
# Total Profit: 2915.8654399999987
# Product    day        SubProduction Production   Sales      Storage
# Chleb_domowy_0_5kg Pon        240.0        239.0        239.0      1.0
# Chleb_domowy_0_5kg Wt         240.0        1.0          1.0        240.0
# Chleb_domowy_0_5kg Sr         1.0          240.0        240.0      0.0
# Chleb_domowy_0_9kg Pon        0.0          0.0          0.0        0.0
# Chleb_domowy_0_9kg Wt         130.0        0.0          0.0        130.0
# Chleb_domowy_0_9kg Sr         0.0          130.0        130.0      0.0
# Chleb_na_zakwasie Pon        200.0        189.0        189.0      11.0
# Chleb_na_zakwasie Wt         0.0          1.0          1.0        10.0
# Chleb_na_zakwasie Sr         1.0          10.0         10.0       0.0
# Bulki      Pon        200.0        199.0        199.0      1.0
# Bulki      Wt         200.0        1.0          1.0        200.0
# Bulki      Sr         1.0          200.0        200.0      0.0
# Bagietki   Pon        200.0        199.0        199.0      1.0
# Bagietki   Wt         200.0        1.0          1.0        200.0
# Bagietki   Sr         1.0          200.0        200.0      0.0
# Rogaliki_z_czekolada Pon        200.0        199.0        199.0      1.0
# Rogaliki_z_czekolada Wt         200.0        1.0          1.0        200.0
# Rogaliki_z_czekolada Sr         1.0          200.0        200.0      0.0

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_colwidth', None)  # Ustaw brak limitu szerokości kolumny


# Po rozwiązaniu problemu upewnijmy się, że rozwiązanie jest optymalne
if pl.LpStatus[model.status] != 'Optimal':
    print("Model did not solve to optimality.")
    exit()

# Pobierz wartości czasu rozpoczęcia
start_times = {
    (subproduct, machine, day): subproduct_batch_start_time[subproduct, machine, day].varValue
    for subproduct in subproducts for machine in sub_machines for day in days
    if subproduct_batch_start_time[subproduct, machine, day].varValue is not None and is_produced_sub[subproduct, machine, day].varValue != 0 
}

# Oblicz czas zakończenia
end_times = {
    (subproduct, machine, day): start_times[subproduct, machine, day] + sub_production_times[subproduct][machine]
    for subproduct, machine, day in start_times
}

# Wersja 1: Widok z perspektywy subproduktu
subproduct_schedule = []
for subproduct in subproducts:
    for day in days:
        for machine in sub_machines:
            if (subproduct, machine, day) in start_times:
                start = start_times[(subproduct, machine, day)]
                end = end_times[(subproduct, machine, day)]
                subproduct_schedule.append({
                    'Subproduct': subproduct,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

subproduct_df = pd.DataFrame(subproduct_schedule)
print("\nSubproduct Schedule:\n")
print(subproduct_df.sort_values(['Day', 'Subproduct', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania subproduktów na litery
subproduct_mapping = {subproduct: chr(65 + i) for i, subproduct in enumerate(subproducts)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for subproduct in subproducts:
        if (subproduct, machine, day) in start_times:
            start = start_times[(subproduct, machine, day)]
            end = end_times[(subproduct, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = subproduct_mapping[subproduct]  # Wstaw literę dla subproduktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_subproduct = timeline[i]
                    prev_duration = (
                        end_times[(subproducts[ord(prev_subproduct) - 65], machine, day)] -
                        start_times[(subproducts[ord(prev_subproduct) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = subproduct_mapping[subproduct]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in sub_machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
subproduct_df.to_csv("subproduct_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Subproduktów:")
for subproduct, letter in subproduct_mapping.items():
    print(f"{letter}: {subproduct}")

print(subproduct_batch_start_time['Ciasto_na_chleb_domowy_0_5kg', 'Dzieza', 'Pon'].varValue)
print(subproduct_batch_start_time['Ciasto_na_chleb_domowy_0_5kg', 'Dzieza', 'Pon'].varValue + sub_production_times['Ciasto_na_chleb_domowy_0_5kg']['Dzieza'])
print(subproduct_batch_start_time['Ciasto_na_bulki', 'Dzieza', 'Pon'].varValue)

print(is_produced_sub['Ciasto_na_chleb_domowy_0_5kg', 'Dzieza', 'Pon'].varValue)
print(is_produced_sub['Ciasto_na_bulki', 'Dzieza', 'Pon'].varValue)
print(subproduct_batch_start_time['Ciasto_na_chleb_domowy_0_5kg', sub_machines[-1], 'Pon'].varValue)
# Out:
# Subproduct Schedule:
#
#                         Subproduct  Day      Machine  Start Time  End Time
# 27              Ciasto_na_bagietki  Pon       Dzieza       14.93     15.88
# 28              Ciasto_na_bagietki  Pon    Dzielarka       15.88     16.12
# 29              Ciasto_na_bagietki  Pon  Rogalikarka       16.12     16.40
# 18                 Ciasto_na_bulki  Pon       Dzieza       13.93     14.93
# 19                 Ciasto_na_bulki  Pon    Dzielarka       15.65     15.88
# 20                 Ciasto_na_bulki  Pon       Tabula       18.55     18.89
# 0     Ciasto_na_chleb_domowy_0_5kg  Pon       Dzieza        9.23     13.93
# 1     Ciasto_na_chleb_domowy_0_5kg  Pon      Wazenie       14.41     14.70
# 2     Ciasto_na_chleb_domowy_0_5kg  Pon       Tabula       14.70     15.40
# 12     Ciasto_na_chleb_na_zakwasie  Pon       Dzieza        0.00      8.60
# 13     Ciasto_na_chleb_na_zakwasie  Pon      Wazenie       11.70     11.92
# 14     Ciasto_na_chleb_na_zakwasie  Pon       Tabula       11.92     12.52
# 36  Ciasto_na_rogaliki_z_czekolada  Pon       Dzieza        8.60      9.15
# 37  Ciasto_na_rogaliki_z_czekolada  Pon    Dzielarka       11.28     11.56
# 38  Ciasto_na_rogaliki_z_czekolada  Pon  Rogalikarka       11.56     11.87
# 39  Ciasto_na_rogaliki_z_czekolada  Pon  Nadziewarka       11.87     12.27
# 33              Ciasto_na_bagietki   Sr       Dzieza       18.53     19.48
# 34              Ciasto_na_bagietki   Sr    Dzielarka       19.48     19.72
# 35              Ciasto_na_bagietki   Sr  Rogalikarka       19.72     20.00
# 24                 Ciasto_na_bulki   Sr       Dzieza       17.13     18.13
# 25                 Ciasto_na_bulki   Sr    Dzielarka       18.13     18.36
# 26                 Ciasto_na_bulki   Sr       Tabula       18.36     18.70
# 6     Ciasto_na_chleb_domowy_0_5kg   Sr       Dzieza        0.00      4.70
# 7     Ciasto_na_chleb_domowy_0_5kg   Sr      Wazenie       18.19     18.48
# 8     Ciasto_na_chleb_domowy_0_5kg   Sr       Tabula       19.30     20.00
# 15     Ciasto_na_chleb_na_zakwasie   Sr       Dzieza        8.53     17.13
# 16     Ciasto_na_chleb_na_zakwasie   Sr      Wazenie       18.48     18.70
# 17     Ciasto_na_chleb_na_zakwasie   Sr       Tabula       18.70     19.30
# 44  Ciasto_na_rogaliki_z_czekolada   Sr       Dzieza        4.70      5.25
# 45  Ciasto_na_rogaliki_z_czekolada   Sr    Dzielarka       19.01     19.29
# 46  Ciasto_na_rogaliki_z_czekolada   Sr  Rogalikarka       19.29     19.60
# 47  Ciasto_na_rogaliki_z_czekolada   Sr  Nadziewarka       19.60     20.00
# 30              Ciasto_na_bagietki   Wt       Dzieza       17.07     18.02
# 31              Ciasto_na_bagietki   Wt    Dzielarka       18.02     18.26
# 32              Ciasto_na_bagietki   Wt  Rogalikarka       18.26     18.54
# 21                 Ciasto_na_bulki   Wt       Dzieza        0.00      1.00
# 22                 Ciasto_na_bulki   Wt    Dzielarka       14.33     14.56
# 23                 Ciasto_na_bulki   Wt       Tabula       14.83     15.17
# 3     Ciasto_na_chleb_domowy_0_5kg   Wt       Dzieza        1.00      5.70
# 4     Ciasto_na_chleb_domowy_0_5kg   Wt      Wazenie       11.16     11.45
# 5     Ciasto_na_chleb_domowy_0_5kg   Wt       Tabula       11.45     12.15
# 9     Ciasto_na_chleb_domowy_0_9kg   Wt       Dzieza        5.70     10.70
# 10    Ciasto_na_chleb_domowy_0_9kg   Wt      Wazenie       10.70     10.90
# 11    Ciasto_na_chleb_domowy_0_9kg   Wt       Tabula       10.90     11.45
# 40  Ciasto_na_rogaliki_z_czekolada   Wt       Dzieza       14.01     14.56
# 41  Ciasto_na_rogaliki_z_czekolada   Wt    Dzielarka       14.56     14.84
# 42  Ciasto_na_rogaliki_z_czekolada   Wt  Rogalikarka       14.84     15.15
# 43  Ciasto_na_rogaliki_z_czekolada   Wt  Nadziewarka       15.15     15.55
#
# Machine Usage Timeline:
#
#         Machine  Day  \
# 0        Dzieza  Pon
# 1       Wazenie  Pon
# 2     Dzielarka  Pon
# 3        Tabula  Pon
# 4   Rogalikarka  Pon
# 5   Nadziewarka  Pon
# 6        Dzieza   Wt
# 7       Wazenie   Wt
# 8     Dzielarka   Wt
# 9        Tabula   Wt
# 10  Rogalikarka   Wt
# 11  Nadziewarka   Wt
# 12       Dzieza   Sr
# 13      Wazenie   Sr
# 14    Dzielarka   Sr
# 15       Tabula   Sr
# 16  Rogalikarka   Sr
# 17  Nadziewarka   Sr
#
#                                                                                                 Timeline
# 0   CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCFFF_AAAAAAAAAAAAAAAAAAAAAAADDDDDEEEEE_____________________
# 1   __________________________________________________________C_____________A___________________________
# 2   ________________________________________________________F_____________________DE____________________
# 3   ___________________________________________________________CCC___________AAA________________DD______
# 4   _________________________________________________________FF_____________________EE__________________
# 5   ___________________________________________________________FF_______________________________________
# 6   DDDDDAAAAAAAAAAAAAAAAAAAAAAABBBBBBBBBBBBBBBBBBBBBBBBB_________________FF_____________EEEEE__________
# 7   _____________________________________________________B_AA___________________________________________
# 8   _______________________________________________________________________DFF________________E_________
# 9   ______________________________________________________BBBAAA______________D_________________________
# 10  __________________________________________________________________________F________________E________
# 11  ___________________________________________________________________________FF_______________________
# 12  AAAAAAAAAAAAAAAAAAAAAAAFFF________________CCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCCDDDDD__EEEEE___
# 13  __________________________________________________________________________________________AAC_______
# 14  __________________________________________________________________________________________D____F_E__
# 15  ___________________________________________________________________________________________DDCCCAAAA
# 16  ________________________________________________________________________________________________F_EE
# 17  __________________________________________________________________________________________________FF
#
# Legenda Subproduktów:
# A: Ciasto_na_chleb_domowy_0_5kg
# B: Ciasto_na_chleb_domowy_0_9kg
# C: Ciasto_na_chleb_na_zakwasie
# D: Ciasto_na_bulki
# E: Ciasto_na_bagietki
# F: Ciasto_na_rogaliki_z_czekolada
# 9.23
# 13.93
# 13.93
# 1.0
# 1.0
# 15.4

# %%
# Pobierz wartości czasu rozpoczęcia
start_times = {
    (product, machine, day): product_batch_start_time[product, machine, day].varValue
    for product in products for machine in machines for day in days
    if product_batch_start_time[product, machine, day].varValue is not None and is_produced[product, machine, day].varValue != 0 
}

# Oblicz czas zakończenia
end_times = {
    (product, machine, day): start_times[product, machine, day] + production_times[product][machine]
    for product, machine, day in start_times
}

# Wersja 1: Widok z perspektywy produktu
product_schedule = []
for product in products:
    for day in days:
        for machine in machines:
            if (product, machine, day) in start_times:
                start = start_times[(product, machine, day)]
                end = end_times[(product, machine, day)]
                product_schedule.append({
                    'Product': product,
                    'Day': day,
                    'Machine': machine,
                    'Start Time': start,
                    'End Time': end
                })

product_df = pd.DataFrame(product_schedule)
print("\nProduct Schedule:\n")
print(product_df.sort_values(['Day', 'Product', 'Start Time']))

# Wersja 2: Oś czasu dla każdej maszyny
# Tworzenie mapowania produktów na litery
product_mapping = {product: chr(65 + i) for i, product in enumerate(products)}

# Długość jednego znaku odpowiadająca 15 minutom
time_slot_length = 0.2  # 15 minut w godzinach
slots_per_day = int(hours_per_day / time_slot_length)  # Liczba slotów w ciągu dnia

def visualize_timeline(machine, day):
    timeline = [None for _ in range(slots_per_day)]
    for product in products:
        if (product, machine, day) in start_times:
            start = start_times[(product, machine, day)]
            end = end_times[(product, machine, day)]
            start_slot = int(start / time_slot_length)
            end_slot = int(end / time_slot_length)
            for i in range(start_slot, end_slot):
                if timeline[i] is None:
                    timeline[i] = product_mapping[product]  # Wstaw literę dla produktu
                else:
                    # Rozstrzyganie konfliktów (krótsze zadanie)
                    prev_product = timeline[i]
                    prev_duration = (
                        end_times[(products[ord(prev_product) - 65], machine, day)] -
                        start_times[(products[ord(prev_product) - 65], machine, day)]
                    )
                    curr_duration = end - start
                    if curr_duration < prev_duration:
                        timeline[i] = product_mapping[product]

    # Zamień None na "_" i pozostałe na stringi
    return "".join(char if char is not None else "_" for char in timeline)

machine_timeline = []

for day in days:
    for machine in machines:
        timeline = visualize_timeline(machine, day)
        machine_timeline.append({
            'Machine': machine,
            'Day': day,
            'Timeline': timeline
        })

machine_timeline_df = pd.DataFrame(machine_timeline)
print("\nMachine Usage Timeline:\n")
print(machine_timeline_df)

# Opcjonalnie: zapis wyników do pliku CSV
product_df.to_csv("product_schedule.csv", index=False)
machine_timeline_df.to_csv("machine_timeline.csv", index=False)
# Wyświetlenie legendy
print("\nLegenda Produktów:")
for product, letter in product_mapping.items():
    print(f"{letter}: {product}")

print(is_produced['Chleb_domowy_0_5kg', 'Garownia', 'Pon'].varValue)
print(all_from_storage['Ciasto_na_chleb_domowy_0_5kg', 'Pon'])
# Out:
# Product Schedule:
#
#                  Product  Day    Machine  Start Time  End Time
# 37              Bagietki  Pon   Garownia       14.89     15.22
# 38              Bagietki  Pon       Piec       15.99     16.22
# 39              Bagietki  Pon  Studzenie       16.48     16.90
# 28                 Bulki  Pon   Garownia       17.89     18.27
# 29                 Bulki  Pon       Piec       18.27     18.52
# 30                 Bulki  Pon  Studzenie       19.52     20.00
# 0     Chleb_domowy_0_5kg  Pon   Garownia       15.22     16.22
# 1     Chleb_domowy_0_5kg  Pon       Piec       16.22     16.90
# 2     Chleb_domowy_0_5kg  Pon  Studzenie       16.90     18.70
# 3     Chleb_domowy_0_5kg  Pon  Pakowanie       19.02     19.58
# 16     Chleb_na_zakwasie  Pon   Garownia       11.78     13.18
# 17     Chleb_na_zakwasie  Pon       Piec       13.18     14.18
# 18     Chleb_na_zakwasie  Pon  Studzenie       14.18     16.48
# 19     Chleb_na_zakwasie  Pon  Pakowanie       18.42     19.02
# 46  Rogaliki_z_czekolada  Pon   Garownia       18.27     18.52
# 47  Rogaliki_z_czekolada  Pon       Piec       18.52     18.70
# 48  Rogaliki_z_czekolada  Pon  Studzenie       18.70     19.52
# 49  Rogaliki_z_czekolada  Pon  Pakowanie       19.58     20.00
# 43              Bagietki   Sr   Garownia        2.50      2.83
# 44              Bagietki   Sr       Piec       11.36     11.59
# 45              Bagietki   Sr  Studzenie       11.59     12.01
# 34                 Bulki   Sr   Garownia       18.89     19.27
# 35                 Bulki   Sr       Piec       19.27     19.52
# 36                 Bulki   Sr  Studzenie       19.52     20.00
# 8     Chleb_domowy_0_5kg   Sr   Garownia        1.50      2.50
# 9     Chleb_domowy_0_5kg   Sr       Piec       10.68     11.36
# 10    Chleb_domowy_0_5kg   Sr  Studzenie       12.01     13.81
# 11    Chleb_domowy_0_5kg   Sr  Pakowanie       18.27     18.83
# 12    Chleb_domowy_0_9kg   Sr   Garownia        0.00      1.50
# 13    Chleb_domowy_0_9kg   Sr       Piec       15.73     16.93
# 14    Chleb_domowy_0_9kg   Sr  Studzenie       16.93     19.43
# 15    Chleb_domowy_0_9kg   Sr  Pakowanie       19.43     20.00
# 24     Chleb_na_zakwasie   Sr   Garownia       12.23     13.63
# 25     Chleb_na_zakwasie   Sr       Piec       13.63     14.63
# 26     Chleb_na_zakwasie   Sr  Studzenie       14.63     16.93
# 27     Chleb_na_zakwasie   Sr  Pakowanie       18.83     19.43
# 54  Rogaliki_z_czekolada   Sr   Garownia        2.83      3.08
# 55  Rogaliki_z_czekolada   Sr       Piec       10.50     10.68
# 56  Rogaliki_z_czekolada   Sr  Studzenie       13.81     14.63
# 57  Rogaliki_z_czekolada   Sr  Pakowanie       17.85     18.27
# 40              Bagietki   Wt   Garownia       12.05     12.38
# 41              Bagietki   Wt       Piec       14.87     15.10
# 42              Bagietki   Wt  Studzenie       15.86     16.28
# 31                 Bulki   Wt   Garownia       18.89     19.27
# 32                 Bulki   Wt       Piec       19.27     19.52
# 33                 Bulki   Wt  Studzenie       19.52     20.00
# 4     Chleb_domowy_0_5kg   Wt   Garownia       12.38     13.38
# 5     Chleb_domowy_0_5kg   Wt       Piec       13.38     14.06
# 6     Chleb_domowy_0_5kg   Wt  Studzenie       14.06     15.86
# 7     Chleb_domowy_0_5kg   Wt  Pakowanie       18.42     18.98
# 20     Chleb_na_zakwasie   Wt   Garownia       13.70     15.10
# 21     Chleb_na_zakwasie   Wt       Piec       15.10     16.10
# 22     Chleb_na_zakwasie   Wt  Studzenie       17.10     19.40
# 23     Chleb_na_zakwasie   Wt  Pakowanie       19.40     20.00
# 50  Rogaliki_z_czekolada   Wt   Garownia       15.85     16.10
# 51  Rogaliki_z_czekolada   Wt       Piec       16.10     16.28
# 52  Rogaliki_z_czekolada   Wt  Studzenie       16.28     17.10
# 53  Rogaliki_z_czekolada   Wt  Pakowanie       18.98     19.40
#
# Machine Usage Timeline:
#
#       Machine  Day  \
# 0    Garownia  Pon
# 1        Piec  Pon
# 2   Studzenie  Pon
# 3   Pakowanie  Pon
# 4    Garownia   Wt
# 5        Piec   Wt
# 6   Studzenie   Wt
# 7   Pakowanie   Wt
# 8    Garownia   Sr
# 9        Piec   Sr
# 10  Studzenie   Sr
# 11  Pakowanie   Sr
#
#                                                                                                 Timeline
# 0   __________________________________________________________CCCCCCC_________EEAAAAA________DDF________
# 1   _________________________________________________________________CCCCC_________EEAAA_______DF_______
# 2   ______________________________________________________________________CCCCCCCCCCCCEEAAAAAAAAAFFFFDDD
# 3   ____________________________________________________________________________________________CCCAAFFF
# 4   ____________________________________________________________EAAAAA__CCCCCCC____F______________DD____
# 5   __________________________________________________________________AAAA____ECCCCCF_______________D___
# 6   ______________________________________________________________________AAAAAAAAAEEFFFFCCCCCCCCCCCCDDD
# 7   ____________________________________________________________________________________________AAFFFCCC
# 8   BBBBBBBAAAAAEEF______________________________________________CCCCCCC__________________________DD____
# 9   ____________________________________________________FAAAE___________CCCCC_____BBBBBB____________D___
# 10  _________________________________________________________EEEAAAAAAAAAFFFFCCCCCCCCCCCBBBBBBBBBBBBBDDD
# 11  _________________________________________________________________________________________FFAAACCCBBB
#
# Legenda Produktów:
# A: Chleb_domowy_0_5kg
# B: Chleb_domowy_0_9kg
# C: Chleb_na_zakwasie
# D: Bulki
# E: Bagietki
# F: Rogaliki_z_czekolada
# 1.0
# 0
